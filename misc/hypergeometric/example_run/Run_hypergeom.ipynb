# %% [markdown]
# #  `stepwise_hypergeom` module

# %%
import sys
sys.path.insert(0,'..')
from stepwise_hypergeom_2 import StepwiseHypergeom


# == Input arguments ==
successes_top_perc = 0.16 
full_ranking_top_perc = 0.05

# == Example - Input files ==
# - Full ranking file
#full_ranking_file = 'full_ranking_file.csv'     
#full_ranking_file = 'targetDB.csv'
#full_ranking_files = 'drugnomeAI_GB.csv'
full_ranking_files = ['targetDB.csv','drugnomeAI_Tier1.csv','drugnomeAI_tclin.csv'] #make drugnomeAI second (for calculating random predictions)

# - External successes files
external_results_dir = 'external_successes_files'
#external_successes_files = ['genes_ot_ab.txt', 'genes_ot_sm.txt', 'kings_approved_targets.txt']
#external_successes_files = ['genes_ot_ab.txt']
#external_successes_files = ['kings_approved_targets.txt']
#external_successes_files = [external_results_dir + '/' + f for f in external_successes_files]
#external_successes_file = external_results_dir + '/' + 'kings_approved_targets.txt'

# %% [markdown]
# ## Main run

# %%
print('\n\nkings data')
external_successes_file = external_results_dir + '/' + 'kings_approved_targets.txt'

hypergeom_obj = StepwiseHypergeom(full_ranking_files, external_successes_file, 2201,
                                          '', 'Kings',
                                          full_ranking_top_perc=full_ranking_top_perc, 
                                          successes_top_perc=successes_top_perc)
hypergeom_obj.main()

print('\n\nOpen Targets - Small Molecules - Bucket 1')
external_successes_file = external_results_dir + '/' + 'genes_ot_sm.txt'
hypergeom_obj = StepwiseHypergeom(full_ranking_files, external_successes_file, 612,
                                          'Bucket 1', 'Small Molecule',
                                          full_ranking_top_perc=full_ranking_top_perc, 
                                          successes_top_perc=successes_top_perc)
hypergeom_obj.main()

print('\n\nOpen Targets - Small Molecules - Bucket 1-3')
hypergeom_obj = StepwiseHypergeom(full_ranking_files, external_successes_file, 895,
                                          'Buckets 1-3', 'Small Molecule',
                                          full_ranking_top_perc=full_ranking_top_perc, 
                                          successes_top_perc=successes_top_perc)
hypergeom_obj.main()

print('\n\nOpen Targets - Small Molecules - all bucket')
hypergeom_obj = StepwiseHypergeom(full_ranking_files, external_successes_file, 5034,
                                          'Buckets 1-8', 'Small Molecule',
                                          full_ranking_top_perc=full_ranking_top_perc, 
                                          successes_top_perc=successes_top_perc)
hypergeom_obj.main()

print('\n\nOpen Targets - Antibody - Bucket 1')
external_successes_file = external_results_dir + '/' + 'genes_ot_ab.txt'
hypergeom_obj = StepwiseHypergeom(full_ranking_files, external_successes_file, 63,
                                          'Bucket 1', 'Antibody',
                                          full_ranking_top_perc=full_ranking_top_perc, 
                                          successes_top_perc=successes_top_perc)
hypergeom_obj.main()

print('\n\nOpen Targets - Antibody - Bucket 1-3')
hypergeom_obj = StepwiseHypergeom(full_ranking_files, external_successes_file, 331,
                                          'Buckets 1-3', 'Antibody',
                                          full_ranking_top_perc=full_ranking_top_perc, 
                                          successes_top_perc=successes_top_perc)
hypergeom_obj.main()

print('\n\nOpen Targets - Antibody - all bucket')
hypergeom_obj = StepwiseHypergeom(full_ranking_files, external_successes_file, 9988,
                                          'Buckets 1-8', 'Antibody',
                                          full_ranking_top_perc=full_ranking_top_perc, 
                                          successes_top_perc=successes_top_perc)
hypergeom_obj.main()
# Out:
# kings data
# hello
#
#
#
# >  targetDB.csv: (19421, 2)
# - Total number of Successes: 2201
# - Restrict full ranking to top % results: 5% (992)
# - Population Size: 992
#
# Total number of Successes in Full ranking (overlap): 178
#
# Max phred: 138.9327971263023
# Avg phred: 84.13710988344185
#
#
#
# >  drugnomeAI_Tier1.csv: (19846, 2)
# - Total number of Successes: 2201
# - Restrict full ranking to top % results: 5% (992)
# - Population Size: 992
#
# Total number of Successes in Full ranking (overlap): 304
#
# Max phred: 122.80485006596152
# Avg phred: 49.30728844924872
#
#
#
# >  drugnomeAI_tclin.csv: (19846, 2)
# - Total number of Successes: 2201
# - Restrict full ranking to top % results: 5% (992)
# - Population Size: 992
#
# Total number of Successes in Full ranking (overlap): 331
#
# Max phred: 257.4396318150824
# Avg phred: 118.29084423080779
#
#
#
# > Random: (19846, 2)
# - Total number of Successes: 2201
# - Restrict full ranking to top % results: 5% (992)
# ...
