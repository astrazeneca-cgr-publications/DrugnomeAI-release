# %%
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt

import os
import pandas as pd
import numpy as np
from scipy.stats import hypergeom
import random
import sys
import glob


def calc_phred_score(pval):

    if pval == 0:
        return 500
    else:
        return -10 * np.log10(pval)



def read_full_ranking(full_ranking_file):
    
    full_ranked_df = pd.read_csv(full_ranking_file)
#     full_ranked_df = full_ranked_df.loc[0:top_genes, :]
    print(full_ranked_df.shape)
    print("full_ranked_df: ", full_ranked_df.head())
    full_ranked_df = full_ranked_df[full_ranked_df.known_gene==1]
    print("\n external_top ranking:", full_ranked_df.head())
    print(full_ranked_df.shape)
    full_ranked_df.sort_values("mantis_ml_proba", ascending=False, inplace=True)
    r = list(range(1, full_ranked_df.shape[0]+1))
    full_ranked_df['full_rank'] = r
    cols = ['Gene_Name'] + ["mantis_ml_proba"] + ['full_rank']
    full_ranked_df = full_ranked_df[cols]
    print('full ranking with rank', full_ranked_df.head())
    return full_ranked_df


def read_external_ranking(disease, top_genes_ratio = 0.05):
    
    synonyms = pd.read_csv('synonyms.csv', index_col=0)
    disease_synonyms = synonyms.synonym[synonyms.disease==disease].tolist()
    external_top_ranking = pd.read_csv('predictions_synonyms.csv', index_col=0)
    # external_top top predictions
    
    external_top_ranking = external_top_ranking.reset_index()
    external_top_ranking = external_top_ranking.rename(columns = {'index':'Gene_Name'})

    external_rankings = []
    for synonym in disease_synonyms:
        external_top_ranking.sort_values(synonym, ascending=False, inplace=True)
        cols = ['Gene_Name'] + [synonym]
        synonym_ranking = external_top_ranking[cols]
        cutoff = int(synonym_ranking.shape[0] * top_genes_ratio)
        synonym_ranking = synonym_ranking.loc[0:cutoff, :]
        synonym_ranking = synonym_ranking['Gene_Name']
        print(synonym_ranking.shape)
        print("external_top_ranking: ", synonym_ranking.head())
        external_rankings.append(synonym_ranking.tolist())
    return external_rankings

# %%
def calc_hypergeom_pvals(external_top_ranking, full_rank_file, top_full_ranking=0.1):

    
    full_ranked_df = read_full_ranking(full_rank_file)
    M = full_ranked_df.shape[0]
    print('\n Population Size:', M)
    print('\n Full ranking:\n', full_ranked_df.head())

    full_rank_cutoff = int(full_ranked_df.shape[0] * top_full_ranking) # 1050 genes (21015 in total)
    print('full_rank_cutoff:', full_rank_cutoff)
    print('full columns', full_ranked_df.columns)
    
#     external_top_genes = read_external_ranking(external_top_ranking)

    full_ranked_df = full_ranked_df.loc[full_ranked_df.Gene_Name.isin(external_top_ranking)]
    full_ranked_df.reset_index(drop=True, inplace=True)
    print('\n', full_ranked_df.head())
    print('\n', full_ranked_df.tail())
    print(full_ranked_df.shape)
    
    
    n = full_ranked_df.shape[0]
    #print('Total number of Successes:', n)



    # ************* Hypergeometric Test *************
    hypergeom_pvals = []
    hypergeom_ordered_genes = []

    for x in range(full_ranked_df.shape[0]):

        print(full_ranked_df.iloc[x, 0])

        full_rank = full_ranked_df.loc[x, 'full_rank']
        print(full_rank)

        N = full_ranked_df.iloc[x, full_ranked_df.shape[1]-1]
        print(x, N)


        cur_pval = hypergeom.sf(x - 1, M, n, N)
        print('cur_pval: ', cur_pval)

        hypergeom_pvals = hypergeom_pvals + [cur_pval]

        cur_gene = full_ranked_df.loc[x, 'Gene_Name']
        hypergeom_ordered_genes = hypergeom_ordered_genes + [cur_gene]


        if full_rank >= full_rank_cutoff:
            break
    # ***********************************************

    
    min_pval = min(hypergeom_pvals)
    hypergeom_pvals = [calc_phred_score(pval) for pval in hypergeom_pvals]
    print('Max:', min(hypergeom_pvals))
    print('Avg:', np.mean(hypergeom_pvals))

    return hypergeom_pvals, hypergeom_ordered_genes




def plot_hypergeom_stepwise(hypergeom_pvals, ax, label, color='#33a02c', signif_thres = 0.05,\
                            plot_pval_thres=True):

    if plot_pval_thres:
        signif_thres = calc_phred_score(signif_thres)
        ax.axhline(y=signif_thres, linestyle='--', color='red', label='p-val: 0.05')


    linewidth = 1
    ax.plot(hypergeom_pvals, color=color,
                label=label,
                linewidth=linewidth)

    ax.set_xlim(left=-0.5)

    y_label = 'Phred score from hypergeometric test\n(significance increasing in positive direction)'
    ax.set_ylabel(y_label, fontsize=14)

    ax.legend(bbox_to_anchor=(1.32, 1), fontsize=12, loc='upper right', framealpha =0.6)
    #ax.set_xlim(0, max_x_lim * 1.5)
    #ax.set_ylim(0, 500)




def run_hypergeom_test(disease, folder='kidney', top=0.1):

    max_x_lim = 50

    # Provide multiple full ranking files
    external_top_files = read_external_ranking(disease, top_genes_ratio = top)
    full_ranking_labels_folders = {'chem': glob.glob(folder + "/chem"),
                                 'clin': glob.glob(folder + "/clin"),
                                  'bio': glob.glob(folder + "/bio")}
    
    
    synonyms = pd.read_csv('synonyms.csv', index_col=0)
    disease_synonyms = synonyms.synonym[synonyms.disease==disease].tolist()
    
    for level in full_ranking_labels_folders.keys():
        
        full_ranking_files = glob.glob(folder + '/' + level + '/*.csv')
        print(full_ranking_files)

        for full_ranking_file in full_ranking_files:

            hypergeom_results = {}
            hypergeom_ordered_genes = {}


            for i, external_file in enumerate(external_top_files):
#                 print("external file: ", external_file)
                full_ranking_name = full_ranking_file
                print(full_ranking_name)
                external_file_name = disease_synonyms[i]

                import ntpath
                def rename_file(file_path):
                    _, file = ntpath.split(file_path)
                    file = file.split('/')[-1]
                    file = file.replace('.mantis-ml_predictions.csv', '')
                    if 'All' not in file:
                        file = file.replace('Classifier', '')
                    return file

                full_rank = rename_file(full_ranking_file)
#                     external_file = rename_file(external_file)
                name = full_rank + "_vs_" + external_file_name
                
                hypergeom_results[name], hypergeom_ordered_genes[name] = calc_hypergeom_pvals(external_file,\
                                                                        full_ranking_name, top)
                print(hypergeom_results[name])


        # random gene ranking
        #random_external_top_ranking = full_ranked_df.sample(frac=1)
        #random_external_top_ranking.drop('full_rank', axis=1, inplace=True)
        #random_hypergeom_pvals = calc_hypergeom_pvals(random_external_top_ranking, full_ranked_df)


        # ------------------------- Start plotting ----------------------------
            fig, ax = plt.subplots(figsize=(18, 13))

            colors = ['#2171b5', '#9ecae1', '#238b45', '#a1d99b', '#cb181d', '#fc9272',
                      '#6a51a3', '#bcbddc', '#fe9929', '#fff7bc']
            cnt = 0

            for external_top_dataset, hypergeom_pvals in hypergeom_results.items():
                print("external_top_dataset: ", external_top_dataset)

                plot_hypergeom_stepwise(hypergeom_pvals, ax, label=external_top_dataset, color=colors[cnt],\
                                        plot_pval_thres=False)
                cnt += 1

            #plot_hypergeom_stepwise(random_hypergeom_pvals, ax, label='random', color='black')

            signif_thres = 0.05
            signif_thres = calc_phred_score(signif_thres)
            ax.axhline(y=signif_thres, linestyle='--', color='red', label='p-val: 0.05')

            fig.savefig(os.path.join(folder, level, full_rank + ".pdf") , bbox_inches='tight')
            plt.close()


    #         print(hypergeom_ordered_genes)
            intersection_genes_fh = os.path.join(folder, level, full_rank + '-hits.intersection.txt')
            print(intersection_genes_fh)
            out_fh =  open(intersection_genes_fh, 'w')
            for clf, genes in hypergeom_ordered_genes.items():
                out_fh.write(clf + '\t' + ','.join(genes) + '\n')

            out_fh.close()

# %%
run_hypergeom_test(disease='Chronic obstructive pulmonary disease', folder='pulmonary_drugnomefull', top=0.15)
# run_hypergeom_test(label='pharos', folder='all-pharos')
# Out:
# (11095,)
# external_top_ranking:  0        PDGFRA
# 7453     CEP104
# 9899     EPSTI1
# 7802       MICA
# 8259    SLC22A5
# Name: Gene_Name, dtype: object
# (9492,)
# external_top_ranking:  0       PDGFRA
# 552       NOS3
# 336       IRS1
# 4389    ATP2B4
# 3147       TNC
# Name: Gene_Name, dtype: object
# (3992,)
# external_top_ranking:  0      PDGFRA
# 935     MEIS1
# 24       JAG1
# 57      ITGA3
# 8      PTPN11
# Name: Gene_Name, dtype: object
# (7749,)
# external_top_ranking:  0       PDGFRA
# 2164     KCNJ2
# 2702      RBM6
# 455       TPP1
# 24        JAG1
# Name: Gene_Name, dtype: object
# (3094,)
# external_top_ranking:  0      PDGFRA
# 86      FGFR1
# 144     UBE4B
# 702      TCF4
# 24       JAG1
# Name: Gene_Name, dtype: object
# (1972,)
# external_top_ranking:  0         PDGFRA
# 676         EPRS
# 453         FLNA
# 141        LRRK2
# 11344    RAPGEF3
# Name: Gene_Name, dtype: object
# (6430,)
# external_top_ranking:  0          PDGFRA
# 4123     TRAPPC11
# 18251      OR51B4
# 14416      CARD18
# 14299        SYBU
# Name: Gene_Name, dtype: object
# (7153,)
# external_top_ranking:  0        PDGFRA
# 401       ITGA5
# 704      NOTCH2
# 232       STAT3
# 256    SERPINH1
# Name: Gene_Name, dtype: object
# (5839,)
# external_top_ranking:  0       PDGFRA
# 1626     PDS5B
# 68       ZMIZ1
# 468      MED12
# 1612    ARID5B
# Name: Gene_Name, dtype: object
# (2516,)
# external_top_ranking:  0      PDGFRA
# 182    ACVR1B
# 86      FGFR1
# 61      SMAD7
# 123     FOXP4
# Name: Gene_Name, dtype: object
# ['pulmonary_drugnomefull/chem\\ExtraTreesClassifier.mantis-ml_predictions.csv', 'pulmonary_drugnomefull/chem\\GradientBoostingClassifier.mantis-ml_predictions.csv', 'pulmonary_drugnomefull/chem\\RandomForestClassifier.mantis-ml_predictions.csv', 'pulmonary_drugnomefull/chem\\SVC.mantis-ml_predictions.csv']
# pulmonary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.947806      100.000000         0.0
# 1     PTGS2         0.940789       99.994961         0.0
# 2    CYP2E1         0.938613       99.989922         0.0
# 3     CXCL8         0.936313       99.984884         0.0
# 4      BCL2         0.929689       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5     CYP1A2         0.924153       99.974806         1.0
# 7      HMOX1         0.919414       99.964728         1.0
# 10      MMP9         0.915654       99.949612         1.0
# 12    CYP1A1         0.913555       99.939534         1.0
# 19      MMP2         0.900070       99.904263         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0    CYP1A2         0.924153          1
# 1     HMOX1         0.919414          2
# 2      MMP2         0.900070          5
# 3      NOS3         0.891249          6
# 4      NQO1         0.887961          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 75      FHIT         0.291388        100
# 76   MAP3K13         0.281413        101
# 77     NUCB1         0.275426        102
# 78     HIPK3         0.228438        105
# 79     MPEG1         0.163024        108
# (80, 3)
# CYP1A2
# 1
# 0 1
# cur_pval:  1.0
# HMOX1
# 2
# 1 2
# cur_pval:  0.9310227658851513
# MMP2
# 5
# 2 5
# cur_pval:  0.9827196364140334
# NOS3
# 6
# 3 6
# cur_pval:  0.9580110622368099
# NQO1
# 7
# 4 7
# cur_pval:  0.9205883673664609
# CXCR1
# 8
# 5 8
# cur_pval:  0.871150052329396
# CYP1B1
# 9
# 6 9
# cur_pval:  0.8116282789778417
# GSTA1
# 10
# 7 10
# cur_pval:  0.7446662839573488
# CCL5
# 11
# 8 11
# cur_pval:  0.6731628549311327
# TGFB1
# 12
# 9 12
# cur_pval:  0.5999265621912749
# APP
# 13
# 10 13
# cur_pval:  0.5274452827786305
# ALB
# 14
# 11 14
# cur_pval:  0.4577575526766835
# TP53
# 16
# 12 16
# cur_pval:  0.5722992656320952
# Max: -0.0
# Avg: 1.250082981250885
# [-0.0, 0.3103969927922293, 0.0757036591698301, 0.1862947605645947, 0.35934517189681525, 0.5990703295335378, 0.9064282956615343, 1.280383091387127, 1.7187985636749894, 2.219019089281628, 2.778225874423479, 3.393644814145837, 2.4237681137299023]
# pulmonary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.947806      100.000000         0.0
# 1     PTGS2         0.940789       99.994961         0.0
# 2    CYP2E1         0.938613       99.989922         0.0
# 3     CXCL8         0.936313       99.984884         0.0
# 4      BCL2         0.929689       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5     CYP1A2         0.924153       99.974806         1.0
# 7      HMOX1         0.919414       99.964728         1.0
# 10      MMP9         0.915654       99.949612         1.0
# 12    CYP1A1         0.913555       99.939534         1.0
# 19      MMP2         0.900070       99.904263         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0    CYP1A2         0.924153          1
# 1     HMOX1         0.919414          2
# 2      MMP9         0.915654          3
# 3    CYP1A1         0.913555          4
# 4      MMP2         0.900070          5
#
#     Gene_Name  mantis_ml_proba  full_rank
# 87       CPM         0.229035        104
# 88     HIPK3         0.228438        105
# 89    ADAM33         0.224402        106
# 90      AOAH         0.173150        107
# 91      CDYL         0.088432        109
# (92, 3)
# CYP1A2
# 1
# 0 1
# cur_pval:  1.0
# HMOX1
# 2
# 1 2
# cur_pval:  0.9768943255181786
# MMP9
# 3
# 2 3
# cur_pval:  0.937161203044766
# CYP1A1
# 4
# 3 4
# cur_pval:  0.8859954368407963
# MMP2
# 5
# 4 5
# cur_pval:  0.8275202754648323
# NOS3
# 6
# 5 6
# cur_pval:  0.7649687206275574
# NQO1
# 7
# 6 7
# cur_pval:  0.7008381945031359
# CXCR1
# 8
# 7 8
# cur_pval:  0.6370220337028523
# CYP1B1
# 9
# 8 9
# cur_pval:  0.5749208758095027
# GSTA1
# 10
# 9 10
# cur_pval:  0.5155366435739875
# CCL5
# 11
# 10 11
# cur_pval:  0.45955150880650325
# TGFB1
# 12
# 11 12
# cur_pval:  0.4073939291710769
# APP
# 13
# 12 13
# cur_pval:  0.3592935933123532
# ALB
# 14
# 13 14
# cur_pval:  0.3153268800664915
# TLR4
# 15
# 14 15
# cur_pval:  0.2754542332362351
# TP53
# 16
# 15 16
# cur_pval:  0.23955067207069158
# Max: -0.0
# Avg: 2.5136490064503496
# [-0.0, 0.10152413073961727, 0.28185698790754404, 0.5256851486234602, 0.8222135656780899, 1.1635632267197447, 1.5438223787601606, 1.958455457650082, 2.4039192150836657, 2.877404602807725, 3.376658036756559, 3.8998544697833393, 4.445505267805968, 5.0123900620431066, 5.599505489141471, 6.206026063705056]
# pulmonary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.947806      100.000000         0.0
# 1     PTGS2         0.940789       99.994961         0.0
# 2    CYP2E1         0.938613       99.989922         0.0
# 3     CXCL8         0.936313       99.984884         0.0
# 4      BCL2         0.929689       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5     CYP1A2         0.924153       99.974806         1.0
# 7      HMOX1         0.919414       99.964728         1.0
# 10      MMP9         0.915654       99.949612         1.0
# 12    CYP1A1         0.913555       99.939534         1.0
# 19      MMP2         0.900070       99.904263         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.919414          2
# 1      MMP9         0.915654          3
# 2    CYP1A1         0.913555          4
# 3      MMP2         0.900070          5
# 4      NOS3         0.891249          6
#
#     Gene_Name  mantis_ml_proba  full_rank
# 52      WNT3         0.408409         96
# 53     DDX3X         0.358343         97
# 54    SLC8A1         0.349303         98
# 55      FHIT         0.291388        100
# 56     ERAP2         0.265197        103
# (57, 3)
# HMOX1
# 2
# 0 2
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.8947288195337586
# CYP1A1
# 4
# 2 4
# cur_pval:  0.7249045567061413
# MMP2
# 5
# 3 5
# cur_pval:  0.543758676356684
# NOS3
# 6
# 4 6
# cur_pval:  0.38409483951020756
# TGFB1
# 12
# 5 12
# cur_pval:  0.8615630772651326
# APP
# 13
# 6 13
# cur_pval:  0.7786324178781299
# ALB
# 14
# 7 14
# cur_pval:  0.6813040745697754
# TLR4
# 15
# 8 15
# cur_pval:  0.5768041691229056
# TP53
# 16
# 9 16
# cur_pval:  0.47258218895648313
# Max: -0.0
# Avg: 1.772716785202028
# [-0.0, 0.4830857365155222, 1.397191702903737, 2.645938002648587, 4.155615277405679, 0.6471292122772364, 1.08667518659856, 1.6665901373508043, 2.3897160921004095, 3.255226504219746]
# pulmonary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.947806      100.000000         0.0
# 1     PTGS2         0.940789       99.994961         0.0
# 2    CYP2E1         0.938613       99.989922         0.0
# 3     CXCL8         0.936313       99.984884         0.0
# 4      BCL2         0.929689       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5     CYP1A2         0.924153       99.974806         1.0
# 7      HMOX1         0.919414       99.964728         1.0
# 10      MMP9         0.915654       99.949612         1.0
# 12    CYP1A1         0.913555       99.939534         1.0
# 19      MMP2         0.900070       99.904263         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0    CYP1A2         0.924153          1
# 1     HMOX1         0.919414          2
# 2      MMP9         0.915654          3
# 3    CYP1A1         0.913555          4
# 4      MMP2         0.900070          5
#
#     Gene_Name  mantis_ml_proba  full_rank
# 73     HIPK3         0.228438        105
# 74    ADAM33         0.224402        106
# 75      AOAH         0.173150        107
# 76     MPEG1         0.163024        108
# 77      CDYL         0.088432        109
# (78, 3)
# CYP1A2
# 1
# 0 1
# cur_pval:  1.0
# HMOX1
# 2
# 1 2
# cur_pval:  0.9209989806320091
# MMP9
# 3
# 2 3
# cur_pval:  0.8058199243571806
# CYP1A1
# 4
# 3 4
# cur_pval:  0.6803182168124364
# MMP2
# 5
# 4 5
# cur_pval:  0.559199108578779
# CXCR1
# 8
# 5 8
# cur_pval:  0.8414549709247913
# CYP1B1
# 9
# 6 9
# cur_pval:  0.7722085066739068
# CCL5
# 11
# 7 11
# cur_pval:  0.8342470435095825
# TGFB1
# 12
# 8 12
# cur_pval:  0.7745598214810918
# APP
# 13
# 9 13
# cur_pval:  0.7090269436869212
# ALB
# 14
# 10 14
# cur_pval:  0.6400050469361197
# AKR1C3
# 17
# 11 17
# cur_pval:  0.8356895417784865
# Max: -0.0
# Avg: 1.1226817250954462
# [-0.0, 0.357408504829974, 0.9376199863614625, 1.6728789982409251, 2.5243352957214955, 0.749691196193865, 1.1226541848354674, 0.7870532376786464, 1.1094503479844695, 1.4933726090689774, 1.9381660125382372, 0.7795503276918346]
# pulmonary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.947806      100.000000         0.0
# 1     PTGS2         0.940789       99.994961         0.0
# 2    CYP2E1         0.938613       99.989922         0.0
# 3     CXCL8         0.936313       99.984884         0.0
# 4      BCL2         0.929689       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5     CYP1A2         0.924153       99.974806         1.0
# 7      HMOX1         0.919414       99.964728         1.0
# 10      MMP9         0.915654       99.949612         1.0
# 12    CYP1A1         0.913555       99.939534         1.0
# 19      MMP2         0.900070       99.904263         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.915654          3
# 1      MMP2         0.900070          5
# 2      NOS3         0.891249          6
# 3     TGFB1         0.872920         12
# 4       APP         0.868060         13
#
#     Gene_Name  mantis_ml_proba  full_rank
# 27     LIMK1         0.594477         79
# 28    BMPR1B         0.552709         83
# 29      WNT3         0.408409         96
# 30     DDX3X         0.358343         97
# 31    SLC8A1         0.349303         98
# (32, 3)
# MMP9
# 3
# 0 3
# cur_pval:  1.0
# MMP2
# 5
# 1 5
# cur_pval:  0.8308815594814376
# NOS3
# 6
# 2 6
# cur_pval:  0.5706993432990347
# TGFB1
# 12
# 3 12
# cur_pval:  0.7464040595858878
# APP
# 13
# 4 13
# cur_pval:  0.567397746597129
# TLR4
# 15
# 5 15
# cur_pval:  0.46417175416787193
# TP53
# 16
# 6 16
# cur_pval:  0.3091084125319753
# Max: -0.0
# Avg: 2.2005748191200847
# [-0.0, 0.8046087962102523, 2.4359262719130745, 1.2702600718900101, 2.4611239332405033, 3.333212908130161, 5.098891752456592]
# pulmonary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.947806      100.000000         0.0
# 1     PTGS2         0.940789       99.994961         0.0
# 2    CYP2E1         0.938613       99.989922         0.0
# 3     CXCL8         0.936313       99.984884         0.0
# 4      BCL2         0.929689       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5     CYP1A2         0.924153       99.974806         1.0
# 7      HMOX1         0.919414       99.964728         1.0
# 10      MMP9         0.915654       99.949612         1.0
# 12    CYP1A1         0.913555       99.939534         1.0
# 19      MMP2         0.900070       99.904263         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.919414          2
# 1      NOS3         0.891249          6
# 2     GSTA1         0.884412         10
# 3       ALB         0.866354         14
# 4      TLR4         0.863594         15
#
#     Gene_Name  mantis_ml_proba  full_rank
# 17     DAPK1         0.624517         69
# 18     PTPRC         0.621276         71
# 19       C1S         0.613160         73
# 20     NUCB1         0.275426        102
# 21     ERAP2         0.265197        103
# (22, 3)
# HMOX1
# 2
# 0 2
# cur_pval:  1.0
# NOS3
# 6
# 1 6
# cur_pval:  0.750629356689239
# GSTA1
# 10
# 2 10
# cur_pval:  0.6414869930275963
# ALB
# 14
# 3 14
# cur_pval:  0.5703116253287476
# TLR4
# 15
# 4 15
# cur_pval:  0.35511617526154315
# TP53
# 16
# 5 16
# cur_pval:  0.19200260273720182
# Max: -0.0
# Avg: 2.8793280080009906
# [-0.0, 1.2457445457944007, 1.9281214507800004, 2.4388777559240262, 4.496295454769217, 7.166928840738297]
# pulmonary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.947806      100.000000         0.0
# 1     PTGS2         0.940789       99.994961         0.0
# 2    CYP2E1         0.938613       99.989922         0.0
# 3     CXCL8         0.936313       99.984884         0.0
# 4      BCL2         0.929689       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5     CYP1A2         0.924153       99.974806         1.0
# 7      HMOX1         0.919414       99.964728         1.0
# 10      MMP9         0.915654       99.949612         1.0
# 12    CYP1A1         0.913555       99.939534         1.0
# 19      MMP2         0.900070       99.904263         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.919414          2
# 1      MMP2         0.900070          5
# 2     CXCR1         0.887449          8
# 3    CYP1B1         0.886072          9
# 4     GSTA1         0.884412         10
#
#     Gene_Name  mantis_ml_proba  full_rank
# 34    SLC8A1         0.349303         98
# 35       KMO         0.341575         99
# 36   MAP3K13         0.281413        101
# 37     NUCB1         0.275426        102
# 38       CPM         0.229035        104
# (39, 3)
# HMOX1
# 2
# 0 2
# cur_pval:  1.0
# MMP2
# 5
# 1 5
# cur_pval:  0.8964033799661401
# CXCR1
# 8
# 2 8
# cur_pval:  0.8520893488951151
# CYP1B1
# 9
# 3 9
# cur_pval:  0.6900378537598433
# GSTA1
# 10
# 4 10
# cur_pval:  0.5101606941596964
# ALB
# 14
# 5 14
# cur_pval:  0.6112255886889508
# CXCR2
# 18
# 6 18
# cur_pval:  0.6883416450625215
# Max: -0.0
# Avg: 1.3520369920007238
# [-0.0, 0.4749651458914482, 0.6951486333472119, 1.6112708429449678, 2.922930050894844, 2.1379847250536015, 1.6219595458729938]
# pulmonary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.947806      100.000000         0.0
# 1     PTGS2         0.940789       99.994961         0.0
# 2    CYP2E1         0.938613       99.989922         0.0
# 3     CXCL8         0.936313       99.984884         0.0
# 4      BCL2         0.929689       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5     CYP1A2         0.924153       99.974806         1.0
# 7      HMOX1         0.919414       99.964728         1.0
# 10      MMP9         0.915654       99.949612         1.0
# 12    CYP1A1         0.913555       99.939534         1.0
# 19      MMP2         0.900070       99.904263         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.919414          2
# 1      MMP9         0.915654          3
# 2    CYP1A1         0.913555          4
# 3      MMP2         0.900070          5
# 4      NOS3         0.891249          6
#
#     Gene_Name  mantis_ml_proba  full_rank
# 73     ERAP2         0.265197        103
# 74       CPM         0.229035        104
# 75     HIPK3         0.228438        105
# 76    ADAM33         0.224402        106
# 77     MPEG1         0.163024        108
# (78, 3)
# HMOX1
# 2
# 0 2
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.9785885087694246
# CYP1A1
# 4
# 2 4
# cur_pval:  0.9313216319019231
# MMP2
# 5
# 3 5
# cur_pval:  0.8619968791629218
# NOS3
# 6
# 4 6
# cur_pval:  0.7775628854423418
# NQO1
# 7
# 5 7
# cur_pval:  0.6853412903591903
# CYP1B1
# 9
# 6 9
# cur_pval:  0.7722085066739068
# CCL5
# 11
# 7 11
# cur_pval:  0.8342470435095825
# TGFB1
# 12
# 8 12
# cur_pval:  0.7745598214810918
# APP
# 13
# 9 13
# cur_pval:  0.7090269436869212
# TLR4
# 15
# 10 15
# cur_pval:  0.7803737885388056
# TP53
# 16
# 11 16
# cur_pval:  0.7221356936185429
# Max: -0.0
# Avg: 0.8987363634846357
# [-0.0, 0.09399888317885575, 0.30900309525984127, 0.6449430652421472, 1.0926447728994801, 1.6409310207294014, 1.1226541848354674, 0.7870532376786464, 1.1094503479844695, 1.4933726090689774, 1.076973262638516, 1.4138118822998273]
# pulmonary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.947806      100.000000         0.0
# 1     PTGS2         0.940789       99.994961         0.0
# 2    CYP2E1         0.938613       99.989922         0.0
# 3     CXCL8         0.936313       99.984884         0.0
# 4      BCL2         0.929689       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5     CYP1A2         0.924153       99.974806         1.0
# 7      HMOX1         0.919414       99.964728         1.0
# 10      MMP9         0.915654       99.949612         1.0
# 12    CYP1A1         0.913555       99.939534         1.0
# 19      MMP2         0.900070       99.904263         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.919414          2
# 1      MMP9         0.915654          3
# 2    CYP1A1         0.913555          4
# 3      MMP2         0.900070          5
# 4      NOS3         0.891249          6
#
#     Gene_Name  mantis_ml_proba  full_rank
# 46      FHIT         0.291388        100
# 47   MAP3K13         0.281413        101
# 48     NUCB1         0.275426        102
# 49     HIPK3         0.228438        105
# 50      CDYL         0.088432        109
# (51, 3)
# HMOX1
# 2
# 0 2
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.8530204731010712
# CYP1A1
# 4
# 2 4
# cur_pval:  0.6408707786148794
# MMP2
# 5
# 3 5
# cur_pval:  0.4388234505327917
# NOS3
# 6
# 4 6
# cur_pval:  0.2801644909811525
# TGFB1
# 12
# 5 12
# cur_pval:  0.7511489329337504
# APP
# 13
# 6 13
# cur_pval:  0.6326422225633379
# TLR4
# 15
# 7 15
# cur_pval:  0.6115971027163953
# TP53
# 16
# 8 16
# cur_pval:  0.49534950945384754
# Max: -0.0
# Avg: 2.2381175249214476
# [-0.0, 0.6904054532940267, 1.9322953021907208, 3.5771017197048427, 5.525869095505333, 1.2427394536781842, 1.9884182662461312, 2.135345806129915, 3.0508826275438734]
# pulmonary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.947806      100.000000         0.0
# 1     PTGS2         0.940789       99.994961         0.0
# 2    CYP2E1         0.938613       99.989922         0.0
# 3     CXCL8         0.936313       99.984884         0.0
# 4      BCL2         0.929689       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5     CYP1A2         0.924153       99.974806         1.0
# 7      HMOX1         0.919414       99.964728         1.0
# 10      MMP9         0.915654       99.949612         1.0
# 12    CYP1A1         0.913555       99.939534         1.0
# 19      MMP2         0.900070       99.904263         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5     CYP1A2         0.924153          1
# 7      HMOX1         0.919414          2
# 10      MMP9         0.915654          3
# 12    CYP1A1         0.913555          4
# 19      MMP2         0.900070          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.919414          2
# 1      MMP9         0.915654          3
# 2      MMP2         0.900070          5
# 3      NOS3         0.891249          6
# 4     TGFB1         0.872920         12
#
#     Gene_Name  mantis_ml_proba  full_rank
# 21     PTPRC         0.621276         71
# 22    BMPR1B         0.552709         83
# 23      WNT3         0.408409         96
# 24     DDX3X         0.358343         97
# 25    SLC8A1         0.349303         98
# (26, 3)
# HMOX1
# 2
# 0 2
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.562333876361143
# MMP2
# 5
# 2 5
# cur_pval:  0.3425177369953541
# NOS3
# 6
# 3 6
# cur_pval:  0.14590222772363065
# TGFB1
# 12
# 4 12
# cur_pval:  0.3101736087813495
# TP53
# 16
# 5 16
# cur_pval:  0.32098169557981626
# Max: -0.0
# Avg: 4.255292756501011
# [-0.0, 2.5000575274606653, 4.653169340116852, 8.359380769845892, 5.083951570324784, 4.935197331257875]
# external_top_dataset:  ExtraTrees_vs_Pulmonary_obstruction
# external_top_dataset:  ExtraTrees_vs_Pulmonary_fibrosis
# external_top_dataset:  ExtraTrees_vs_Abnormality_of_pulmonary_circulation
# external_top_dataset:  ExtraTrees_vs_Interstitial_pulmonary_abnormality
# external_top_dataset:  ExtraTrees_vs_Abnormality_of_the_pulmonary_artery
# external_top_dataset:  ExtraTrees_vs_Chronic_kidney_disease
# external_top_dataset:  ExtraTrees_vs_Chronic_bronchitis
# external_top_dataset:  ExtraTrees_vs_Pulmonary_arterial_hypertension
# external_top_dataset:  ExtraTrees_vs_Abnormal_pulmonary_valve_physiology
# external_top_dataset:  ExtraTrees_vs_Abnormality_of_the_pulmonary_vasculature
# pulmonary_drugnomefull\chem\ExtraTrees-hits.intersection.txt
# pulmonary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5       MMP9         0.999893       99.974806         1.0
# 11      MMP2         0.999835       99.944573         1.0
# 20      TLR4         0.999729       99.899224         1.0
# 25    CYP1B1         0.999685       99.874030         1.0
# 28     CXCR1         0.999678       99.858914         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP2         0.999835          2
# 1    CYP1B1         0.999685          4
# 2     CXCR1         0.999678          5
# 3     GSTA1         0.999647          6
# 4      TLR2         0.999636          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 75     BCAT1         0.084750        102
# 76     MPEG1         0.057297        104
# 77      WNT3         0.055119        105
# 78     HIPK3         0.040869        106
# 79     DDX3X         0.011325        107
# (80, 3)
# MMP2
# 2
# 0 2
# cur_pval:  1.0
# CYP1B1
# 4
# 1 4
# cur_pval:  0.9957307337022907
# CXCR1
# 5
# 2 5
# cur_pval:  0.9827196364140334
# GSTA1
# 6
# 3 6
# cur_pval:  0.9580110622368099
# TLR2
# 7
# 4 7
# cur_pval:  0.9205883673664609
# CCR2
# 8
# 5 8
# cur_pval:  0.871150052329396
# ICAM1
# 9
# 6 9
# cur_pval:  0.8116282789778417
# MMP1
# 10
# 7 10
# cur_pval:  0.7446662839573488
# HMOX1
# 11
# 8 11
# cur_pval:  0.6731628549311327
# AKR1C3
# 12
# 9 12
# cur_pval:  0.5999265621912749
# TGM2
# 13
# 10 13
# cur_pval:  0.5274452827786305
# NQO1
# 15
# 11 15
# cur_pval:  0.637478540834339
# NOS3
# 16
# 12 16
# cur_pval:  0.5722992656320952
# Max: -0.0
# Avg: 1.1169970869290329
# [-0.0, 0.01858087959287016, 0.0757036591698301, 0.1862947605645947, 0.35934517189681525, 0.5990703295335378, 0.9064282956615343, 1.280383091387127, 1.7187985636749894, 2.219019089281628, 2.778225874423479, 1.9553443011611211, 2.4237681137299023]
# pulmonary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5       MMP9         0.999893       99.974806         1.0
# 11      MMP2         0.999835       99.944573         1.0
# 20      TLR4         0.999729       99.899224         1.0
# 25    CYP1B1         0.999685       99.874030         1.0
# 28     CXCR1         0.999678       99.858914         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.999893          1
# 1      MMP2         0.999835          2
# 2      TLR4         0.999729          3
# 3    CYP1B1         0.999685          4
# 4     CXCR1         0.999678          5
#
#     Gene_Name  mantis_ml_proba  full_rank
# 87       CPM         0.062836        103
# 88      WNT3         0.055119        105
# 89     HIPK3         0.040869        106
# 90     DDX3X         0.011325        107
# 91      CDYL         0.000037        109
# (92, 3)
# MMP9
# 1
# 0 1
# cur_pval:  1.0
# MMP2
# 2
# 1 2
# cur_pval:  0.9768943255181786
# TLR4
# 3
# 2 3
# cur_pval:  0.937161203044766
# CYP1B1
# 4
# 3 4
# cur_pval:  0.8859954368407963
# CXCR1
# 5
# 4 5
# cur_pval:  0.8275202754648323
# GSTA1
# 6
# 5 6
# cur_pval:  0.7649687206275574
# TLR2
# 7
# 6 7
# cur_pval:  0.7008381945031359
# CCR2
# 8
# 7 8
# cur_pval:  0.6370220337028523
# ICAM1
# 9
# 8 9
# cur_pval:  0.5749208758095027
# HMOX1
# 11
# 9 11
# cur_pval:  0.767469750027683
# AKR1C3
# 12
# 10 12
# cur_pval:  0.7203394069836218
# TGM2
# 13
# 11 13
# cur_pval:  0.6719457763940525
# NQO1
# 15
# 12 15
# cur_pval:  0.8174730260850465
# NOS3
# 16
# 13 16
# cur_pval:  0.7812854177583849
# Max: -0.0
# Avg: 1.074920137254645
# [-0.0, 0.10152413073961727, 0.28185698790754404, 0.5256851486234602, 0.8222135656780899, 1.1635632267197447, 1.5438223787601606, 1.958455457650082, 2.4039192150836657, 1.1493873331651938, 1.4246282600159703, 1.7266577153395248, 0.8752656871744939, 1.0719028147074834]
# pulmonary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5       MMP9         0.999893       99.974806         1.0
# 11      MMP2         0.999835       99.944573         1.0
# 20      TLR4         0.999729       99.899224         1.0
# 25    CYP1B1         0.999685       99.874030         1.0
# 28     CXCR1         0.999678       99.858914         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.999893          1
# 1      MMP2         0.999835          2
# 2      TLR4         0.999729          3
# 3      TLR2         0.999636          7
# 4      CCR2         0.999475          8
#
#     Gene_Name  mantis_ml_proba  full_rank
# 52    SLC8A1         0.236453         99
# 53      FHIT         0.118864        101
# 54      WNT3         0.055119        105
# 55     DDX3X         0.011325        107
# 56     ERAP2         0.009502        108
# (57, 3)
# MMP9
# 1
# 0 1
# cur_pval:  1.0
# MMP2
# 2
# 1 2
# cur_pval:  0.7747196738022415
# TLR4
# 3
# 2 3
# cur_pval:  0.534701382339211
# TLR2
# 7
# 3 7
# cur_pval:  0.8173573870693359
# CCR2
# 8
# 4 8
# cur_pval:  0.6922524275300086
# ICAM1
# 9
# 5 9
# cur_pval:  0.5584768272305253
# HMOX1
# 11
# 6 11
# cur_pval:  0.5649223788813178
# TGM2
# 13
# 7 13
# cur_pval:  0.5709986188203019
# NOS2
# 14
# 8 14
# cur_pval:  0.4606931630708327
# NOS3
# 16
# 9 16
# cur_pval:  0.47258218895648313
# Max: -0.0
# Avg: 2.0365495174057693
# [-0.0, 1.1085541509915777, 2.718886931363987, 0.8758800797878863, 1.5973551263397492, 2.529948422703026, 2.480112207457761, 2.4336494226106415, 3.365882328583318, 3.255226504219746]
# pulmonary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5       MMP9         0.999893       99.974806         1.0
# 11      MMP2         0.999835       99.944573         1.0
# 20      TLR4         0.999729       99.899224         1.0
# 25    CYP1B1         0.999685       99.874030         1.0
# 28     CXCR1         0.999678       99.858914         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.999893          1
# 1      MMP2         0.999835          2
# 2    CYP1B1         0.999685          4
# 3     CXCR1         0.999678          5
# 4      TLR2         0.999636          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 73      WNT3         0.055119        105
# 74     HIPK3         0.040869        106
# 75     DDX3X         0.011325        107
# 76     ERAP2         0.009502        108
# 77      CDYL         0.000037        109
# (78, 3)
# MMP9
# 1
# 0 1
# cur_pval:  1.0
# MMP2
# 2
# 1 2
# cur_pval:  0.9209989806320091
# CYP1B1
# 4
# 2 4
# cur_pval:  0.9313216319019231
# CXCR1
# 5
# 3 5
# cur_pval:  0.8619968791629218
# TLR2
# 7
# 4 7
# cur_pval:  0.9005250122198875
# CCR2
# 8
# 5 8
# cur_pval:  0.8414549709247913
# ICAM1
# 9
# 6 9
# cur_pval:  0.7722085066739068
# HMOX1
# 11
# 7 11
# cur_pval:  0.8342470435095825
# AKR1C3
# 12
# 8 12
# cur_pval:  0.7745598214810918
# TGM2
# 13
# 9 13
# cur_pval:  0.7090269436869212
# NOS2
# 14
# 10 14
# cur_pval:  0.6400050469361197
# CCR1
# 17
# 11 17
# cur_pval:  0.8356895417784865
# Max: -0.0
# Avg: 0.8121945651780337
# [-0.0, 0.357408504829974, 0.30900309525984127, 0.6449430652421472, 0.45504220081294366, 0.749691196193865, 1.1226541848354674, 0.7870532376786464, 1.1094503479844695, 1.4933726090689774, 1.9381660125382372, 0.7795503276918346]
# pulmonary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5       MMP9         0.999893       99.974806         1.0
# 11      MMP2         0.999835       99.944573         1.0
# 20      TLR4         0.999729       99.899224         1.0
# 25    CYP1B1         0.999685       99.874030         1.0
# 28     CXCR1         0.999678       99.858914         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.999893          1
# 1      MMP2         0.999835          2
# 2      TLR4         0.999729          3
# 3      NOS2         0.998885         14
# 4      NOS3         0.998759         16
#
#     Gene_Name  mantis_ml_proba  full_rank
# 27     PTPRC         0.881252         79
# 28    BMPR1B         0.473305         91
# 29    SLC8A1         0.236453         99
# 30      WNT3         0.055119        105
# 31     DDX3X         0.011325        107
# (32, 3)
# MMP9
# 1
# 0 1
# cur_pval:  1.0
# MMP2
# 2
# 1 2
# cur_pval:  0.5028882093102264
# TLR4
# 3
# 2 3
# cur_pval:  0.20555031581354113
# NOS2
# 14
# 3 14
# cur_pval:  0.8443998451339981
# NOS3
# 16
# 4 16
# cur_pval:  0.7561741507549523
# Max: -0.0
# Avg: 2.360880852181504
# [-0.0, 2.9852854670465465, 6.870818516203238, 0.7345185501556102, 1.2137817275021254]
# pulmonary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5       MMP9         0.999893       99.974806         1.0
# 11      MMP2         0.999835       99.944573         1.0
# 20      TLR4         0.999729       99.899224         1.0
# 25    CYP1B1         0.999685       99.874030         1.0
# 28     CXCR1         0.999678       99.858914         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      TLR4         0.999729          3
# 1     GSTA1         0.999647          6
# 2     HMOX1         0.999338         11
# 3      NOS2         0.998885         14
# 4      NOS3         0.998759         16
#
#     Gene_Name  mantis_ml_proba  full_rank
# 17      MAPT         0.971389         63
# 18    NOTCH2         0.943291         74
# 19     PTPRC         0.881252         79
# 20     NUCB1         0.449857         94
# 21     ERAP2         0.009502        108
# (22, 3)
# TLR4
# 3
# 0 3
# cur_pval:  1.0
# GSTA1
# 6
# 1 6
# cur_pval:  0.750629356689239
# HMOX1
# 11
# 2 11
# cur_pval:  0.697629969510967
# NOS2
# 14
# 3 14
# cur_pval:  0.5703116253287476
# NOS3
# 16
# 4 16
# cur_pval:  0.4094873661029911
# Max: -0.0
# Avg: 1.8251931878822134
# [-0.0, 1.2457445457944007, 1.563748708024593, 2.4388777559240262, 3.877594929668046]
# pulmonary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5       MMP9         0.999893       99.974806         1.0
# 11      MMP2         0.999835       99.944573         1.0
# 20      TLR4         0.999729       99.899224         1.0
# 25    CYP1B1         0.999685       99.874030         1.0
# 28     CXCR1         0.999678       99.858914         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
# full_rank_cutoff: 16
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP2         0.999835          2
# 1    CYP1B1         0.999685          4
# 2     CXCR1         0.999678          5
# 3     GSTA1         0.999647          6
# 4      CCR2         0.999475          8
#
#     Gene_Name  mantis_ml_proba  full_rank
# 34       KMO         0.359836         95
# 35   MAP3K13         0.297200         98
# 36    SLC8A1         0.236453         99
# 37       CPM         0.062836        103
# 38      WNT3         0.055119        105
# (39, 3)
# MMP2
# 2
# 0 2
# cur_pval:  1.0
# CYP1B1
# 4
# 1 4
# cur_pval:  0.8351871954006754
# CXCR1
# 5
# 2 5
# cur_pval:  0.5903224571388207
# GSTA1
# 6
# 3 6
# cur_pval:  0.3666479366111642
# CCR2
# 8
# 4 8
# cur_pval:  0.305204507499913
# ICAM1
# 9
# 5 9
# cur_pval:  0.17548540201903612
# HMOX1
# 11
# 6 11
# cur_pval:  0.14989536030144493
# CCR1
# 17
# 7 17
# cur_pval:  0.4026552047056706
# Max: -0.0
# Avg: 4.041655220687435
# [-0.0, 0.7821617263857811, 2.2891069496624548, 4.357507547455749, 5.154090566677345, 7.5575900504582325, 8.24211809624468, 3.950666828615234]
# pulmonary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 5       MMP9         0.999893       99.974806         1.0
# 11      MMP2         0.999835       99.944573         1.0
# 20      TLR4         0.999729       99.899224         1.0
# 25    CYP1B1         0.999685       99.874030         1.0
# 28     CXCR1         0.999678       99.858914         1.0
# (109, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
#
#  Population Size: 109
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 5       MMP9         0.999893          1
# 11      MMP2         0.999835          2
# 20      TLR4         0.999729          3
# 25    CYP1B1         0.999685          4
# 28     CXCR1         0.999678          5
# full_rank_cutoff: 16
# ...
# Max: -0.0
# Avg: 13.120353806368863
# [-0.0, 3.1491041938511204, 5.3989868873561075, 7.3873755344105785, 8.304717250257305, 11.075997113422314, 13.97399376001346, 14.64302153977221, 11.084401689224636, 12.714863215488885, 13.60484905115576, 15.272467503814191, 17.81110756905815, 21.41316247336992, 23.267210067235887, 22.33674384022017, 21.608013019619957]
# pulmonary_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       FTL         0.981036      100.000000         0.0
# 1      RAC1         0.948311       99.994961         0.0
# 2      FTH1         0.924415       99.989922         0.0
# 3      COMT         0.922351       99.984884         0.0
# 4    TMSB4X         0.919213       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7      SFTPC         0.906184       99.964728         1.0
# 18        C3         0.863785       99.909302         1.0
# 32      CD8A         0.838887       99.838758         1.0
# 36     ITGAM         0.831877       99.818603         1.0
# 44     SFTPB         0.821400       99.778293         1.0
# (362, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7      SFTPC         0.906184          1
# 18        C3         0.863785          2
# 32      CD8A         0.838887          3
# 36     ITGAM         0.831877          4
# 44     SFTPB         0.821400          5
#
#  Population Size: 362
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7      SFTPC         0.906184          1
# 18        C3         0.863785          2
# 32      CD8A         0.838887          3
# 36     ITGAM         0.831877          4
# 44     SFTPB         0.821400          5
# full_rank_cutoff: 54
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      CD8A         0.838887          3
# 1  SERPINA1         0.790302         10
# 2     CXCL2         0.758287         13
# 3    COL4A1         0.704830         22
# 4    CD300A         0.700594         25
#
#      Gene_Name  mantis_ml_proba  full_rank
# 136     ACSL3         0.265665        352
# 137    TRIM71         0.248404        355
# 138     CDIPT         0.239333        358
# 139     GPR65         0.197455        361
# 140     DOC2B         0.172565        362
# (141, 3)
# CD8A
# 3
# 0 3
# cur_pval:  1.0
# SERPINA1
# 10
# 1 10
# cur_pval:  0.9933690391680078
# CXCL2
# 13
# 2 13
# cur_pval:  0.986125538821078
# COL4A1
# 22
# 3 22
# cur_pval:  0.9983701410227367
# CD300A
# 25
# 4 25
# cur_pval:  0.9975414793311408
# HLA-DMA
# 29
# 5 29
# cur_pval:  0.9977716816812562
# IRF8
# 32
# 6 32
# cur_pval:  0.9971827748715322
# HLA-DPA1
# 33
# 7 33
# cur_pval:  0.9931914363065777
# CSF1
# 34
# 8 34
# cur_pval:  0.98547045788389
# CAMP
# 35
# 9 35
# cur_pval:  0.972064673701603
# HLA-DMB
# 36
# 10 36
# cur_pval:  0.9508604856733974
# HLA-DQA1
# 37
# 11 37
# cur_pval:  0.9199518042283173
# BMP7
# 41
# 12 41
# cur_pval:  0.9378740238187697
# SIGLEC14
# 42
# 13 42
# cur_pval:  0.9044265249494515
# COL1A2
# 43
# 14 43
# cur_pval:  0.8608643737779024
# IL10
# 45
# 15 45
# cur_pval:  0.8386242302583916
# OASL
# 49
# 16 49
# cur_pval:  0.8712944392409976
# APOE
# 53
# 17 53
# cur_pval:  0.8978186484797942
# CXCL9
# 55
# 18 55
# cur_pval:  0.8812929600685606
# Max: -0.0
# Avg: 0.245884877858543
# [-0.0, 0.028893800042020877, 0.060677936320928466, 0.007084162263290417, 0.010690366235779781, 0.009688261776456436, 0.012252320162926465, 0.029670337618873548, 0.06356390329555617, 0.12304839500321152, 0.21883199936410466, 0.362349245087591, 0.278554925746639, 0.43626709185750895, 0.6506526475946539, 0.7643259373844593, 0.5983505770316417, 0.46811378163861406, 0.5487969908880606]
# pulmonary_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       FTL         0.981036      100.000000         0.0
# 1      RAC1         0.948311       99.994961         0.0
# 2      FTH1         0.924415       99.989922         0.0
# 3      COMT         0.922351       99.984884         0.0
# 4    TMSB4X         0.919213       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7      SFTPC         0.906184       99.964728         1.0
# 18        C3         0.863785       99.909302         1.0
# 32      CD8A         0.838887       99.838758         1.0
# 36     ITGAM         0.831877       99.818603         1.0
# 44     SFTPB         0.821400       99.778293         1.0
# (362, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7      SFTPC         0.906184          1
# 18        C3         0.863785          2
# 32      CD8A         0.838887          3
# 36     ITGAM         0.831877          4
# 44     SFTPB         0.821400          5
#
#  Population Size: 362
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7      SFTPC         0.906184          1
# 18        C3         0.863785          2
# 32      CD8A         0.838887          3
# 36     ITGAM         0.831877          4
# 44     SFTPB         0.821400          5
# full_rank_cutoff: 54
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     SFTPC         0.906184          1
# 1        C3         0.863785          2
# 2      CD8A         0.838887          3
# 3     ITGAM         0.831877          4
# 4     SFTPB         0.821400          5
#
#      Gene_Name  mantis_ml_proba  full_rank
# 212      WWP2         0.266211        351
# 213     ACSL3         0.265665        352
# 214     SRP72         0.257724        353
# 215     CDIPT         0.239333        358
# 216      TBCK         0.216631        360
# (217, 3)
# SFTPC
# 1
# 0 1
# cur_pval:  1.0
# C3
# 2
# 1 2
# cur_pval:  0.8402228309943562
# CD8A
# 3
# 2 3
# cur_pval:  0.6476025772487732
# ITGAM
# 4
# 3 4
# cur_pval:  0.47376145687628113
# SFTPB
# 5
# 4 5
# cur_pval:  0.3345590699862573
# CD14
# 6
# 5 6
# cur_pval:  0.2302547604815873
# CD44
# 7
# 6 7
# cur_pval:  0.15536661017441766
# ACTB
# 9
# 7 9
# cur_pval:  0.22758706503952394
# SERPINA1
# 10
# 8 10
# cur_pval:  0.16279640749593827
# HLA-DRA
# 11
# 9 11
# cur_pval:  0.11447951089029217
# TYROBP
# 12
# 10 12
# cur_pval:  0.07931631199932901
# CXCL2
# 13
# 11 13
# cur_pval:  0.054239927875949376
# SOD2
# 14
# 12 14
# cur_pval:  0.03666229055478377
# VCAN
# 16
# 13 16
# cur_pval:  0.06038124191899433
# SLPI
# 17
# 14 17
# cur_pval:  0.04226873634885011
# ANXA2
# 18
# 15 18
# cur_pval:  0.02926373234942746
# LILRB2
# 19
# 16 19
# cur_pval:  0.020054374866095494
# LCN2
# 20
# 17 20
# cur_pval:  0.013613865751487214
# COL4A1
# 22
# 18 22
# cur_pval:  0.02287284436629901
# SERPINB1
# 24
# 19 24
# cur_pval:  0.03469021318932139
# CD300A
# 25
# 20 25
# cur_pval:  0.024870999706148342
# CYB5R3
# 26
# 21 26
# cur_pval:  0.017659559536766886
# C1QA
# 27
# 22 27
# cur_pval:  0.01242472442514833
# HLA-DMA
# 29
# 23 29
# cur_pval:  0.018907057929875175
# CLEC7A
# 30
# 24 30
# cur_pval:  0.01351703008831303
# THBS1
# 31
# 25 31
# cur_pval:  0.00958003686067254
# IRF8
# 32
# 26 32
# cur_pval:  0.006733507497411314
# HLA-DPA1
# 33
# 27 33
# cur_pval:  0.004695153603719632
# CSF1
# 34
# 28 34
# cur_pval:  0.003248824143859104
# HLA-DMB
# 36
# 29 36
# cur_pval:  0.0051715111783544815
# HLA-DQA1
# 37
# 30 37
# cur_pval:  0.0036265487573404307
# COL4A2
# 38
# 31 38
# cur_pval:  0.0025243171059996044
# RAB6A
# 39
# 32 39
# cur_pval:  0.0017445024789159872
# LILRB1
# 40
# 33 40
# cur_pval:  0.0011972138464796912
# BMP7
# 41
# 34 41
# cur_pval:  0.0008160792822005204
# COL1A2
# 43
# 35 43
# cur_pval:  0.001343594147635396
# ACTN1
# 44
# 36 44
# cur_pval:  0.0009262572568003547
# IL10
# 45
# 37 45
# cur_pval:  0.0006343255812408273
# ELN
# 46
# 38 46
# cur_pval:  0.0004315987078981397
# GSN
# 47
# 39 47
# cur_pval:  0.00029181035752546826
# SFTPD
# 48
# 40 48
# cur_pval:  0.00019608065531253523
# OASL
# 49
# 41 49
# cur_pval:  0.00013096006807468308
# FCER1G
# 50
# 42 50
# cur_pval:  8.694924807048348e-05
# RAB5B
# 51
# 43 51
# cur_pval:  5.739375234120039e-05
# C1QB
# 52
# 44 52
# cur_pval:  3.7668724345657076e-05
# APOE
# 53
# 45 53
# cur_pval:  2.458426295978678e-05
# CCL4
# 54
# 46 54
# cur_pval:  1.595632865937991e-05
# Max: -0.0
# Avg: 21.097289319719543
# [-0.0, 0.7560552175047736, 1.8869143156367079, 3.244402744423713, 4.75527191784886, 6.377913820669993, 8.086423096991759, 6.428524247971492, 7.883551831194526, 9.412722347523063, 11.006374875526781, 12.656808966317383, 14.357804050522777, 12.190979586693402, 13.73980735490704, 15.336702839732592, 16.977908712757824, 18.66018536357818, 16.406798250837976, 14.597930311852858, 16.043067576276183, 17.53020132759423, 19.057132349459103, 17.233760451489783, 18.691187194849032, 20.18632819903096, 21.71758651978019, 23.28350195057803, 24.88273796016844, 22.863825322402374, 24.405064792661932, 25.978560897070714, 27.58328409088459, 29.218282689326237, 30.882676474353335, 28.717318965058638, 30.332683765014092, 31.976877739127847, 33.64919864159535, 35.34899297307796, 37.07565250317064, 38.82861107844347, 40.607341693858444, 42.411353806232285, 44.2401908696484, 46.093428073980505, 47.9706702691941]
# pulmonary_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       FTL         0.981036      100.000000         0.0
# 1      RAC1         0.948311       99.994961         0.0
# 2      FTH1         0.924415       99.989922         0.0
# 3      COMT         0.922351       99.984884         0.0
# 4    TMSB4X         0.919213       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7      SFTPC         0.906184       99.964728         1.0
# 18        C3         0.863785       99.909302         1.0
# 32      CD8A         0.838887       99.838758         1.0
# 36     ITGAM         0.831877       99.818603         1.0
# 44     SFTPB         0.821400       99.778293         1.0
# (362, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7      SFTPC         0.906184          1
# 18        C3         0.863785          2
# 32      CD8A         0.838887          3
# 36     ITGAM         0.831877          4
# 44     SFTPB         0.821400          5
#
#  Population Size: 362
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7      SFTPC         0.906184          1
# 18        C3         0.863785          2
# 32      CD8A         0.838887          3
# 36     ITGAM         0.831877          4
# 44     SFTPB         0.821400          5
# full_rank_cutoff: 54
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     SFTPC         0.906184          1
# 1        C3         0.863785          2
# 2     ITGAM         0.831877          4
# 3     SFTPB         0.821400          5
# 4      CD44         0.811881          7
#
#      Gene_Name  mantis_ml_proba  full_rank
# 146      WWP2         0.266211        351
# 147     SRP72         0.257724        353
# 148     GLYR1         0.255259        354
# 149    TRIM71         0.248404        355
# 150      TBCK         0.216631        360
# (151, 3)
# SFTPC
# 1
# 0 1
# cur_pval:  1.0
# C3
# 2
# 1 2
# cur_pval:  0.6609326456589799
# ITGAM
# 4
# 2 4
# cur_pval:  0.5547629018064937
# SFTPB
# 5
# 3 5
# cur_pval:  0.34661514041859304
# CD44
# 7
# 4 7
# cur_pval:  0.322212332651914
# ACTB
# 9
# 5 9
# cur_pval:  0.30129042511614157
# SOD2
# 14
# 6 14
# cur_pval:  0.5685245988729604
# VCAN
# 16
# 7 16
# cur_pval:  0.5304649926047734
# ANXA2
# 18
# 8 18
# cur_pval:  0.49662260035501654
# COL4A1
# 22
# 9 22
# cur_pval:  0.6144127209046948
# SERPINB1
# 24
# 10 24
# cur_pval:  0.5824859189602735
# CLEC7A
# 30
# 11 30
# cur_pval:  0.7805803282843429
# THBS1
# 31
# 12 31
# cur_pval:  0.7046573222430854
# IRF8
# 32
# 13 32
# cur_pval:  0.6217001605564964
# CSF1
# 34
# 14 34
# cur_pval:  0.5952166887022168
# HLA-DQA1
# 37
# 15 37
# cur_pval:  0.6258780519691033
# COL4A2
# 38
# 16 38
# cur_pval:  0.5454578421796937
# BMP7
# 41
# 17 41
# cur_pval:  0.5773938160759158
# COL1A2
# 43
# 18 43
# cur_pval:  0.5543614971597712
# ACTN1
# 44
# 19 44
# cur_pval:  0.4782421103587713
# ELN
# 46
# 20 46
# cur_pval:  0.4576504395515893
# GSN
# 47
# 21 47
# cur_pval:  0.3861044665741248
# SFTPD
# 48
# 22 48
# cur_pval:  0.31951209233032063
# APOE
# 53
# 23 53
# cur_pval:  0.4506597079272963
# P4HB
# 57
# 24 57
# cur_pval:  0.5299713642792041
# Max: -0.0
# Avg: 2.8091758242372764
# [-0.0, 1.7984279635259572, 2.5589258883779946, 4.601524708874299, 4.918578410112394, 5.210146698045675, 2.4525073955379173, 2.7534327155572362, 3.039735204114715, 2.115398011771921, 2.3471456882858392, 1.0758239774502163, 1.5202203086628587, 2.0641902047358234, 2.253249005306005, 2.0351027783771776, 2.6323880990835664, 2.385278717516058, 2.5620694100759307, 3.2035218587131546, 3.3946611618241413, 4.13295174295984, 4.955127007827232, 3.461512691024526, 2.757475958171441]
# pulmonary_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       FTL         0.981036      100.000000         0.0
# 1      RAC1         0.948311       99.994961         0.0
# 2      FTH1         0.924415       99.989922         0.0
# 3      COMT         0.922351       99.984884         0.0
# 4    TMSB4X         0.919213       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7      SFTPC         0.906184       99.964728         1.0
# 18        C3         0.863785       99.909302         1.0
# 32      CD8A         0.838887       99.838758         1.0
# 36     ITGAM         0.831877       99.818603         1.0
# 44     SFTPB         0.821400       99.778293         1.0
# (362, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7      SFTPC         0.906184          1
# 18        C3         0.863785          2
# 32      CD8A         0.838887          3
# 36     ITGAM         0.831877          4
# 44     SFTPB         0.821400          5
#
#  Population Size: 362
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7      SFTPC         0.906184          1
# 18        C3         0.863785          2
# 32      CD8A         0.838887          3
# 36     ITGAM         0.831877          4
# 44     SFTPB         0.821400          5
# full_rank_cutoff: 54
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0        C3         0.863785          2
# 1     SFTPB         0.821400          5
# 2      ACTB         0.795331          9
# 3      SOD2         0.732787         14
# 4      VCAN         0.723969         16
#
#     Gene_Name  mantis_ml_proba  full_rank
# 70     WNT5A         0.289024        343
# 71     IREB2         0.286535        344
# 72       SF1         0.273298        349
# 73      WWP2         0.266211        351
# 74    TRIM71         0.248404        355
# (75, 3)
# C3
# 2
# 0 2
# cur_pval:  1.0
# SFTPB
# 5
# 1 5
# cur_pval:  0.6890419408221334
# ACTB
# 9
# 2 9
# cur_pval:  0.5878893650286893
# SOD2
# 14
# 3 14
# cur_pval:  0.582092586318886
# VCAN
# 16
# 4 16
# cur_pval:  0.43117947510521554
# COL4A1
# 22
# 5 22
# cur_pval:  0.49334130302609813
# SERPINB1
# 24
# 6 24
# cur_pval:  0.37614649000988
# THBS1
# 31
# 7 31
# cur_pval:  0.4705088677663858
# IRF8
# 32
# 8 32
# cur_pval:  0.33434713560495777
# CSF1
# 34
# 9 34
# cur_pval:  0.2522859950455096
# COL4A2
# 38
# 10 38
# cur_pval:  0.2403004683139735
# RAB6A
# 39
# 11 39
# cur_pval:  0.15550917174128562
# BMP7
# 41
# 12 41
# cur_pval:  0.11159732243971218
# COL1A2
# 43
# 13 43
# cur_pval:  0.07860591329781666
# ELN
# 46
# 14 46
# cur_pval:  0.06492388402246228
# GSN
# 47
# 15 47
# cur_pval:  0.03704950203428868
# APOE
# 53
# 16 53
# cur_pval:  0.05233335502637354
# FBN1
# 59
# 17 59
# cur_pval:  0.06970383098290488
# Max: -0.0
# Avg: 6.481557681246131
# [-0.0, 1.6175434251434848, 2.307043961659644, 2.3500793196628225, 3.6534192050383285, 3.068525234484217, 4.246429864207684, 3.274321869323341, 4.758023931049948, 5.9810685746209895, 6.192453828125114, 8.08243991722904, 9.52346225323243, 11.04544782001135, 11.875955067283396, 14.312176248024384, 12.812214222881542, 11.56743352045265]
# external_top_dataset:  SVC_vs_Pulmonary_obstruction
# external_top_dataset:  SVC_vs_Pulmonary_fibrosis
# external_top_dataset:  SVC_vs_Abnormality_of_pulmonary_circulation
# external_top_dataset:  SVC_vs_Interstitial_pulmonary_abnormality
# external_top_dataset:  SVC_vs_Abnormality_of_the_pulmonary_artery
# external_top_dataset:  SVC_vs_Chronic_kidney_disease
# external_top_dataset:  SVC_vs_Chronic_bronchitis
# external_top_dataset:  SVC_vs_Pulmonary_arterial_hypertension
# external_top_dataset:  SVC_vs_Abnormal_pulmonary_valve_physiology
# external_top_dataset:  SVC_vs_Abnormality_of_the_pulmonary_vasculature
# pulmonary_drugnomefull\bio\SVC-hits.intersection.txt

# %%
run_hypergeom_test(disease='Coronary artery disease', folder='coronary_drugnomefull', top=0.1)
# Out:
# (2205,)
# external_top_ranking:  0       PDGFRA
# 4         TBX3
# 135     EFEMP1
# 9        LTBP1
# 1367      LDLR
# Name: Gene_Name, dtype: object
# (2038,)
# external_top_ranking:  0         PDGFRA
# 24          JAG1
# 120         PTK2
# 1074       ATXN2
# 2363    MAPK8IP3
# Name: Gene_Name, dtype: object
# (3142,)
# external_top_ranking:  0       PDGFRA
# 1306     KAT2B
# 122      PSMC3
# 567       TYK2
# 25       STAT1
# Name: Gene_Name, dtype: object
# (1967,)
# external_top_ranking:  0       PDGFRA
# 641       ZEB2
# 6378    PIK3CG
# 334         C3
# 1172     HMGCR
# Name: Gene_Name, dtype: object
# (802,)
# external_top_ranking:  0       PDGFRA
# 1367      LDLR
# 858         TF
# 1634    RAD51C
# 1462     ERCC4
# Name: Gene_Name, dtype: object
# (961,)
# external_top_ranking:  0      PDGFRA
# 160      FBN1
# 742    STXBP1
# 702      TCF4
# 232     STAT3
# Name: Gene_Name, dtype: object
# (638,)
# external_top_ranking:  0      PDGFRA
# 458       TEK
# 236    TGFBR2
# 615       RET
# 172      IL6R
# Name: Gene_Name, dtype: object
# (1066,)
# external_top_ranking:  0       PDGFRA
# 182     ACVR1B
# 1239      BRAF
# 120       PTK2
# 22      PDGFRB
# Name: Gene_Name, dtype: object
# (591,)
# external_top_ranking:  0       PDGFRA
# 64      PRDM16
# 217      EDNRA
# 2351     SOCS1
# 481     GABBR1
# Name: Gene_Name, dtype: object
# (1728,)
# external_top_ranking:  0      PDGFRA
# 86      FGFR1
# 144     UBE4B
# 702      TCF4
# 24       JAG1
# Name: Gene_Name, dtype: object
# ['coronary_drugnomefull/chem\\ExtraTreesClassifier.mantis-ml_predictions.csv', 'coronary_drugnomefull/chem\\GradientBoostingClassifier.mantis-ml_predictions.csv', 'coronary_drugnomefull/chem\\RandomForestClassifier.mantis-ml_predictions.csv', 'coronary_drugnomefull/chem\\SVC.mantis-ml_predictions.csv']
# coronary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PTGS2         0.945182      100.000000         0.0
# 1     CXCL8         0.934902       99.994961         0.0
# 2       IL6         0.933341       99.989922         0.0
# 3     CASP8         0.931425       99.984884         0.0
# 4      BCL2         0.930928       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7       MMP9         0.922805       99.964728         1.0
# 8      HMOX1         0.921739       99.959690         1.0
# 10     CASP3         0.916264       99.949612         1.0
# 16      NOS3         0.901825       99.919379         1.0
# 18     ICAM1         0.898100       99.909302         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.922805          1
# 1      NOS3         0.901825          4
# 2     ICAM1         0.898100          5
# 3     TGFB1         0.898091          6
# 4      MMP2         0.891551          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 48   SMARCA4         0.508272        112
# 49      SHBG         0.383116        125
# 50     LATS2         0.373956        127
# 51    TUBA1A         0.367580        128
# 52     SORT1         0.286001        132
# (53, 3)
# MMP9
# 1
# 0 1
# cur_pval:  1.0
# NOS3
# 4
# 1 4
# cur_pval:  0.8652161571619973
# ICAM1
# 5
# 2 5
# cur_pval:  0.6487451368464233
# TGFB1
# 6
# 3 6
# cur_pval:  0.433926567067611
# MMP2
# 7
# 4 7
# cur_pval:  0.265376612318081
# ALB
# 12
# 5 12
# cur_pval:  0.5355904923467706
# CCND1
# 13
# 6 13
# cur_pval:  0.39160780411905344
# Max: -0.0
# Avg: 2.668340257907284
# [-0.0, 0.6287537908410155, 1.8792588470985057, 3.6258375946366006, 5.761373542250271, 2.711671410662696, 4.071486619861897]
# coronary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PTGS2         0.945182      100.000000         0.0
# 1     CXCL8         0.934902       99.994961         0.0
# 2       IL6         0.933341       99.989922         0.0
# 3     CASP8         0.931425       99.984884         0.0
# 4      BCL2         0.930928       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7       MMP9         0.922805       99.964728         1.0
# 8      HMOX1         0.921739       99.959690         1.0
# 10     CASP3         0.916264       99.949612         1.0
# 16      NOS3         0.901825       99.919379         1.0
# 18     ICAM1         0.898100       99.909302         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.901825          4
# 1     TGFB1         0.898091          6
# 2      MMP2         0.891551          7
# 3      CCL2         0.888504         10
# 4     CCND1         0.884257         13
#
#     Gene_Name  mantis_ml_proba  full_rank
# 33   SMARCA4         0.508272        112
# 34     PTPRA         0.499467        114
# 35      POLB         0.467647        118
# 36     LATS2         0.373956        127
# 37     SORT1         0.286001        132
# (38, 3)
# NOS3
# 4
# 0 4
# cur_pval:  1.0
# TGFB1
# 6
# 1 6
# cur_pval:  0.8660541978572412
# MMP2
# 7
# 2 7
# cur_pval:  0.6311338679453204
# CCL2
# 10
# 3 10
# cur_pval:  0.5661079478703206
# CCND1
# 13
# 4 13
# cur_pval:  0.5180375864616527
# Max: -0.0
# Avg: 1.5901458388398537
# [-0.0, 0.6245492889048909, 1.9987851406209578, 2.471007477969239, 2.856387286704181]
# coronary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PTGS2         0.945182      100.000000         0.0
# 1     CXCL8         0.934902       99.994961         0.0
# 2       IL6         0.933341       99.989922         0.0
# 3     CASP8         0.931425       99.984884         0.0
# 4      BCL2         0.930928       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7       MMP9         0.922805       99.964728         1.0
# 8      HMOX1         0.921739       99.959690         1.0
# 10     CASP3         0.916264       99.949612         1.0
# 16      NOS3         0.901825       99.919379         1.0
# 18     ICAM1         0.898100       99.909302         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.922805          1
# 1      NOS3         0.901825          4
# 2     ICAM1         0.898100          5
# 3     TGFB1         0.898091          6
# 4      MMP2         0.891551          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 54      SHBG         0.383116        125
# 55     LATS2         0.373956        127
# 56    TUBA1A         0.367580        128
# 57      AMD1         0.363258        131
# 58     SORT1         0.286001        132
# (59, 3)
# MMP9
# 1
# 0 1
# cur_pval:  1.0
# NOS3
# 4
# 1 4
# cur_pval:  0.9007413910837953
# ICAM1
# 5
# 2 5
# cur_pval:  0.7232790296881586
# TGFB1
# 6
# 3 6
# cur_pval:  0.5268512250899363
# MMP2
# 7
# 4 7
# cur_pval:  0.35459915028841715
# ABCB1
# 11
# 5 11
# cur_pval:  0.5633613471523389
# ALB
# 12
# 6 12
# cur_pval:  0.4248909606607138
# CCND1
# 13
# 7 13
# cur_pval:  0.30428772081317323
# Max: -0.0
# Avg: 2.565399195321119
# [-0.0, 0.45399879993814457, 1.4069412639015177, 2.7831200574452453, 4.502623094161326, 2.492129537547779, 3.7172250820662764, 5.167155727508664]
# coronary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PTGS2         0.945182      100.000000         0.0
# 1     CXCL8         0.934902       99.994961         0.0
# 2       IL6         0.933341       99.989922         0.0
# 3     CASP8         0.931425       99.984884         0.0
# 4      BCL2         0.930928       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7       MMP9         0.922805       99.964728         1.0
# 8      HMOX1         0.921739       99.959690         1.0
# 10     CASP3         0.916264       99.949612         1.0
# 16      NOS3         0.901825       99.919379         1.0
# 18     ICAM1         0.898100       99.909302         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.922805          1
# 1     CASP3         0.916264          3
# 2      NOS3         0.901825          4
# 3     ICAM1         0.898100          5
# 4     TGFB1         0.898091          6
#
#     Gene_Name  mantis_ml_proba  full_rank
# 49     CPT1B         0.473242        117
# 50      CPB2         0.416856        121
# 51      SHBG         0.383116        125
# 52     LATS2         0.373956        127
# 53     SORT1         0.286001        132
# (54, 3)
# MMP9
# 1
# 0 1
# cur_pval:  1.0
# CASP3
# 3
# 1 3
# cur_pval:  0.7840210711150122
# NOS3
# 4
# 2 4
# cur_pval:  0.5209489923227733
# ICAM1
# 5
# 3 5
# cur_pval:  0.3096941411714289
# TGFB1
# 6
# 4 6
# cur_pval:  0.169932662038225
# MMP2
# 7
# 5 7
# cur_pval:  0.08768840700983908
# CCL2
# 10
# 6 10
# cur_pval:  0.15238203562327293
# CCND1
# 13
# 7 13
# cur_pval:  0.21119576103854049
# Max: -0.0
# Avg: 5.27138258017744
# [-0.0, 1.0567226519055448, 2.832047976932212, 5.090670105973199, 7.697231392023639, 10.5705781945558, 8.170662291220461, 6.753148028808669]
# coronary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PTGS2         0.945182      100.000000         0.0
# 1     CXCL8         0.934902       99.994961         0.0
# 2       IL6         0.933341       99.989922         0.0
# 3     CASP8         0.931425       99.984884         0.0
# 4      BCL2         0.930928       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7       MMP9         0.922805       99.964728         1.0
# 8      HMOX1         0.921739       99.959690         1.0
# 10     CASP3         0.916264       99.949612         1.0
# 16      NOS3         0.901825       99.919379         1.0
# 18     ICAM1         0.898100       99.909302         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.922805          1
# 1     CCND1         0.884257         13
# 2      NOS2         0.876026         20
# 3      TLR4         0.873255         21
# 4      AKT1         0.867347         26
#
#     Gene_Name  mantis_ml_proba  full_rank
# 14      CETP         0.665172         88
# 15    CAMK2D         0.653139         93
# 16     NEDD4         0.604135        101
# 17    SLC8A1         0.536146        108
# 18   SMARCA4         0.508272        112
# (19, 3)
# MMP9
# 1
# 0 1
# cur_pval:  1.0
# CCND1
# 13
# 1 13
# cur_pval:  0.8720428587773507
# Max: -0.0
# Avg: 0.2973108501473867
# [-0.0, 0.5946217002947733]
# coronary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PTGS2         0.945182      100.000000         0.0
# 1     CXCL8         0.934902       99.994961         0.0
# 2       IL6         0.933341       99.989922         0.0
# 3     CASP8         0.931425       99.984884         0.0
# 4      BCL2         0.930928       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7       MMP9         0.922805       99.964728         1.0
# 8      HMOX1         0.921739       99.959690         1.0
# 10     CASP3         0.916264       99.949612         1.0
# 16      NOS3         0.901825       99.919379         1.0
# 18     ICAM1         0.898100       99.909302         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.901825          4
# 1     TGFB1         0.898091          6
# 2    BCL2L1         0.878635         19
# 3      AKT1         0.867347         26
# 4       AHR         0.863760         27
#
#     Gene_Name  mantis_ml_proba  full_rank
# 11    STAT5A         0.741066         56
# 12     PRKCE         0.729507         62
# 13       HK2         0.699781         76
# 14    SLC8A1         0.536146        108
# 15   SMARCA4         0.508272        112
# (16, 3)
# NOS3
# 4
# 0 4
# cur_pval:  1.0
# TGFB1
# 6
# 1 6
# cur_pval:  0.5351877523882096
# BCL2L1
# 19
# 2 19
# cur_pval:  0.6935138781448971
# Max: -0.0
# Avg: 1.4347955917111646
# [-0.0, 2.714938338259569, 1.5894484368739246]
# coronary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PTGS2         0.945182      100.000000         0.0
# 1     CXCL8         0.934902       99.994961         0.0
# 2       IL6         0.933341       99.989922         0.0
# 3     CASP8         0.931425       99.984884         0.0
# 4      BCL2         0.930928       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7       MMP9         0.922805       99.964728         1.0
# 8      HMOX1         0.921739       99.959690         1.0
# 10     CASP3         0.916264       99.949612         1.0
# 16      NOS3         0.901825       99.919379         1.0
# 18     ICAM1         0.898100       99.909302         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.901825          4
# 1     TGFB1         0.898091          6
# 2      NOS2         0.876026         20
# 3      TLR4         0.873255         21
# 4    NFKBIA         0.867642         25
#
#     Gene_Name  mantis_ml_proba  full_rank
# 10      LDLR         0.789738         42
# 11    CAMK2D         0.653139         93
# 12     NEDD4         0.604135        101
# 13   SMARCA4         0.508272        112
# 14     SORT1         0.286001        132
# (15, 3)
# NOS3
# 4
# 0 4
# cur_pval:  1.0
# TGFB1
# 6
# 1 6
# cur_pval:  0.5109366785997681
# NOS2
# 20
# 2 20
# cur_pval:  0.6861585209196261
# Max: -0.0
# Avg: 1.517361528677455
# [-0.0, 2.9163291951051216, 1.635755390927244]
# coronary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PTGS2         0.945182      100.000000         0.0
# 1     CXCL8         0.934902       99.994961         0.0
# 2       IL6         0.933341       99.989922         0.0
# 3     CASP8         0.931425       99.984884         0.0
# 4      BCL2         0.930928       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7       MMP9         0.922805       99.964728         1.0
# 8      HMOX1         0.921739       99.959690         1.0
# 10     CASP3         0.916264       99.949612         1.0
# 16      NOS3         0.901825       99.919379         1.0
# 18     ICAM1         0.898100       99.909302         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.901825          4
# 1     TGFB1         0.898091          6
# 2     CCND1         0.884257         13
# 3    NFKBIA         0.867642         25
# 4      AKT1         0.867347         26
#
#     Gene_Name  mantis_ml_proba  full_rank
# 17    CAMK2D         0.653139         93
# 18    SLC8A1         0.536146        108
# 19      POLB         0.467647        118
# 20     LATS2         0.373956        127
# 21     SORT1         0.286001        132
# (22, 3)
# NOS3
# 4
# 0 4
# cur_pval:  1.0
# TGFB1
# 6
# 1 6
# cur_pval:  0.6606333695986472
# CCND1
# 13
# 2 13
# cur_pval:  0.6592584246661936
# Max: -0.0
# Avg: 1.2032793495407672
# [-0.0, 1.800394932141819, 1.8094431164804825]
# coronary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PTGS2         0.945182      100.000000         0.0
# 1     CXCL8         0.934902       99.994961         0.0
# 2       IL6         0.933341       99.989922         0.0
# 3     CASP8         0.931425       99.984884         0.0
# 4      BCL2         0.930928       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7       MMP9         0.922805       99.964728         1.0
# 8      HMOX1         0.921739       99.959690         1.0
# 10     CASP3         0.916264       99.949612         1.0
# 16      NOS3         0.901825       99.919379         1.0
# 18     ICAM1         0.898100       99.909302         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CCND1         0.884257         13
# 1     MAPK8         0.882624         14
# 2    NFKBIA         0.867642         25
# 3    MAPK14         0.852155         30
# 4       HGF         0.826078         33
#
#    Gene_Name  mantis_ml_proba  full_rank
# 4       HGF         0.826078         33
# 5     PRKCE         0.729507         62
# 6      TERT         0.698831         77
# 7    PPP2CA         0.681414         83
# 8    CAMK2D         0.653139         93
# (9, 3)
# CCND1
# 13
# 0 13
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# coronary_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PTGS2         0.945182      100.000000         0.0
# 1     CXCL8         0.934902       99.994961         0.0
# 2       IL6         0.933341       99.989922         0.0
# 3     CASP8         0.931425       99.984884         0.0
# 4      BCL2         0.930928       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 7       MMP9         0.922805       99.964728         1.0
# 8      HMOX1         0.921739       99.959690         1.0
# 10     CASP3         0.916264       99.949612         1.0
# 16      NOS3         0.901825       99.919379         1.0
# 18     ICAM1         0.898100       99.909302         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 7       MMP9         0.922805          1
# 8      HMOX1         0.921739          2
# 10     CASP3         0.916264          3
# 16      NOS3         0.901825          4
# 18     ICAM1         0.898100          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.901825          4
# 1     TGFB1         0.898091          6
# 2      CCL2         0.888504         10
# 3     CCND1         0.884257         13
# 4     MAPK8         0.882624         14
#
#     Gene_Name  mantis_ml_proba  full_rank
# 34     PPM1B         0.480262        116
# 35      POLB         0.467647        118
# 36     LATS2         0.373956        127
# 37      AMD1         0.363258        131
# 38     SORT1         0.286001        132
# (39, 3)
# NOS3
# 4
# 0 4
# cur_pval:  1.0
# TGFB1
# 6
# 1 6
# cur_pval:  0.8742549612537306
# CCL2
# 10
# 2 10
# cur_pval:  0.8392888862427648
# CCND1
# 13
# 3 13
# cur_pval:  0.7805413011123652
# Max: -0.0
# Avg: 0.6051363354220368
# [-0.0, 0.5836189446166317, 0.7608852772139614, 1.0760411198575541]
# external_top_dataset:  ExtraTrees_vs_Coronary_artery_atherosclerosis
# external_top_dataset:  ExtraTrees_vs_Pulmonary_artery_stenosis
# external_top_dataset:  ExtraTrees_vs_Abnormal_coronary_artery_morphology
# external_top_dataset:  ExtraTrees_vs_Arterial_stenosis
# external_top_dataset:  ExtraTrees_vs_Abnormal_carotid_artery_morphology
# external_top_dataset:  ExtraTrees_vs_Dilatation_of_the_cerebral_artery
# external_top_dataset:  ExtraTrees_vs_Elevated_pulmonary_artery_pressure
# external_top_dataset:  ExtraTrees_vs_Abnormal_pulmonary_artery_morphology
# external_top_dataset:  ExtraTrees_vs_Coarctation_of_aorta
# external_top_dataset:  ExtraTrees_vs_Abnormality_of_the_pulmonary_artery
# coronary_drugnomefull\chem\ExtraTrees-hits.intersection.txt
# coronary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       AGT         0.999944      100.000000         0.0
# 1      PLAT         0.999939       99.994961         0.0
# 2     CASP8         0.999932       99.989922         0.0
# 3     FABP4         0.999931       99.984884         0.0
# 4      PLAU         0.999923       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       PLAU         0.999923       99.979845         1.0
# 12        F3         0.999835       99.939534         1.0
# 13      MMP9         0.999830       99.934496         1.0
# 17      NOS3         0.999805       99.914340         1.0
# 23      MMP2         0.999769       99.884108         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0        F3         0.999835          2
# 1      MMP9         0.999830          3
# 2      NOS3         0.999805          4
# 3      MMP2         0.999769          5
# 4     ICAM1         0.999719          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 48   SMARCA4         0.443149        118
# 49     LATS2         0.421917        119
# 50    TUBA1A         0.172171        127
# 51    SLC8A1         0.109972        131
# 52     SORT1         0.108534        132
# (53, 3)
# F3
# 2
# 0 2
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.7759218612818236
# NOS3
# 4
# 2 4
# cur_pval:  0.5080389736413002
# MMP2
# 5
# 3 5
# cur_pval:  0.29697972883361645
# ICAM1
# 7
# 4 7
# cur_pval:  0.265376612318081
# NOS2
# 9
# 5 9
# cur_pval:  0.23858133426469338
# LDLR
# 10
# 6 10
# cur_pval:  0.14057391252170803
# VCAM1
# 11
# 7 11
# cur_pval:  0.07834697808171742
# BCL2L1
# 13
# 8 13
# cur_pval:  0.07431444332195287
# Max: -0.0
# Avg: 5.796732061500403
# [-0.0, 1.1018201188972616, 2.9410297002295325, 5.272731936328015, 5.761373542250271, 6.223635369563086, 8.520952675030566, 11.059777500281271, 11.289267710923633]
# coronary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       AGT         0.999944      100.000000         0.0
# 1      PLAT         0.999939       99.994961         0.0
# 2     CASP8         0.999932       99.989922         0.0
# 3     FABP4         0.999931       99.984884         0.0
# 4      PLAU         0.999923       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       PLAU         0.999923       99.979845         1.0
# 12        F3         0.999835       99.939534         1.0
# 13      MMP9         0.999830       99.934496         1.0
# 17      NOS3         0.999805       99.914340         1.0
# 23      MMP2         0.999769       99.884108         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.999805          4
# 1      MMP2         0.999769          5
# 2      CCL2         0.999639          8
# 3      LDLR         0.999591         10
# 4    BCL2L1         0.999422         13
#
#     Gene_Name  mantis_ml_proba  full_rank
# 33   SMARCA4         0.443149        118
# 34     LATS2         0.421917        119
# 35   PIK3C2A         0.416640        120
# 36    SLC8A1         0.109972        131
# 37     SORT1         0.108534        132
# (38, 3)
# NOS3
# 4
# 0 4
# cur_pval:  1.0
# MMP2
# 5
# 1 5
# cur_pval:  0.8113236550462192
# CCL2
# 8
# 2 8
# cur_pval:  0.7097441592207568
# LDLR
# 10
# 3 10
# cur_pval:  0.5661079478703206
# BCL2L1
# 13
# 4 13
# cur_pval:  0.5180375864616527
# Max: -0.0
# Avg: 1.5448870214834716
# [-0.0, 0.9080586149746263, 1.4889817277693116, 2.471007477969239, 2.856387286704181]
# coronary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       AGT         0.999944      100.000000         0.0
# 1      PLAT         0.999939       99.994961         0.0
# 2     CASP8         0.999932       99.989922         0.0
# 3     FABP4         0.999931       99.984884         0.0
# 4      PLAU         0.999923       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       PLAU         0.999923       99.979845         1.0
# 12        F3         0.999835       99.939534         1.0
# 13      MMP9         0.999830       99.934496         1.0
# 17      NOS3         0.999805       99.914340         1.0
# 23      MMP2         0.999769       99.884108         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0        F3         0.999835          2
# 1      MMP9         0.999830          3
# 2      NOS3         0.999805          4
# 3      MMP2         0.999769          5
# 4     ICAM1         0.999719          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 54     PPM1B         0.187345        126
# 55    TUBA1A         0.172171        127
# 56    SLC8A1         0.109972        131
# 57     SORT1         0.108534        132
# 58      AMD1         0.102463        133
# (59, 3)
# F3
# 2
# 0 2
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.821602770461417
# NOS3
# 4
# 2 4
# cur_pval:  0.5841869085942826
# MMP2
# 5
# 3 5
# cur_pval:  0.3755487269534666
# ICAM1
# 7
# 4 7
# cur_pval:  0.35459915028841715
# NOS2
# 9
# 5 9
# cur_pval:  0.3361972207856385
# VCAM1
# 11
# 6 11
# cur_pval:  0.31957545544173666
# BCL2L1
# 13
# 7 13
# cur_pval:  0.30428772081317323
# Max: -0.0
# Avg: 3.349912921401822
# [-0.0, 0.853381049583961, 2.3344817962705, 4.253337058659641, 4.502623094161326, 4.73405881028761, 4.954265834742878, 5.167155727508664]
# coronary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       AGT         0.999944      100.000000         0.0
# 1      PLAT         0.999939       99.994961         0.0
# 2     CASP8         0.999932       99.989922         0.0
# 3     FABP4         0.999931       99.984884         0.0
# 4      PLAU         0.999923       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       PLAU         0.999923       99.979845         1.0
# 12        F3         0.999835       99.939534         1.0
# 13      MMP9         0.999830       99.934496         1.0
# 17      NOS3         0.999805       99.914340         1.0
# 23      MMP2         0.999769       99.884108         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0        F3         0.999835          2
# 1      MMP9         0.999830          3
# 2      NOS3         0.999805          4
# 3      MMP2         0.999769          5
# 4     ICAM1         0.999719          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 49     LATS2         0.421917        119
# 50     PPM1B         0.187345        126
# 51     NEDD4         0.169963        128
# 52    SLC8A1         0.109972        131
# 53     SORT1         0.108534        132
# (54, 3)
# F3
# 2
# 0 2
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.7840210711150122
# NOS3
# 4
# 2 4
# cur_pval:  0.5209489923227733
# MMP2
# 5
# 3 5
# cur_pval:  0.3096941411714289
# ICAM1
# 7
# 4 7
# cur_pval:  0.2795916687427385
# CCL2
# 8
# 5 8
# cur_pval:  0.16206951620863755
# NOS2
# 9
# 6 9
# cur_pval:  0.08861817087482382
# LDLR
# 10
# 7 10
# cur_pval:  0.046108927709192025
# BCL2L1
# 13
# 8 13
# cur_pval:  0.08300825674449251
# Max: -0.0
# Avg: 6.345877126619293
# [-0.0, 1.0567226519055448, 2.832047976932212, 5.090670105973199, 5.534757738167825, 7.902986642838727, 10.524772182760708, 13.362149774421802, 10.808787066573615]
# coronary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       AGT         0.999944      100.000000         0.0
# 1      PLAT         0.999939       99.994961         0.0
# 2     CASP8         0.999932       99.989922         0.0
# 3     FABP4         0.999931       99.984884         0.0
# 4      PLAU         0.999923       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       PLAU         0.999923       99.979845         1.0
# 12        F3         0.999835       99.939534         1.0
# 13      MMP9         0.999830       99.934496         1.0
# 17      NOS3         0.999805       99.914340         1.0
# 23      MMP2         0.999769       99.884108         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.999830          3
# 1      NOS2         0.999622          9
# 2      LDLR         0.999591         10
# 3      TLR4         0.999237         19
# 4      APOB         0.998700         25
#
#     Gene_Name  mantis_ml_proba  full_rank
# 14      CETP         0.959258         88
# 15    CAMK2D         0.773180        108
# 16   SMARCA4         0.443149        118
# 17     NEDD4         0.169963        128
# 18    SLC8A1         0.109972        131
# (19, 3)
# MMP9
# 3
# 0 3
# cur_pval:  1.0
# NOS2
# 9
# 1 9
# cur_pval:  0.7532439580548304
# LDLR
# 10
# 2 10
# cur_pval:  0.4209976338609378
# TLR4
# 19
# 3 19
# cur_pval:  0.517788472347276
# Max: -0.0
# Avg: 1.9615807771142326
# [-0.0, 1.2306434321779265, 3.7572034502900116, 2.858476225988993]
# coronary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       AGT         0.999944      100.000000         0.0
# 1      PLAT         0.999939       99.994961         0.0
# 2     CASP8         0.999932       99.989922         0.0
# 3     FABP4         0.999931       99.984884         0.0
# 4      PLAU         0.999923       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       PLAU         0.999923       99.979845         1.0
# 12        F3         0.999835       99.939534         1.0
# 13      MMP9         0.999830       99.934496         1.0
# 17      NOS3         0.999805       99.914340         1.0
# 23      MMP2         0.999769       99.884108         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.999805          4
# 1    BCL2L1         0.999422         13
# 2     TGFB1         0.999339         15
# 3       AHR         0.998804         23
# 4      APOB         0.998700         25
#
#     Gene_Name  mantis_ml_proba  full_rank
# 11    MAP3K8         0.987635         67
# 12    STAT5A         0.984313         70
# 13     PRKCE         0.972301         83
# 14   SMARCA4         0.443149        118
# 15    SLC8A1         0.109972        131
# (16, 3)
# NOS3
# 4
# 0 4
# cur_pval:  1.0
# BCL2L1
# 13
# 1 13
# cur_pval:  0.8189511371591366
# Max: -0.0
# Avg: 0.43371004855576756
# [-0.0, 0.8674200971115351]
# coronary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       AGT         0.999944      100.000000         0.0
# 1      PLAT         0.999939       99.994961         0.0
# 2     CASP8         0.999932       99.989922         0.0
# 3     FABP4         0.999931       99.984884         0.0
# 4      PLAU         0.999923       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       PLAU         0.999923       99.979845         1.0
# 12        F3         0.999835       99.939534         1.0
# 13      MMP9         0.999830       99.934496         1.0
# 17      NOS3         0.999805       99.914340         1.0
# 23      MMP2         0.999769       99.884108         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.999805          4
# 1      NOS2         0.999622          9
# 2      LDLR         0.999591         10
# 3     TGFB1         0.999339         15
# 4      TLR4         0.999237         19
#
#     Gene_Name  mantis_ml_proba  full_rank
# 10      AKT1         0.987915         66
# 11    CAMK2D         0.773180        108
# 12   SMARCA4         0.443149        118
# 13     NEDD4         0.169963        128
# 14     SORT1         0.108534        132
# (15, 3)
# NOS3
# 4
# 0 4
# cur_pval:  1.0
# NOS2
# 9
# 1 9
# cur_pval:  0.6624771372698933
# LDLR
# 10
# 2 10
# cur_pval:  0.30369299184812193
# TGFB1
# 15
# 3 15
# cur_pval:  0.21726268156240125
# Max: -0.0
# Avg: 3.398522998708415
# [-0.0, 1.7882910505735385, 5.175652299349006, 6.630148644911115]
# coronary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       AGT         0.999944      100.000000         0.0
# 1      PLAT         0.999939       99.994961         0.0
# 2     CASP8         0.999932       99.989922         0.0
# 3     FABP4         0.999931       99.984884         0.0
# 4      PLAU         0.999923       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       PLAU         0.999923       99.979845         1.0
# 12        F3         0.999835       99.939534         1.0
# 13      MMP9         0.999830       99.934496         1.0
# 17      NOS3         0.999805       99.914340         1.0
# 23      MMP2         0.999769       99.884108         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.999805          4
# 1      LDLR         0.999591         10
# 2     TGFB1         0.999339         15
# 3       AHR         0.998804         23
# 4      APOB         0.998700         25
#
#     Gene_Name  mantis_ml_proba  full_rank
# 17    CAMK2D         0.773180        108
# 18      POLB         0.650911        112
# 19     LATS2         0.421917        119
# 20    SLC8A1         0.109972        131
# 21     SORT1         0.108534        132
# (22, 3)
# NOS3
# 4
# 0 4
# cur_pval:  1.0
# LDLR
# 10
# 1 10
# cur_pval:  0.8398875582671214
# TGFB1
# 15
# 2 15
# cur_pval:  0.7407501819017733
# Max: -0.0
# Avg: 0.6870236178149994
# [-0.0, 0.7577885214380651, 1.3032823320069333]
# coronary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       AGT         0.999944      100.000000         0.0
# 1      PLAT         0.999939       99.994961         0.0
# 2     CASP8         0.999932       99.989922         0.0
# 3     FABP4         0.999931       99.984884         0.0
# 4      PLAU         0.999923       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       PLAU         0.999923       99.979845         1.0
# 12        F3         0.999835       99.939534         1.0
# 13      MMP9         0.999830       99.934496         1.0
# 17      NOS3         0.999805       99.914340         1.0
# 23      MMP2         0.999769       99.884108         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0    NFKBIA         0.998310         28
# 1     CCND1         0.997795         31
# 2     MAPK8         0.997532         33
# 3       HGF         0.996634         37
# 4    MAPK14         0.995557         46
#
#    Gene_Name  mantis_ml_proba  full_rank
# 4    MAPK14         0.995557         46
# 5      TERT         0.980904         74
# 6     PRKCE         0.972301         83
# 7    PPP2CA         0.854430        102
# 8    CAMK2D         0.773180        108
# (9, 3)
# NFKBIA
# 28
# 0 28
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# coronary_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       AGT         0.999944      100.000000         0.0
# 1      PLAT         0.999939       99.994961         0.0
# 2     CASP8         0.999932       99.989922         0.0
# 3     FABP4         0.999931       99.984884         0.0
# 4      PLAU         0.999923       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       PLAU         0.999923       99.979845         1.0
# 12        F3         0.999835       99.939534         1.0
# 13      MMP9         0.999830       99.934496         1.0
# 17      NOS3         0.999805       99.914340         1.0
# 23      MMP2         0.999769       99.884108         1.0
# (136, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
#
#  Population Size: 136
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       PLAU         0.999923          1
# 12        F3         0.999835          2
# 13      MMP9         0.999830          3
# 17      NOS3         0.999805          4
# 23      MMP2         0.999769          5
# full_rank_cutoff: 13
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.999805          4
# 1      CCL2         0.999639          8
# 2      NOS2         0.999622          9
# 3      LDLR         0.999591         10
# 4     VCAM1         0.999447         11
#
#     Gene_Name  mantis_ml_proba  full_rank
# 34     PPM1B         0.187345        126
# 35     NEDD4         0.169963        128
# 36    SLC8A1         0.109972        131
# 37     SORT1         0.108534        132
# 38      AMD1         0.102463        133
# (39, 3)
# NOS3
# 4
# 0 4
# cur_pval:  1.0
# CCL2
# 8
# 1 8
# cur_pval:  0.9385896322401979
# NOS2
# 9
# 2 9
# cur_pval:  0.788901860825673
# LDLR
# 10
# 3 10
# cur_pval:  0.5873537591572995
# VCAM1
# 11
# 4 11
# cur_pval:  0.39007122577820735
# BCL2L1
# 13
# 5 13
# cur_pval:  0.29997674755085796
# Max: -0.0
# Avg: 2.155616678554555
# ...
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
# full_rank_cutoff: 33
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MYL2         0.992624          1
# 1       INS         0.959386          3
# 2      ACTB         0.945360          4
# 3      CD36         0.932662          5
# 4       AGT         0.932086          6
#
#      Gene_Name  mantis_ml_proba  full_rank
# 102    TCF7L2         0.254281        316
# 103  ADAMTS13         0.248535        319
# 104      TBX1         0.238277        325
# 105   ADAMTS7         0.237904        326
# 106   SLC22A4         0.214824        332
# (107, 3)
# MYL2
# 1
# 0 1
# cur_pval:  1.0
# INS
# 3
# 1 3
# cur_pval:  0.6847423489908646
# ACTB
# 4
# 2 4
# cur_pval:  0.38084533405374593
# CD36
# 5
# 3 5
# cur_pval:  0.1867906136724468
# AGT
# 6
# 4 6
# cur_pval:  0.08419370712641995
# SOD2
# 7
# 5 7
# cur_pval:  0.03569335130464667
# SOD1
# 8
# 6 8
# cur_pval:  0.01443574854021585
# TNNI3
# 10
# 7 10
# cur_pval:  0.013788840064950942
# MYH6
# 11
# 8 11
# cur_pval:  0.005700358000743082
# MYH7
# 15
# 9 15
# cur_pval:  0.020318424950519883
# ALDOA
# 16
# 10 16
# cur_pval:  0.009640947595349829
# VWF
# 17
# 11 17
# cur_pval:  0.0044089836913184105
# GATA4
# 18
# 12 18
# cur_pval:  0.0019503035893668752
# IL10
# 19
# 13 19
# cur_pval:  0.0008369390148984222
# TNNT2
# 21
# 14 21
# cur_pval:  0.0007637467896030933
# APOA1
# 22
# 15 22
# cur_pval:  0.0003256012481633613
# CALR
# 27
# 16 27
# cur_pval:  0.002034314190676819
# ID3
# 30
# 17 30
# cur_pval:  0.0028635912975827666
# CRP
# 32
# 18 32
# cur_pval:  0.0023623117182104943
# APOE
# 36
# 19 36
# cur_pval:  0.0047824221790258884
# Max: -0.0
# Avg: 19.20826953294361
# [-0.0, 1.6447281166197052, 4.192513608192487, 7.2864495108601846, 10.747203676737843, 14.474126735409577, 18.40560691626927, 18.604722657007834, 22.44097868386301, 16.92109960847266, 20.158802777977684, 23.556615076113097, 27.09897779958289, 30.773061865205122, 31.170506022951724, 34.873139389504615, 26.915819714036758, 25.430889660675597, 26.266627957290734, 23.203520882101515]
# coronary_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       IL6         0.999162      100.000000         0.0
# 1      RHOA         0.994767       99.994961         0.0
# 2      TP53         0.994668       99.989922         0.0
# 3       BAX         0.994312       99.984884         0.0
# 4      MYL2         0.992624       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       MYL2         0.992624       99.979845         1.0
# 14      MYL9         0.959729       99.929457         1.0
# 15       INS         0.959386       99.924418         1.0
# 21      ACTB         0.945360       99.894185         1.0
# 33      CD36         0.932662       99.833720         1.0
# (336, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
#
#  Population Size: 336
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
# full_rank_cutoff: 33
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      CD36         0.932662          5
# 1      MYH6         0.900442         11
# 2      MYH7         0.877869         15
# 3       VWF         0.873802         17
# 4    NKX2-5         0.654077         73
#
#     Gene_Name  mantis_ml_proba  full_rank
# 24     CNOT1         0.317267        278
# 25     CHD1L         0.267449        307
# 26     KALRN         0.259490        313
# 27    TCF7L2         0.254281        316
# 28     TRAF6         0.215695        331
# (29, 3)
# CD36
# 5
# 0 5
# cur_pval:  1.0
# MYH6
# 11
# 1 11
# cur_pval:  0.6353094146834791
# MYH7
# 15
# 2 15
# cur_pval:  0.377656406143203
# VWF
# 17
# 3 17
# cur_pval:  0.17249218309645983
# NKX2-5
# 73
# 4 73
# cur_pval:  0.9125840393612035
# Max: -0.0
# Avg: 2.845751130295861
# [-0.0, 1.9701470878438554, 4.2290314401581, 7.632305812573423, 0.39727131090392687]
# coronary_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       IL6         0.999162      100.000000         0.0
# 1      RHOA         0.994767       99.994961         0.0
# 2      TP53         0.994668       99.989922         0.0
# 3       BAX         0.994312       99.984884         0.0
# 4      MYL2         0.992624       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       MYL2         0.992624       99.979845         1.0
# 14      MYL9         0.959729       99.929457         1.0
# 15       INS         0.959386       99.924418         1.0
# 21      ACTB         0.945360       99.894185         1.0
# 33      CD36         0.932662       99.833720         1.0
# (336, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
#
#  Population Size: 336
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
# full_rank_cutoff: 33
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      ACTB         0.945360          4
# 1      MYH7         0.877869         15
# 2       VWF         0.873802         17
# 3    ATP2A2         0.711263         57
# 4     ARNTL         0.697226         60
#
#     Gene_Name  mantis_ml_proba  full_rank
# 24     WDTC1         0.312186        282
# 25      EGR2         0.308853        284
# 26     KALRN         0.259490        313
# 27    TCF7L2         0.254281        316
# 28      SCAI         0.241925        323
# (29, 3)
# ACTB
# 4
# 0 4
# cur_pval:  1.0
# MYH7
# 15
# 1 15
# cur_pval:  0.749523800824206
# VWF
# 17
# 2 17
# cur_pval:  0.4417736047026322
# ATP2A2
# 57
# 3 57
# cur_pval:  0.9016914264738165
# Max: -0.0
# Avg: 1.312392168917856
# [-0.0, 1.2521457175166044, 3.5480023612064198, 0.44942059694839875]
# coronary_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       IL6         0.999162      100.000000         0.0
# 1      RHOA         0.994767       99.994961         0.0
# 2      TP53         0.994668       99.989922         0.0
# 3       BAX         0.994312       99.984884         0.0
# 4      MYL2         0.992624       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       MYL2         0.992624       99.979845         1.0
# 14      MYL9         0.959729       99.929457         1.0
# 15       INS         0.959386       99.924418         1.0
# 21      ACTB         0.945360       99.894185         1.0
# 33      CD36         0.932662       99.833720         1.0
# (336, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
#
#  Population Size: 336
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
# full_rank_cutoff: 33
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      SOD2         0.924695          7
# 1      MYH6         0.900442         11
# 2       VWF         0.873802         17
# 3      IL10         0.870006         19
# 4      APOE         0.777151         36
#
#     Gene_Name  mantis_ml_proba  full_rank
# 25     CNOT1         0.317267        278
# 26     SH2B3         0.316239        279
# 27    TCF7L2         0.254281        316
# 28  ADAMTS13         0.248535        319
# 29   SLC22A4         0.214824        332
# (30, 3)
# SOD2
# 7
# 0 7
# cur_pval:  1.0
# MYH6
# 11
# 1 11
# cur_pval:  0.6483765040595796
# VWF
# 17
# 2 17
# cur_pval:  0.4600682010518494
# IL10
# 19
# 3 19
# cur_pval:  0.23453322448448663
# APOE
# 36
# 4 36
# cur_pval:  0.4042966437484227
# Max: -0.0
# Avg: 3.0968920083876084
# [-0.0, 1.8817273155048007, 3.371777832206721, 6.297956254939223, 3.932998639287298]
# coronary_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       IL6         0.999162      100.000000         0.0
# 1      RHOA         0.994767       99.994961         0.0
# 2      TP53         0.994668       99.989922         0.0
# 3       BAX         0.994312       99.984884         0.0
# 4      MYL2         0.992624       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       MYL2         0.992624       99.979845         1.0
# 14      MYL9         0.959729       99.929457         1.0
# 15       INS         0.959386       99.924418         1.0
# 21      ACTB         0.945360       99.894185         1.0
# 33      CD36         0.932662       99.833720         1.0
# (336, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
#
#  Population Size: 336
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
# full_rank_cutoff: 33
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      ACTB         0.945360          4
# 1      MYH6         0.900442         11
# 2      TFRC         0.761300         40
# 3      GJA1         0.719577         52
# 4       CRK         0.718251         53
#
#     Gene_Name  mantis_ml_proba  full_rank
# 26     CNOT1         0.317267        278
# 27     KALRN         0.259490        313
# 28    TCF7L2         0.254281        316
# 29      TBX1         0.238277        325
# 30     TRAF6         0.215695        331
# (31, 3)
# ACTB
# 4
# 0 4
# cur_pval:  1.0
# MYH6
# 11
# 1 11
# cur_pval:  0.6610165643712703
# TFRC
# 40
# 2 40
# cur_pval:  0.9088856340105591
# Max: -0.0
# Avg: 0.7375947282346015
# [-0.0, 1.797876574207085, 0.4149076104967195]
# coronary_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       IL6         0.999162      100.000000         0.0
# 1      RHOA         0.994767       99.994961         0.0
# 2      TP53         0.994668       99.989922         0.0
# 3       BAX         0.994312       99.984884         0.0
# 4      MYL2         0.992624       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       MYL2         0.992624       99.979845         1.0
# 14      MYL9         0.959729       99.929457         1.0
# 15       INS         0.959386       99.924418         1.0
# 21      ACTB         0.945360       99.894185         1.0
# 33      CD36         0.932662       99.833720         1.0
# (336, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
#
#  Population Size: 336
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
# full_rank_cutoff: 33
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0       CRK         0.718251         53
# 1     HSPD1         0.712588         56
# 2     ARNTL         0.697226         60
# 3     KITLG         0.686166         65
# 4     CREB1         0.641740         82
#
#     Gene_Name  mantis_ml_proba  full_rank
# 14    ATP2B1         0.449840        204
# 15      IRF6         0.410726        222
# 16      TLE4         0.339055        272
# 17     WDTC1         0.312186        282
# 18     KALRN         0.259490        313
# (19, 3)
# CRK
# 53
# 0 53
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# coronary_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       IL6         0.999162      100.000000         0.0
# 1      RHOA         0.994767       99.994961         0.0
# 2      TP53         0.994668       99.989922         0.0
# 3       BAX         0.994312       99.984884         0.0
# 4      MYL2         0.992624       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 4       MYL2         0.992624       99.979845         1.0
# 14      MYL9         0.959729       99.929457         1.0
# 15       INS         0.959386       99.924418         1.0
# 21      ACTB         0.945360       99.894185         1.0
# 33      CD36         0.932662       99.833720         1.0
# (336, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
#
#  Population Size: 336
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 4       MYL2         0.992624          1
# 14      MYL9         0.959729          2
# 15       INS         0.959386          3
# 21      ACTB         0.945360          4
# 33      CD36         0.932662          5
# full_rank_cutoff: 33
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0       INS         0.959386          3
# 1      ACTB         0.945360          4
# 2      MYH6         0.900442         11
# 3       VWF         0.873802         17
# 4     GATA4         0.873191         18
#
#     Gene_Name  mantis_ml_proba  full_rank
# 54     KALRN         0.259490        313
# 55    TCF7L2         0.254281        316
# 56  ADAMTS13         0.248535        319
# 57      TBX1         0.238277        325
# 58     TRAF6         0.215695        331
# (59, 3)
# INS
# 3
# 0 3
# cur_pval:  1.0
# ACTB
# 4
# 1 4
# cur_pval:  0.5398522285417898
# MYH6
# 11
# 2 11
# cur_pval:  0.6042423075690906
# VWF
# 17
# 3 17
# cur_pval:  0.600231052389451
# GATA4
# 18
# 4 18
# cur_pval:  0.39155930474874745
# MEF2A
# 37
# 5 37
# cur_pval:  0.8181942078171448
# Max: -0.0
# Avg: 2.0042359372658667
# [-0.0, 2.6772510149451145, 2.1878886976029803, 2.2168154051306095, 4.072024512954906, 0.8714359929615899]
# external_top_dataset:  SVC_vs_Coronary_artery_atherosclerosis
# external_top_dataset:  SVC_vs_Pulmonary_artery_stenosis
# external_top_dataset:  SVC_vs_Abnormal_coronary_artery_morphology
# external_top_dataset:  SVC_vs_Arterial_stenosis
# external_top_dataset:  SVC_vs_Abnormal_carotid_artery_morphology
# external_top_dataset:  SVC_vs_Dilatation_of_the_cerebral_artery
# external_top_dataset:  SVC_vs_Elevated_pulmonary_artery_pressure
# external_top_dataset:  SVC_vs_Abnormal_pulmonary_artery_morphology
# external_top_dataset:  SVC_vs_Coarctation_of_aorta
# external_top_dataset:  SVC_vs_Abnormality_of_the_pulmonary_artery
# coronary_drugnomefull\bio\SVC-hits.intersection.txt

# %%
run_hypergeom_test(disease='Kidney disease', folder='kidney_drugnomefull', top=0.1)
# Out:
# (3092,)
# external_top_ranking:  0       PDGFRA
# 935      MEIS1
# 114     CREBBP
# 1487     PRMT5
# 1939     CASZ1
# Name: Gene_Name, dtype: object
# (1793,)
# external_top_ranking:  0         PDGFRA
# 676         EPRS
# 453         FLNA
# 141        LRRK2
# 11344    RAPGEF3
# Name: Gene_Name, dtype: object
# (881,)
# external_top_ranking:  0      PDGFRA
# 314      SPTB
# 731     TRRAP
# 338      MDM2
# 490      HIRA
# Name: Gene_Name, dtype: object
# (3304,)
# external_top_ranking:  0       PDGFRA
# 4836    TAPBPL
# 4880     PMPCA
# 1143     DNAH5
# 678      EXOC4
# Name: Gene_Name, dtype: object
# (1499,)
# external_top_ranking:  0        PDGFRA
# 4138    LAPTM4B
# 899         ATM
# 766         WRN
# 2612     RNF213
# Name: Gene_Name, dtype: object
# (824,)
# external_top_ranking:  0        PDGFRA
# 328       ERBB3
# 470       SYNE2
# 57        ITGA3
# 3454    RALGAPB
# Name: Gene_Name, dtype: object
# (2582,)
# external_top_ranking:  0       PDGFRA
# 369       TJP1
# 1387    SEMA5A
# 1895     FGFR3
# 4144    CEP192
# Name: Gene_Name, dtype: object
# (3781,)
# external_top_ranking:  0        PDGFRA
# 10078    LANCL1
# 8479      FARP2
# 3357      STAP2
# 1465       IGF2
# Name: Gene_Name, dtype: object
# (1768,)
# external_top_ranking:  0       PDGFRA
# 24        JAG1
# 191       KLF4
# 377       BMP2
# 962    TNFAIP3
# Name: Gene_Name, dtype: object
# (2977,)
# external_top_ranking:  0        PDGFRA
# 1161      PROCR
# 1194      PTPRF
# 11633    CLCNKA
# 3972      NPHS2
# Name: Gene_Name, dtype: object
# ['kidney_drugnomefull/chem\\AllClassifiers.Merged.mantis-ml_predictions.csv', 'kidney_drugnomefull/chem\\ExtraTreesClassifier.mantis-ml_predictions.csv', 'kidney_drugnomefull/chem\\GradientBoostingClassifier.mantis-ml_predictions.csv', 'kidney_drugnomefull/chem\\RandomForestClassifier.mantis-ml_predictions.csv', 'kidney_drugnomefull/chem\\SVC.mantis-ml_predictions.csv']
# kidney_drugnomefull/chem\AllClassifiers.Merged.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 1     IKBKB         0.944495       99.994961         0.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 3      ERN1         0.942335       99.984884         0.0
# 4      MMP9         0.941130       99.979845         1.0
#
#  external_top ranking:   Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 4      MMP9         0.941130       99.979845         1.0
# 8     MAPK3         0.936824       99.959690         1.0
# 9     MAPK1         0.936654       99.954651         1.0
# (602, 4)
# full ranking with rank   Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
#
#  Population Size: 602
#
#  Full ranking:
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 1    MAP3K5         0.944441          2
# 2     MAPK3         0.936824          4
# 3     MAPK1         0.936654          5
# 4       BAX         0.932929          6
#
#      Gene_Name  mantis_ml_proba  full_rank
# 237      UBA6         0.145511        593
# 238     SF3B3         0.145229        594
# 239    GIGYF2         0.118908        598
# 240    POLR1A         0.112202        599
# 241      MYT1         0.110286        600
# (242, 3)
# FASN
# 1
# 0 1
# cur_pval:  1.0
# MAP3K5
# 2
# 1 2
# cur_pval:  0.6427880442892947
# MAPK3
# 4
# 2 4
# cur_pval:  0.5285378653552641
# MAPK1
# 5
# 3 5
# cur_pval:  0.3203221933662482
# BAX
# 6
# 4 6
# cur_pval:  0.18081420543399548
# CASP8
# 8
# 5 8
# cur_pval:  0.1752198414882675
# HMOX1
# 10
# 6 10
# cur_pval:  0.1676312054834577
# RELA
# 11
# 7 11
# cur_pval:  0.09975247403628695
# CHEK1
# 12
# 8 12
# cur_pval:  0.057158036802364184
# ALB
# 15
# 9 15
# cur_pval:  0.09502691699632003
# ABCB1
# 16
# 10 16
# cur_pval:  0.05780698051984071
# AHR
# 18
# 11 18
# cur_pval:  0.05693385444830363
# MMP2
# 19
# 12 19
# cur_pval:  0.03437699706863416
# AKT1
# 20
# 13 20
# cur_pval:  0.020225761071004867
# CTSD
# 21
# 14 21
# cur_pval:  0.011622048992091415
# MAPK8
# 22
# 15 22
# cur_pval:  0.006535344862808891
# TP53
# 23
# 16 23
# cur_pval:  0.0036025968268976697
# JUN
# 24
# 17 24
# cur_pval:  0.0019497603096818267
# EPHB2
# 26
# 18 26
# cur_pval:  0.002149193844363433
# CHUK
# 28
# 19 28
# cur_pval:  0.002314753479122435
# DDR2
# 30
# 20 30
# cur_pval:  0.002447696186450696
# ALDH1A1
# 32
# 21 32
# cur_pval:  0.0025501454509961035
# PRKCA
# 34
# 22 34
# cur_pval:  0.002624685510768126
# G6PD
# 35
# 23 35
# cur_pval:  0.001517730063372495
# CCND1
# 36
# 24 36
# cur_pval:  0.0008641331808518308
# GLS
# 37
# 25 37
# cur_pval:  0.0004847929407322889
# ATM
# 38
# 26 38
# cur_pval:  0.00026817287865736345
# EPHB4
# 40
# 27 40
# cur_pval:  0.0002865636559539212
# ALPL
# 41
# 28 41
# cur_pval:  0.00015831714699435272
# ENPP2
# 42
# 29 42
# cur_pval:  8.634789715493832e-05
# RPS6KA5
# 44
# 30 44
# cur_pval:  9.313234206917823e-05
# PTEN
# 46
# 31 46
# cur_pval:  9.914515161570044e-05
# HIF1A
# 47
# 32 47
# cur_pval:  5.457460979187424e-05
# APOB
# 48
# 33 48
# cur_pval:  2.9686881004335213e-05
# ACACA
# 53
# 34 53
# cur_pval:  0.00019968386778163204
# PAK1
# 55
# 35 55
# cur_pval:  0.00020178353506575334
# TGFBR1
# 57
# 36 57
# cur_pval:  0.00020271417892389648
# HSPA5
# 59
# 37 59
# cur_pval:  0.00020257326454560547
# CDK1
# 60
# 38 60
# cur_pval:  0.0001190153320636502
# Max: -0.0
# Avg: 24.157032468388326
# [-0.0, 1.9193220961167072, 2.769238936436529, 4.9441297041332195, 7.4276745273649745, 7.564167168839107, 7.756451318407782, 10.010763242428876, 12.42922696265639, 10.221533605301618, 12.380197148978313, 12.44629413255664, 14.637320628869245, 16.940951274304506, 19.34717298149516, 21.847314902466817, 24.43384337836042, 27.100187745763158, 26.677244119907538, 26.354952544765577, 26.11242488788028, 25.934350482862378, 25.80922726208593, 28.188054632312813, 30.634193185724182, 33.144437127347864, 35.715851461154365, 35.42778890768893, 38.004720450761276, 40.63748234415304, 40.30899475377187, 40.03728518756017, 42.63009360810607, 45.27435428330566, 36.99657019838456, 36.95114273786994, 36.93115873344255, 36.93417873025542, 39.24397087332474]
# kidney_drugnomefull/chem\AllClassifiers.Merged.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 1     IKBKB         0.944495       99.994961         0.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 3      ERN1         0.942335       99.984884         0.0
# 4      MMP9         0.941130       99.979845         1.0
#
#  external_top ranking:   Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 4      MMP9         0.941130       99.979845         1.0
# 8     MAPK3         0.936824       99.959690         1.0
# 9     MAPK1         0.936654       99.954651         1.0
# (602, 4)
# full ranking with rank   Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
#
#  Population Size: 602
#
#  Full ranking:
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 1     MAPK1         0.936654          5
# 2     HMOX1         0.929187         10
# 3      RELA         0.926918         11
# 4     GSTA1         0.925485         13
#
#      Gene_Name  mantis_ml_proba  full_rank
# 160      RARS         0.210816        578
# 161       PAM         0.197161        582
# 162    DNASE1         0.161319        591
# 163      UBA6         0.145511        593
# 164      TGM3         0.136051        597
# (165, 3)
# FASN
# 1
# 0 1
# cur_pval:  1.0
# MAPK1
# 5
# 1 5
# cur_pval:  0.7996983213143342
# HMOX1
# 10
# 2 10
# cur_pval:  0.8082928980162601
# RELA
# 11
# 3 11
# cur_pval:  0.6185300201143994
# GSTA1
# 13
# 4 13
# cur_pval:  0.4968827401147311
# ALB
# 15
# 5 15
# cur_pval:  0.39456596095053004
# ABCB1
# 16
# 6 16
# cur_pval:  0.2557677075995173
# PLAU
# 17
# 7 17
# cur_pval:  0.15470868354432632
# AHR
# 18
# 8 18
# cur_pval:  0.08800232407641673
# MAPK8
# 22
# 9 22
# cur_pval:  0.11655368261470757
# TP53
# 23
# 10 23
# cur_pval:  0.06789860726842957
# CHUK
# 28
# 11 28
# cur_pval:  0.11215297117942466
# ALDH1A1
# 32
# 12 32
# cur_pval:  0.13407857424201985
# G6PD
# 35
# 13 35
# cur_pval:  0.12927693146493743
# ATM
# 38
# 14 38
# cur_pval:  0.12449420931971256
# MAP2K4
# 39
# 15 39
# cur_pval:  0.08143241920207252
# EPHB4
# 40
# 16 40
# cur_pval:  0.05140389557822952
# ALPL
# 41
# 17 41
# cur_pval:  0.03136706931676444
# PTEN
# 46
# 18 46
# cur_pval:  0.04937841218542339
# HIF1A
# 47
# 19 47
# cur_pval:  0.03083608316453182
# APOB
# 48
# 20 48
# cur_pval:  0.018687296895658484
# CASP1
# 50
# 21 50
# cur_pval:  0.014407601991412926
# STK4
# 51
# 22 51
# cur_pval:  0.00841659298514513
# ACACA
# 53
# 23 53
# cur_pval:  0.006422734579109083
# ANPEP
# 54
# 24 54
# cur_pval:  0.0036283646685261223
# MERTK
# 65
# 25 65
# cur_pval:  0.02693006224127272
# Max: -0.0
# Avg: 10.703031754741032
# [-0.0, 0.9707381563046341, 0.9243123706919483, 2.0863921720925354, 3.0374608879103118, 4.038803838810812, 5.921542890076312, 8.104853093804888, 10.555058583017027, 9.334740000157344, 11.681391338467318, 9.501892165104705, 8.726406168680015, 8.884789649208274, 9.048508487207114, 10.89202662953642, 12.890039673078222, 15.035260563425684, 13.06462879373626, 15.109407917125559, 17.284535144692402, 18.414082973651343, 20.748636741998286, 21.92280024928149, 24.402890706831407, 15.697626428376521]
# kidney_drugnomefull/chem\AllClassifiers.Merged.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 1     IKBKB         0.944495       99.994961         0.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 3      ERN1         0.942335       99.984884         0.0
# 4      MMP9         0.941130       99.979845         1.0
#
#  external_top ranking:   Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 4      MMP9         0.941130       99.979845         1.0
# 8     MAPK3         0.936824       99.959690         1.0
# 9     MAPK1         0.936654       99.954651         1.0
# (602, 4)
# full ranking with rank   Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
#
#  Population Size: 602
#
#  Full ranking:
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 1      AKT1         0.918212         20
# 2      CHUK         0.910810         28
# 3       ATM         0.902972         38
# 4    MAP2K4         0.902747         39
#
#     Gene_Name  mantis_ml_proba  full_rank
# 87       CIT         0.275519        567
# 88      UBA6         0.145511        593
# 89     SF3B3         0.145229        594
# 90    POLR1A         0.112202        599
# 91      MYT1         0.110286        600
# (92, 3)
# FASN
# 1
# 0 1
# cur_pval:  1.0
# AKT1
# 20
# 1 20
# cur_pval:  0.965790290270073
# CHUK
# 28
# 2 28
# cur_pval:  0.945799124207418
# ATM
# 38
# 3 38
# cur_pval:  0.9490961106458864
# MAP2K4
# 39
# 4 39
# cur_pval:  0.8752314324121561
# EPHB4
# 40
# 5 40
# cur_pval:  0.7613840531263207
# RPS6KA5
# 44
# 6 44
# cur_pval:  0.691332563428273
# APOB
# 48
# 7 48
# cur_pval:  0.6223643440450304
# ACACA
# 53
# 8 53
# cur_pval:  0.5801638445179186
# ABCC1
# 62
# 9 62
# cur_pval:  0.6301409085754351
# Max: -0.0
# Avg: 1.0415613290104981
# [-0.0, 0.15117165164006982, 0.24201092469103597, 0.2268980631911097, 0.578770938008355, 1.1839622354446395, 1.6031298632002333, 2.0595529652618185, 2.364493396761023, 2.0056232519066968]
# kidney_drugnomefull/chem\AllClassifiers.Merged.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 1     IKBKB         0.944495       99.994961         0.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 3      ERN1         0.942335       99.984884         0.0
# 4      MMP9         0.941130       99.979845         1.0
#
#  external_top ranking:   Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 4      MMP9         0.941130       99.979845         1.0
# 8     MAPK3         0.936824       99.959690         1.0
# 9     MAPK1         0.936654       99.954651         1.0
# (602, 4)
# full ranking with rank   Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
#
#  Population Size: 602
#
#  Full ranking:
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0    MAP3K5         0.944441          2
# 1     MAPK1         0.936654          5
# 2       BAX         0.932929          6
# 3      RELA         0.926918         11
# 4     ABCB1         0.923979         16
#
#      Gene_Name  mantis_ml_proba  full_rank
# 210    DNASE1         0.161319        591
# 211      TGM3         0.136051        597
# 212    GIGYF2         0.118908        598
# 213    POLR1A         0.112202        599
# 214     PREPL         0.109570        601
# (215, 3)
# MAP3K5
# 2
# 0 2
# cur_pval:  1.0
# MAPK1
# 5
# 1 5
# cur_pval:  0.8912225740943083
# BAX
# 6
# 2 6
# cur_pval:  0.6953503247677096
# RELA
# 11
# 3 11
# cur_pval:  0.8157719327393843
# ABCB1
# 16
# 4 16
# cur_pval:  0.8816413647534591
# PLAU
# 17
# 5 17
# cur_pval:  0.7871759058471965
# AHR
# 18
# 6 18
# cur_pval:  0.6713305721390541
# AKT1
# 20
# 7 20
# cur_pval:  0.6118382570968394
# MAPK8
# 22
# 8 22
# cur_pval:  0.5561772643338169
# TP53
# 23
# 9 23
# cur_pval:  0.44200337535903483
# CASP2
# 25
# 10 25
# cur_pval:  0.3971734871816481
# EPHB2
# 26
# 11 26
# cur_pval:  0.301297377735708
# GSTP1
# 27
# 12 27
# cur_pval:  0.22064402177837525
# CASP9
# 29
# 13 29
# cur_pval:  0.19610803928595366
# CHEK2
# 33
# 14 33
# cur_pval:  0.25808956413866413
# CCND1
# 36
# 15 36
# cur_pval:  0.2747592431137927
# GLS
# 37
# 16 37
# cur_pval:  0.20775234282990887
# ATM
# 38
# 17 38
# cur_pval:  0.15290156162396737
# MAP2K4
# 39
# 18 39
# cur_pval:  0.10964106856194547
# EPHB4
# 40
# 19 40
# cur_pval:  0.07667703388404368
# ACACB
# 43
# 20 43
# cur_pval:  0.0870418160980847
# PTEN
# 46
# 21 46
# cur_pval:  0.09739424934325504
# HIF1A
# 47
# 22 47
# cur_pval:  0.06910486638139514
# CASP1
# 50
# 23 50
# cur_pval:  0.0776630372515841
# STK4
# 51
# 24 51
# cur_pval:  0.05484160954735941
# NQO1
# 52
# 25 52
# cur_pval:  0.03794298431451225
# ACACA
# 53
# 26 53
# cur_pval:  0.0257366464372069
# PAK1
# 55
# 27 55
# cur_pval:  0.02285311510020564
# TGFB1
# 58
# 28 58
# cur_pval:  0.026641633562298418
# ABCC1
# 62
# 29 62
# cur_pval:  0.03909588848349419
# Max: -0.0
# Avg: 7.231922734037941
# [-0.0, 0.5001382163126534, 1.5779633817081504, 0.8843124099747158, 0.5470804183310445, 1.0392820740922157, 1.7306357475912137, 2.133633708842061, 2.5478676839559062, 3.5457441414817943, 4.010197499929079, 5.210046480806019, 6.563078350141404, 7.07504602426233, 5.882295558149898, 5.610476886559038, 6.824540699632768, 8.155880790009665, 9.600267404775312, 11.153346953858822, 10.602720561437293, 10.114666853413247, 11.60491368426519, 11.09785629038364, 12.608898075791203, 14.208685137121453, 15.894480436282327, 16.4105459302866, 15.744391494213566, 14.078689127529607]
# kidney_drugnomefull/chem\AllClassifiers.Merged.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 1     IKBKB         0.944495       99.994961         0.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 3      ERN1         0.942335       99.984884         0.0
# 4      MMP9         0.941130       99.979845         1.0
#
#  external_top ranking:   Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 4      MMP9         0.941130       99.979845         1.0
# 8     MAPK3         0.936824       99.959690         1.0
# 9     MAPK1         0.936654       99.954651         1.0
# (602, 4)
# full ranking with rank   Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
#
#  Population Size: 602
#
#  Full ranking:
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 1     CASP8         0.930627          8
# 2      RELA         0.926918         11
# 3       AHR         0.920627         18
# 4      CHUK         0.910810         28
#
#      Gene_Name  mantis_ml_proba  full_rank
# 123     PARP4         0.262333        569
# 124      ECE2         0.255667        571
# 125      RARS         0.210816        578
# 126    DNASE1         0.161319        591
# 127      UBA6         0.145511        593
# (128, 3)
# FASN
# 1
# 0 1
# cur_pval:  1.0
# CASP8
# 8
# 1 8
# cur_pval:  0.854136024557254
# RELA
# 11
# 2 11
# cur_pval:  0.7162538910115511
# AHR
# 18
# 3 18
# cur_pval:  0.773930714766387
# CHUK
# 28
# 4 28
# cur_pval:  0.8811603461104558
# ALDH1A1
# 32
# 5 32
# cur_pval:  0.8477139962336344
# CHEK2
# 33
# 6 33
# cur_pval:  0.7391831510189865
# G6PD
# 35
# 7 35
# cur_pval:  0.6438021381229584
# ATM
# 38
# 8 38
# cur_pval:  0.580688404442596
# ALPL
# 41
# 9 41
# cur_pval:  0.5210210956166601
# ENPP2
# 42
# 10 42
# cur_pval:  0.40002264805353055
# ACACB
# 43
# 11 43
# cur_pval:  0.2920315336035362
# HIF1A
# 47
# 12 47
# cur_pval:  0.2810914059397855
# APOB
# 48
# 13 48
# cur_pval:  0.1969718048396972
# CASP1
# 50
# 14 50
# cur_pval:  0.15034550546292813
# STK4
# 51
# 15 51
# cur_pval:  0.098179617550565
# NQO1
# 52
# 16 52
# cur_pval:  0.0614836136398764
# ACACA
# 53
# 17 53
# cur_pval:  0.03698069102856591
# ANPEP
# 54
# 18 54
# cur_pval:  0.021396275661527
# ABCC1
# 62
# 19 62
# cur_pval:  0.044405664267099465
# Max: -0.0
# Avg: 5.4893539700019005
# [-0.0, 0.6847296068051782, 1.4493300573623855, 1.1129791727768867, 0.5494505515825202, 0.7175064633796642, 1.3124794100720847, 1.9124758531822055, 2.3605684615003164, 2.8314469220060765, 3.9791541955646514, 5.345702508440587, 5.511524322651456, 7.055959356601739, 8.229095504821553, 10.079786639860245, 12.112406151843697, 14.320249777877425, 16.696618154550517, 13.525616289158823]
# kidney_drugnomefull/chem\AllClassifiers.Merged.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 1     IKBKB         0.944495       99.994961         0.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 3      ERN1         0.942335       99.984884         0.0
# 4      MMP9         0.941130       99.979845         1.0
#
#  external_top ranking:   Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 4      MMP9         0.941130       99.979845         1.0
# 8     MAPK3         0.936824       99.959690         1.0
# 9     MAPK1         0.936654       99.954651         1.0
# (602, 4)
# full ranking with rank   Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
#
#  Population Size: 602
#
#  Full ranking:
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 1      DDR1         0.931874          7
# 2     CASP8         0.930627          8
# 3     ABCB1         0.923979         16
# 4     EPHB4         0.901233         40
#
#     Gene_Name  mantis_ml_proba  full_rank
# 70     ITGA3         0.393919        533
# 71       CIT         0.275519        567
# 72      UBA6         0.145511        593
# 73    POLR1A         0.112202        599
# 74      MYT1         0.110286        600
# (75, 3)
# FASN
# 1
# 0 1
# cur_pval:  1.0
# DDR1
# 7
# 1 7
# cur_pval:  0.6079639055262729
# CASP8
# 8
# 2 8
# cur_pval:  0.26204970452008214
# ABCB1
# 16
# 3 16
# cur_pval:  0.3204735280214655
# EPHB4
# 40
# 4 40
# cur_pval:  0.760560212203359
# ENPP2
# 42
# 5 42
# cur_pval:  0.6202519198015746
# HIF1A
# 47
# 6 47
# cur_pval:  0.5454934325617734
# APOB
# 48
# 7 48
# cur_pval:  0.3889117327583224
# ACACA
# 53
# 8 53
# cur_pval:  0.33417487426156234
# ABCC1
# 62
# 9 62
# cur_pval:  0.3627579615680296
# Max: -0.0
# Avg: 3.208013331111121
# [-0.0, 2.161222037800354, 5.8161632565942325, 4.942078385601904, 1.1886639792588483, 2.074318828269103, 2.6321047370873085, 4.101489547817365, 4.760262066860991, 4.403830471821107]
# kidney_drugnomefull/chem\AllClassifiers.Merged.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 1     IKBKB         0.944495       99.994961         0.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 3      ERN1         0.942335       99.984884         0.0
# 4      MMP9         0.941130       99.979845         1.0
#
#  external_top ranking:   Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 4      MMP9         0.941130       99.979845         1.0
# 8     MAPK3         0.936824       99.959690         1.0
# 9     MAPK1         0.936654       99.954651         1.0
# (602, 4)
# full ranking with rank   Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
#
#  Population Size: 602
#
#  Full ranking:
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 1      MMP9         0.941130          3
# 2     MAPK3         0.936824          4
# 3       BAX         0.932929          6
# 4     CASP3         0.930304          9
#
#      Gene_Name  mantis_ml_proba  full_rank
# 232     PARP4         0.262333        569
# 233     DDX3X         0.223064        576
# 234    DNASE1         0.161319        591
# 235      UBA6         0.145511        593
# 236    POLR1A         0.112202        599
# (237, 3)
# FASN
# 1
# 0 1
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.7778334558678979
# MAPK3
# 4
# 2 4
# cur_pval:  0.5141265896278616
# BAX
# 6
# 3 6
# cur_pval:  0.4425374111335244
# CASP3
# 9
# 4 9
# cur_pval:  0.5018347207022761
# HMOX1
# 10
# 5 10
# cur_pval:  0.35019783891151673
# RELA
# 11
# 6 11
# cur_pval:  0.23083502317764729
# CHEK1
# 12
# 7 12
# cur_pval:  0.1449314964567525
# SGK1
# 14
# 8 14
# cur_pval:  0.13605612532100264
# ALB
# 15
# 9 15
# cur_pval:  0.08393497614575862
# ABCB1
# 16
# 10 16
# cur_pval:  0.05004587006643509
# PLAU
# 17
# 11 17
# cur_pval:  0.028949034063492134
# MAPK8
# 22
# 12 22
# cur_pval:  0.10448041760397421
# JUN
# 24
# 13 24
# cur_pval:  0.09770568049323627
# EPHB2
# 26
# 14 26
# cur_pval:  0.09135715725521935
# CHUK
# 28
# 15 28
# cur_pval:  0.08541254545417537
# CASP9
# 29
# 16 29
# cur_pval:  0.05723356580902117
# DDR2
# 30
# 17 30
# cur_pval:  0.03744557813938214
# ALDH1A1
# 32
# 18 32
# cur_pval:  0.03546416899806513
# CHEK2
# 33
# 19 33
# cur_pval:  0.022863309357229727
# PRKCA
# 34
# 20 34
# cur_pval:  0.014439813600646315
# CCND1
# 36
# 21 36
# cur_pval:  0.013851760539491534
# MAP2K4
# 39
# 22 39
# cur_pval:  0.019610780493279308
# EPHB4
# 40
# 23 40
# cur_pval:  0.012639403988835915
# ENPP2
# 42
# 24 42
# cur_pval:  0.012031261346444543
# ACACB
# 43
# 25 43
# cur_pval:  0.007661128911933268
# HIF1A
# 47
# 26 47
# cur_pval:  0.01562616401722333
# ACACA
# 53
# 27 53
# cur_pval:  0.04967591811919238
# ANPEP
# 54
# 28 54
# cur_pval:  0.03529254619366484
# PAK1
# 55
# 29 55
# cur_pval:  0.024662499423867446
# TGFB1
# 58
# 30 58
# cur_pval:  0.03072988540390024
# HSPA5
# 59
# 31 59
# cur_pval:  0.021526904006672367
# CDK1
# 60
# 32 60
# cur_pval:  0.014849780986174961
# Max: -0.0
# Avg: 12.16394521663457
# [-0.0, 1.0911338108269895, 2.88929934685703, 3.540500091196691, 2.9943929422157844, 4.556865382974016, 6.366982976876908, 8.388372235631216, 8.662819012695321, 10.76057028661215, 13.006317559741277, 15.383659227100807, 9.809651002081747, 10.100801861773254, 10.392574227538722, 10.6847833514978, 12.423491955045233, 14.265994597548692, 14.502102121522064, 16.408609072932336, 18.4043841291134, 18.584950248670445, 17.07505121417426, 18.982734047294663, 19.196888392366787, 21.157072298323342, 18.061476215085115, 13.038540974357776, 14.523170081753541, 16.07962911885163, 15.124390592863023, 16.670184257966525, 18.28279951545226]
# kidney_drugnomefull/chem\AllClassifiers.Merged.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 1     IKBKB         0.944495       99.994961         0.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 3      ERN1         0.942335       99.984884         0.0
# 4      MMP9         0.941130       99.979845         1.0
#
#  external_top ranking:   Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 4      MMP9         0.941130       99.979845         1.0
# 8     MAPK3         0.936824       99.959690         1.0
# 9     MAPK1         0.936654       99.954651         1.0
# (602, 4)
# full ranking with rank   Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
#
#  Population Size: 602
#
#  Full ranking:
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.941130          3
# 1     MAPK3         0.936824          4
# 2     MAPK1         0.936654          5
# 3       BAX         0.932929          6
# 4      RELA         0.926918         11
#
#      Gene_Name  mantis_ml_proba  full_rank
# 230    DNASE1         0.161319        591
# 231    PGGT1B         0.158897        592
# 232      HARS         0.139533        595
# 233     PREPL         0.109570        601
# 234      FUT6         0.095951        602
# (235, 3)
# MMP9
# 3
# 0 3
# cur_pval:  1.0
# MAPK3
# 4
# 1 4
# cur_pval:  0.8627563177340065
# MAPK1
# 5
# 2 5
# cur_pval:  0.6470221014629519
# BAX
# 6
# 3 6
# cur_pval:  0.43562425134836863
# RELA
# 11
# 4 11
# cur_pval:  0.6823465609255376
# GSTA1
# 13
# 5 13
# cur_pval:  0.621530720486871
# SGK1
# 14
# 6 14
# cur_pval:  0.4843877702061795
# AKT1
# 20
# 7 20
# cur_pval:  0.7248416007997383
# CTSD
# 21
# 8 21
# cur_pval:  0.6187376431367428
# MAPK8
# 22
# 9 22
# cur_pval:  0.5094377831336242
# JUN
# 24
# 10 24
# cur_pval:  0.4719244681665803
# EPHB2
# 26
# 11 26
# cur_pval:  0.4375163452150558
# CHUK
# 28
# 12 28
# cur_pval:  0.40590520915591477
# CASP9
# 29
# 13 29
# cur_pval:  0.3193610650830591
# ALDH1A1
# 32
# 14 32
# cur_pval:  0.3500104162393295
# PRKCA
# 34
# 15 34
# cur_pval:  0.32527065754600076
# GLS
# 37
# 16 37
# cur_pval:  0.35323618612420277
# ENPP2
# 42
# 17 42
# cur_pval:  0.482183130076241
# BIRC5
# 45
# 18 45
# cur_pval:  0.5044254948877269
# PTEN
# 46
# 19 46
# cur_pval:  0.4285366115901972
# HIF1A
# 47
# 20 47
# cur_pval:  0.35682865692536136
# AKR1C3
# 49
# 21 49
# cur_pval:  0.33487722509739964
# STK4
# 51
# 22 51
# cur_pval:  0.3141828146976021
# NQO1
# 52
# 23 52
# cur_pval:  0.25486044136163033
# ACACA
# 53
# 24 53
# cur_pval:  0.20291936570383173
# GAPDH
# 56
# 25 56
# cur_pval:  0.22287918516772798
# TGFBR1
# 57
# 26 57
# cur_pval:  0.17662492820301412
# TGFB1
# 58
# 27 58
# cur_pval:  0.13755199553781514
# HSPA5
# 59
# 28 59
# cur_pval:  0.1053051212343648
# CDK1
# 60
# 29 60
# cur_pval:  0.0792768627859019
# Max: -0.0
# Avg: 4.316426559888257
# [-0.0, 0.6411185180237384, 1.8908088412347421, 3.608879509236009, 1.6599499298345675, 2.0653740055700736, 3.148068304320006, 1.3975688917326876, 2.084934613046188, 2.929088481475725, 3.261275049324337, 3.590057174894319, 3.9157537515930363, 4.957180319992985, 4.559190309412961, 4.877551123732983, 4.51934812939664, 3.1678798815798843, 2.972029712479614, 3.6801206864774274, 4.47540274686082, 4.751143876970997, 5.028175738667579, 5.9369756912707246, 6.926765038933497, 6.5193048867049885, 7.529480016814805, 8.615331046943265, 9.775505075444078, 11.008535444679062]
# kidney_drugnomefull/chem\AllClassifiers.Merged.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 1     IKBKB         0.944495       99.994961         0.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 3      ERN1         0.942335       99.984884         0.0
# 4      MMP9         0.941130       99.979845         1.0
#
#  external_top ranking:   Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 4      MMP9         0.941130       99.979845         1.0
# 8     MAPK3         0.936824       99.959690         1.0
# 9     MAPK1         0.936654       99.954651         1.0
# (602, 4)
# full ranking with rank   Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
#
#  Population Size: 602
#
#  Full ranking:
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 1      MMP9         0.941130          3
# 2     MAPK3         0.936824          4
# 3     MAPK1         0.936654          5
# 4      DDR1         0.931874          7
#
#      Gene_Name  mantis_ml_proba  full_rank
# 178     DDX3X         0.223064        576
# 179       PAM         0.197161        582
# 180    DNASE1         0.161319        591
# 181      TGM3         0.136051        597
# 182    GIGYF2         0.118908        598
# (183, 3)
# FASN
# 1
# 0 1
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.6635626945125497
# MAPK3
# 4
# 2 4
# cur_pval:  0.35520863656143303
# MAPK1
# 5
# 3 5
# cur_pval:  0.1675148621564595
# DDR1
# 7
# 4 7
# cur_pval:  0.12995978968622363
# CASP8
# 8
# 5 8
# cur_pval:  0.059866972473433686
# CASP3
# 9
# 6 9
# cur_pval:  0.026071378450309674
# HMOX1
# 10
# 7 10
# cur_pval:  0.010854812507335967
# RELA
# 11
# 8 11
# cur_pval:  0.004355458810653737
# ABCB1
# 16
# 9 16
# cur_pval:  0.026272804290372112
# PLAU
# 17
# 10 17
# cur_pval:  0.012842262212916298
# AHR
# 18
# 11 18
# cur_pval:  0.006051229141958275
# AKT1
# 20
# 12 20
# cur_pval:  0.005065912545766132
# MAPK8
# 22
# 13 22
# cur_pval:  0.004215489012008023
# TP53
# 23
# 14 23
# cur_pval:  0.001985144410669993
# CHUK
# 28
# 15 28
# cur_pval:  0.007490999716431005
# CASP9
# 29
# 16 29
# cur_pval:  0.00386802982396348
# ALDH1A1
# 32
# 17 32
# cur_pval:  0.0049128790057326455
# CHEK2
# 33
# 18 33
# cur_pval:  0.002557244119256972
# G6PD
# 35
# 19 35
# cur_pval:  0.002075067116280791
# CCND1
# 36
# 20 36
# cur_pval:  0.0010567660290419186
# ATM
# 38
# 21 38
# cur_pval:  0.0008591449308356526
# EPHB4
# 40
# 22 40
# cur_pval:  0.0006971852897160861
# ALPL
# 41
# 23 41
# cur_pval:  0.00034931012189372637
# ENPP2
# 42
# 24 42
# cur_pval:  0.00017134189878338394
# ACACB
# 43
# 25 43
# cur_pval:  8.235778722824621e-05
# CASP1
# 50
# 26 50
# cur_pval:  0.0007060819400313519
# ACACA
# 53
# 27 53
# cur_pval:  0.0008444759866658903
# ANPEP
# 54
# 28 54
# cur_pval:  0.0004533513363439759
# TGFB1
# 58
# 29 58
# cur_pval:  0.000791512217394901
# HSPA5
# 59
# 30 59
# cur_pval:  0.0004316680321556254
# ICAM1
# 64
# 31 64
# cur_pval:  0.001033740089279472
# Max: -0.0
# Avg: 23.1663238277475
# [-0.0, 1.781180379924054, 4.495164833062352, 7.759466556945834, 8.861910001447406, 12.228127039610008, 15.838360061336758, 19.643776736128423, 23.60966089005418, 15.804935692834054, 18.913584669175737, 22.181564013224296, 22.953423118251834, 23.75152038382526, 27.02207894706476, 21.254602193690445, 24.12510186002471, 23.08663931527648, 25.92227811439581, 26.82967851839117, 29.760211560642045, 30.65933568004703, 31.566517848760558, 34.56788829710473, 37.66136424626857, 40.84295330430307, 31.511448966273473, 30.734126954201137, 33.435650997620876, 31.015423771929854, 33.64850112503051, 29.85588641107469]
# kidney_drugnomefull/chem\AllClassifiers.Merged.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 1     IKBKB         0.944495       99.994961         0.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 3      ERN1         0.942335       99.984884         0.0
# 4      MMP9         0.941130       99.979845         1.0
#
#  external_top ranking:   Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      FASN         0.947741      100.000000         1.0
# 2    MAP3K5         0.944441       99.989922         1.0
# 4      MMP9         0.941130       99.979845         1.0
# 8     MAPK3         0.936824       99.959690         1.0
# 9     MAPK1         0.936654       99.954651         1.0
# (602, 4)
# full ranking with rank   Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
#
#  Population Size: 602
#
#  Full ranking:
#    Gene_Name  mantis_ml_proba  full_rank
# 0      FASN         0.947741          1
# 2    MAP3K5         0.944441          2
# 4      MMP9         0.941130          3
# 8     MAPK3         0.936824          4
# 9     MAPK1         0.936654          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      MMP9         0.941130          3
# 1       BAX         0.932929          6
# 2      DDR1         0.931874          7
# 3     CASP8         0.930627          8
# 4     HMOX1         0.929187         10
#
#      Gene_Name  mantis_ml_proba  full_rank
# 263      CBFB         0.174129        589
# 264    DNASE1         0.161319        591
# 265      UBA6         0.145511        593
# 266      HARS         0.139533        595
# 267      TGM3         0.136051        597
# (268, 3)
# MMP9
# 3
# 0 3
# cur_pval:  1.0
# BAX
# 6
# 1 6
# cur_pval:  0.9714147454144774
# DDR1
# 7
# 2 7
# cur_pval:  0.8942921122371665
# CASP8
# 8
# 3 8
# cur_pval:  0.7731642118943046
# HMOX1
# 10
# 4 10
# cur_pval:  0.7254771921632693
# RELA
# 11
# 5 11
# cur_pval:  0.5911751246879591
# GSTA1
# 13
# 6 13
# cur_pval:  0.5600485930862842
# SGK1
# 14
# 7 14
# cur_pval:  0.438728334354666
# ALB
# 15
# 8 15
# cur_pval:  0.3306130017430872
# ABCB1
# 16
# 9 16
# cur_pval:  0.2404785198063769
# AHR
# 18
# 10 18
# cur_pval:  0.23627049696956773
# MMP2
# 19
# 11 19
# cur_pval:  0.1690619877082443
# AKT1
# 20
# 12 20
# cur_pval:  0.11768882188898148
# CTSD
# 21
# 13 21
# cur_pval:  0.07987981955355745
# MAPK8
# 22
# 14 22
# cur_pval:  0.05296850000423054
# TP53
# 23
# 15 23
# cur_pval:  0.03437582726146099
# JUN
# 24
# 16 24
# cur_pval:  0.021869391548946657
# CHUK
# 28
# 17 28
# cur_pval:  0.05844659344291252
# ALDH1A1
# 32
# 18 32
# cur_pval:  0.11737744890815384
# CHEK2
# 33
# 19 33
# cur_pval:  0.08537002597395933
# PRKCA
# 34
# 20 34
# cur_pval:  0.06094478878892845
# G6PD
# 35
# 21 35
# cur_pval:  0.042741966781161975
# CCND1
# 36
# 22 36
# cur_pval:  0.02947241987365028
# GLS
# 37
# 23 37
# cur_pval:  0.019996607867443682
# ATM
# 38
# 24 38
# cur_pval:  0.013359528923185775
# MAP2K4
# 39
# 25 39
# cur_pval:  0.008794575837273937
# EPHB4
# 40
# 26 40
# cur_pval:  0.005708245921417652
# ALPL
# 41
# 27 41
# cur_pval:  0.003655198646430507
# ENPP2
# 42
# 28 42
# cur_pval:  0.0023103557691349086
# ACACB
# 43
# 29 43
# cur_pval:  0.0014422116617381262
# PTEN
# 46
# 30 46
# cur_pval:  0.0027023559616531313
# HIF1A
# 47
# 31 47
# cur_pval:  0.0017215033402714637
# APOB
# 48
# 32 48
# cur_pval:  0.0010837923595818295
# CASP1
# 50
# 33 50
# cur_pval:  0.001177945801782387
# STK4
# 51
# 34 51
# cur_pval:  0.0007399559835778892
# ANPEP
# 54
# 35 54
# cur_pval:  0.0013571062751880198
# PAK1
# 55
# 36 55
# cur_pval:  0.0008667087596917433
# GAPDH
# 56
# 37 56
# cur_pval:  0.0005475718431218906
# TGFBR1
# 57
# 38 57
# cur_pval:  0.000342333410290004
# TGFB1
# 58
# 39 58
# cur_pval:  0.00021184695712275187
# HSPA5
# 59
# 40 59
# cur_pval:  0.0001298008935266799
# ABCC1
# 62
# 41 62
# cur_pval:  0.00025176105136855327
# Max: -0.0
# Avg: 16.995813736608795
# [-0.0, 0.1259530851838968, 0.48520599759817096, 1.1172825673418807, 1.3937623653201827, 2.282838483582225, 2.5177428943368376, 3.5780431668575434, 4.806800712901395, 6.189237099187649, 6.265905052117314, 7.719540292107913, 9.292647845862277, 10.975629248602083, 12.759823255184218, 14.637468416485305, 16.601632997520696, 12.332407965989649, 9.304153337145172, 10.686945864435547, 12.150634237120386, 13.691454975544195, 15.30584204339159, 16.99043669805826, 18.742088554583724, 20.557851017407497, 22.43497324973295, 24.37089015777442, 26.36321138430276, 28.40970997051311, 25.682574450994707, 27.64092130287186, 29.650539149615195, 29.288746913216936, 31.30794113590357, 28.673861413450666, 30.62126814066621, 32.61558891968261, 34.655507134928214, 36.73977769634617, 38.86722317918001, 35.990114564524475]
# external_top_dataset:  AllClassifiers.Merged_vs_Horseshoe_kidney
# external_top_dataset:  AllClassifiers.Merged_vs_Chronic_kidney_disease
# external_top_dataset:  AllClassifiers.Merged_vs_Ectopic_kidney
# external_top_dataset:  AllClassifiers.Merged_vs_Renal_tubular_dysfunction
# external_top_dataset:  AllClassifiers.Merged_vs_Stage_5_chronic_kidney_disease
# external_top_dataset:  AllClassifiers.Merged_vs_Polycystic_kidney_dysplasia
# external_top_dataset:  AllClassifiers.Merged_vs_Renal_insufficiency
# external_top_dataset:  AllClassifiers.Merged_vs_Abnormality_of_renal_excretion
# external_top_dataset:  AllClassifiers.Merged_vs_Abnormality_of_the_kidney
# external_top_dataset:  AllClassifiers.Merged_vs_Abnormality_of_renal_glomerulus_morphology
# kidney_drugnomefull\chem\AllClassifiers.Merged-hits.intersection.txt
# kidney_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    PIK3CA         0.928501      100.000000         0.0
# 1       TNF         0.915231       99.994961         0.0
# 2      HRAS         0.910856       99.989922         0.0
# 3     MAPK9         0.906101       99.984884         0.0
# 4      BCL2         0.901624       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 6       RELA         0.900029       99.969767         1.0
# 7      CASP3         0.899322       99.964728         1.0
# 8      MAPK1         0.894733       99.959690         1.0
# 11     MAPK3         0.889384       99.944573         1.0
# 13     MAPK8         0.884321       99.934496         1.0
# (602, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 6       RELA         0.900029          1
# 7      CASP3         0.899322          2
# 8      MAPK1         0.894733          3
# 11     MAPK3         0.889384          4
# 13     MAPK8         0.884321          5
#
#  Population Size: 602
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 6       RELA         0.900029          1
# 7      CASP3         0.899322          2
# 8      MAPK1         0.894733          3
# 11     MAPK3         0.889384          4
# 13     MAPK8         0.884321          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      RELA         0.900029          1
# 1     MAPK1         0.894733          3
# 2     MAPK3         0.889384          4
# 3     MAPK8         0.884321          5
# 4      FASN         0.884172          6
#
#      Gene_Name  mantis_ml_proba  full_rank
# 237     SF3B3         0.197077        587
# 238       PAM         0.196664        589
# 239    GIGYF2         0.156731        597
# 240    ATAD2B         0.136955        601
# 241      MYT1         0.130303        602
# (242, 3)
# RELA
# 1
# 0 1
# cur_pval:  1.0
# MAPK1
# 3
# 1 3
# cur_pval:  0.7868635330928273
# MAPK3
# 4
# 2 4
# cur_pval:  0.5285378653552641
# MAPK8
# 5
# 3 5
# cur_pval:  0.3203221933662482
# FASN
# 6
# 4 6
# cur_pval:  0.18081420543399548
# CASP8
# 8
# 5 8
# cur_pval:  0.1752198414882675
# MAP3K5
# 9
# 6 9
# cur_pval:  0.09990501051147666
# EPHB2
# 13
# 7 13
# cur_pval:  0.23114548380867364
# EPHA3
# 14
# 8 14
# cur_pval:  0.15104769318012246
# ABCB1
# 15
# 9 15
# cur_pval:  0.09502691699632003
# HMOX1
# 16
# 10 16
# cur_pval:  0.05780698051984071
# EPHB1
# 18
# 11 18
# cur_pval:  0.05693385444830363
# JUN
# 19
# 12 19
# cur_pval:  0.03437699706863416
# EPHA7
# 20
# 13 20
# cur_pval:  0.020225761071004867
# TP53
# 21
# 14 21
# cur_pval:  0.011622048992091415
# G6PD
# 23
# 15 23
# cur_pval:  0.012034247430145369
# BAX
# 24
# 16 24
# cur_pval:  0.0069082698613354455
# ALDH1A1
# 25
# 17 25
# cur_pval:  0.0038885547018508724
# HIF1A
# 26
# 18 26
# cur_pval:  0.002149193844363433
# NOS3
# 27
# 19 27
# cur_pval:  0.0011677836383167921
# EP300
# 29
# 20 29
# cur_pval:  0.0012811554967781223
# STAT3
# 30
# 21 30
# cur_pval:  0.0006978851519430302
# AKT1
# 31
# 22 31
# cur_pval:  0.00037449350220867644
# GLS
# 35
# 23 35
# cur_pval:  0.001517730063372495
# EPHB4
# 36
# 24 36
# cur_pval:  0.0008641331808518308
# CHUK
# 38
# 25 38
# cur_pval:  0.0009013699831839256
# AHR
# 39
# 26 39
# cur_pval:  0.0005117965873141279
# MMP2
# 41
# 27 41
# cur_pval:  0.000533896208946841
# CTSD
# 42
# 28 42
# cur_pval:  0.0003022556466730943
# ALB
# 43
# 29 43
# cur_pval:  0.00016885550143511195
# PRKCA
# 44
# 30 44
# cur_pval:  9.313234206917823e-05
# EPHB3
# 45
# 31 45
# cur_pval:  5.0738229191263476e-05
# CDK1
# 46
# 32 46
# cur_pval:  2.731552479238629e-05
# KRAS
# 47
# 33 47
# cur_pval:  1.4537828698870991e-05
# CHEK1
# 49
# 34 49
# cur_pval:  1.596473319891712e-05
# CREBBP
# 52
# 35 52
# cur_pval:  3.3775668269124676e-05
# CCND1
# 54
# 36 54
# cur_pval:  3.545877845440526e-05
# HPRT1
# 55
# 37 55
# cur_pval:  1.9585461433405296e-05
# TKT
# 59
# 38 59
# cur_pval:  6.833670437474541e-05
# ITPR1
# 60
# 39 60
# cur_pval:  3.899644623914682e-05
# Max: -0.0
# Avg: 25.626441988371244
# [-0.0, 1.041005814450231, 2.769238936436529, 4.9441297041332195, 7.4276745273649745, 7.564167168839107, 10.004127301632291, 6.361145875217373, 8.208859029414695, 10.221533605301618, 12.380197148978313, 12.44629413255664, 14.637320628869245, 16.940951274304506, 19.34717298149516, 19.195810634408318, 21.606307057021866, 24.102117872720854, 26.677244119907538, 29.32637613892499, 28.92398155739852, 31.562160415333885, 34.2655571329001, 28.188054632312813, 30.634193185724182, 30.45096908606558, 32.9090261433704, 32.72543162939269, 35.19625576998013, 37.72484785167808, 40.30899475377187, 42.94664694108433, 45.63590451299934, 48.37500452797145, 47.96838334951424, 44.71396049479222, 44.502762298081144, 47.08066192019052, 41.65345969440891, 44.089749685901864]
# kidney_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    PIK3CA         0.928501      100.000000         0.0
# 1       TNF         0.915231       99.994961         0.0
# 2      HRAS         0.910856       99.989922         0.0
# 3     MAPK9         0.906101       99.984884         0.0
# 4      BCL2         0.901624       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 6       RELA         0.900029       99.969767         1.0
# 7      CASP3         0.899322       99.964728         1.0
# 8      MAPK1         0.894733       99.959690         1.0
# 11     MAPK3         0.889384       99.944573         1.0
# 13     MAPK8         0.884321       99.934496         1.0
# (602, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 6       RELA         0.900029          1
# 7      CASP3         0.899322          2
# 8      MAPK1         0.894733          3
# 11     MAPK3         0.889384          4
# 13     MAPK8         0.884321          5
#
#  Population Size: 602
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 6       RELA         0.900029          1
# 7      CASP3         0.899322          2
# 8      MAPK1         0.894733          3
# 11     MAPK3         0.889384          4
# 13     MAPK8         0.884321          5
# full_rank_cutoff: 60
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      RELA         0.900029          1
# 1     MAPK1         0.894733          3
# 2     MAPK8         0.884321          5
# 3      FASN         0.884172          6
# 4     GSTA1         0.883631          7
#
#      Gene_Name  mantis_ml_proba  full_rank
# 160      UBA6         0.205023        583
# 161    DNASE1         0.200051        585
# 162       PAM         0.196664        589
# 163      RARS         0.154232        598
# 164      TGM3         0.152077        599
# (165, 3)
# RELA
# 1
# 0 1
# cur_pval:  1.0
# MAPK1
# 3
# 1 3
# cur_pval:  0.6182008391329347
# MAPK8
# 5
# 2 5
# cur_pval:  0.4180611737038072
# FASN
# 6
# 3 6
# cur_pval:  0.20838448288946212
# GSTA1
# 7
# 4 7
# cur_pval:  0.09369555469221603
# EPHA3
# 14
# 5 14
# cur_pval:  0.33096363876708484
# ABCB1
# 15
# 6 15
# cur_pval:  0.2037589944002787
# HMOX1
# 16
# 7 16
# cur_pval:  0.1170778057345673
# EPHA1
# 17
# 8 17
# cur_pval:  0.0633194088634582
# TP53
# 21
# 9 21
# cur_pval:  0.08932603539057725
# G6PD
# 23
# 10 23
# cur_pval:  0.06789860726842957
# ALDH1A1
# 25
# 11 25
# cur_pval:  0.05160841165922014
# HIF1A
# 26
# 12 26
# cur_pval:  0.02851431582985765
# NOS3
# 27
# 13 27
# cur_pval:  0.015136312400942388
# EP300
# 29
# 14 29
# cur_pval:  0.011397612778180681
# STAT3
# 30
# 15 30
# cur_pval:  0.0058223985486151
# EPHB4
# 36
# 16 36
# cur_pval:  0.01780003361636606
# CHUK
# 38
# 17 38
# cur_pval:  0.013539899656832152
# AHR
# 39
# 18 39
# cur_pval:  0.007443833652648343
# ALB
# 43
# 19 43
# cur_pval:  0.010617563448014929
# PLAU
# 50
# 20 50
# cur_pval:  0.03037260806052099
# CREBBP
# 52
# 21 52
# cur_pval:  0.02369754164045868
# TKT
# 59
# 22 59
# cur_pval:  0.05345859719860841
# GUSB
# 61
# 23 61
# cur_pval:  0.04271827286651039
# Max: -0.0
# Avg: 12.562460421545609
# ...
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
#
#  Population Size: 296
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
# full_rank_cutoff: 29
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      EGFR         1.000000          1
# 1       KIT         0.999504          6
# 2      FLT1         0.998710         10
# 3     HMGCR         0.998134         13
# 4       MET         0.997502         15
#
#     Gene_Name  mantis_ml_proba  full_rank
# 57      CPS1         0.233643        284
# 58      PLAT         0.218797        286
# 59       DMD         0.168216        292
# 60     NISCH         0.108979        295
# 61    TOP1MT         0.066691        296
# (62, 3)
# EGFR
# 1
# 0 1
# cur_pval:  1.0
# KIT
# 6
# 1 6
# cur_pval:  0.7592143819098328
# FLT1
# 10
# 2 10
# cur_pval:  0.6564529920631429
# HMGCR
# 13
# 3 13
# cur_pval:  0.5359541215284775
# MET
# 15
# 4 15
# cur_pval:  0.3870133492003451
# FLT4
# 16
# 5 16
# cur_pval:  0.22615218703482398
# PDGFRB
# 17
# 6 17
# cur_pval:  0.11952421668514508
# PPARG
# 26
# 7 26
# cur_pval:  0.28767928757526
# ALDH2
# 34
# 8 34
# cur_pval:  0.41994195601881995
# Max: -0.0
# Avg: 3.8573598017541904
# [-0.0, 1.1963557359851933, 1.8279636785100504, 2.7087238497101893, 4.122740546605185, 6.455992079951658, 9.225440938186095, 5.4109140545616885, 3.768107332277648]
# kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADRB2              1.0      100.000000         0.0
# 1      EGFR              1.0       99.994961         1.0
# 2    ADRA1A              1.0       99.989922         0.0
# 3     KCNH2              1.0       99.984884         0.0
# 4     HTR1A              1.0       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 1       EGFR         1.000000       99.994961         1.0
# 7        KDR         0.999971       99.964728         1.0
# 8      HTR2A         0.999896       99.959690         1.0
# 9       HRH1         0.999871       99.954651         1.0
# 12     PTGS1         0.999648       99.939534         1.0
# (296, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
#
#  Population Size: 296
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
# full_rank_cutoff: 29
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0       KIT         0.999504          6
# 1      FLT1         0.998710         10
# 2     ERBB2         0.998221         11
# 3     HMGCR         0.998134         13
# 4       MET         0.997502         15
#
#     Gene_Name  mantis_ml_proba  full_rank
# 36    DNMT3A         0.535718        249
# 37      RARB         0.482842        256
# 38        C5         0.296856        279
# 39      TOP1         0.221742        285
# 40       DMD         0.168216        292
# (41, 3)
# KIT
# 6
# 0 6
# cur_pval:  1.0
# FLT1
# 10
# 1 10
# cur_pval:  0.7804077371406957
# ERBB2
# 11
# 2 11
# cur_pval:  0.4656076400342782
# HMGCR
# 13
# 3 13
# cur_pval:  0.2626483088336013
# MET
# 15
# 4 15
# cur_pval:  0.1381873140749057
# FLT4
# 16
# 5 16
# cur_pval:  0.054294154529899705
# SCN5A
# 27
# 6 27
# cur_pval:  0.15133134280374264
# CACNA1C
# 44
# 7 44
# cur_pval:  0.408868733988201
# Max: -0.0
# Avg: 5.441937111722798
# [-0.0, 1.076784335614087, 3.3197990207486443, 5.80625391230945, 8.595318244013852, 12.652469253294473, 8.200711142967172, 3.8841609848347063]
# kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADRB2              1.0      100.000000         0.0
# 1      EGFR              1.0       99.994961         1.0
# 2    ADRA1A              1.0       99.989922         0.0
# 3     KCNH2              1.0       99.984884         0.0
# 4     HTR1A              1.0       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 1       EGFR         1.000000       99.994961         1.0
# 7        KDR         0.999971       99.964728         1.0
# 8      HTR2A         0.999896       99.959690         1.0
# 9       HRH1         0.999871       99.954651         1.0
# 12     PTGS1         0.999648       99.939534         1.0
# (296, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
#
#  Population Size: 296
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
# full_rank_cutoff: 29
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      EGFR         1.000000          1
# 1     PTGS1         0.999648          5
# 2       KIT         0.999504          6
# 3     PTGS2         0.998879          9
# 4      FLT1         0.998710         10
#
#      Gene_Name  mantis_ml_proba  full_rank
# 106      CPS1         0.233643        284
# 107      PLAT         0.218797        286
# 108     APOC3         0.179178        288
# 109       GAA         0.176921        289
# 110    TOP1MT         0.066691        296
# (111, 3)
# EGFR
# 1
# 0 1
# cur_pval:  1.0
# PTGS1
# 5
# 1 5
# cur_pval:  0.90657156486842
# KIT
# 6
# 2 6
# cur_pval:  0.7283833122976373
# PTGS2
# 9
# 3 9
# cur_pval:  0.7219050924483087
# FLT1
# 10
# 4 10
# cur_pval:  0.5549641562643193
# ERBB2
# 11
# 5 11
# cur_pval:  0.3973625731533848
# NR3C1
# 12
# 6 12
# cur_pval:  0.26718919538405406
# HMGCR
# 13
# 7 13
# cur_pval:  0.17001751902101017
# MET
# 15
# 8 15
# cur_pval:  0.1524475707725348
# FLT4
# 16
# 9 16
# cur_pval:  0.09379094831363109
# PDGFRB
# 17
# 10 17
# cur_pval:  0.055431379340521725
# PPARG
# 26
# 11 26
# cur_pval:  0.3704728204517571
# SCN5A
# 27
# 12 27
# cur_pval:  0.2802658625357832
# HCN4
# 29
# 13 29
# cur_pval:  0.2535902316186872
# Max: -0.0
# Avg: 5.001069399349658
# [-0.0, 0.4259790695657818, 1.3764001271247184, 1.4151989458449956, 2.557350659571693, 4.008130406947894, 5.731811078729838, 7.695063255502861, 8.168794916560227, 10.278390729975806, 12.562443143982655, 4.312436483076125, 5.524297977631294, 5.95867479638131]
# kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADRB2              1.0      100.000000         0.0
# 1      EGFR              1.0       99.994961         1.0
# 2    ADRA1A              1.0       99.989922         0.0
# 3     KCNH2              1.0       99.984884         0.0
# 4     HTR1A              1.0       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 1       EGFR         1.000000       99.994961         1.0
# 7        KDR         0.999971       99.964728         1.0
# 8      HTR2A         0.999896       99.959690         1.0
# 9       HRH1         0.999871       99.954651         1.0
# 12     PTGS1         0.999648       99.939534         1.0
# (296, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
#
#  Population Size: 296
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
# full_rank_cutoff: 29
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0       KDR         0.999971          2
# 1       KIT         0.999504          6
# 2      FLT1         0.998710         10
# 3       MET         0.997502         15
# 4      FLT4         0.996804         16
#
#      Gene_Name  mantis_ml_proba  full_rank
# 104     ALAS1         0.171215        290
# 105    NDUFA6         0.169666        291
# 106      SOST         0.139990        294
# 107     NISCH         0.108979        295
# 108    TOP1MT         0.066691        296
# (109, 3)
# KDR
# 2
# 0 2
# cur_pval:  1.0
# KIT
# 6
# 1 6
# cur_pval:  0.9383032820573871
# FLT1
# 10
# 2 10
# cur_pval:  0.9341409895554655
# MET
# 15
# 3 15
# cur_pval:  0.9576952143194173
# FLT4
# 16
# 4 16
# cur_pval:  0.9020517368731884
# GABRG2
# 24
# 5 24
# cur_pval:  0.9763448350294279
# CD4
# 28
# 6 28
# cur_pval:  0.979678518282417
# HCN4
# 29
# 7 29
# cur_pval:  0.9584061616552032
# Max: -0.0
# Avg: 0.19818644456545476
# [-0.0, 0.276567645685079, 0.2958757091666563, 0.1877268277929146, 0.44768552930151095, 0.10396766861494182, 0.08916414757779495, 0.18450402838474061]
# kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADRB2              1.0      100.000000         0.0
# 1      EGFR              1.0       99.994961         1.0
# 2    ADRA1A              1.0       99.989922         0.0
# 3     KCNH2              1.0       99.984884         0.0
# 4     HTR1A              1.0       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 1       EGFR         1.000000       99.994961         1.0
# 7        KDR         0.999971       99.964728         1.0
# 8      HTR2A         0.999896       99.959690         1.0
# 9       HRH1         0.999871       99.954651         1.0
# 12     PTGS1         0.999648       99.939534         1.0
# (296, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
#
#  Population Size: 296
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
# full_rank_cutoff: 29
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      EGFR         1.000000          1
# 1       KDR         0.999971          2
# 2     PTGS1         0.999648          5
# 3       KIT         0.999504          6
# 4      FLT1         0.998710         10
#
#     Gene_Name  mantis_ml_proba  full_rank
# 95        C5         0.296856        279
# 96      CPS1         0.233643        284
# 97      TOP1         0.221742        285
# 98      PLAT         0.218797        286
# 99       DMD         0.168216        292
# (100, 3)
# EGFR
# 1
# 0 1
# cur_pval:  1.0
# KDR
# 2
# 1 2
# cur_pval:  0.562299587723369
# PTGS1
# 5
# 2 5
# cur_pval:  0.5491373214109797
# KIT
# 6
# 3 6
# cur_pval:  0.3274808588426018
# FLT1
# 10
# 4 10
# cur_pval:  0.45322099675330524
# ERBB2
# 11
# 5 11
# cur_pval:  0.29760671902301045
# NR3C1
# 12
# 6 12
# cur_pval:  0.1822883489998588
# HMGCR
# 13
# 7 13
# cur_pval:  0.10513873525196082
# MET
# 15
# 8 15
# cur_pval:  0.08893770581272664
# FLT4
# 16
# 9 16
# cur_pval:  0.04935175518250985
# PDGFRB
# 17
# 10 17
# cur_pval:  0.026228533227089866
# JAK2
# 21
# 11 21
# cur_pval:  0.0542608045100317
# PPARG
# 26
# 12 26
# cur_pval:  0.12023749215893297
# SCN5A
# 27
# 13 27
# cur_pval:  0.07678560344473187
# PIK3CG
# 33
# 14 33
# cur_pval:  0.1785956752509159
# Max: -0.0
# Avg: 7.713234354858357
# [-0.0, 2.500322349140926, 2.6031903902229585, 4.848140793118127, 3.436899784139614, 5.263572680129971, 7.392410884858406, 9.782372515557341, 10.509140775599406, 13.066973971478662, 15.812259956922416, 12.655137713617945, 9.19960090578959, 11.147201983356975, 7.481290618943]
# kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADRB2              1.0      100.000000         0.0
# 1      EGFR              1.0       99.994961         1.0
# 2    ADRA1A              1.0       99.989922         0.0
# 3     KCNH2              1.0       99.984884         0.0
# 4     HTR1A              1.0       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 1       EGFR         1.000000       99.994961         1.0
# 7        KDR         0.999971       99.964728         1.0
# 8      HTR2A         0.999896       99.959690         1.0
# 9       HRH1         0.999871       99.954651         1.0
# 12     PTGS1         0.999648       99.939534         1.0
# (296, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
#
#  Population Size: 296
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 1       EGFR         1.000000          1
# 7        KDR         0.999971          2
# 8      HTR2A         0.999896          3
# 9       HRH1         0.999871          4
# 12     PTGS1         0.999648          5
# full_rank_cutoff: 29
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      EGFR         1.000000          1
# 1       KDR         0.999971          2
# 2     PTGS1         0.999648          5
# 3       KIT         0.999504          6
# 4     PTGS2         0.998879          9
#
#      Gene_Name  mantis_ml_proba  full_rank
# 127      PLAT         0.218797        286
# 128     APOC3         0.179178        288
# 129     ALAS1         0.171215        290
# 130       DMD         0.168216        292
# 131      SOST         0.139990        294
# (132, 3)
# EGFR
# 1
# 0 1
# cur_pval:  1.0
# KDR
# 2
# 1 2
# cur_pval:  0.6938616582684585
# PTGS1
# 5
# 2 5
# cur_pval:  0.7396997014878653
# KIT
# 6
# 3 6
# cur_pval:  0.5510687081983957
# PTGS2
# 9
# 4 9
# cur_pval:  0.6314823939787791
# FLT1
# 10
# 5 10
# cur_pval:  0.4851085287503012
# NR3C1
# 12
# 6 12
# cur_pval:  0.46112651207936006
# HMGCR
# 13
# 7 13
# cur_pval:  0.3420279517661483
# MET
# 15
# 8 15
# cur_pval:  0.33085322781526566
# FLT4
# 16
# 9 16
# cur_pval:  0.2393952828906842
# PDGFRB
# 17
# 10 17
# cur_pval:  0.16739029768025845
# JAK2
# 21
# 11 21
# cur_pval:  0.3012208292253584
# PPARG
# 26
# 12 26
# cur_pval:  0.513053756000289
# SCN5A
# 27
# 13 27
# cur_pval:  0.4238762969943453
# CD4
# 28
# 14 28
# cur_pval:  0.3412526289418554
# PIK3CG
# 33
# 15 33
# cur_pval:  0.5298588222004476
# Max: -0.0
# Avg: 3.5427372765941296
# [-0.0, 1.5872711029397761, 1.3094455656130555, 2.5879424918610687, 1.996387532708884, 3.1416108992427034, 3.361799076683213, 4.659384003714954, 4.80364624008083, 6.2088441130107626, 7.762697183023752, 5.211150002506693, 2.8983712862853688, 3.7276086833948288, 4.669239942206581, 2.758398302233596]
# external_top_dataset:  SVC_vs_Horseshoe_kidney
# external_top_dataset:  SVC_vs_Chronic_kidney_disease
# external_top_dataset:  SVC_vs_Ectopic_kidney
# external_top_dataset:  SVC_vs_Renal_tubular_dysfunction
# external_top_dataset:  SVC_vs_Stage_5_chronic_kidney_disease
# external_top_dataset:  SVC_vs_Polycystic_kidney_dysplasia
# external_top_dataset:  SVC_vs_Renal_insufficiency
# external_top_dataset:  SVC_vs_Abnormality_of_renal_excretion
# external_top_dataset:  SVC_vs_Abnormality_of_the_kidney
# external_top_dataset:  SVC_vs_Abnormality_of_renal_glomerulus_morphology
# kidney_drugnomefull\clin\SVC-hits.intersection.txt
# []

# %%
run_hypergeom_test(disease='Hypertension', folder='hypertension_drugnomefull', top=0.20)
# Out:
# (838,)
# external_top_ranking:  0       PDGFRA
# 1099       CBL
# 275       BMP4
# 2588      FRS2
# 1160     KNTC1
# Name: Gene_Name, dtype: object
# (4840,)
# external_top_ranking:  0        PDGFRA
# 401       ITGA5
# 704      NOTCH2
# 232       STAT3
# 256    SERPINH1
# Name: Gene_Name, dtype: object
# (3604,)
# external_top_ranking:  0       PDGFRA
# 458        TEK
# 6873     PHTF1
# 1         TBX5
# 5237     CEBPE
# Name: Gene_Name, dtype: object
# (3088,)
# external_top_ranking:  0      PDGFRA
# 458       TEK
# 236    TGFBR2
# 615       RET
# 172      IL6R
# Name: Gene_Name, dtype: object
# (3406,)
# external_top_ranking:  0       PDGFRA
# 363      FGFR2
# 2846     HAND1
# 4343     PEX13
# 237      ADCY3
# Name: Gene_Name, dtype: object
# (2764,)
# external_top_ranking:  0       PDGFRA
# 296        ERG
# 1058       NBN
# 1161     PROCR
# 598       LRP6
# Name: Gene_Name, dtype: object
# (4940,)
# external_top_ranking:  0       PDGFRA
# 583      IL2RA
# 304      GATA3
# 1568    MAP2K5
# 8       PTPN11
# Name: Gene_Name, dtype: object
# (7183,)
# external_top_ranking:  0        PDGFRA
# 128        RAF1
# 690        TP53
# 2467       PYGM
# 2117    CCDC88A
# Name: Gene_Name, dtype: object
# (4214,)
# external_top_ranking:  0       PDGFRA
# 233       LRP5
# 1465      IGF2
# 2925     HNF1A
# 1861     ITPR2
# Name: Gene_Name, dtype: object
# (3881,)
# external_top_ranking:  0        PDGFRA
# 9385      ADH1A
# 418      PLXND1
# 209       LAMC1
# 11103      AIF1
# Name: Gene_Name, dtype: object
# ['hypertension_drugnomefull/chem\\ExtraTreesClassifier.mantis-ml_predictions.csv', 'hypertension_drugnomefull/chem\\GradientBoostingClassifier.mantis-ml_predictions.csv', 'hypertension_drugnomefull/chem\\RandomForestClassifier.mantis-ml_predictions.csv', 'hypertension_drugnomefull/chem\\SVC.mantis-ml_predictions.csv']
# hypertension_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP1A2         0.940097      100.000000         0.0
# 1     PTGS2         0.933275       99.994961         0.0
# 2     HMOX1         0.920474       99.989922         1.0
# 3    CYP3A4         0.913943       99.984884         0.0
# 4       TNF         0.909227       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 2      HMOX1         0.920474       99.989922         1.0
# 7       NOS3         0.904800       99.964728         1.0
# 10    CYP2C9         0.896208       99.949612         1.0
# 14     GSTA1         0.888468       99.929457         1.0
# 17    CYP1A1         0.886356       99.914340         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.904800          2
# 1    CYP2C9         0.896208          3
# 2    CYP1A1         0.886356          5
# 3      NOS2         0.883855          6
# 4     HIF1A         0.870731         13
#
#     Gene_Name  mantis_ml_proba  full_rank
# 29     ERAP1         0.582289        146
# 30    ACVR2A         0.559654        153
# 31     ESRRG         0.530469        163
# 32      TGM2         0.487093        170
# 33     NR4A2         0.446803        179
# (34, 3)
# NOS3
# 2
# 0 2
# cur_pval:  1.0
# CYP2C9
# 3
# 1 3
# cur_pval:  0.4282194554863173
# CYP1A1
# 5
# 2 5
# cur_pval:  0.1994544660570911
# NOS2
# 6
# 3 6
# cur_pval:  0.0618354047890851
# HIF1A
# 13
# 4 13
# cur_pval:  0.15788262561641356
# ALB
# 15
# 5 15
# cur_pval:  0.08633027773915142
# MMP2
# 21
# 6 21
# cur_pval:  0.11821565399910781
# NOS1
# 25
# 7 25
# cur_pval:  0.10150747017151517
# TP53
# 31
# 8 31
# cur_pval:  0.12192490360927802
# APOB
# 38
# 9 38
# cur_pval:  0.15922304793470854
# AHR
# 48
# 10 48
# cur_pval:  0.2660743106779497
# Max: -0.0
# Avg: 7.591346236668334
# [-0.0, 3.683336050976185, 7.001562348004419, 12.08762791872632, 8.016656598212503, 10.638368618875585, 9.2732501080425, 9.93501995830681, 9.139075790784114, 7.979940668347093, 5.7499705430761505]
# hypertension_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP1A2         0.940097      100.000000         0.0
# 1     PTGS2         0.933275       99.994961         0.0
# 2     HMOX1         0.920474       99.989922         1.0
# 3    CYP3A4         0.913943       99.984884         0.0
# 4       TNF         0.909227       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 2      HMOX1         0.920474       99.989922         1.0
# 7       NOS3         0.904800       99.964728         1.0
# 10    CYP2C9         0.896208       99.949612         1.0
# 14     GSTA1         0.888468       99.929457         1.0
# 17    CYP1A1         0.886356       99.914340         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.920474          1
# 1      NOS3         0.904800          2
# 2      NOS2         0.883855          6
# 3      MMP9         0.871722         10
# 4     HIF1A         0.870731         13
#
#     Gene_Name  mantis_ml_proba  full_rank
# 88     ORAI1         0.399601        185
# 89      SHBG         0.376822        190
# 90   EIF2AK4         0.368753        191
# 91      BRD4         0.339167        193
# 92     FCGRT         0.186529        198
# (93, 3)
# HMOX1
# 1
# 0 1
# cur_pval:  1.0
# NOS3
# 2
# 1 2
# cur_pval:  0.7125373134327584
# NOS2
# 6
# 2 6
# cur_pval:  0.8554324307049246
# MMP9
# 10
# 3 10
# cur_pval:  0.9192240766523744
# HIF1A
# 13
# 4 13
# cur_pval:  0.9281968067512728
# TGFB1
# 14
# 5 14
# cur_pval:  0.8645139403217639
# ICAM1
# 16
# 6 16
# cur_pval:  0.8398756907396496
# GSTP1
# 18
# 7 18
# cur_pval:  0.8169670619336652
# MMP2
# 21
# 8 21
# cur_pval:  0.8473582223889824
# RELA
# 22
# 9 22
# cur_pval:  0.7756902687181083
# CCL2
# 24
# 10 24
# cur_pval:  0.7569958890160836
# NOS1
# 25
# 11 25
# cur_pval:  0.6747913149503569
# SLC2A3
# 26
# 12 26
# cur_pval:  0.5866846562798018
# CASP3
# 27
# 13 27
# cur_pval:  0.49723541995338294
# F7
# 28
# 14 28
# cur_pval:  0.41075200711247095
# JUN
# 29
# 15 29
# cur_pval:  0.3307673478376373
# TP53
# 31
# 16 31
# cur_pval:  0.3245370726302959
# SGK1
# 33
# 17 33
# cur_pval:  0.3184414108351915
# APOB
# 38
# 18 38
# cur_pval:  0.5106831407311829
# AKT1
# 40
# 19 40
# cur_pval:  0.49998112881077156
# Max: -0.0
# Avg: 1.9826335801702288
# [-0.0, 1.4719238803013788, 0.6781428902285052, 0.36578608971284143, 0.32359930005210197, 0.6322799931775603, 0.7578498872489665, 0.8779545278070222, 0.7193295198619691, 1.103116568844689, 1.2090647899725613, 1.708305157293384, 2.3159526985449133, 3.0343794249538285, 3.8642030573650143, 4.80477368992057, 4.887356855534834, 4.969704606335149, 2.9184847934491853, 3.0104638728001016]
# hypertension_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP1A2         0.940097      100.000000         0.0
# 1     PTGS2         0.933275       99.994961         0.0
# 2     HMOX1         0.920474       99.989922         1.0
# 3    CYP3A4         0.913943       99.984884         0.0
# 4       TNF         0.909227       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 2      HMOX1         0.920474       99.989922         1.0
# 7       NOS3         0.904800       99.964728         1.0
# 10    CYP2C9         0.896208       99.949612         1.0
# 14     GSTA1         0.888468       99.929457         1.0
# 17    CYP1A1         0.886356       99.914340         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0    CYP2C9         0.896208          3
# 1    CYP1A1         0.886356          5
# 2      NOS2         0.883855          6
# 3    CYP4F2         0.874341          9
# 4   CYP11B2         0.871693         11
#
#     Gene_Name  mantis_ml_proba  full_rank
# 72    ADAM12         0.365333        192
# 73      BRD4         0.339167        193
# 74    STK32B         0.337428        194
# 75     KDM4A         0.293133        196
# 76      FUT6         0.170794        199
# (77, 3)
# CYP2C9
# 3
# 0 3
# cur_pval:  1.0
# CYP1A1
# 5
# 1 5
# cur_pval:  0.913414992735258
# NOS2
# 6
# 2 6
# cur_pval:  0.7433372998936697
# CYP4F2
# 9
# 3 9
# cur_pval:  0.7405914354356804
# CYP11B2
# 11
# 4 11
# cur_pval:  0.6677449662248434
# TGFB1
# 14
# 5 14
# cur_pval:  0.6823822466025451
# ALB
# 15
# 6 15
# cur_pval:  0.5464262358162248
# ICAM1
# 16
# 7 16
# cur_pval:  0.4148559027971762
# CCL2
# 24
# 8 24
# cur_pval:  0.7736791283188231
# NOS1
# 25
# 9 25
# cur_pval:  0.6780184051016734
# F7
# 28
# 10 28
# cur_pval:  0.6928596329565371
# NPPA
# 36
# 11 36
# cur_pval:  0.8947034942178004
# AKT1
# 40
# 12 40
# cur_pval:  0.9192027668952105
# Max: -0.0
# Avg: 1.391509241494212
# [-0.0, 0.39331864188670984, 1.2881407420423265, 1.3042131465294289, 1.7538937721001706, 1.65972280643063, 2.6246845684358844, 3.8210272614874876, 1.1143911902482062, 1.6875851686213315, 1.5935474057871877, 0.4832086653895492, 0.3658867704658435]
# hypertension_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP1A2         0.940097      100.000000         0.0
# 1     PTGS2         0.933275       99.994961         0.0
# 2     HMOX1         0.920474       99.989922         1.0
# 3    CYP3A4         0.913943       99.984884         0.0
# 4       TNF         0.909227       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 2      HMOX1         0.920474       99.989922         1.0
# 7       NOS3         0.904800       99.964728         1.0
# 10    CYP2C9         0.896208       99.949612         1.0
# 14     GSTA1         0.888468       99.929457         1.0
# 17    CYP1A1         0.886356       99.914340         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.904800          2
# 1      NOS2         0.883855          6
# 2      MMP9         0.871722         10
# 3     ABCB1         0.871198         12
# 4     HIF1A         0.870731         13
#
#     Gene_Name  mantis_ml_proba  full_rank
# 73   EIF2AK4         0.368753        191
# 74    ADAM12         0.365333        192
# 75      BRD4         0.339167        193
# 76     FCGRT         0.186529        198
# 77     RIPK4         0.152201        200
# (78, 3)
# NOS3
# 2
# 0 2
# cur_pval:  1.0
# NOS2
# 6
# 1 6
# cur_pval:  0.9499742152726686
# MMP9
# 10
# 2 10
# cur_pval:  0.9502058594269405
# ABCB1
# 12
# 3 12
# cur_pval:  0.909922978847584
# HIF1A
# 13
# 4 13
# cur_pval:  0.8169582082072938
# TGFB1
# 14
# 5 14
# cur_pval:  0.6964254271245512
# ICAM1
# 16
# 6 16
# cur_pval:  0.6414964119332559
# DBH
# 17
# 7 17
# cur_pval:  0.5134315622419826
# SLC2A2
# 19
# 8 19
# cur_pval:  0.4689951422267404
# RELA
# 22
# 9 22
# cur_pval:  0.5013658990534793
# CCL2
# 24
# 10 24
# cur_pval:  0.46181031293214925
# NOS1
# 25
# 11 25
# cur_pval:  0.3592921902012561
# SLC2A3
# 26
# 12 26
# cur_pval:  0.2692711113570265
# CASP3
# 27
# 13 27
# cur_pval:  0.19459648309674324
# F7
# 28
# 14 28
# cur_pval:  0.13576792979881097
# TP53
# 31
# 15 31
# cur_pval:  0.16102204630336636
# APOB
# 38
# 16 38
# cur_pval:  0.38735135418055094
# AKT1
# 40
# 17 40
# cur_pval:  0.3589874254105334
# Max: -0.0
# Avg: 3.344049138312324
# [-0.0, 0.2228818241301481, 0.22182295839628138, 0.409953673241143, 0.8780015939070168, 1.5712538077945024, 1.9280576841133732, 2.8951743740550766, 3.288316556112428, 2.9984520838447226, 3.355363728490839, 4.4455222278800735, 5.698102371982737, 7.1086501291391375, 8.672028041075047, 7.931146585494111, 4.118949214008516, 4.449207635956683]
# hypertension_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP1A2         0.940097      100.000000         0.0
# 1     PTGS2         0.933275       99.994961         0.0
# 2     HMOX1         0.920474       99.989922         1.0
# 3    CYP3A4         0.913943       99.984884         0.0
# 4       TNF         0.909227       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 2      HMOX1         0.920474       99.989922         1.0
# 7       NOS3         0.904800       99.964728         1.0
# 10    CYP2C9         0.896208       99.949612         1.0
# 14     GSTA1         0.888468       99.929457         1.0
# 17    CYP1A1         0.886356       99.914340         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.920474          1
# 1      NOS3         0.904800          2
# 2    CYP1A1         0.886356          5
# 3      NOS2         0.883855          6
# 4      MMP9         0.871722         10
#
#      Gene_Name  mantis_ml_proba  full_rank
# 97     IGFBP5         0.438828        181
# 98     PDE11A         0.379077        188
# 99    EIF2AK4         0.368753        191
# 100    ADAM12         0.365333        192
# 101     KDM4A         0.293133        196
# (102, 3)
# HMOX1
# 1
# 0 1
# cur_pval:  1.0
# NOS3
# 2
# 1 2
# cur_pval:  0.7586567164178287
# CYP1A1
# 5
# 2 5
# cur_pval:  0.8248343010606041
# NOS2
# 6
# 3 6
# cur_pval:  0.6726537452776151
# MMP9
# 10
# 4 10
# cur_pval:  0.8463542570884767
# CYP11B2
# 11
# 5 11
# cur_pval:  0.7482201858918357
# ABCB1
# 12
# 6 12
# cur_pval:  0.6368638398390809
# HIF1A
# 13
# 7 13
# cur_pval:  0.5225615587055523
# TGFB1
# 14
# 8 14
# cur_pval:  0.4141654744695443
# ICAM1
# 16
# 9 16
# cur_pval:  0.4221591480957638
# DBH
# 17
# 10 17
# cur_pval:  0.3298944974195687
# SLC2A2
# 19
# 11 19
# cur_pval:  0.34029153325133593
# ACE2
# 20
# 12 20
# cur_pval:  0.26284543111843534
# MMP2
# 21
# 13 21
# cur_pval:  0.1979504468266829
# RELA
# 22
# 14 22
# cur_pval:  0.14553526720636217
# CTH
# 23
# 15 23
# cur_pval:  0.10458198640167601
# CCL2
# 24
# 16 24
# cur_pval:  0.07353725218868384
# NOS1
# 25
# 17 25
# cur_pval:  0.05064833798080061
# SLC2A3
# 26
# 18 26
# cur_pval:  0.03420075591297622
# CASP3
# 27
# 19 27
# cur_pval:  0.022661341192378524
# JUN
# 29
# 20 29
# cur_pval:  0.026561037024544275
# BHMT
# 30
# 21 30
# cur_pval:  0.017595969626867488
# TP53
# 31
# 22 31
# cur_pval:  0.011454486530716887
# NOX1
# 34
# 23 34
# cur_pval:  0.02350381951361265
# MAPK8
# 35
# 24 35
# cur_pval:  0.01577130233144104
# NPPA
# 36
# 25 36
# cur_pval:  0.010404733554153354
# APOB
# 38
# 26 38
# cur_pval:  0.01204012101862061
# AKT1
# 40
# 27 40
# cur_pval:  0.0137208899946319
# Max: -0.0
# Avg: 9.23828376089112
# [-0.0, 1.1995469299816965, 0.8363328704122801, 1.72208435348794, 0.7244781699000611, 1.2597057934660802, 1.9595340899496771, 2.8186254152048744, 3.828261074520234, 3.745237952230167, 4.816249283474953, 4.681488563933717, 5.802995676556276, 7.0344351359278825, 8.37031752401936, 9.805431135572917, 11.334926021199621, 12.954348013917553, 14.659642949612222, 16.447143903591062, 15.757549727812389, 17.54586796348234, 19.41024374119659, 16.288615564986383, 18.02132442878738, 19.827690367827287, 19.193691478410678, 18.62617717548973]
# hypertension_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP1A2         0.940097      100.000000         0.0
# 1     PTGS2         0.933275       99.994961         0.0
# 2     HMOX1         0.920474       99.989922         1.0
# 3    CYP3A4         0.913943       99.984884         0.0
# 4       TNF         0.909227       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 2      HMOX1         0.920474       99.989922         1.0
# 7       NOS3         0.904800       99.964728         1.0
# 10    CYP2C9         0.896208       99.949612         1.0
# 14     GSTA1         0.888468       99.929457         1.0
# 17    CYP1A1         0.886356       99.914340         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.920474          1
# 1      NOS3         0.904800          2
# 2    CYP2C9         0.896208          3
# 3    CYP1A1         0.886356          5
# 4      NOS2         0.883855          6
#
#     Gene_Name  mantis_ml_proba  full_rank
# 82   SLC14A1         0.429218        182
# 83    MAP4K4         0.407360        184
# 84   EIF2AK4         0.368753        191
# 85    ADAM12         0.365333        192
# 86      BRD4         0.339167        193
# (87, 3)
# HMOX1
# 1
# 0 1
# cur_pval:  1.0
# NOS3
# 2
# 1 2
# cur_pval:  0.6795522388058969
# CYP2C9
# 3
# 2 3
# cur_pval:  0.39936173404328634
# CYP1A1
# 5
# 3 5
# cur_pval:  0.3743424157823757
# NOS2
# 6
# 4 6
# cur_pval:  0.2243147577799387
# CYP4F2
# 9
# 5 9
# cur_pval:  0.33546380416163046
# MMP9
# 10
# 6 10
# cur_pval:  0.22066957971471868
# CYP11B2
# 11
# 7 11
# cur_pval:  0.13853060585219043
# ABCB1
# 12
# 8 12
# cur_pval:  0.08350366922697136
# HIF1A
# 13
# 9 13
# cur_pval:  0.048565931687148726
# TGFB1
# 14
# 10 14
# cur_pval:  0.027359633546846167
# ALB
# 15
# 11 15
# cur_pval:  0.01497606265422125
# ICAM1
# 16
# 12 16
# cur_pval:  0.007985337150319403
# DBH
# 17
# 13 17
# cur_pval:  0.004156183000433468
# SLC2A2
# 19
# 14 19
# cur_pval:  0.005086362621319906
# ACE2
# 20
# 15 20
# cur_pval:  0.002671370793294031
# MMP2
# 21
# 16 21
# cur_pval:  0.001372701154651049
# RELA
# 22
# 17 22
# cur_pval:  0.00069089959436313
# CTH
# 23
# 18 23
# cur_pval:  0.00034092455750165063
# NOS1
# 25
# 19 25
# cur_pval:  0.0004392876931395041
# CASP3
# 27
# 20 27
# cur_pval:  0.0005374325370277187
# F7
# 28
# 21 28
# cur_pval:  0.00027214416323210377
# JUN
# 29
# 22 29
# cur_pval:  0.00013515517637810467
# BHMT
# 30
# 23 30
# cur_pval:  6.586423535311393e-05
# TP53
# 31
# 24 31
# cur_pval:  3.1509459101218894e-05
# NPPA
# 36
# 25 36
# cur_pval:  0.0004661275125569523
# TRPC3
# 39
# 26 39
# cur_pval:  0.0009733915128279129
# AKT1
# 40
# 27 40
# cur_pval:  0.000533204366607546
# Max: -0.0
# Avg: 21.645551719279776
# [-0.0, 1.6777715239268343, 3.9863355060703705, 4.2673096129974555, 6.49142153026239, 4.743543324276269, 6.562575321424516, 8.584542664240608, 10.78294440803637, 13.13668275357996, 15.628897238250353, 18.246023516771746, 20.977067427149557, 23.81305338321618, 22.935926809624405, 25.732658265780014, 28.62424001009903, 31.605850622964304, 34.673417145137634, 33.572509635374814, 32.696760442224615, 35.65200975707637, 38.69167316377416, 41.813503457263785, 45.01559051963167, 33.31495262656265, 30.117124447661034, 32.73106302645657]
# hypertension_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP1A2         0.940097      100.000000         0.0
# 1     PTGS2         0.933275       99.994961         0.0
# 2     HMOX1         0.920474       99.989922         1.0
# 3    CYP3A4         0.913943       99.984884         0.0
# 4       TNF         0.909227       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 2      HMOX1         0.920474       99.989922         1.0
# 7       NOS3         0.904800       99.964728         1.0
# 10    CYP2C9         0.896208       99.949612         1.0
# 14     GSTA1         0.888468       99.929457         1.0
# 17    CYP1A1         0.886356       99.914340         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.920474          1
# 1      NOS3         0.904800          2
# 2    CYP1A1         0.886356          5
# 3      NOS2         0.883855          6
# 4   CYP11B2         0.871693         11
#
#      Gene_Name  mantis_ml_proba  full_rank
# 97    EIF2AK4         0.368753        191
# 98     ADAM12         0.365333        192
# 99       BRD4         0.339167        193
# 100     FCGRT         0.186529        198
# 101     RIPK4         0.152201        200
# (102, 3)
# HMOX1
# 1
# 0 1
# cur_pval:  1.0
# NOS3
# 2
# 1 2
# cur_pval:  0.7586567164178287
# CYP1A1
# 5
# 2 5
# cur_pval:  0.8248343010606041
# NOS2
# 6
# 3 6
# cur_pval:  0.6726537452776151
# CYP11B2
# 11
# 4 11
# cur_pval:  0.902430869201019
# ABCB1
# 12
# 5 12
# cur_pval:  0.8277604330723393
# HIF1A
# 13
# 6 13
# cur_pval:  0.7348372236677404
# TGFB1
# 14
# 7 14
# cur_pval:  0.6309576429415663
# ALB
# 15
# 8 15
# cur_pval:  0.5243005333190068
# ICAM1
# 16
# 9 16
# cur_pval:  0.4221591480957638
# DBH
# 17
# 10 17
# cur_pval:  0.3298944974195687
# SLC2A2
# 19
# 11 19
# cur_pval:  0.34029153325133593
# MMP2
# 21
# 12 21
# cur_pval:  0.34937207684088606
# RELA
# 22
# 13 22
# cur_pval:  0.2736612618337479
# CCL2
# 24
# 14 24
# cur_pval:  0.28332439550673655
# NOS1
# 25
# 15 25
# cur_pval:  0.21946504238755712
# SLC2A3
# 26
# 16 26
# cur_pval:  0.16624891478826875
# CASP3
# 27
# 17 27
# cur_pval:  0.12325788599200337
# F7
# 28
# 18 28
# cur_pval:  0.08951036440139902
# JUN
# 29
# 19 29
# cur_pval:  0.06371746093780252
# MAPK8
# 35
# 20 35
# cur_pval:  0.2591822494504525
# APOB
# 38
# 21 38
# cur_pval:  0.3309492150824451
# TRPC3
# 39
# 22 39
# cur_pval:  0.271338566234575
# AKT1
# 40
# 23 40
# cur_pval:  0.21850185475576542
# Max: -0.0
# Avg: 4.538672629876001
# [-0.0, 1.1995469299816965, 0.8363328704122801, 1.72208435348794, 0.44586057316442684, 0.820953367043245, 1.3380885233351514, 1.9999979456599108, 2.804197005212873, 3.745237952230167, 4.816249283474953, 4.681488563933717, 4.567118084501708, 5.627866748680352, 5.477160291582979, 6.586346467532897, 7.792411809301499, 9.091852851683877, 10.481266748323701, 11.957415386253302, 5.863947451999559, 4.802386445977357, 5.6648847416134895, 6.605448721636948]
# hypertension_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP1A2         0.940097      100.000000         0.0
# 1     PTGS2         0.933275       99.994961         0.0
# 2     HMOX1         0.920474       99.989922         1.0
# 3    CYP3A4         0.913943       99.984884         0.0
# 4       TNF         0.909227       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 2      HMOX1         0.920474       99.989922         1.0
# 7       NOS3         0.904800       99.964728         1.0
# 10    CYP2C9         0.896208       99.949612         1.0
# 14     GSTA1         0.888468       99.929457         1.0
# 17    CYP1A1         0.886356       99.914340         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.920474          1
# 1    CYP2C9         0.896208          3
# 2    CYP1A1         0.886356          5
# 3    CYP2B6         0.879834          7
# 4    CYP1B1         0.877216          8
#
#      Gene_Name  mantis_ml_proba  full_rank
# 124    ADAM12         0.365333        192
# 125      BRD4         0.339167        193
# 126     GPR83         0.286131        197
# 127     FCGRT         0.186529        198
# 128     RIPK4         0.152201        200
# (129, 3)
# HMOX1
# 1
# 0 1
# cur_pval:  1.0
# CYP2C9
# 3
# 1 3
# cur_pval:  0.9552688817218893
# CYP1A1
# 5
# 2 5
# cur_pval:  0.9435820943978048
# CYP2B6
# 7
# 3 7
# cur_pval:  0.9420437664119353
# CYP1B1
# 8
# 4 8
# cur_pval:  0.8887820233388082
# CYP4F2
# 9
# 5 9
# cur_pval:  0.8192381930050091
# MMP9
# 10
# 6 10
# cur_pval:  0.7377415168327679
# CYP11B2
# 11
# 7 11
# cur_pval:  0.6495601220216681
# ABCB1
# 12
# 8 12
# cur_pval:  0.5598537857964284
# HIF1A
# 13
# 9 13
# cur_pval:  0.4729952697687999
# TGFB1
# 14
# 10 14
# cur_pval:  0.3922455973625369
# ALB
# 15
# 11 15
# cur_pval:  0.3197004371259142
# ICAM1
# 16
# 12 16
# cur_pval:  0.256409571523571
# DBH
# 17
# 13 17
# cur_pval:  0.2025838263626201
# ACE2
# 20
# 14 20
# cur_pval:  0.3790247374670729
# MMP2
# 21
# 15 21
# cur_pval:  0.317002683449418
# RELA
# 22
# 16 22
# cur_pval:  0.261527401800195
# CTH
# 23
# 17 23
# cur_pval:  0.21294779063533362
# CCL2
# 24
# 18 24
# cur_pval:  0.17122326670357918
# SLC2A3
# 26
# 19 26
# cur_pval:  0.21531225175864901
# CASP3
# 27
# 20 27
# cur_pval:  0.17501065830738835
# F7
# 28
# 21 28
# cur_pval:  0.14061533286187772
# JUN
# 29
# 22 29
# cur_pval:  0.1117206085955141
# BHMT
# 30
# 23 30
# cur_pval:  0.0878045736054853
# TP53
# 31
# 24 31
# cur_pval:  0.06828500271355958
# ARG2
# 32
# 25 32
# cur_pval:  0.05256409341186452
# SGK1
# 33
# 26 33
# cur_pval:  0.040061784476082996
# NOX1
# 34
# 27 34
# cur_pval:  0.03023854174082745
# MAPK8
# 35
# 28 35
# cur_pval:  0.022609134763924316
# NPPA
# 36
# 29 36
# cur_pval:  0.01674919868226318
# TRPC6
# 37
# 30 37
# cur_pval:  0.012296382048423258
# TRPC3
# 39
# 31 39
# cur_pval:  0.018608508924780404
# FABP4
# 41
# 32 41
# cur_pval:  0.02679664148575648
# Max: -0.0
# Avg: 7.428021202375599
# [-0.0, 0.1987436934582679, 0.25220308967038174, 0.25928919850801624, 0.5120473809476831, 0.8658980902367379, 1.3209577567944288, 1.873806452778848, 2.5192538069568577, 3.2514320244100547, 4.06441922315625, 4.9525676991773135, 5.9106576705383045, 6.933952302583174, 4.213324443990774, 4.989370614341663, 5.824828007655168, 6.717268614360208, 7.664372214672027, 6.6693125712594545, 7.569355015815232, 8.519673207511826, 9.518667071551215, 10.564828617716612, 11.656746689968928, 12.7931082158826, 13.972697097889355, 15.194391565961755, 16.45716057488488, 17.760059657134608, 19.102226517750303, 17.30288424917786, 15.719196341653976]
# hypertension_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP1A2         0.940097      100.000000         0.0
# 1     PTGS2         0.933275       99.994961         0.0
# 2     HMOX1         0.920474       99.989922         1.0
# 3    CYP3A4         0.913943       99.984884         0.0
# 4       TNF         0.909227       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 2      HMOX1         0.920474       99.989922         1.0
# 7       NOS3         0.904800       99.964728         1.0
# 10    CYP2C9         0.896208       99.949612         1.0
# 14     GSTA1         0.888468       99.929457         1.0
# 17    CYP1A1         0.886356       99.914340         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     HMOX1         0.920474          1
# 1      NOS3         0.904800          2
# 2    CYP2C9         0.896208          3
# 3    CYP1A1         0.886356          5
# 4    CYP1B1         0.877216          8
#
#      Gene_Name  mantis_ml_proba  full_rank
# 106      SHBG         0.376822        190
# 107   EIF2AK4         0.368753        191
# 108    ADAM12         0.365333        192
# 109      BRD4         0.339167        193
# 110     FCGRT         0.186529        198
# (111, 3)
# HMOX1
# 1
# 0 1
# cur_pval:  1.0
# NOS3
# 2
# 1 2
# cur_pval:  0.8007462686566287
# CYP2C9
# 3
# 2 3
# cur_pval:  0.5784632115801953
# CYP1A1
# 5
# 3 5
# cur_pval:  0.5982091684271997
# CYP1B1
# 8
# 4 8
# cur_pval:  0.7480693843828384
# CYP4F2
# 9
# 5 9
# cur_pval:  0.6292365155412157
# MMP9
# 10
# 6 10
# cur_pval:  0.5100322939845909
# CYP11B2
# 11
# 7 11
# cur_pval:  0.3997735899270101
# ABCB1
# 12
# 8 12
# cur_pval:  0.3040226100874665
# HIF1A
# 13
# 9 13
# cur_pval:  0.22499005529926489
# TGFB1
# 14
# 10 14
# cur_pval:  0.16244597086582827
# ALB
# 15
# 11 15
# cur_pval:  0.11468503366212131
# ICAM1
# 16
# 12 16
# cur_pval:  0.07931953030746539
# DBH
# 17
# 13 17
# cur_pval:  0.05383087924103579
# GSTP1
# 18
# 14 18
# cur_pval:  0.0358971836955609
# MMP2
# 21
# 15 21
# cur_pval:  0.08770350232658054
# RELA
# 22
# 16 22
# cur_pval:  0.062127827379219645
# CTH
# 23
# 17 23
# cur_pval:  0.043267553116368734
# CCL2
# 24
# 18 24
# cur_pval:  0.029649014033641962
# NOS1
# 25
# 19 25
# cur_pval:  0.02000575472082625
# CASP3
# 27
# 20 27
# cur_pval:  0.0263930251075074
# F7
# 28
# 21 28
# cur_pval:  0.017962235859064545
# JUN
# 29
# 22 29
# cur_pval:  0.012049312378460998
# TP53
# 31
# 23 31
# cur_pval:  0.015930963735641096
# SGK1
# 33
# 24 33
# cur_pval:  0.020337081956815842
# NPPA
# 36
# 25 36
# cur_pval:  0.04248784220165289
# TRPC6
# 37
# 26 37
# cur_pval:  0.030593455365001198
# APOB
# 38
# 27 38
# cur_pval:  0.02171729708305961
# FABP4
# 41
# 28 41
# cur_pval:  0.042545628672247586
# Max: -0.0
# Avg: 10.273077495432581
# [-0.0, 0.9650507639890413, 2.377242555812926, 2.231469350579153, 1.260581189041148, 2.011860825555871, 2.924023245779855, 3.9818589988228004, 5.170941168153302, 6.478366775513118, 7.8929105595604305, 9.40493253607422, 11.00619866144495, 12.689685266228848, 14.449396225485673, 10.56983063296024, 12.067138334738665, 13.63837664498677, 15.279897443526147, 16.98845060135645, 15.785108290977561, 17.45639605262404, 19.190377363887702, 17.977579509778487, 16.91711361195296, 13.717353245403094, 15.143714690367375, 16.631942276540087, 13.7114505464039]
# hypertension_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP1A2         0.940097      100.000000         0.0
# 1     PTGS2         0.933275       99.994961         0.0
# 2     HMOX1         0.920474       99.989922         1.0
# 3    CYP3A4         0.913943       99.984884         0.0
# 4       TNF         0.909227       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 2      HMOX1         0.920474       99.989922         1.0
# 7       NOS3         0.904800       99.964728         1.0
# 10    CYP2C9         0.896208       99.949612         1.0
# 14     GSTA1         0.888468       99.929457         1.0
# 17    CYP1A1         0.886356       99.914340         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 2      HMOX1         0.920474          1
# 7       NOS3         0.904800          2
# 10    CYP2C9         0.896208          3
# 14     GSTA1         0.888468          4
# 17    CYP1A1         0.886356          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     GSTA1         0.888468          4
# 1    CYP1B1         0.877216          8
# 2   CYP11B2         0.871693         11
# 3     HIF1A         0.870731         13
# 4     TGFB1         0.868126         14
#
#     Gene_Name  mantis_ml_proba  full_rank
# 83    PDE11A         0.379077        188
# 84    ADAM12         0.365333        192
# 85      BRD4         0.339167        193
# 86     KDM4A         0.293133        196
# 87      FUT6         0.170794        199
# (88, 3)
# GSTA1
# 4
# 0 4
# cur_pval:  1.0
# CYP1B1
# 8
# 1 8
# cur_pval:  0.991082377828067
# CYP11B2
# 11
# 2 11
# cur_pval:  0.9852643508650849
# HIF1A
# 13
# 3 13
# cur_pval:  0.9714217945723645
# TGFB1
# 14
# 4 14
# cur_pval:  0.9318933085504151
# GSTP1
# 18
# 5 18
# cur_pval:  0.9566407218079253
# ACE2
# 20
# 6 20
# cur_pval:  0.9413203968510625
# CCL2
# 24
# 7 24
# cur_pval:  0.9627265369298885
# NOS1
# 25
# 8 25
# cur_pval:  0.9328656470188965
# SLC2A3
# 26
# 9 26
# cur_pval:  0.8899194097536022
# SGK1
# 33
# 10 33
# cur_pval:  0.9727714624597765
# MAPK8
# 35
# 11 35
# cur_pval:  0.9661956558728431
# NPPA
# 36
# 12 36
# cur_pval:  0.9442564886247272
# TRPC6
# 37
# 13 37
# cur_pval:  0.9135416544773074
# KHK
# 43
# 14 43
# cur_pval:  0.9687395083180287
# Max: -0.0
# Avg: 0.2008687588969191
# [-0.0, 0.038902458686338175, 0.06447230701256108, 0.12592157033115986, 0.3063380670199576, 0.19251136238400146, 0.2626253076922078, 0.1649705697534104, 0.30180899618843177, 0.5064932086524068, 0.11989178488730415, 0.1493491948321276, 0.24910022159180223, 0.3927164546830628, 0.137929879739015]
# external_top_dataset:  ExtraTrees_vs_Hypertension
# external_top_dataset:  ExtraTrees_vs_Pulmonary_arterial_hypertension
# external_top_dataset:  ExtraTrees_vs_Portal_hypertension
# external_top_dataset:  ExtraTrees_vs_Elevated_pulmonary_artery_pressure
# external_top_dataset:  ExtraTrees_vs_Diabetes_mellitus
# external_top_dataset:  ExtraTrees_vs_Abnormal_systemic_blood_pressure
# external_top_dataset:  ExtraTrees_vs_Abnormality_of_intracranial_pressure
# external_top_dataset:  ExtraTrees_vs_Type_II_diabetes_mellitus
# external_top_dataset:  ExtraTrees_vs_Insulin-resistant_diabetes_mellitus
# external_top_dataset:  ExtraTrees_vs_Hyperlipidemia
# hypertension_drugnomefull\chem\ExtraTrees-hits.intersection.txt
# hypertension_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      NQO1         0.999904      100.000000         0.0
# 1   CYP11B1         0.999888       99.994961         0.0
# 2      PLAU         0.999868       99.989922         0.0
# 3      FASN         0.999862       99.984884         0.0
# 4     CASP8         0.999861       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 10      NOS3         0.999787       99.949612         1.0
# 19    CYP1B1         0.999651       99.904263         1.0
# 21      MMP9         0.999645       99.894185         1.0
# 22     HMOX1         0.999633       99.889146         1.0
# 24       ALB         0.999605       99.879069         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 10      NOS3         0.999787          1
# 19    CYP1B1         0.999651          2
# 21      MMP9         0.999645          3
# 22     HMOX1         0.999633          4
# 24       ALB         0.999605          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 10      NOS3         0.999787          1
# 19    CYP1B1         0.999651          2
# 21      MMP9         0.999645          3
# 22     HMOX1         0.999633          4
# 24       ALB         0.999605          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.999787          1
# 1       ALB         0.999605          5
# 2      NOS1         0.999470          9
# 3     HIF1A         0.999432         10
# 4      NOS2         0.999400         11
#
#     Gene_Name  mantis_ml_proba  full_rank
# 29      WNK1         0.710365        161
# 30      BMP4         0.658580        165
# 31     NR4A2         0.616502        170
# 32     ERAP1         0.605777        172
# 33    SLC8A1         0.596181        173
# (34, 3)
# NOS3
# 1
# 0 1
# cur_pval:  1.0
# ALB
# 5
# 1 5
# cur_pval:  0.608141375277217
# NOS1
# 9
# 2 9
# cur_pval:  0.46863430316851673
# HIF1A
# 10
# 3 10
# cur_pval:  0.22823417742467522
# NOS2
# 11
# 4 11
# cur_pval:  0.09397930789932027
# MMP2
# 17
# 5 17
# cur_pval:  0.13700732252758333
# F11
# 21
# 6 21
# cur_pval:  0.11821565399910781
# APOB
# 33
# 7 33
# cur_pval:  0.3102662099922944
# CYP1A1
# 38
# 8 38
# cur_pval:  0.2950026425103316
# TLR4
# 39
# 9 39
# cur_pval:  0.18088114277499429
# CYP2C9
# 43
# 10 43
# cur_pval:  0.1534484181240452
# Max: -0.0
# Avg: 5.999466897512497
# [-0.0, 2.1599544808658755, 3.2916592501873154, 6.416193206735757, 10.269677576170988, 8.63256220811926, 9.2732501080425, 5.082655193335022, 5.301740937760221, 7.426067068584823, 8.140375842835715]
# hypertension_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      NQO1         0.999904      100.000000         0.0
# 1   CYP11B1         0.999888       99.994961         0.0
# 2      PLAU         0.999868       99.989922         0.0
# 3      FASN         0.999862       99.984884         0.0
# 4     CASP8         0.999861       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 10      NOS3         0.999787       99.949612         1.0
# 19    CYP1B1         0.999651       99.904263         1.0
# 21      MMP9         0.999645       99.894185         1.0
# 22     HMOX1         0.999633       99.889146         1.0
# 24       ALB         0.999605       99.879069         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 10      NOS3         0.999787          1
# 19    CYP1B1         0.999651          2
# 21      MMP9         0.999645          3
# 22     HMOX1         0.999633          4
# 24       ALB         0.999605          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 10      NOS3         0.999787          1
# 19    CYP1B1         0.999651          2
# 21      MMP9         0.999645          3
# 22     HMOX1         0.999633          4
# 24       ALB         0.999605          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.999787          1
# 1      MMP9         0.999645          3
# 2     HMOX1         0.999633          4
# 3      SGK1         0.999540          6
# 4        F7         0.999483          8
#
#     Gene_Name  mantis_ml_proba  full_rank
# 88     PTPRB         0.459889        184
# 89      BRD4         0.324877        187
# 90      PLK2         0.259884        189
# 91     ORAI1         0.255398        190
# 92     FCGRT         0.034041        197
# (93, 3)
# NOS3
# 1
# 0 1
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.8468791719791613
# HMOX1
# 4
# 2 4
# cur_pval:  0.6311180052228171
# SGK1
# 6
# 3 6
# cur_pval:  0.5855353946970594
# F7
# 8
# 4 8
# cur_pval:  0.5539392010200933
# NOS1
# 9
# 5 9
# cur_pval:  0.40700310834377534
# HIF1A
# 10
# 6 10
# cur_pval:  0.284403306017051
# NOS2
# 11
# 7 11
# cur_pval:  0.19026035135081823
# TGFB1
# 15
# 8 15
# cur_pval:  0.3801094411282925
# MMP2
# 17
# 9 17
# cur_pval:  0.37220110207317164
# ICAM1
# 19
# 10 19
# cur_pval:  0.36465935955414924
# SERPINE1
# 20
# 11 20
# cur_pval:  0.2773607892255818
# ANPEP
# 22
# 12 22
# cur_pval:  0.27420675750336476
# FABP4
# 23
# 13 23
# cur_pval:  0.20431610728029215
# CASP1
# 26
# 14 26
# cur_pval:  0.26724786456589433
# GLS
# 29
# 15 29
# cur_pval:  0.3307673478376373
# APOB
# 33
# 16 33
# cur_pval:  0.46358987522593836
# TLR4
# 39
# 17 39
# cur_pval:  0.7088713198644979
# F3
# 40
# 18 40
# cur_pval:  0.6383913687417223
# Max: -0.0
# Avg: 3.8136564919965776
# [-0.0, 0.7217854797619785, 1.9988942962181562, 2.3244684737724755, 2.565378997309215, 3.9040227399002654, 5.4606535950128245, 7.206517055836928, 4.200913432908732, 4.292223452740629, 4.381126351091967, 5.569549355720682, 5.619218467373859, 6.896973943699782, 5.730857563191984, 4.80477368992057, 3.3386605756935985, 1.494325943583024, 1.9491299341983057]
# hypertension_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      NQO1         0.999904      100.000000         0.0
# 1   CYP11B1         0.999888       99.994961         0.0
# 2      PLAU         0.999868       99.989922         0.0
# 3      FASN         0.999862       99.984884         0.0
# 4     CASP8         0.999861       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 10      NOS3         0.999787       99.949612         1.0
# 19    CYP1B1         0.999651       99.904263         1.0
# 21      MMP9         0.999645       99.894185         1.0
# 22     HMOX1         0.999633       99.889146         1.0
# 24       ALB         0.999605       99.879069         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 10      NOS3         0.999787          1
# 19    CYP1B1         0.999651          2
# 21      MMP9         0.999645          3
# 22     HMOX1         0.999633          4
# 24       ALB         0.999605          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 10      NOS3         0.999787          1
# 19    CYP1B1         0.999651          2
# 21      MMP9         0.999645          3
# 22     HMOX1         0.999633          4
# 24       ALB         0.999605          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0       ALB         0.999605          5
# 1      PROC         0.999489          7
# 2        F7         0.999483          8
# 3      NOS1         0.999470          9
# 4      NOS2         0.999400         11
#
#     Gene_Name  mantis_ml_proba  full_rank
# 72      BRD4         0.324877        187
# 73   SLC14A1         0.245222        191
# 74    PDE11A         0.228633        192
# 75   SLC6A13         0.051941        195
# 76      FUT6         0.000066        201
# (77, 3)
# ALB
# 5
# 0 5
# cur_pval:  1.0
# PROC
# 7
# 1 7
# cur_pval:  0.9681887317632594
# F7
# 8
# 2 8
# cur_pval:  0.8798058782597659
# NOS1
# 9
# 3 9
# cur_pval:  0.7405914354356804
# NOS2
# 11
# 4 11
# cur_pval:  0.6677449662248434
# TGFB1
# 15
# 5 15
# cur_pval:  0.7503602519957808
# ICAM1
# 19
# 6 19
# cur_pval:  0.8098521581075694
# F11
# 21
# 7 21
# cur_pval:  0.7655600299401887
# CYP4F2
# 24
# 8 24
# cur_pval:  0.7736791283188231
# GLS
# 29
# 9 29
# cur_pval:  0.8598763174276169
# ENPEP
# 35
# 10 35
# cur_pval:  0.9346534406300645
# CYP1A1
# 38
# 11 38
# cur_pval:  0.9355580248582072
# F3
# 40
# 12 40
# cur_pval:  0.9192027668952105
# Max: -0.0
# Avg: 0.7535995880249844
# [-0.0, 0.14039976189567174, 0.5561314069144598, 1.3042131465294289, 1.7538937721001706, 1.2473017942123659, 0.9159425615633867, 1.1602074925101733, 1.1143911902482062, 0.6556401215364505, 0.2934939096928654, 0.28929271665577455, 0.3658867704658435]
# hypertension_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      NQO1         0.999904      100.000000         0.0
# 1   CYP11B1         0.999888       99.994961         0.0
# 2      PLAU         0.999868       99.989922         0.0
# 3      FASN         0.999862       99.984884         0.0
# 4     CASP8         0.999861       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 10      NOS3         0.999787       99.949612         1.0
# 19    CYP1B1         0.999651       99.904263         1.0
# 21      MMP9         0.999645       99.894185         1.0
# 22     HMOX1         0.999633       99.889146         1.0
# 24       ALB         0.999605       99.879069         1.0
# (201, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 10      NOS3         0.999787          1
# 19    CYP1B1         0.999651          2
# 21      MMP9         0.999645          3
# 22     HMOX1         0.999633          4
# 24       ALB         0.999605          5
#
#  Population Size: 201
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 10      NOS3         0.999787          1
# 19    CYP1B1         0.999651          2
# 21      MMP9         0.999645          3
# 22     HMOX1         0.999633          4
# 24       ALB         0.999605          5
# full_rank_cutoff: 40
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      NOS3         0.999787          1
# 1      MMP9         0.999645          3
# 2      PROC         0.999489          7
# 3        F7         0.999483          8
# 4      NOS1         0.999470          9
#
#     Gene_Name  mantis_ml_proba  full_rank
# 73     PTPRB         0.459889        184
# 74      BRD4         0.324877        187
# 75      PLK2         0.259884        189
# 76     FCGRT         0.034041        197
# 77     RIPK4         0.004005        199
# (78, 3)
# NOS3
# 1
# 0 1
# cur_pval:  1.0
# MMP9
# 3
# 1 3
# cur_pval:  0.7730285757142671
# PROC
# 7
# 2 7
# cur_pval:  0.8299123319273054
# F7
# 8
# 3 8
# cur_pval:  0.6631253341869588
# NOS1
# 9
# 4 9
# cur_pval:  0.4879845835373684
# HIF1A
# 10
# 5 10
# cur_pval:  0.3340522831618496
# NOS2
# 11
# 6 11
# cur_pval:  0.21477489857769147
# SELE
# 14
# 7 14
# cur_pval:  0.26875562865335345
# TGFB1
# 15
# 8 15
# cur_pval:  0.17696693421423285
# ABCB1
# 16
# 9 16
# cur_pval:  0.1112713968636436
# ICAM1
# 19
# 10 19
# cur_pval:  0.1465544896971199
# SERPINE1
# 20
# 11 20
# cur_pval:  0.09388080899674991
# DBH
# 25
# 12 25
# cur_pval:  0.21393705371880933
# APOB
# 33
# 13 33
# cur_pval:  0.5435959772922702
# TLR4
# 39
# 14 39
# cur_pval:  0.7230972793744519
# F3
# 40
# 15 40
# cur_pval:  0.6416973576462783
# Max: -0.0
# Avg: 4.5204213341039825
# [-0.0, 1.1180445168886632, 0.8096778204694643, 1.7840437988858513, 3.115938980596036, 4.761855556085173, 6.6801647737756955, 5.706424313833382, 7.521078727896349, 9.536164599308366, 8.340008724093229, 10.274231766223314, 6.697139894726403, 2.6472376578471173, 1.408032724792406, 1.926697490242268]
# ...
# (505, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 10       INS         0.949012          1
# 12      POMC         0.935539          2
# 16      EDN1         0.930567          3
# 18      SOD2         0.927328          4
# 21      CD44         0.925345          5
#
#  Population Size: 505
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 10       INS         0.949012          1
# 12      POMC         0.935539          2
# 16      EDN1         0.930567          3
# 18      SOD2         0.927328          4
# 21      CD44         0.925345          5
# full_rank_cutoff: 101
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0       INS         0.949012          1
# 1      POMC         0.935539          2
# 2      EDN1         0.930567          3
# 3      SOD2         0.927328          4
# 4      CD44         0.925345          5
#
#      Gene_Name  mantis_ml_proba  full_rank
# 249    ZNF652         0.235228        499
# 250     DHX16         0.229165        501
# 251      PEF1         0.229027        502
# 252      GNAS         0.214779        503
# 253     NUCB2         0.196897        505
# (254, 3)
# INS
# 1
# 0 1
# cur_pval:  1.0
# POMC
# 2
# 1 2
# cur_pval:  0.7534574886059806
# EDN1
# 3
# 2 3
# cur_pval:  0.5044642564228388
# SOD2
# 4
# 3 4
# cur_pval:  0.31623132492164635
# CD44
# 5
# 4 5
# cur_pval:  0.18999127505277633
# ATP7A
# 7
# 5 7
# cur_pval:  0.22983721383924408
# ACTA2
# 8
# 6 8
# cur_pval:  0.14649411478378102
# PON1
# 11
# 7 11
# cur_pval:  0.27893042034969046
# APOE
# 12
# 8 12
# cur_pval:  0.19674519705948837
# CAV1
# 13
# 9 13
# cur_pval:  0.13498125136170447
# CRP
# 14
# 10 14
# cur_pval:  0.09037395724661855
# SOD1
# 15
# 11 15
# cur_pval:  0.05921244628640489
# ANXA1
# 16
# 12 16
# cur_pval:  0.038052681886689525
# SLC39A8
# 17
# 13 17
# cur_pval:  0.024032715290588945
# AGT
# 21
# 14 21
# cur_pval:  0.09457128380021948
# GDF15
# 23
# 15 23
# cur_pval:  0.10495512465107654
# GNB3
# 28
# 16 28
# cur_pval:  0.2912731486410262
# TAGLN
# 29
# 17 29
# cur_pval:  0.23238799335808247
# CYBA
# 30
# 18 30
# cur_pval:  0.18216241973426744
# ANK2
# 33
# 19 33
# cur_pval:  0.24701626529608192
# SERPINA1
# 36
# 20 36
# cur_pval:  0.31531306753927546
# ENG
# 37
# 21 37
# cur_pval:  0.2595881821270086
# ADIPOQ
# 38
# 22 38
# cur_pval:  0.21049721164476237
# NPPB
# 39
# 23 39
# cur_pval:  0.16819124973616534
# EGR1
# 40
# 24 40
# cur_pval:  0.13247709193147061
# ADM
# 41
# 25 41
# cur_pval:  0.10290730536208377
# SLC31A1
# 42
# 26 42
# cur_pval:  0.07886910817678958
# HP
# 47
# 27 47
# cur_pval:  0.19055607982244133
# ANGPT1
# 49
# 28 49
# cur_pval:  0.19548616276304415
# COL4A1
# 51
# 29 51
# cur_pval:  0.20019017934511296
# CRH
# 54
# 30 54
# cur_pval:  0.25040670271024984
# GJA1
# 56
# 31 56
# cur_pval:  0.2543465857033399
# NRG1
# 59
# 32 59
# cur_pval:  0.3067814056047831
# LEP
# 60
# 33 60
# cur_pval:  0.2617120384586142
# F8
# 61
# 34 61
# cur_pval:  0.22083195875885214
# EPO
# 63
# 35 63
# cur_pval:  0.2244696737394156
# CD40LG
# 64
# 36 64
# cur_pval:  0.18801277962184212
# CD36
# 65
# 37 65
# cur_pval:  0.15582710136835692
# IL13RA2
# 68
# 38 68
# cur_pval:  0.19500203966238894
# OCLN
# 70
# 39 70
# cur_pval:  0.19831738760708867
# INHBA
# 71
# 40 71
# cur_pval:  0.16600200168237073
# CD93
# 73
# 41 73
# cur_pval:  0.1691848084795363
# KCNJ16
# 74
# 42 74
# cur_pval:  0.14066384443327506
# ACSM3
# 75
# 43 75
# cur_pval:  0.11582971365781204
# ALDH7A1
# 76
# 44 76
# cur_pval:  0.09447424154698116
# TIAM1
# 81
# 45 81
# cur_pval:  0.18099035971526503
# SPTB
# 82
# 46 82
# cur_pval:  0.152156786325518
# TPM1
# 85
# 47 85
# cur_pval:  0.18639160084166528
# MYH9
# 86
# 48 86
# cur_pval:  0.15745374105310592
# STIM1
# 90
# 49 90
# cur_pval:  0.22617173528358087
# EPCAM
# 91
# 50 91
# cur_pval:  0.1939416898744372
# INHA
# 92
# 51 92
# cur_pval:  0.16489572383072315
# SLC6A11
# 93
# 52 93
# cur_pval:  0.1390145724890134
# ADH6
# 94
# 53 94
# cur_pval:  0.11620789510940857
# FTCD
# 98
# 54 98
# cur_pval:  0.17178802924010655
# CFI
# 99
# 55 99
# cur_pval:  0.14569849634423124
# FOS
# 100
# 56 100
# cur_pval:  0.12256492037755637
# GATM
# 104
# 57 104
# cur_pval:  0.17818472135184818
# Max: -0.0
# Avg: 7.569208566156203
# [-0.0, 1.2294124631507355, 2.9716960006781887, 4.999951123709278, 7.212663426442143, 6.3857965164183135, 8.341798221922499, 5.545041186864057, 7.060958608292346, 8.697265499910143, 10.439567006479207, 12.275869962268924, 14.196147294966838, 16.19197158488643, 10.242407153988735, 9.789963512373847, 5.356995494764426, 6.3378631411748, 7.395412134520902, 6.072744487817905, 5.012580303856198, 5.857150828803529, 6.7675365268015995, 7.741966024153399, 8.778592138621624, 9.875537936940798, 11.030930699903678, 7.199771902074038, 7.088839781572949, 6.9855723135639565, 6.013540504172157, 5.945740878739927, 5.131709670436671, 5.821762998442671, 6.559380753801154, 6.488423246707677, 7.258126298287885, 8.073570078241978, 7.099608460247242, 7.026392070717119, 7.798866751264093, 7.716386359170149, 8.518175172130906, 9.361800172726735, 10.246865859765268, 7.42344556810171, 8.17708672960769, 7.295736616725014, 8.028470161997532, 6.455616698674994, 7.123288245660948, 7.827906065798615, 8.569396715456005, 9.3476436518173, 7.6500710253095665, 8.365449302668855, 9.116338125782452, 7.491295377685966]
# hypertension_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      TP53         0.998780      100.000000         0.0
# 1       HBB         0.994434       99.994961         0.0
# 2       TNF         0.991532       99.989922         0.0
# 3     ICAM1         0.984208       99.984884         0.0
# 4      MYL9         0.968353       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 10       INS         0.949012       99.949612         1.0
# 12      POMC         0.935539       99.939534         1.0
# 16      EDN1         0.930567       99.919379         1.0
# 18      SOD2         0.927328       99.909302         1.0
# 21      CD44         0.925345       99.894185         1.0
# (505, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 10       INS         0.949012          1
# 12      POMC         0.935539          2
# 16      EDN1         0.930567          3
# 18      SOD2         0.927328          4
# 21      CD44         0.925345          5
#
#  Population Size: 505
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 10       INS         0.949012          1
# 12      POMC         0.935539          2
# 16      EDN1         0.930567          3
# 18      SOD2         0.927328          4
# 21      CD44         0.925345          5
# full_rank_cutoff: 101
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0       INS         0.949012          1
# 1      POMC         0.935539          2
# 2      EDN1         0.930567          3
# 3      SOD2         0.927328          4
# 4      CD44         0.925345          5
#
#      Gene_Name  mantis_ml_proba  full_rank
# 214  ADAMTS13         0.258960        487
# 215       UNK         0.241357        495
# 216     SH2B3         0.240830        496
# 217      ULK4         0.236372        498
# 218      GNAS         0.214779        503
# (219, 3)
# INS
# 1
# 0 1
# cur_pval:  1.0
# POMC
# 2
# 1 2
# cur_pval:  0.6797501178692894
# EDN1
# 3
# 2 3
# cur_pval:  0.40088441533753794
# SOD2
# 4
# 3 4
# cur_pval:  0.2192328521344744
# CD44
# 5
# 4 5
# cur_pval:  0.11432695934665646
# AVP
# 6
# 5 6
# cur_pval:  0.05767777724122054
# ATP7A
# 7
# 6 7
# cur_pval:  0.02838822016063527
# ACTA2
# 8
# 7 8
# cur_pval:  0.013704232039253845
# PON1
# 11
# 8 11
# cur_pval:  0.04680098688033029
# APOE
# 12
# 9 12
# cur_pval:  0.025961839046921852
# CAV1
# 13
# 10 13
# cur_pval:  0.014069857457070479
# SOD1
# 15
# 11 15
# cur_pval:  0.017301961712754332
# SLC39A8
# 17
# 12 17
# cur_pval:  0.020088198699595137
# CHGA
# 18
# 13 18
# cur_pval:  0.011521867916203115
# AGT
# 21
# 14 21
# cur_pval:  0.024409468011862744
# EDN3
# 22
# 15 22
# cur_pval:  0.014757918827674622
# GDF15
# 23
# 16 23
# cur_pval:  0.00874984611259511
# CDH5
# 24
# 17 24
# cur_pval:  0.0050945197148879375
# APOA1
# 26
# 18 26
# cur_pval:  0.005780787465187726
# GNB3
# 28
# 19 28
# cur_pval:  0.0064086894273191865
# TAGLN
# 29
# 20 29
# cur_pval:  0.0038165105957353074
# COL1A2
# 32
# 21 32
# cur_pval:  0.0074792736427400155
# ANK2
# 33
# 22 33
# cur_pval:  0.004593656481340531
# SERPINA1
# 36
# 23 36
# cur_pval:  0.008307020477927035
# ENG
# 37
# 24 37
# cur_pval:  0.005229945923627964
# ADIPOQ
# 38
# 25 38
# cur_pval:  0.0032432165194448298
# NPPB
# 39
# 26 39
# cur_pval:  0.001982260212380545
# EGR1
# 40
# 27 40
# cur_pval:  0.0011948389991688947
# ADM
# 41
# 28 41
# cur_pval:  0.0007106580540487029
# TNNI3
# 43
# 29 43
# cur_pval:  0.0007803573612811143
# VWF
# 44
# 30 44
# cur_pval:  0.00046340952998690074
# COL3A1
# 45
# 31 45
# cur_pval:  0.00027181995156149076
# HP
# 47
# 32 47
# cur_pval:  0.0003010800000809269
# CTGF
# 50
# 33 50
# cur_pval:  0.000590792333485439
# COL4A1
# 51
# 34 51
# cur_pval:  0.00035670398793804007
# NRG1
# 59
# 35 59
# cur_pval:  0.006541276092556377
# LEP
# 60
# 36 60
# cur_pval:  0.004395347208265661
# F8
# 61
# 37 61
# cur_pval:  0.0029165048310728263
# CD36
# 65
# 38 65
# cur_pval:  0.006447682841617121
# LRP2
# 66
# 39 66
# cur_pval:  0.004386337692341465
# RHOA
# 67
# 40 67
# cur_pval:  0.002948055515294724
# ASS1
# 69
# 41 69
# cur_pval:  0.0029428770888688853
# INHBA
# 71
# 42 71
# cur_pval:  0.0029308261003087154
# NFATC2
# 72
# 43 72
# cur_pval:  0.0019610723441152115
# KCNJ16
# 74
# 44 74
# cur_pval:  0.0019553361491694717
# ACSM3
# 75
# 45 75
# cur_pval:  0.0012980066145432325
# ALDH7A1
# 76
# 46 76
# cur_pval:  0.0008521435581112064
# SPTB
# 82
# 47 82
# cur_pval:  0.003987061033234726
# CFH
# 83
# 48 83
# cur_pval:  0.0027439256210174756
# TPM1
# 85
# 49 85
# cur_pval:  0.0026981418169883427
# MYH9
# 86
# 50 86
# cur_pval:  0.0018407572679798477
# B2M
# 88
# 51 88
# cur_pval:  0.001811239363009791
# STIM1
# 90
# 52 90
# cur_pval:  0.0017795042846427214
# SLC6A11
# 93
# 53 93
# cur_pval:  0.00248809913114649
# ADH6
# 94
# 54 94
# cur_pval:  0.0017103841377788698
# CYR61
# 95
# 55 95
# cur_pval:  0.0011635938000069403
# NOV
# 96
# 56 96
# cur_pval:  0.0007835078335079699
# MTHFR
# 97
# 57 97
# cur_pval:  0.0005222402183939752
# CFI
# 99
# 58 99
# cur_pval:  0.0005136074022998312
# FOS
# 100
# 59 100
# cur_pval:  0.0003395389864213516
# SLC3A1
# 102
# 60 102
# cur_pval:  0.0003339540334112163
# Max: -0.0
# Avg: 23.474413602200745
# [-0.0, 1.676507084333971, 3.9698082692351115, 6.59094366101573, 9.418513469020208, 12.389914846005732, 15.468618353235836, 18.631452965315724, 13.29744988973678, 15.856645468623729, 18.517103024175153, 17.619046533611243, 16.97059004511037, 19.384771077237026, 16.1244168563935, 18.30974882715146, 20.579995850392272, 22.928967527774308, 22.3801299748061, 21.932307743310023, 24.183335275538404, 21.26140577037567, 23.37841484943415, 20.8055471893891, 22.815028016090913, 24.89024056550221, 27.028393360347465, 29.22690610601358, 31.483393176415653, 31.077064684756532, 33.3403503921638, 35.657186692552784, 35.21318092521031, 32.28565149017793, 34.476920352374705, 21.84337519887569, 23.570068123586108, 25.351372998420466, 21.905963334118994, 23.57897936207302, 25.30464342468634, 25.31227876106542, 25.330099495304736, 27.07506384878616, 27.08778570656846, 28.867230943982793, 30.69487234759627, 23.99347116182558, 25.616276651298207, 25.689352271189605, 27.350034760951498, 27.420241520244083, 27.49700961976263, 26.041323204232402, 27.6690633979377, 29.34198601476153, 31.059566570993113, 32.82129685645986, 32.893687256814076, 34.691103521181816, 34.76313306870137]
# hypertension_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      TP53         0.998780      100.000000         0.0
# 1       HBB         0.994434       99.994961         0.0
# 2       TNF         0.991532       99.989922         0.0
# 3     ICAM1         0.984208       99.984884         0.0
# 4      MYL9         0.968353       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 10       INS         0.949012       99.949612         1.0
# 12      POMC         0.935539       99.939534         1.0
# 16      EDN1         0.930567       99.919379         1.0
# 18      SOD2         0.927328       99.909302         1.0
# 21      CD44         0.925345       99.894185         1.0
# (505, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 10       INS         0.949012          1
# 12      POMC         0.935539          2
# 16      EDN1         0.930567          3
# 18      SOD2         0.927328          4
# 21      CD44         0.925345          5
#
#  Population Size: 505
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 10       INS         0.949012          1
# 12      POMC         0.935539          2
# 16      EDN1         0.930567          3
# 18      SOD2         0.927328          4
# 21      CD44         0.925345          5
# full_rank_cutoff: 101
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0       INS         0.949012          1
# 1      EDN1         0.930567          3
# 2     ATP7A         0.901189          7
# 3     ACTA2         0.897202          8
# 4       OXT         0.894083          9
#
#      Gene_Name  mantis_ml_proba  full_rank
# 151    GIMAP8         0.256298        489
# 152      CTBS         0.251493        491
# 153    ZNF652         0.235228        499
# 154     DHX16         0.229165        501
# 155     OXSR1         0.204612        504
# (156, 3)
# INS
# 1
# 0 1
# cur_pval:  1.0
# EDN1
# 3
# 1 3
# cur_pval:  0.6708118099512161
# ATP7A
# 7
# 2 7
# cur_pval:  0.6908723939648187
# ACTA2
# 8
# 3 8
# cur_pval:  0.47122192338252533
# OXT
# 9
# 4 9
# cur_pval:  0.2897266988637216
# SLC39A8
# 17
# 5 17
# cur_pval:  0.6448609392944874
# GDF15
# 23
# 6 23
# cur_pval:  0.7665197998650267
# CDH5
# 24
# 7 24
# cur_pval:  0.6517264713150815
# GNB3
# 28
# 8 28
# cur_pval:  0.678579536264852
# COL1A2
# 32
# 9 32
# cur_pval:  0.702178497036082
# ANK2
# 33
# 10 33
# cur_pval:  0.5984625252030544
# ENG
# 37
# 11 37
# cur_pval:  0.6273392270480603
# ADIPOQ
# 38
# 12 38
# cur_pval:  0.526712091959829
# SLC31A1
# 42
# 13 42
# cur_pval:  0.5583505404089424
# COL3A1
# 45
# 14 45
# cur_pval:  0.5468425689575822
# ATF3
# 48
# 15 48
# cur_pval:  0.5360441129499072
# CTGF
# 50
# 16 50
# cur_pval:  0.48636673331332564
# COL4A1
# 51
# 17 51
# cur_pval:  0.3999740088092436
# ALAD
# 52
# 18 52
# cur_pval:  0.32005122402614683
# CALCA
# 57
# 19 57
# cur_pval:  0.387750391321777
# NRG1
# 59
# 20 59
# cur_pval:  0.34670383193808396
# LEP
# 60
# 21 60
# cur_pval:  0.27621094925196793
# RGS2
# 62
# 22 62
# cur_pval:  0.24319846959364502
# CD40LG
# 64
# 23 64
# cur_pval:  0.2132296416150306
# RHOA
# 67
# 24 67
# cur_pval:  0.21170222613785994
# OCLN
# 70
# 25 70
# cur_pval:  0.21008776047776612
# INHBA
# 71
# 26 71
# cur_pval:  0.16134969660512236
# ACSM3
# 75
# 27 75
# cur_pval:  0.18283714721247213
# PRL
# 78
# 28 78
# cur_pval:  0.1815339142858656
# TIAM1
# 81
# 29 81
# cur_pval:  0.18015567007031952
# SPTB
# 82
# 30 82
# cur_pval:  0.13848394904428246
# TPM1
# 85
# 31 85
# cur_pval:  0.13776506219705856
# CORIN
# 89
# 32 89
# cur_pval:  0.15558678686118255
# EPCAM
# 91
# 33 91
# cur_pval:  0.13608672840996194
# INHA
# 92
# 34 92
# cur_pval:  0.10341335577911762
# ADH6
# 94
# 35 94
# cur_pval:  0.08937291554050505
# FTCD
# 98
# 36 98
# cur_pval:  0.10243286544656731
# FOS
# 100
# 37 100
# cur_pval:  0.08869335417478685
# SLC3A1
# 102
# 38 102
# cur_pval:  0.0765225170326945
# Max: -0.0
# Avg: 5.224880222288587
# [-0.0, 1.7339930004404478, 1.6060216060641739, 3.2677451240056605, 5.380114818935368, 1.9053392847841657, 1.1547662246510093, 1.8593463881322256, 1.6839924139184168, 1.535524741608441, 2.2296303925435246, 2.0249755550765864, 2.7842671123973095, 2.5309305918649483, 2.6213768513607083, 2.7079946922063747, 3.1303613774958254, 3.9796822916571184, 4.947805075190118, 4.114477552195731, 4.600413582848548, 5.587591095899032, 6.140391623315654, 6.7115242302711176, 6.742745751676199, 6.77599248459369, 7.922318468875636, 7.379355635779975, 7.410422278658712, 7.443520647015553, 8.586005605017624, 8.608609073839125, 8.080272880464287, 8.661842264451668, 9.854233687217599, 10.48794074195766, 9.895606782033239, 10.521089207922731, 11.162107532888644]
# external_top_dataset:  SVC_vs_Hypertension
# external_top_dataset:  SVC_vs_Pulmonary_arterial_hypertension
# external_top_dataset:  SVC_vs_Portal_hypertension
# external_top_dataset:  SVC_vs_Elevated_pulmonary_artery_pressure
# external_top_dataset:  SVC_vs_Diabetes_mellitus
# external_top_dataset:  SVC_vs_Abnormal_systemic_blood_pressure
# external_top_dataset:  SVC_vs_Abnormality_of_intracranial_pressure
# external_top_dataset:  SVC_vs_Type_II_diabetes_mellitus
# external_top_dataset:  SVC_vs_Insulin-resistant_diabetes_mellitus
# external_top_dataset:  SVC_vs_Hyperlipidemia
# hypertension_drugnomefull\bio\SVC-hits.intersection.txt

# %%
run_hypergeom_test(disease='Epilepsy', folder='epilepsy_drugnomefull', top=0.20)
# Out:
# (766,)
# external_top_ranking:  0       PDGFRA
# 3747    PABPC4
# 836      ACTG1
# 8316      SDC1
# 1638      CTSA
# Name: Gene_Name, dtype: object
# (5496,)
# external_top_ranking:  0       PDGFRA
# 4305      RFX3
# 6259     BRSK1
# 296        ERG
# 5022     WASF1
# Name: Gene_Name, dtype: object
# (2738,)
# external_top_ranking:  0        PDGFRA
# 2255      KMT2E
# 3230       MYRF
# 499      MAP2K2
# 8906    HSPA12A
# Name: Gene_Name, dtype: object
# (3585,)
# external_top_ranking:  0       PDGFRA
# 521      KPNB1
# 7394      FGD1
# 2046    CALCRL
# 1159      ANK3
# Name: Gene_Name, dtype: object
# (2725,)
# external_top_ranking:  0       PDGFRA
# 5837      MTO1
# 928      APAF1
# 1316     HBEGF
# 6040     TRPM3
# Name: Gene_Name, dtype: object
# (4429,)
# external_top_ranking:  0          PDGFRA
# 7236         GNL1
# 13983    ANKRD34A
# 652          DDX6
# 578          CCT5
# Name: Gene_Name, dtype: object
# (5774,)
# external_top_ranking:  0        PDGFRA
# 9468      HCFC2
# 7529      USP11
# 5136     U2SURP
# 10401    FBXL19
# Name: Gene_Name, dtype: object
# (9918,)
# external_top_ranking:  0       PDGFRA
# 4655    NELFCD
# 1809     LPIN1
# 1132       TPR
# 1428    FERMT2
# Name: Gene_Name, dtype: object
# (6475,)
# external_top_ranking:  0       PDGFRA
# 3120    CAMTA1
# 1550    FNDC3B
# 933       RAI1
# 150      TRPM7
# Name: Gene_Name, dtype: object
# (12154,)
# external_top_ranking:  0        PDGFRA
# 3326       MLH3
# 11217    FBXO42
# 6948     KCTD13
# 4245      KIF5A
# Name: Gene_Name, dtype: object
# ['epilepsy_drugnomefull/chem\\ExtraTreesClassifier.mantis-ml_predictions.csv', 'epilepsy_drugnomefull/chem\\GradientBoostingClassifier.mantis-ml_predictions.csv', 'epilepsy_drugnomefull/chem\\RandomForestClassifier.mantis-ml_predictions.csv', 'epilepsy_drugnomefull/chem\\SVC.mantis-ml_predictions.csv']
# epilepsy_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.903575      100.000000         0.0
# 1       TNF         0.902871       99.994961         0.0
# 2     MAPK9         0.900717       99.989922         0.0
# 3     NPY1R         0.893909       99.984884         0.0
# 4     PTGS2         0.880948       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 18     CASP3         0.860185       99.909302         1.0
# 45     GALR1         0.841282       99.773254         1.0
# 57    BDKRB1         0.833489       99.712788         1.0
# 61     ABCB1         0.831530       99.692633         1.0
# 62      GRM1         0.829974       99.687594         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP3         0.860185          1
# 1      GRM5         0.826614          8
# 2      AKT1         0.815638         11
# 3      GRM7         0.802605         18
# 4    SLC2A1         0.799064         21
#
#     Gene_Name  mantis_ml_proba  full_rank
# 9        ADK         0.386148         99
# 10     CDKL5         0.352475        102
# 11    EEF1A2         0.303088        107
# 12      POLG         0.278035        109
# 13       PAM         0.224092        111
# (14, 3)
# CASP3
# 1
# 0 1
# cur_pval:  1.0
# GRM5
# 8
# 1 8
# cur_pval:  0.6583259504072367
# AKT1
# 11
# 2 11
# cur_pval:  0.39859101339535313
# GRM7
# 18
# 3 18
# cur_pval:  0.37934531703761076
# SLC2A1
# 21
# 4 21
# cur_pval:  0.2336477843723409
# ALPL
# 46
# 5 46
# cur_pval:  0.7352830162105071
# Max: -0.0
# Avg: 2.944967655814512
# [-0.0, 1.8155902521091987, 3.99472497097662, 4.20965272868605, 6.314383329338199, 1.335454653777008]
# epilepsy_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.903575      100.000000         0.0
# 1       TNF         0.902871       99.994961         0.0
# 2     MAPK9         0.900717       99.989922         0.0
# 3     NPY1R         0.893909       99.984884         0.0
# 4     PTGS2         0.880948       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 18     CASP3         0.860185       99.909302         1.0
# 45     GALR1         0.841282       99.773254         1.0
# 57    BDKRB1         0.833489       99.712788         1.0
# 61     ABCB1         0.831530       99.692633         1.0
# 62      GRM1         0.829974       99.687594         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP3         0.860185          1
# 1     ABCB1         0.831530          4
# 2      GRM1         0.829974          5
# 3     CASP8         0.827685          6
# 4      GRM5         0.826614          8
#
#     Gene_Name  mantis_ml_proba  full_rank
# 55     SGMS1         0.299968        108
# 56      POLG         0.278035        109
# 57      VARS         0.240147        110
# 58       PAM         0.224092        111
# 59     PPME1         0.211807        113
# (60, 3)
# CASP3
# 1
# 0 1
# cur_pval:  1.0
# ABCB1
# 4
# 1 4
# cur_pval:  0.9506671160394258
# GRM1
# 5
# 2 5
# cur_pval:  0.8440014209895342
# CASP8
# 6
# 3 6
# cur_pval:  0.7009724208090015
# GRM5
# 8
# 4 8
# cur_pval:  0.6893449358299981
# AKT1
# 11
# 5 11
# cur_pval:  0.7839156937501748
# JUN
# 12
# 6 12
# cur_pval:  0.6790748082730574
# GRM4
# 17
# 7 17
# cur_pval:  0.8937842384622998
# GRM7
# 18
# 8 18
# cur_pval:  0.8343263475142085
# HMOX1
# 19
# 9 19
# cur_pval:  0.7612299197249252
# SLC2A1
# 21
# 10 21
# cur_pval:  0.7592302278872509
# GLUL
# 24
# 11 24
# cur_pval:  0.8234477874297857
# Max: -0.0
# Avg: 0.9460081611069276
# [-0.0, 0.2197152825225019, 0.7365682218075009, 1.5429906866113772, 1.6156341054262375, 1.0573064102453045, 1.68082380313598, 0.48767308222543665, 0.78664041446316, 1.1848415034288466, 1.1962650929612875, 0.843639330455501]
# epilepsy_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.903575      100.000000         0.0
# 1       TNF         0.902871       99.994961         0.0
# 2     MAPK9         0.900717       99.989922         0.0
# 3     NPY1R         0.893909       99.984884         0.0
# 4     PTGS2         0.880948       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 18     CASP3         0.860185       99.909302         1.0
# 45     GALR1         0.841282       99.773254         1.0
# 57    BDKRB1         0.833489       99.712788         1.0
# 61     ABCB1         0.831530       99.692633         1.0
# 62      GRM1         0.829974       99.687594         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     ABCB1         0.831530          4
# 1      GRM1         0.829974          5
# 2     CASP8         0.827685          6
# 3     HMOX1         0.802202         19
# 4    SLC2A1         0.799064         21
#
#     Gene_Name  mantis_ml_proba  full_rank
# 21       ADK         0.386148         99
# 22      QARS         0.334841        103
# 23     DDX3X         0.327050        106
# 24      POLG         0.278035        109
# 25      VARS         0.240147        110
# (26, 3)
# ABCB1
# 4
# 0 4
# cur_pval:  1.0
# GRM1
# 5
# 1 5
# cur_pval:  0.7295498841943826
# CASP8
# 6
# 2 6
# cur_pval:  0.4099270200604712
# HMOX1
# 19
# 3 19
# cur_pval:  0.8612331083060244
# SLC2A1
# 21
# 4 21
# cur_pval:  0.7583095319977435
# MAPK10
# 33
# 5 33
# cur_pval:  0.9316763277748314
# Max: -0.0
# Avg: 1.2333436142134957
# [-0.0, 1.3694500714315903, 3.8729345451488717, 0.648792829843755, 1.2015348487061361, 0.307349390150621]
# epilepsy_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.903575      100.000000         0.0
# 1       TNF         0.902871       99.994961         0.0
# 2     MAPK9         0.900717       99.989922         0.0
# 3     NPY1R         0.893909       99.984884         0.0
# 4     PTGS2         0.880948       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 18     CASP3         0.860185       99.909302         1.0
# 45     GALR1         0.841282       99.773254         1.0
# 57    BDKRB1         0.833489       99.712788         1.0
# 61     ABCB1         0.831530       99.692633         1.0
# 62      GRM1         0.829974       99.687594         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     ABCB1         0.831530          4
# 1     CASP8         0.827685          6
# 2      AKT1         0.815638         11
# 3       JUN         0.813275         12
# 4      GRM7         0.802605         18
#
#     Gene_Name  mantis_ml_proba  full_rank
# 38      QARS         0.334841        103
# 39     SGMS1         0.299968        108
# 40      POLG         0.278035        109
# 41       PAM         0.224092        111
# 42     PPME1         0.211807        113
# (43, 3)
# ABCB1
# 4
# 0 4
# cur_pval:  1.0
# CASP8
# 6
# 1 6
# cur_pval:  0.944472659982672
# AKT1
# 11
# 2 11
# cur_pval:  0.9633470215337722
# JUN
# 12
# 3 12
# cur_pval:  0.8979131546924588
# GRM7
# 18
# 4 18
# cur_pval:  0.9608366923996351
# HMOX1
# 19
# 5 19
# cur_pval:  0.9144101676116749
# SLC2A1
# 21
# 6 21
# cur_pval:  0.8809637253790095
# GLUL
# 24
# 7 24
# cur_pval:  0.8807648885822608
# Max: -0.0
# Avg: 0.3177310882371034
# [-0.0, 0.2481060925142674, 0.16217241027803125, 0.4676566585133099, 0.17350420465249286, 0.38858953530212903, 0.550419737582881, 0.5514000670537157]
# epilepsy_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.903575      100.000000         0.0
# 1       TNF         0.902871       99.994961         0.0
# 2     MAPK9         0.900717       99.989922         0.0
# 3     NPY1R         0.893909       99.984884         0.0
# 4     PTGS2         0.880948       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 18     CASP3         0.860185       99.909302         1.0
# 45     GALR1         0.841282       99.773254         1.0
# 57    BDKRB1         0.833489       99.712788         1.0
# 61     ABCB1         0.831530       99.692633         1.0
# 62      GRM1         0.829974       99.687594         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     ABCB1         0.831530          4
# 1     CASP8         0.827685          6
# 2       JUN         0.813275         12
# 3      GRM8         0.805584         16
# 4      GLUL         0.789980         24
#
#     Gene_Name  mantis_ml_proba  full_rank
# 26       ICK         0.333183        104
# 27      POLG         0.278035        109
# 28       PAM         0.224092        111
# 29      PPIG         0.217676        112
# 30     PPME1         0.211807        113
# (31, 3)
# ABCB1
# 4
# 0 4
# cur_pval:  1.0
# CASP8
# 6
# 1 6
# cur_pval:  0.8555363757121524
# JUN
# 12
# 2 12
# cur_pval:  0.8883013599096581
# GRM8
# 16
# 3 16
# cur_pval:  0.8665707756944714
# GLUL
# 24
# 4 24
# cur_pval:  0.9428990562834463
# Max: -0.0
# Avg: 0.4138639071711527
# [-0.0, 0.6776152038914235, 0.5143967302465506, 0.6219596123822189, 0.25534798933557074]
# epilepsy_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.903575      100.000000         0.0
# 1       TNF         0.902871       99.994961         0.0
# 2     MAPK9         0.900717       99.989922         0.0
# 3     NPY1R         0.893909       99.984884         0.0
# 4     PTGS2         0.880948       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 18     CASP3         0.860185       99.909302         1.0
# 45     GALR1         0.841282       99.773254         1.0
# 57    BDKRB1         0.833489       99.712788         1.0
# 61     ABCB1         0.831530       99.692633         1.0
# 62      GRM1         0.829974       99.687594         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP3         0.860185          1
# 1     ABCB1         0.831530          4
# 2     CASP8         0.827685          6
# 3       JUN         0.813275         12
# 4      GRM4         0.805413         17
#
#     Gene_Name  mantis_ml_proba  full_rank
# 36       PAM         0.224092        111
# 37      PPIG         0.217676        112
# 38     PPME1         0.211807        113
# 39     KCNT2         0.157636        114
# 40     KCNT1         0.147466        115
# (41, 3)
# CASP3
# 1
# 0 1
# cur_pval:  1.0
# ABCB1
# 4
# 1 4
# cur_pval:  0.8335643842194931
# CASP8
# 6
# 2 6
# cur_pval:  0.6994344530745202
# JUN
# 12
# 3 12
# cur_pval:  0.8731196783584674
# GRM4
# 17
# 4 17
# cur_pval:  0.9237094509784588
# SLC2A1
# 21
# 5 21
# cur_pval:  0.9373282031946931
# GRM3
# 28
# 6 28
# cur_pval:  0.9815673995914644
# Max: -0.0
# Avg: 0.5198469348803861
# [-0.0, 0.7906084978757356, 1.552529788159922, 0.5892622354714931, 0.34464612849159126, 0.2810831532457868, 0.08079874091817402]
# epilepsy_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.903575      100.000000         0.0
# 1       TNF         0.902871       99.994961         0.0
# 2     MAPK9         0.900717       99.989922         0.0
# 3     NPY1R         0.893909       99.984884         0.0
# 4     PTGS2         0.880948       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 18     CASP3         0.860185       99.909302         1.0
# 45     GALR1         0.841282       99.773254         1.0
# 57    BDKRB1         0.833489       99.712788         1.0
# 61     ABCB1         0.831530       99.692633         1.0
# 62      GRM1         0.829974       99.687594         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP3         0.860185          1
# 1     ABCB1         0.831530          4
# 2      GRM1         0.829974          5
# 3     CASP8         0.827685          6
# 4      CCR2         0.820543          9
#
#     Gene_Name  mantis_ml_proba  full_rank
# 52      POLG         0.278035        109
# 53       PAM         0.224092        111
# 54      PPIG         0.217676        112
# 55     PPME1         0.211807        113
# 56     KCNT2         0.157636        114
# (57, 3)
# CASP3
# 1
# 0 1
# cur_pval:  1.0
# ABCB1
# 4
# 1 4
# cur_pval:  0.9386302424009249
# GRM1
# 5
# 2 5
# cur_pval:  0.8125734430082237
# CASP8
# 6
# 3 6
# cur_pval:  0.6521375165084268
# CCR2
# 9
# 4 9
# cur_pval:  0.7462937205648007
# JUN
# 12
# 5 12
# cur_pval:  0.8109325518061623
# GRM2
# 13
# 6 13
# cur_pval:  0.7098438738531359
# ALB
# 15
# 7 15
# cur_pval:  0.6968537203395658
# GRM8
# 16
# 8 16
# cur_pval:  0.5911359816386867
# GRM4
# 17
# 9 17
# cur_pval:  0.4843503869913351
# HMOX1
# 19
# 10 19
# cur_pval:  0.48331066470668205
# NPY2R
# 20
# 11 20
# cur_pval:  0.38651252000544256
# SLC2A1
# 21
# 12 21
# cur_pval:  0.2994405046761017
# GLUL
# 24
# 13 24
# cur_pval:  0.39084520436465847
# Max: -0.0
# Avg: 2.164680242992026
# [-0.0, 0.27505457052726884, 0.9013737563925954, 1.856608147535605, 1.2709021258773778, 0.9101526612983141, 1.4883716139381225, 1.5685837701912724, 2.2831260493543653, 3.1484034892987367, 3.1577362163711338, 4.128364337476954, 5.236894539344393, 4.079952124282228]
# epilepsy_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.903575      100.000000         0.0
# 1       TNF         0.902871       99.994961         0.0
# 2     MAPK9         0.900717       99.989922         0.0
# 3     NPY1R         0.893909       99.984884         0.0
# 4     PTGS2         0.880948       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 18     CASP3         0.860185       99.909302         1.0
# 45     GALR1         0.841282       99.773254         1.0
# 57    BDKRB1         0.833489       99.712788         1.0
# 61     ABCB1         0.831530       99.692633         1.0
# 62      GRM1         0.829974       99.687594         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP3         0.860185          1
# 1    BDKRB1         0.833489          3
# 2     ABCB1         0.831530          4
# 3      GRM1         0.829974          5
# 4     CASP8         0.827685          6
#
#     Gene_Name  mantis_ml_proba  full_rank
# 63       PAM         0.224092        111
# 64      PPIG         0.217676        112
# 65     PPME1         0.211807        113
# 66     KCNT2         0.157636        114
# 67     KCNT1         0.147466        115
# (68, 3)
# CASP3
# 1
# 0 1
# cur_pval:  1.0
# BDKRB1
# 3
# 1 3
# cur_pval:  0.9343269678621318
# ABCB1
# 4
# 2 4
# cur_pval:  0.8147082307538751
# GRM1
# 5
# 3 5
# cur_pval:  0.670303629199763
# CASP8
# 6
# 4 6
# cur_pval:  0.5258990276456496
# GRM5
# 8
# 5 8
# cur_pval:  0.5753341741171993
# AKT1
# 11
# 6 11
# cur_pval:  0.7436751988673275
# JUN
# 12
# 7 12
# cur_pval:  0.6483813702561728
# GRM2
# 13
# 8 13
# cur_pval:  0.5500476552954344
# ALB
# 15
# 9 15
# cur_pval:  0.5869478543173636
# GRM8
# 16
# 10 16
# cur_pval:  0.4964319815029011
# GRM4
# 17
# 11 17
# cur_pval:  0.41012189671820226
# GRM7
# 18
# 12 18
# cur_pval:  0.33117779319527463
# SLC2A1
# 21
# 13 21
# cur_pval:  0.4877434830429342
# GLUL
# 24
# 14 24
# cur_pval:  0.6291297951463861
# Max: -0.0
# Avg: 2.2022837283718832
# [-0.0, 0.29501115751850043, 0.8899789611978142, 1.7372842921560694, 2.790976321690854, 2.400798286692202, 1.2861670173782989, 1.881694720949253, 2.5959968225982704, 2.3140048067432635, 3.041402478364281, 3.870870427826945, 4.799387921048206, 3.1180852469592653, 2.01259746445503]
# epilepsy_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.903575      100.000000         0.0
# 1       TNF         0.902871       99.994961         0.0
# 2     MAPK9         0.900717       99.989922         0.0
# 3     NPY1R         0.893909       99.984884         0.0
# 4     PTGS2         0.880948       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 18     CASP3         0.860185       99.909302         1.0
# 45     GALR1         0.841282       99.773254         1.0
# 57    BDKRB1         0.833489       99.712788         1.0
# 61     ABCB1         0.831530       99.692633         1.0
# 62      GRM1         0.829974       99.687594         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     ABCB1         0.831530          4
# 1      GRM1         0.829974          5
# 2     CASP8         0.827685          6
# 3      GRM5         0.826614          8
# 4      CCR2         0.820543          9
#
#     Gene_Name  mantis_ml_proba  full_rank
# 59       PAM         0.224092        111
# 60      PPIG         0.217676        112
# 61     PPME1         0.211807        113
# 62     KCNT2         0.157636        114
# 63     KCNT1         0.147466        115
# (64, 3)
# ABCB1
# 4
# 0 4
# cur_pval:  1.0
# GRM1
# 5
# 1 5
# cur_pval:  0.9846942992079809
# CASP8
# 6
# 2 6
# cur_pval:  0.9401686241766454
# GRM5
# 8
# 3 8
# cur_pval:  0.9250135549687271
# CCR2
# 9
# 4 9
# cur_pval:  0.8538783520846365
# CHRNA2
# 10
# 5 10
# cur_pval:  0.7617716860861266
# AKT1
# 11
# 6 11
# cur_pval:  0.656506924944972
# GRM8
# 16
# 7 16
# cur_pval:  0.9035621726785384
# GRM4
# 17
# 8 17
# cur_pval:  0.8500387188571975
# GRM7
# 18
# 9 18
# cur_pval:  0.7838853684070977
# HMOX1
# 19
# 10 19
# cur_pval:  0.70750211840286
# SLC2A1
# 21
# 11 21
# cur_pval:  0.7188800400180708
# GLUL
# 24
# 12 24
# cur_pval:  0.8046421255924967
# Max: -0.0
# Avg: 0.8040371860220533
# [-0.0, 0.0669857637897488, 0.26794246419749346, 0.33851903147466894, 0.6860399673662543, 1.1817517345122928, 1.8276068853942626, 0.4404195896111634, 0.7056129192917283, 1.0574744179023952, 1.5027225543717715, 1.4334357457507214, 0.9439723446241934]
# epilepsy_drugnomefull/chem\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A4         0.903575      100.000000         0.0
# 1       TNF         0.902871       99.994961         0.0
# 2     MAPK9         0.900717       99.989922         0.0
# 3     NPY1R         0.893909       99.984884         0.0
# 4     PTGS2         0.880948       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 18     CASP3         0.860185       99.909302         1.0
# 45     GALR1         0.841282       99.773254         1.0
# 57    BDKRB1         0.833489       99.712788         1.0
# 61     ABCB1         0.831530       99.692633         1.0
# 62      GRM1         0.829974       99.687594         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 18     CASP3         0.860185          1
# 45     GALR1         0.841282          2
# 57    BDKRB1         0.833489          3
# 61     ABCB1         0.831530          4
# 62      GRM1         0.829974          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP3         0.860185          1
# 1     GALR1         0.841282          2
# 2     ABCB1         0.831530          4
# 3      GRM1         0.829974          5
# 4      CCR8         0.826642          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 84      VARS         0.240147        110
# 85       PAM         0.224092        111
# 86      PPIG         0.217676        112
# 87     KCNT2         0.157636        114
# 88     KCNT1         0.147466        115
# (89, 3)
# CASP3
# 1
# 0 1
# cur_pval:  1.0
# GALR1
# 2
# 1 2
# cur_pval:  0.9504195270785665
# ABCB1
# 4
# 2 4
# cur_pval:  0.9643659938611429
# GRM1
# 5
# 3 5
# cur_pval:  0.9245620238005967
# CCR8
# 7
# 4 7
# cur_pval:  0.9548880677124492
# CCR2
# 9
# 5 9
# cur_pval:  0.973055876816096
# CHRNA2
# 10
# 6 10
# cur_pval:  0.9547411582048727
# AKT1
# 11
# 7 11
# cur_pval:  0.9303215333899073
# JUN
# 12
# 8 12
# cur_pval:  0.8996963720491586
# GALR2
# 14
# 9 14
# cur_pval:  0.9386345768994779
# GRM4
# 17
# 10 17
# cur_pval:  0.9856115282593843
# GRM7
# 18
# 11 18
# cur_pval:  0.9781777243606118
# HMOX1
# 19
# 12 19
# cur_pval:  0.9682706305048941
# NPY2R
# 20
# 13 20
# cur_pval:  0.9555255670550886
# SLC2A1
# 21
# 14 21
# cur_pval:  0.9396329373282147
# CCR3
# 22
# 15 22
# cur_pval:  0.9203588970211352
# CYP2C9
# 23
# 16 23
# cur_pval:  0.897561645045023
# Max: -0.0
# Avg: 0.22844875379224866
# [-0.0, 0.22084649366933243, 0.1575811241615704, 0.3406394909019338, 0.20047533572118648, 0.11862220064506394, 0.20114354908679202, 0.31366926668311634, 0.45904030773681104, 0.27503451529814965, 0.06294225400676465, 0.09582231411914427, 0.1400324092697292, 0.197576880099187, 0.2704176812987378, 0.3604278504414903, 0.46935714132921813]
# external_top_dataset:  ExtraTrees_vs_Seizure
# external_top_dataset:  ExtraTrees_vs_Myoclonic_seizure
# external_top_dataset:  ExtraTrees_vs_Psychogenic_non-epileptic_seizure
# external_top_dataset:  ExtraTrees_vs_Generalized_myoclonic_seizure
# external_top_dataset:  ExtraTrees_vs_Dialeptic_seizure
# external_top_dataset:  ExtraTrees_vs_Epileptic_encephalopathy
# external_top_dataset:  ExtraTrees_vs_Atonic_seizure
# external_top_dataset:  ExtraTrees_vs_Focal_motor_seizure
# external_top_dataset:  ExtraTrees_vs_Focal-onset_seizure
# external_top_dataset:  ExtraTrees_vs_Symptomatic_seizures
# epilepsy_drugnomefull\chem\ExtraTrees-hits.intersection.txt
# epilepsy_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     NPY1R         0.999846      100.000000         0.0
# 1      IL1B         0.999807       99.994961         0.0
# 2     HIF1A         0.999801       99.989922         0.0
# 3     NPY5R         0.999788       99.984884         0.0
# 4     OPRL1         0.999769       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 48      GRM5         0.998970       99.758138         1.0
# 54     CASP8         0.998801       99.727905         1.0
# 68    SLC1A2         0.998485       99.657362         1.0
# 75      GRM1         0.998300       99.622090         1.0
# 99     P2RX7         0.997749       99.501159         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      GRM5         0.998970          1
# 1     CASP3         0.995203         10
# 2    SLC2A1         0.989757         23
# 3      ALPL         0.989009         25
# 4      GRM7         0.981820         32
#
#     Gene_Name  mantis_ml_proba  full_rank
# 9      MECP2         0.641082         92
# 10    EEF1A2         0.097554        106
# 11     CDKL5         0.040815        111
# 12      POLG         0.010027        114
# 13       PAM         0.008235        115
# (14, 3)
# GRM5
# 1
# 0 1
# cur_pval:  1.0
# CASP3
# 10
# 1 10
# cur_pval:  0.7422532914551502
# SLC2A1
# 23
# 2 23
# cur_pval:  0.8203377253762766
# Max: -0.0
# Avg: 0.7181839456998
# [-0.0, 1.2944786788801106, 0.8600731582192895]
# epilepsy_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     NPY1R         0.999846      100.000000         0.0
# 1      IL1B         0.999807       99.994961         0.0
# 2     HIF1A         0.999801       99.989922         0.0
# 3     NPY5R         0.999788       99.984884         0.0
# 4     OPRL1         0.999769       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 48      GRM5         0.998970       99.758138         1.0
# 54     CASP8         0.998801       99.727905         1.0
# 68    SLC1A2         0.998485       99.657362         1.0
# 75      GRM1         0.998300       99.622090         1.0
# 99     P2RX7         0.997749       99.501159         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      GRM5         0.998970          1
# 1     CASP8         0.998801          2
# 2    SLC1A2         0.998485          3
# 3      GRM1         0.998300          4
# 4     ABCB1         0.995924          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 55      VARS         0.170864        103
# 56    EEF1A2         0.097554        106
# 57     SGMS1         0.052210        110
# 58      POLG         0.010027        114
# 59       PAM         0.008235        115
# (60, 3)
# GRM5
# 1
# 0 1
# cur_pval:  1.0
# CASP8
# 2
# 1 2
# cur_pval:  0.7734553775743689
# SLC1A2
# 3
# 2 3
# cur_pval:  0.5328770174763569
# GRM1
# 4
# 3 4
# cur_pval:  0.34277715257748076
# ABCB1
# 7
# 4 7
# cur_pval:  0.5487580719930168
# ERN1
# 8
# 5 8
# cur_pval:  0.408171208156029
# CCL2
# 9
# 6 9
# cur_pval:  0.2904461333916027
# CASP3
# 10
# 7 10
# cur_pval:  0.19882048557966372
# KCNJ3
# 12
# 8 12
# cur_pval:  0.22584429811132456
# NOS2
# 13
# 9 13
# cur_pval:  0.1557757830827924
# GRM4
# 15
# 10 15
# cur_pval:  0.17712991081913457
# GRM3
# 18
# 11 18
# cur_pval:  0.2855833055432886
# EIF2AK3
# 20
# 12 20
# cur_pval:  0.3009611392588756
# TGFB1
# 22
# 13 22
# cur_pval:  0.3148294923643432
# SLC2A1
# 23
# 14 23
# cur_pval:  0.2425983272882398
# Max: -0.0
# Avg: 4.750912290062503
# [-0.0, 1.1156473669276814, 2.733730100995559, 4.649881331905118, 2.6061907841954075, 3.891576330838449, 5.369344007607192, 7.015388698589834, 6.461908695925026, 8.075000568751214, 7.517080960269842, 5.442671838788504, 5.214895778114174, 5.019245908900149, 6.1511219791294005]
# epilepsy_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     NPY1R         0.999846      100.000000         0.0
# 1      IL1B         0.999807       99.994961         0.0
# 2     HIF1A         0.999801       99.989922         0.0
# 3     NPY5R         0.999788       99.984884         0.0
# 4     OPRL1         0.999769       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 48      GRM5         0.998970       99.758138         1.0
# 54     CASP8         0.998801       99.727905         1.0
# 68    SLC1A2         0.998485       99.657362         1.0
# 75      GRM1         0.998300       99.622090         1.0
# 99     P2RX7         0.997749       99.501159         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP8         0.998801          2
# 1      GRM1         0.998300          4
# 2     ABCB1         0.995924          7
# 3   EIF2AK3         0.992185         20
# 4    SLC2A1         0.989757         23
#
#     Gene_Name  mantis_ml_proba  full_rank
# 21       ADK         0.643685         90
# 22      QARS         0.345364        101
# 23     DDX3X         0.189168        102
# 24      VARS         0.170864        103
# 25      POLG         0.010027        114
# (26, 3)
# CASP8
# 2
# 0 2
# cur_pval:  1.0
# GRM1
# 4
# 1 4
# cur_pval:  0.6468239664185467
# ABCB1
# 7
# 2 7
# cur_pval:  0.49789661569365845
# EIF2AK3
# 20
# 3 20
# cur_pval:  0.8866298349275505
# SLC2A1
# 23
# 4 23
# cur_pval:  0.8273207025526532
# Max: -0.0
# Avg: 1.2533169785515974
# [-0.0, 1.8921389678899228, 3.0286082570398296, 0.522576588629893, 0.8232610791983409]
# epilepsy_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     NPY1R         0.999846      100.000000         0.0
# 1      IL1B         0.999807       99.994961         0.0
# 2     HIF1A         0.999801       99.989922         0.0
# 3     NPY5R         0.999788       99.984884         0.0
# 4     OPRL1         0.999769       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 48      GRM5         0.998970       99.758138         1.0
# 54     CASP8         0.998801       99.727905         1.0
# 68    SLC1A2         0.998485       99.657362         1.0
# 75      GRM1         0.998300       99.622090         1.0
# 99     P2RX7         0.997749       99.501159         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP8         0.998801          2
# 1     ABCB1         0.995924          7
# 2      ERN1         0.995764          8
# 3      CCL2         0.995224          9
# 4     KCNJ3         0.994296         12
#
#     Gene_Name  mantis_ml_proba  full_rank
# 38      QARS         0.345364        101
# 39     KCNK5         0.069715        108
# 40     SGMS1         0.052210        110
# 41      POLG         0.010027        114
# 42       PAM         0.008235        115
# (43, 3)
# CASP8
# 2
# 0 2
# cur_pval:  1.0
# ABCB1
# 7
# 1 7
# cur_pval:  0.9663779409069391
# ERN1
# 8
# 2 8
# cur_pval:  0.8726720169531297
# CCL2
# 9
# 3 9
# cur_pval:  0.7255449587826741
# KCNJ3
# 12
# 4 12
# cur_pval:  0.7275773743436519
# NOS2
# 13
# 5 13
# cur_pval:  0.5787402847184828
# GRM3
# 18
# 6 18
# cur_pval:  0.7394844648936437
# EIF2AK3
# 20
# 7 20
# cur_pval:  0.6862164607533763
# TGFB1
# 22
# 8 22
# cur_pval:  0.6343343367576327
# SLC2A1
# 23
# 9 23
# cur_pval:  0.5142104835384633
# Max: -0.0
# Avg: 1.3701253806626295
# [-0.0, 0.14852992062898082, 0.5914894986997751, 1.3933567110182556, 1.381208147631496, 2.3751628639052154, 1.3107094523954905, 1.6353886842992296, 1.976817794416411, 2.8885907336314407]
# epilepsy_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     NPY1R         0.999846      100.000000         0.0
# 1      IL1B         0.999807       99.994961         0.0
# 2     HIF1A         0.999801       99.989922         0.0
# 3     NPY5R         0.999788       99.984884         0.0
# 4     OPRL1         0.999769       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 48      GRM5         0.998970       99.758138         1.0
# 54     CASP8         0.998801       99.727905         1.0
# 68    SLC1A2         0.998485       99.657362         1.0
# 75      GRM1         0.998300       99.622090         1.0
# 99     P2RX7         0.997749       99.501159         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP8         0.998801          2
# 1     ABCB1         0.995924          7
# 2      CCL2         0.995224          9
# 3      NOS2         0.993888         13
# 4      GRM8         0.992942         16
#
#     Gene_Name  mantis_ml_proba  full_rank
# 26      QARS         0.345364        101
# 27       ICK         0.143767        104
# 28      PPIG         0.016110        113
# 29      POLG         0.010027        114
# 30       PAM         0.008235        115
# (31, 3)
# CASP8
# 2
# 0 2
# cur_pval:  1.0
# ABCB1
# 7
# 1 7
# cur_pval:  0.8966223606013567
# CCL2
# 9
# 2 9
# cur_pval:  0.7554666170853299
# NOS2
# 13
# 3 13
# cur_pval:  0.7387199804235683
# GRM8
# 16
# 4 16
# cur_pval:  0.6787890030377728
# GRM3
# 18
# 5 18
# cur_pval:  0.5683689852057322
# EIF2AK3
# 20
# 6 20
# cur_pval:  0.4647327418932396
# GLUL
# 36
# 7 36
# cur_pval:  0.9293706013435266
# Max: -0.0
# Avg: 1.348672425239633
# [-0.0, 0.4739043459281305, 1.2178472171006358, 1.3152015430194473, 1.6826520223930546, 2.4536962870639916, 3.327967290217976, 0.3181106961938269]
# epilepsy_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     NPY1R         0.999846      100.000000         0.0
# 1      IL1B         0.999807       99.994961         0.0
# 2     HIF1A         0.999801       99.989922         0.0
# 3     NPY5R         0.999788       99.984884         0.0
# 4     OPRL1         0.999769       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 48      GRM5         0.998970       99.758138         1.0
# 54     CASP8         0.998801       99.727905         1.0
# 68    SLC1A2         0.998485       99.657362         1.0
# 75      GRM1         0.998300       99.622090         1.0
# 99     P2RX7         0.997749       99.501159         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP8         0.998801          2
# 1     ABCB1         0.995924          7
# 2      ERN1         0.995764          8
# 3      CCL2         0.995224          9
# 4     CASP3         0.995203         10
#
#     Gene_Name  mantis_ml_proba  full_rank
# 36     SGMS1         0.052210        110
# 37     CDKL5         0.040815        111
# 38      PPIG         0.016110        113
# 39      POLG         0.010027        114
# 40       PAM         0.008235        115
# (41, 3)
# CASP8
# 2
# 0 2
# cur_pval:  1.0
# ABCB1
# 7
# 1 7
# cur_pval:  0.9589266478469719
# ERN1
# 8
# 2 8
# cur_pval:  0.849778017588446
# CCL2
# 9
# 3 9
# cur_pval:  0.6865651125289787
# CASP3
# 10
# 4 10
# cur_pval:  0.5064150192086184
# NOS2
# 13
# 5 13
# cur_pval:  0.5234579371434196
# GRM4
# 15
# 6 15
# cur_pval:  0.4568127308895012
# GRM3
# 18
# 7 18
# cur_pval:  0.47521717076776243
# EIF2AK3
# 20
# 8 20
# cur_pval:  0.4187752116485421
# SLC2A1
# 23
# 9 23
# cur_pval:  0.4366020245065982
# Max: -0.0
# Avg: 2.230141986991623
# [-0.0, 0.18214612489063348, 0.7069450761166867, 1.633182688116698, 2.954934225351348, 2.811182106430994, 3.4026180126392402, 3.2310787561321663, 3.7801903320824817, 3.599142548155977]
# epilepsy_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     NPY1R         0.999846      100.000000         0.0
# 1      IL1B         0.999807       99.994961         0.0
# 2     HIF1A         0.999801       99.989922         0.0
# 3     NPY5R         0.999788       99.984884         0.0
# 4     OPRL1         0.999769       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 48      GRM5         0.998970       99.758138         1.0
# 54     CASP8         0.998801       99.727905         1.0
# 68    SLC1A2         0.998485       99.657362         1.0
# 75      GRM1         0.998300       99.622090         1.0
# 99     P2RX7         0.997749       99.501159         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
#
#  Population Size: 115
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# 99     P2RX7         0.997749          5
# full_rank_cutoff: 23
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     CASP8         0.998801          2
# 1      GRM1         0.998300          4
# 2       ALB         0.997204          6
# 3     ABCB1         0.995924          7
# 4      ERN1         0.995764          8
#
#     Gene_Name  mantis_ml_proba  full_rank
# 52     KCNT2         0.057215        109
# 53     SGMS1         0.052210        110
# 54      PPIG         0.016110        113
# 55      POLG         0.010027        114
# 56       PAM         0.008235        115
# (57, 3)
# CASP8
# 2
# 0 2
# cur_pval:  1.0
# GRM1
# 4
# 1 4
# cur_pval:  0.9386302424009249
# ALB
# 6
# 2 6
# cur_pval:  0.892791406258122
# ABCB1
# 7
# 3 7
# cur_pval:  0.773568378308732
# ERN1
# 8
# 4 8
# cur_pval:  0.6318990395417108
# CCL2
# 9
# 5 9
# cur_pval:  0.4889056882628465
# CASP3
# 10
# 6 10
# cur_pval:  0.36021167211186894
# NOS2
# 13
# 7 13
# cur_pval:  0.48652378791768724
# GRM2
# 14
# 8 14
# cur_pval:  0.37486374494996333
# GRM4
# 15
# 9 15
# cur_pval:  0.27812855921059876
# GRM8
# 16
# 10 16
# cur_pval:  0.19912815752345
# GRM3
# 18
# 11 18
# cur_pval:  0.20922323491547057
# CCR2
# 19
# 12 19
# cur_pval:  0.14781080940971345
# EIF2AK3
# 20
# 13 20
# cur_pval:  0.10121839630899107
# NPY2R
# 21
# 14 21
# cur_pval:  0.06726441105340472
# TGFB1
# 22
# 15 22
# cur_pval:  0.043424378852672724
# SLC2A1
# 23
# 16 23
# cur_pval:  0.027257589991101703
# Max: -0.0
# Avg: 5.729934368662695
# [-0.0, 0.27505457052726884, 0.49249998774595743, 1.1150129151904589, 1.9935230474370635, 3.1077490982801397, 4.4344221863573265, 3.1289592063956704, 4.261265604575006, 5.557544139738427, 7.008673246414656, 6.793900873226988, 8.302938048090297, 9.947405478775892, 11.722146560023809, 13.622663850348308, 15.645125454138544]
# epilepsy_drugnomefull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     NPY1R         0.999846      100.000000         0.0
# 1      IL1B         0.999807       99.994961         0.0
# 2     HIF1A         0.999801       99.989922         0.0
# 3     NPY5R         0.999788       99.984884         0.0
# 4     OPRL1         0.999769       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 48      GRM5         0.998970       99.758138         1.0
# 54     CASP8         0.998801       99.727905         1.0
# 68    SLC1A2         0.998485       99.657362         1.0
# 75      GRM1         0.998300       99.622090         1.0
# 99     P2RX7         0.997749       99.501159         1.0
# (115, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 48      GRM5         0.998970          1
# 54     CASP8         0.998801          2
# 68    SLC1A2         0.998485          3
# 75      GRM1         0.998300          4
# ...
# epilepsy_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      GFAP         0.951744      100.000000         1.0
# 1       MBP         0.947350       99.994961         0.0
# 2       FTL         0.944930       99.989922         0.0
# 3     CALM3         0.926912       99.984884         0.0
# 4       CLU         0.911780       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       GFAP         0.951744      100.000000         1.0
# 4        CLU         0.911780       99.979845         1.0
# 14      TSC1         0.854300       99.929457         1.0
# 35   SLC17A7         0.795543       99.823642         1.0
# 39       MT3         0.785350       99.803487         1.0
# (365, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 0       GFAP         0.951744          1
# 4        CLU         0.911780          2
# 14      TSC1         0.854300          3
# 35   SLC17A7         0.795543          4
# 39       MT3         0.785350          5
#
#  Population Size: 365
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 0       GFAP         0.951744          1
# 4        CLU         0.911780          2
# 14      TSC1         0.854300          3
# 35   SLC17A7         0.795543          4
# 39       MT3         0.785350          5
# full_rank_cutoff: 73
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      GFAP         0.951744          1
# 1       CLU         0.911780          2
# 2       MT3         0.785350          5
# 3      APOE         0.779079          6
# 4   SPARCL1         0.760562          9
#
#      Gene_Name  mantis_ml_proba  full_rank
# 219      CCT5         0.270791        357
# 220     MRPS7         0.267075        358
# 221    ELOVL4         0.265542        359
# 222    ZNF451         0.264590        360
# 223  SMARCAD1         0.259072        361
# (224, 3)
# GFAP
# 1
# 0 1
# cur_pval:  1.0
# CLU
# 2
# 1 2
# cur_pval:  0.8514225500527215
# MT3
# 5
# 2 5
# cur_pval:  0.9244804024174522
# APOE
# 6
# 3 6
# cur_pval:  0.8411171270163126
# SPARCL1
# 9
# 4 9
# cur_pval:  0.9177853692241453
# TSPAN7
# 10
# 5 10
# cur_pval:  0.8590020169127301
# CNTNAP2
# 11
# 6 11
# cur_pval:  0.7861437774280435
# CREB1
# 13
# 7 13
# cur_pval:  0.8055733992465274
# CACNG4
# 16
# 8 16
# cur_pval:  0.8872888334953379
# SCN1B
# 18
# 9 18
# cur_pval:  0.8957680947583444
# CACNG2
# 19
# 10 19
# cur_pval:  0.8519007465770373
# SOD2
# 22
# 11 22
# cur_pval:  0.911071946819308
# INS
# 25
# 12 25
# cur_pval:  0.9474501032514461
# ATP7A
# 27
# 13 27
# cur_pval:  0.9511868603428653
# KCNJ10
# 28
# 14 28
# cur_pval:  0.9302031279428887
# AGT
# 29
# 15 29
# cur_pval:  0.9039267627418879
# KCNAB2
# 31
# 16 31
# cur_pval:  0.9117933312790015
# KCNAB1
# 32
# 17 32
# cur_pval:  0.8828366150809775
# DCX
# 35
# 18 35
# cur_pval:  0.9256403424659619
# CNTN2
# 37
# 19 37
# cur_pval:  0.9317356157323177
# ADAM22
# 38
# 20 38
# cur_pval:  0.9096407332801647
# PAFAH1B1
# 39
# 21 39
# cur_pval:  0.8833228228365533
# CACNB4
# 40
# 22 40
# cur_pval:  0.8527377665275833
# JUND
# 41
# 23 41
# cur_pval:  0.818003408873181
# SST
# 44
# 24 44
# cur_pval:  0.8757590468347202
# NRP2
# 45
# 25 45
# cur_pval:  0.845865663733858
# DAB1
# 46
# 26 46
# cur_pval:  0.8122356077454664
# PRNP
# 48
# 27 48
# cur_pval:  0.8268423516027743
# NDRG4
# 50
# 28 50
# cur_pval:  0.8403663583471249
# EMX2
# 52
# 29 52
# cur_pval:  0.8528902832246124
# CERS1
# 53
# 30 53
# cur_pval:  0.8223830192372652
# GAD2
# 54
# 31 54
# cur_pval:  0.7886979152513541
# AQP4
# 57
# 32 57
# cur_pval:  0.8486108175083302
# NEU1
# 58
# 33 58
# cur_pval:  0.8188964895106937
# LGI4
# 59
# 34 59
# cur_pval:  0.7862344860974425
# CRH
# 60
# 35 60
# cur_pval:  0.7508569278063528
# PCDH19
# 61
# 36 61
# cur_pval:  0.713076678202787
# EXT1
# 63
# 37 63
# cur_pval:  0.7321631807574266
# CLIP1
# 64
# 38 64
# cur_pval:  0.6939825004230898
# BDNF
# 65
# 39 65
# cur_pval:  0.6540326506026082
# CCK
# 66
# 40 66
# cur_pval:  0.6127511391219168
# SYN1
# 68
# 41 68
# cur_pval:  0.6351799737688527
# ADAM11
# 69
# 42 69
# cur_pval:  0.5940719943958386
# GNB3
# 70
# 43 70
# cur_pval:  0.5523192228752319
# SLC25A22
# 72
# 44 72
# cur_pval:  0.575848406871079
# DIAPH1
# 74
# 45 74
# cur_pval:  0.5986417723934438
# Max: -0.0
# Avg: 0.9185629072401114
# [-0.0, 0.6985485165268894, 0.341022907916334, 0.7514352373240878, 0.3725886984452541, 0.660058164562538, 1.0449801880371634, 0.9389488300953208, 0.5193498403033475, 0.4780441020697782, 0.6961100115449783, 0.40447325691282654, 0.2344365255056648, 0.21734157674480564, 0.31422204443882795, 0.4386675517235284, 0.40103588487776726, 0.5411966305245159, 0.33557725654678494, 0.3070730322268888, 0.4113010038417477, 0.5388054834275326, 0.691845023136169, 0.8724488648548965, 0.5761536760421369, 0.726986040196244, 0.9031797531336163, 0.8257728652428258, 0.7553134165000248, 0.691068333750649, 0.8492586567332587, 1.030893071339465, 0.7129143644610303, 0.8677099063928146, 1.0444791091868855, 1.244428078475579, 1.4686376730123465, 1.3539211483708213, 1.5865148064818249, 1.8440057029562351, 2.1271587270925396, 1.9710320299088615, 2.261609205504806, 2.5780984136194744, 2.3969183033434884, 2.2283298197125543]
# epilepsy_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      GFAP         0.951744      100.000000         1.0
# 1       MBP         0.947350       99.994961         0.0
# 2       FTL         0.944930       99.989922         0.0
# 3     CALM3         0.926912       99.984884         0.0
# 4       CLU         0.911780       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       GFAP         0.951744      100.000000         1.0
# 4        CLU         0.911780       99.979845         1.0
# 14      TSC1         0.854300       99.929457         1.0
# 35   SLC17A7         0.795543       99.823642         1.0
# 39       MT3         0.785350       99.803487         1.0
# (365, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 0       GFAP         0.951744          1
# 4        CLU         0.911780          2
# 14      TSC1         0.854300          3
# 35   SLC17A7         0.795543          4
# 39       MT3         0.785350          5
#
#  Population Size: 365
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 0       GFAP         0.951744          1
# 4        CLU         0.911780          2
# 14      TSC1         0.854300          3
# 35   SLC17A7         0.795543          4
# 39       MT3         0.785350          5
# full_rank_cutoff: 73
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      GFAP         0.951744          1
# 1      TSC1         0.854300          3
# 2   SLC17A7         0.795543          4
# 3      APOE         0.779079          6
# 4      CDH2         0.769305          8
#
#      Gene_Name  mantis_ml_proba  full_rank
# 193    AFG3L2         0.287283        351
# 194   RHOBTB2         0.273385        355
# 195      CCT5         0.270791        357
# 196    ZNF451         0.264590        360
# 197  SMARCAD1         0.259072        361
# (198, 3)
# GFAP
# 1
# 0 1
# cur_pval:  1.0
# TSC1
# 3
# 1 3
# cur_pval:  0.9051564873482861
# SLC17A7
# 4
# 2 4
# cur_pval:  0.749529287030567
# APOE
# 6
# 3 6
# cur_pval:  0.7338021102259409
# CDH2
# 8
# 4 8
# cur_pval:  0.7272135878579011
# CNTNAP2
# 11
# 5 11
# cur_pval:  0.8163162382895698
# CREB1
# 13
# 6 13
# cur_pval:  0.8105769352939429
# TSC2
# 15
# 7 15
# cur_pval:  0.8069676636155787
# CACNG4
# 16
# 8 16
# cur_pval:  0.7282649166161198
# CACNG2
# 19
# 9 19
# cur_pval:  0.8037733365002362
# DPYSL2
# 21
# 10 21
# cur_pval:  0.8034976453426448
# SOD2
# 22
# 11 22
# cur_pval:  0.7373356143451606
# SLC6A11
# 23
# 12 23
# cur_pval:  0.6648081401323763
# CACNG3
# 24
# 13 24
# cur_pval:  0.588799205778444
# SYT1
# 26
# 14 26
# cur_pval:  0.5990233610782125
# ATP7A
# 27
# 15 27
# cur_pval:  0.5253483882013987
# KCNJ10
# 28
# 16 28
# cur_pval:  0.4531556337138158
# SLC4A10
# 30
# 17 30
# cur_pval:  0.4674482459941592
# KCNAB2
# 31
# 18 31
# cur_pval:  0.40019893279602925
# KCNAB1
# 32
# 19 32
# cur_pval:  0.3374351443140172
# DCX
# 35
# 20 35
# cur_pval:  0.4289950505846625
# GNAO1
# 36
# 21 36
# cur_pval:  0.36766780741842864
# CNTN2
# 37
# 22 37
# cur_pval:  0.3107876548333511
# ADAM22
# 38
# 23 38
# cur_pval:  0.2591651327602798
# PAFAH1B1
# 39
# 24 39
# cur_pval:  0.2132601430482203
# CACNB4
# 40
# 25 40
# cur_pval:  0.17321648829551814
# JUND
# 41
# 26 41
# cur_pval:  0.1389144775781257
# ADAM23
# 43
# 27 43
# cur_pval:  0.15040478862344359
# NRP2
# 45
# 28 45
# cur_pval:  0.16182564584311088
# DAB1
# 46
# 29 46
# cur_pval:  0.13050701443632315
# MLST8
# 49
# 30 49
# cur_pval:  0.18439360563609453
# GAD2
# 54
# 31 54
# cur_pval:  0.36161056894422067
# GAD1
# 55
# 32 55
# cur_pval:  0.31343443092392925
# FLNA
# 56
# 33 56
# cur_pval:  0.268827795065605
# NEU1
# 58
# 34 58
# cur_pval:  0.279901806900007
# LGI4
# 59
# 35 59
# cur_pval:  0.23878998277362895
# PCDH19
# 61
# 36 61
# cur_pval:  0.24928735415433906
# TBCD
# 62
# 37 62
# cur_pval:  0.21158102646755111
# EXT1
# 63
# 38 63
# cur_pval:  0.1777997085400328
# CLIP1
# 64
# 39 64
# cur_pval:  0.1479422749622736
# SYN1
# 68
# 40 68
# cur_pval:  0.24090607032728564
# ADAM11
# 69
# 41 69
# cur_pval:  0.2053264656704016
# GNB3
# 70
# 42 70
# cur_pval:  0.1733646289886599
# DIAPH1
# 74
# 43 74
# cur_pval:  0.26947065430297573
# Max: -0.0
# Avg: 4.370438904684129
# [-0.0, 0.4327633160500271, 1.2521139290606988, 1.3442104365916066, 1.383380149943175, 0.8814156436127629, 0.9120575812834925, 0.93143867749661, 1.3771061121423336, 0.9486640471636704, 0.9501539160280782, 1.3233478855718612, 1.7730367154504991, 2.3003278448283986, 2.2255624039946236, 2.7955259584447107, 3.437526164089531, 3.3026646548314305, 3.9772407382427897, 4.718096870498262, 3.6754771834247704, 4.34544394805056, 5.075362406569548, 5.864234274479935, 6.710903038175862, 7.614107703155812, 8.572524900101264, 8.227383363532159, 7.90952651045459, 8.843661454205593, 7.342541433968669, 4.41758884703653, 5.038532977878712, 5.705258300395278, 5.529942979462367, 6.219838957896774, 6.032997518222867, 6.7452328025641375, 7.500689552868355, 8.29907707278254, 6.1815225655446495, 6.875550683896251, 7.6103950548731225, 5.694885231236828]
# epilepsy_drugnomefull/bio\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0      GFAP         0.951744      100.000000         1.0
# 1       MBP         0.947350       99.994961         0.0
# 2       FTL         0.944930       99.989922         0.0
# 3     CALM3         0.926912       99.984884         0.0
# 4       CLU         0.911780       99.979845         1.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       GFAP         0.951744      100.000000         1.0
# 4        CLU         0.911780       99.979845         1.0
# 14      TSC1         0.854300       99.929457         1.0
# 35   SLC17A7         0.795543       99.823642         1.0
# 39       MT3         0.785350       99.803487         1.0
# (365, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 0       GFAP         0.951744          1
# 4        CLU         0.911780          2
# 14      TSC1         0.854300          3
# 35   SLC17A7         0.795543          4
# 39       MT3         0.785350          5
#
#  Population Size: 365
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 0       GFAP         0.951744          1
# 4        CLU         0.911780          2
# 14      TSC1         0.854300          3
# 35   SLC17A7         0.795543          4
# 39       MT3         0.785350          5
# full_rank_cutoff: 73
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      GFAP         0.951744          1
# 1      TSC1         0.854300          3
# 2       MT3         0.785350          5
# 3      APOE         0.779079          6
# 4      CDH2         0.769305          8
#
#      Gene_Name  mantis_ml_proba  full_rank
# 258    ZNF451         0.264590        360
# 259  SMARCAD1         0.259072        361
# 260      RTP1         0.255496        362
# 261      VRK2         0.229111        363
# 262    ATP2A2         0.225401        364
# (263, 3)
# GFAP
# 1
# 0 1
# cur_pval:  1.0
# TSC1
# 3
# 1 3
# cur_pval:  0.978639044641486
# MT3
# 5
# 2 5
# cur_pval:  0.9771344181891072
# APOE
# 6
# 3 6
# cur_pval:  0.9461606079299241
# CDH2
# 8
# 4 8
# cur_pval:  0.9583634051837124
# SPARCL1
# 9
# 5 9
# cur_pval:  0.9269375638625782
# CNTNAP2
# 11
# 6 11
# cur_pval:  0.9456016490270122
# SLIT2
# 12
# 7 12
# cur_pval:  0.915551928304623
# CREB1
# 13
# 8 13
# cur_pval:  0.8780475419402043
# RELN
# 14
# 9 14
# cur_pval:  0.8337241762368737
# TSC2
# 15
# 10 15
# cur_pval:  0.7836341428206198
# CACNG4
# 16
# 11 16
# cur_pval:  0.7291075635875336
# SCN1B
# 18
# 12 18
# cur_pval:  0.7895765217253577
# CACNG2
# 19
# 13 19
# cur_pval:  0.7406231477636672
# PLCB1
# 20
# 14 20
# cur_pval:  0.6887203819959383
# SOD2
# 22
# 15 22
# cur_pval:  0.7516651994051922
# CACNG3
# 24
# 16 24
# cur_pval:  0.8030795369353879
# INS
# 25
# 17 25
# cur_pval:  0.7622227134582134
# SYT1
# 26
# 18 26
# cur_pval:  0.7185737714216943
# ATP7A
# 27
# 19 27
# cur_pval:  0.6728217830136729
# KCNJ10
# 28
# 20 28
# cur_pval:  0.6256948127054903
# AGT
# 29
# 21 29
# cur_pval:  0.5779245662447743
# SLC4A10
# 30
# 22 30
# cur_pval:  0.5302152512208725
# KCNAB2
# 31
# 23 31
# cur_pval:  0.48321801552564314
# KCNAB1
# 32
# 24 32
# cur_pval:  0.4375116437633426
# PDYN
# 33
# 25 33
# cur_pval:  0.39358960483238004
# DCX
# 35
# 26 35
# cur_pval:  0.4652239888099655
# GNAO1
# 36
# 27 36
# cur_pval:  0.42221439738506467
# CNTN2
# 37
# 28 37
# cur_pval:  0.38090427309836117
# ADAM22
# 38
# 29 38
# cur_pval:  0.34162726904014334
# PAFAH1B1
# 39
# 30 39
# cur_pval:  0.30464069873119415
# CACNB4
# 40
# 31 40
# cur_pval:  0.2701274634919203
# SPTAN1
# 42
# 32 42
# cur_pval:  0.3319316036272666
# ADAM23
# 43
# 33 43
# cur_pval:  0.296891290568575
# SST
# 44
# 34 44
# cur_pval:  0.2641362153180667
# DAB1
# 46
# 35 46
# cur_pval:  0.3226802100520875
# SYNGAP1
# 47
# 36 47
# cur_pval:  0.2893436338678307
# PRNP
# 48
# 37 48
# cur_pval:  0.25813864169539197
# MLST8
# 49
# 38 49
# cur_pval:  0.22914984514731007
# NDRG4
# 50
# 39 50
# cur_pval:  0.20241584006971672
# STXBP1
# 51
# 40 51
# cur_pval:  0.1779341504381485
# EMX2
# 52
# 41 52
# cur_pval:  0.15566672827640182
# CERS1
# 53
# 42 53
# cur_pval:  0.13554571001201732
# GAD1
# 55
# 43 55
# cur_pval:  0.17525142718933373
# FLNA
# 56
# 44 56
# cur_pval:  0.1537981144964062
# AQP4
# 57
# 45 57
# cur_pval:  0.1343582194996005
# LGI4
# 59
# 46 59
# cur_pval:  0.1723189560955869
# PCDH19
# 61
# 47 61
# cur_pval:  0.2147218358701487
# EXT1
# 63
# 48 63
# cur_pval:  0.2608643749878398
# CCK
# 66
# 49 66
# cur_pval:  0.3926166816945
# PTPRD
# 67
# 50 67
# cur_pval:  0.3609478746059155
# ADAM11
# 69
# 51 69
# cur_pval:  0.413038096982029
# GNB3
# 70
# 52 70
# cur_pval:  0.3813380384924849
# GDNF
# 71
# 53 71
# cur_pval:  0.35067122832409003
# SLC25A22
# 72
# 54 72
# cur_pval:  0.3211872414716352
# SDF4
# 73
# 55 73
# cur_pval:  0.293011417858498
# Max: -0.0
# Avg: 3.680145048205642
# [-0.0, 0.0937746123694544, 0.10045689032168345, 0.24035137152797564, 0.18469778041376306, 0.32949517833015474, 0.24291779099550573, 0.383170183348869, 0.5648196855482276, 0.7897760469939992, 1.0588665012043625, 1.372083964741726, 1.0260577401207454, 1.3040271844249327, 1.6195706431047636, 1.2397555625404295, 0.9524144009921558, 1.1791811383911786, 1.4352863897483334, 1.7209995643503253, 2.0363744550628877, 2.381288442811748, 2.7554778428718385, 3.1585688254602218, 3.5901038434480497, 4.049563803208606, 3.3233789940535057, 3.7446696146351517, 4.1918415526599135, 4.664474707670006, 5.1621207718626465, 5.684312594383879, 4.789513958965825, 5.2740254242917555, 5.781720492492724, 4.91227669020406, 5.385860685328076, 5.881469794974019, 6.398804319024652, 6.937555047487624, 7.497406909071906, 8.07804202268565, 8.679142231782327, 7.5633843659709, 8.130489887792292, 8.717357600151166, 7.636669449844611, 6.6812378828053856, 5.83585226390781, 4.060312518222116, 4.42555511129046, 3.840098889101551, 4.186898716646252, 4.550998654064237, 4.93241714540668, 5.331154560406831]
# external_top_dataset:  SVC_vs_Seizure
# external_top_dataset:  SVC_vs_Myoclonic_seizure
# external_top_dataset:  SVC_vs_Psychogenic_non-epileptic_seizure
# external_top_dataset:  SVC_vs_Generalized_myoclonic_seizure
# external_top_dataset:  SVC_vs_Dialeptic_seizure
# external_top_dataset:  SVC_vs_Epileptic_encephalopathy
# external_top_dataset:  SVC_vs_Atonic_seizure
# external_top_dataset:  SVC_vs_Focal_motor_seizure
# external_top_dataset:  SVC_vs_Focal-onset_seizure
# external_top_dataset:  SVC_vs_Symptomatic_seizures
# epilepsy_drugnomefull\bio\SVC-hits.intersection.txt

# %%
run_hypergeom_test(disease='Polycystic kidney disease', folder='polycystic_kidney_drugnomefull', top=0.1)
# Out:
# (824,)
# external_top_ranking:  0        PDGFRA
# 328       ERBB3
# 470       SYNE2
# 57        ITGA3
# 3454    RALGAPB
# Name: Gene_Name, dtype: object
# (881,)
# external_top_ranking:  0      PDGFRA
# 314      SPTB
# 731     TRRAP
# 338      MDM2
# 490      HIRA
# Name: Gene_Name, dtype: object
# (1793,)
# external_top_ranking:  0         PDGFRA
# 676         EPRS
# 453         FLNA
# 141        LRRK2
# 11344    RAPGEF3
# Name: Gene_Name, dtype: object
# (1499,)
# external_top_ranking:  0        PDGFRA
# 4138    LAPTM4B
# 899         ATM
# 766         WRN
# 2612     RNF213
# Name: Gene_Name, dtype: object
# (2582,)
# external_top_ranking:  0       PDGFRA
# 369       TJP1
# 1387    SEMA5A
# 1895     FGFR3
# 4144    CEP192
# Name: Gene_Name, dtype: object
# (1974,)
# external_top_ranking:  0       PDGFRA
# 201       TSC2
# 1013      BRD1
# 1321      ATRX
# 418     PLXND1
# Name: Gene_Name, dtype: object
# (3781,)
# external_top_ranking:  0        PDGFRA
# 10078    LANCL1
# 8479      FARP2
# 3357      STAP2
# 1465       IGF2
# Name: Gene_Name, dtype: object
# (1405,)
# external_top_ranking:  0        PDGFRA
# 7046    ANGPTL3
# 5543      HBS1L
# 2707      TTC37
# 8774     PNPLA7
# Name: Gene_Name, dtype: object
# (1768,)
# external_top_ranking:  0       PDGFRA
# 24        JAG1
# 191       KLF4
# 377       BMP2
# 962    TNFAIP3
# Name: Gene_Name, dtype: object
# (3092,)
# external_top_ranking:  0       PDGFRA
# 935      MEIS1
# 114     CREBBP
# 1487     PRMT5
# 1939     CASZ1
# Name: Gene_Name, dtype: object
# []
# ['polycystic_kidney_drugnomefull/clin\\ExtraTreesClassifier.mantis-ml_predictions.csv', 'polycystic_kidney_drugnomefull/clin\\RandomForestClassifier.mantis-ml_predictions.csv', 'polycystic_kidney_drugnomefull/clin\\SVC.mantis-ml_predictions.csv']
# polycystic_kidney_drugnomefull/clin\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADCY9         0.837037      100.000000         0.0
# 1     MAPK1         0.826788       99.994961         0.0
# 2      RAF1         0.825983       99.989922         0.0
# 3    PRKACA         0.823895       99.984884         0.0
# 4       SMO         0.819882       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 16      PKD1         0.787488       99.919379         1.0
# 30      ARL6         0.764728       99.848836         1.0
# 38     NPHP3         0.759153       99.808526         1.0
# 92      ARF4         0.731780       99.536431         1.0
# 93      PKD2         0.731391       99.531392         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     NPHP3         0.759153          3
# 1     IFT88         0.723115          6
# 2    TMEM67         0.683044         14
# 3     TRPM4         0.564261         23
# 4      AQP1         0.531270         26
#
#    Gene_Name  mantis_ml_proba  full_rank
# 5    PRKCSH         0.520710         27
# 6      NEK8         0.500823         31
# 7     SEC63         0.464519         36
# 8     HDAC5         0.427529         43
# 9     GLIS3         0.352178         51
# (10, 3)
# NPHP3
# 3
# 0 3
# cur_pval:  1.0
# IFT88
# 6
# 1 6
# cur_pval:  0.6302044641048139
# Max: -0.0
# Avg: 1.002592623953378
# [-0.0, 2.005185247906756]
# polycystic_kidney_drugnomefull/clin\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADCY9         0.837037      100.000000         0.0
# 1     MAPK1         0.826788       99.994961         0.0
# 2      RAF1         0.825983       99.989922         0.0
# 3    PRKACA         0.823895       99.984884         0.0
# 4       SMO         0.819882       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 16      PKD1         0.787488       99.919379         1.0
# 30      ARL6         0.764728       99.848836         1.0
# 38     NPHP3         0.759153       99.808526         1.0
# 92      ARF4         0.731780       99.536431         1.0
# 93      PKD2         0.731391       99.531392         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD2         0.731391          5
# 1    TMEM67         0.683044         14
# 2      EGFR         0.622725         17
# 3      CFTR         0.609919         20
# 4       SRC         0.604170         21
#
#     Gene_Name  mantis_ml_proba  full_rank
# 6      PKHD1         0.463282         37
# 7      BICC1         0.447715         39
# 8       BRD4         0.431648         42
# 9      HDAC5         0.427529         43
# 10     GLIS3         0.352178         51
# (11, 3)
# PKD2
# 5
# 0 5
# cur_pval:  1.0
# TMEM67
# 14
# 1 14
# cur_pval:  0.9375608417505567
# Max: -0.0
# Avg: 0.1400026986456586
# [-0.0, 0.2800053972913172]
# polycystic_kidney_drugnomefull/clin\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADCY9         0.837037      100.000000         0.0
# 1     MAPK1         0.826788       99.994961         0.0
# 2      RAF1         0.825983       99.989922         0.0
# 3    PRKACA         0.823895       99.984884         0.0
# 4       SMO         0.819882       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 16      PKD1         0.787488       99.919379         1.0
# 30      ARL6         0.764728       99.848836         1.0
# 38     NPHP3         0.759153       99.808526         1.0
# 92      ARF4         0.731780       99.536431         1.0
# 93      PKD2         0.731391       99.531392         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     EXOC5         0.718751          7
# 1     KIF3A         0.699535         11
# 2    TMEM67         0.683044         14
# 3      EGFR         0.622725         17
# 4     TRPC1         0.613640         18
#
#      Gene_Name  mantis_ml_proba  full_rank
# 14      PKHD1         0.463282         37
# 15      BICC1         0.447715         39
# 16      HDAC5         0.427529         43
# 17      GLIS3         0.352178         51
# 18  KIAA0319L         0.326066         53
# (19, 3)
# EXOC5
# 7
# 0 7
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# polycystic_kidney_drugnomefull/clin\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADCY9         0.837037      100.000000         0.0
# 1     MAPK1         0.826788       99.994961         0.0
# 2      RAF1         0.825983       99.989922         0.0
# 3    PRKACA         0.823895       99.984884         0.0
# 4       SMO         0.819882       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 16      PKD1         0.787488       99.919379         1.0
# 30      ARL6         0.764728       99.848836         1.0
# 38     NPHP3         0.759153       99.808526         1.0
# 92      ARF4         0.731780       99.536431         1.0
# 93      PKD2         0.731391       99.531392         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     KIF3A         0.699535         11
# 1    TMEM67         0.683044         14
# 2      EGFR         0.622725         17
# 3     TRPC1         0.613640         18
# 4      CFTR         0.609919         20
#
#     Gene_Name  mantis_ml_proba  full_rank
# 9      SEC63         0.464519         36
# 10     BICC1         0.447715         39
# 11     HDAC5         0.427529         43
# 12     TTLL4         0.326668         52
# 13    PKD2L1         0.316992         56
# (14, 3)
# KIF3A
# 11
# 0 11
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# polycystic_kidney_drugnomefull/clin\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADCY9         0.837037      100.000000         0.0
# 1     MAPK1         0.826788       99.994961         0.0
# 2      RAF1         0.825983       99.989922         0.0
# 3    PRKACA         0.823895       99.984884         0.0
# 4       SMO         0.819882       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 16      PKD1         0.787488       99.919379         1.0
# 30      ARL6         0.764728       99.848836         1.0
# 38     NPHP3         0.759153       99.808526         1.0
# 92      ARF4         0.731780       99.536431         1.0
# 93      PKD2         0.731391       99.531392         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      ARL6         0.764728          2
# 1      EGFR         0.622725         17
# 2     TRPC4         0.610413         19
# 3     TRPM4         0.564261         23
# 4      AQP1         0.531270         26
#
#     Gene_Name  mantis_ml_proba  full_rank
# 8      BICC1         0.447715         39
# 9       BRD4         0.431648         42
# 10     HDAC5         0.427529         43
# 11    PKD1L1         0.326041         54
# 12    PKD2L1         0.316992         56
# (13, 3)
# ARL6
# 2
# 0 2
# cur_pval:  1.0
# EGFR
# 17
# 1 17
# cur_pval:  0.9848173568363496
# Max: -0.0
# Avg: 0.03322152910108833
# [-0.0, 0.06644305820217666]
# polycystic_kidney_drugnomefull/clin\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADCY9         0.837037      100.000000         0.0
# 1     MAPK1         0.826788       99.994961         0.0
# 2      RAF1         0.825983       99.989922         0.0
# 3    PRKACA         0.823895       99.984884         0.0
# 4       SMO         0.819882       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 16      PKD1         0.787488       99.919379         1.0
# 30      ARL6         0.764728       99.848836         1.0
# 38     NPHP3         0.759153       99.808526         1.0
# 92      ARF4         0.731780       99.536431         1.0
# 93      PKD2         0.731391       99.531392         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD1         0.787488          1
# 1     NPHP3         0.759153          3
# 2      PKD2         0.731391          5
# 3     IFT88         0.723115          6
# 4     EXOC5         0.718751          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 13     PKHD1         0.463282         37
# 14     HDAC7         0.461514         38
# 15     BICC1         0.447715         39
# 16      BRD4         0.431648         42
# 17     HDAC5         0.427529         43
# (18, 3)
# PKD1
# 1
# 0 1
# cur_pval:  1.0
# NPHP3
# 3
# 1 3
# cur_pval:  0.6089073349828394
# PKD2
# 5
# 2 5
# cur_pval:  0.39907107817555443
# IFT88
# 6
# 3 6
# cur_pval:  0.18445360609539715
# Max: -0.0
# Avg: 3.3712784745386175
# [-0.0, 2.1544879434195434, 3.98949745640941, 7.341128498325516]
# polycystic_kidney_drugnomefull/clin\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADCY9         0.837037      100.000000         0.0
# 1     MAPK1         0.826788       99.994961         0.0
# 2      RAF1         0.825983       99.989922         0.0
# 3    PRKACA         0.823895       99.984884         0.0
# 4       SMO         0.819882       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 16      PKD1         0.787488       99.919379         1.0
# 30      ARL6         0.764728       99.848836         1.0
# 38     NPHP3         0.759153       99.808526         1.0
# 92      ARF4         0.731780       99.536431         1.0
# 93      PKD2         0.731391       99.531392         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD2         0.731391          5
# 1     IFT88         0.723115          6
# 2      GNB2         0.693909         12
# 3     ADCY6         0.584632         22
# 4     TRPM4         0.564261         23
#
#     Gene_Name  mantis_ml_proba  full_rank
# 10     PI4KB         0.399793         46
# 11     VTI1B         0.359488         50
# 12    PKD1L1         0.326041         54
# 13    PKD2L1         0.316992         56
# 14      ABT1         0.267776         60
# (15, 3)
# PKD2
# 5
# 0 5
# cur_pval:  1.0
# IFT88
# 6
# 1 6
# cur_pval:  0.7902532790592476
# Max: -0.0
# Avg: 0.5111684671642637
# [-0.0, 1.0223369343285273]
# polycystic_kidney_drugnomefull/clin\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADCY9         0.837037      100.000000         0.0
# 1     MAPK1         0.826788       99.994961         0.0
# 2      RAF1         0.825983       99.989922         0.0
# 3    PRKACA         0.823895       99.984884         0.0
# 4       SMO         0.819882       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 16      PKD1         0.787488       99.919379         1.0
# 30      ARL6         0.764728       99.848836         1.0
# 38     NPHP3         0.759153       99.808526         1.0
# 92      ARF4         0.731780       99.536431         1.0
# 93      PKD2         0.731391       99.531392         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD2         0.731391          5
# 1    ARL13B         0.717350          8
# 2    TMEM67         0.683044         14
# 3     TRPM4         0.564261         23
# 4    MCOLN3         0.552381         25
#
#     Gene_Name  mantis_ml_proba  full_rank
# 9      BICC1         0.447715         39
# 10     ANKS6         0.434521         40
# 11    PKD1L1         0.326041         54
# 12      SSH1         0.325652         55
# 13    PKD2L1         0.316992         56
# (14, 3)
# PKD2
# 5
# 0 5
# cur_pval:  1.0
# ARL13B
# 8
# 1 8
# cur_pval:  0.8592445325892085
# Max: -0.0
# Avg: 0.32941611308427277
# [-0.0, 0.6588322261685455]
# polycystic_kidney_drugnomefull/clin\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADCY9         0.837037      100.000000         0.0
# 1     MAPK1         0.826788       99.994961         0.0
# 2      RAF1         0.825983       99.989922         0.0
# 3    PRKACA         0.823895       99.984884         0.0
# 4       SMO         0.819882       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 16      PKD1         0.787488       99.919379         1.0
# 30      ARL6         0.764728       99.848836         1.0
# 38     NPHP3         0.759153       99.808526         1.0
# 92      ARF4         0.731780       99.536431         1.0
# 93      PKD2         0.731391       99.531392         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD1         0.787488          1
# 1     NPHP3         0.759153          3
# 2      PKD2         0.731391          5
# 3     IFT88         0.723115          6
# 4    ARL13B         0.717350          8
#
#     Gene_Name  mantis_ml_proba  full_rank
# 21      BRD4         0.431648         42
# 22       PGP         0.420671         45
# 23     GLIS3         0.352178         51
# 24    PKD1L1         0.326041         54
# 25      FJX1         0.310730         57
# (26, 3)
# PKD1
# 1
# 0 1
# cur_pval:  1.0
# NPHP3
# 3
# 1 3
# cur_pval:  0.7709314390613764
# PKD2
# 5
# 2 5
# cur_pval:  0.6392170165216684
# IFT88
# 6
# 3 6
# cur_pval:  0.41764772394710986
# Max: -0.0
# Avg: 1.7163144910791208
# [-0.0, 1.1298424316991402, 1.9435167223740932, 3.79189881024325]
# polycystic_kidney_drugnomefull/clin\ExtraTreesClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     ADCY9         0.837037      100.000000         0.0
# 1     MAPK1         0.826788       99.994961         0.0
# 2      RAF1         0.825983       99.989922         0.0
# 3    PRKACA         0.823895       99.984884         0.0
# 4       SMO         0.819882       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 16      PKD1         0.787488       99.919379         1.0
# 30      ARL6         0.764728       99.848836         1.0
# 38     NPHP3         0.759153       99.808526         1.0
# 92      ARF4         0.731780       99.536431         1.0
# 93      PKD2         0.731391       99.531392         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 16      PKD1         0.787488          1
# 30      ARL6         0.764728          2
# 38     NPHP3         0.759153          3
# 92      ARF4         0.731780          4
# 93      PKD2         0.731391          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD1         0.787488          1
# 1     NPHP3         0.759153          3
# 2      PKD2         0.731391          5
# 3     IFT88         0.723115          6
# 4     EXOC5         0.718751          7
#
#     Gene_Name  mantis_ml_proba  full_rank
# 25       PGP         0.420671         45
# 26     GLIS3         0.352178         51
# 27    PKD1L1         0.326041         54
# 28      FJX1         0.310730         57
# 29      PIFO         0.261587         61
# (30, 3)
# PKD1
# 1
# 0 1
# cur_pval:  1.0
# NPHP3
# 3
# 1 3
# cur_pval:  0.8316705243834295
# PKD2
# 5
# 2 5
# cur_pval:  0.7394130233243473
# IFT88
# 6
# 3 6
# cur_pval:  0.5438379114300971
# Max: -0.0
# Avg: 1.189230288374223
# [-0.0, 0.8004869027382023, 1.3111290444171855, 2.645305206341504]
# external_top_dataset:  ExtraTrees_vs_Polycystic_kidney_dysplasia
# external_top_dataset:  ExtraTrees_vs_Ectopic_kidney
# external_top_dataset:  ExtraTrees_vs_Chronic_kidney_disease
# external_top_dataset:  ExtraTrees_vs_Stage_5_chronic_kidney_disease
# external_top_dataset:  ExtraTrees_vs_Renal_insufficiency
# external_top_dataset:  ExtraTrees_vs_Multiple_renal_cysts
# external_top_dataset:  ExtraTrees_vs_Abnormality_of_renal_excretion
# external_top_dataset:  ExtraTrees_vs_Abnormal_renal_insterstitial_morphology
# external_top_dataset:  ExtraTrees_vs_Abnormality_of_the_kidney
# external_top_dataset:  ExtraTrees_vs_Horseshoe_kidney
# polycystic_kidney_drugnomefull\clin\ExtraTrees-hits.intersection.txt
# polycystic_kidney_drugnomefull/clin\RandomForestClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PARP1         0.711791      100.000000         0.0
# 1    IFT122         0.697154       99.994961         0.0
# 2     WDR19         0.692675       99.989922         0.0
# 3     ASAP1         0.691995       99.984884         0.0
# 4     SEL1L         0.689564       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 20      PKD1         0.652569       99.899224         1.0
# 49     NPHP3         0.636505       99.753099         1.0
# 59     TRPV4         0.630877       99.702711         1.0
# 78      PKD2         0.623452       99.606974         1.0
# 80      EGFR         0.622961       99.596896         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     NPHP3         0.636505          2
# 1     IFT88         0.585501         12
# 2     TRPM4         0.576888         14
# 3    TMEM67         0.556578         18
# 4     HDAC5         0.528306         25
#
#    Gene_Name  mantis_ml_proba  full_rank
# 5      AQP1         0.495103         35
# 6      NEK8         0.468068         40
# 7     GLIS3         0.446672         42
# 8    PRKCSH         0.444336         44
# 9     SEC63         0.427500         45
# (10, 3)
# NPHP3
# 2
# 0 2
# cur_pval:  1.0
# IFT88
# 12
# 1 12
# cur_pval:  0.8775347910663129
# Max: -0.0
# Avg: 0.2836782816121415
# [-0.0, 0.567356563224283]
# polycystic_kidney_drugnomefull/clin\RandomForestClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PARP1         0.711791      100.000000         0.0
# 1    IFT122         0.697154       99.994961         0.0
# 2     WDR19         0.692675       99.989922         0.0
# 3     ASAP1         0.691995       99.984884         0.0
# 4     SEL1L         0.689564       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 20      PKD1         0.652569       99.899224         1.0
# 49     NPHP3         0.636505       99.753099         1.0
# 59     TRPV4         0.630877       99.702711         1.0
# 78      PKD2         0.623452       99.606974         1.0
# 80      EGFR         0.622961       99.596896         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD2         0.623452          4
# 1      EGFR         0.622961          5
# 2       SRC         0.577506         13
# 3      CFTR         0.569963         16
# 4    TMEM67         0.556578         18
#
#     Gene_Name  mantis_ml_proba  full_rank
# 6       BRD4         0.519536         29
# 7       NEK1         0.511177         32
# 8      BICC1         0.492739         36
# 9      PKHD1         0.481061         38
# 10     GLIS3         0.446672         42
# (11, 3)
# PKD2
# 4
# 0 4
# cur_pval:  1.0
# EGFR
# 5
# 1 5
# cur_pval:  0.5983255385966076
# SRC
# 13
# 2 13
# cur_pval:  0.6739288402529197
# Max: -0.0
# Avg: 1.3148280583921712
# [-0.0, 2.230624595766866, 1.7138595794096476]
# polycystic_kidney_drugnomefull/clin\RandomForestClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PARP1         0.711791      100.000000         0.0
# 1    IFT122         0.697154       99.994961         0.0
# 2     WDR19         0.692675       99.989922         0.0
# 3     ASAP1         0.691995       99.984884         0.0
# 4     SEL1L         0.689564       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 20      PKD1         0.652569       99.899224         1.0
# 49     NPHP3         0.636505       99.753099         1.0
# 59     TRPV4         0.630877       99.702711         1.0
# 78      PKD2         0.623452       99.606974         1.0
# 80      EGFR         0.622961       99.596896         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      EGFR         0.622961          5
# 1     TRPC1         0.606764          7
# 2     ADCY6         0.599658          8
# 3     EXOC5         0.596998          9
# 4     PRKD3         0.571330         15
#
#      Gene_Name  mantis_ml_proba  full_rank
# 14      PKHD1         0.481061         38
# 15       NEK8         0.468068         40
# 16      GLIS3         0.446672         42
# 17      SEC63         0.427500         45
# 18  KIAA0319L         0.415717         49
# (19, 3)
# EGFR
# 5
# 0 5
# cur_pval:  1.0
# TRPC1
# 7
# 1 7
# cur_pval:  0.9113918983392761
# Max: -0.0
# Avg: 0.20147418161064778
# [-0.0, 0.40294836322129557]
# polycystic_kidney_drugnomefull/clin\RandomForestClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PARP1         0.711791      100.000000         0.0
# 1    IFT122         0.697154       99.994961         0.0
# 2     WDR19         0.692675       99.989922         0.0
# 3     ASAP1         0.691995       99.984884         0.0
# 4     SEL1L         0.689564       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 20      PKD1         0.652569       99.899224         1.0
# 49     NPHP3         0.636505       99.753099         1.0
# 59     TRPV4         0.630877       99.702711         1.0
# 78      PKD2         0.623452       99.606974         1.0
# 80      EGFR         0.622961       99.596896         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      EGFR         0.622961          5
# 1     TRPC1         0.606764          7
# 2     PRKD3         0.571330         15
# 3      CFTR         0.569963         16
# 4    TMEM67         0.556578         18
#
#     Gene_Name  mantis_ml_proba  full_rank
# 9      BICC1         0.492739         36
# 10      NEK8         0.468068         40
# 11     SEC63         0.427500         45
# 12    PKD2L1         0.348615         55
# 13     TTLL4         0.347277         56
# (14, 3)
# EGFR
# 5
# 0 5
# cur_pval:  1.0
# TRPC1
# 7
# 1 7
# cur_pval:  0.8173173720838627
# Max: -0.0
# Avg: 0.4380463502611317
# [-0.0, 0.8760927005222634]
# polycystic_kidney_drugnomefull/clin\RandomForestClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PARP1         0.711791      100.000000         0.0
# 1    IFT122         0.697154       99.994961         0.0
# 2     WDR19         0.692675       99.989922         0.0
# 3     ASAP1         0.691995       99.984884         0.0
# 4     SEL1L         0.689564       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 20      PKD1         0.652569       99.899224         1.0
# 49     NPHP3         0.636505       99.753099         1.0
# 59     TRPV4         0.630877       99.702711         1.0
# 78      PKD2         0.623452       99.606974         1.0
# 80      EGFR         0.622961       99.596896         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      EGFR         0.622961          5
# 1      ARL6         0.588260         11
# 2     TRPM4         0.576888         14
# 3     HDAC7         0.530858         22
# 4     PPARG         0.528985         24
#
#     Gene_Name  mantis_ml_proba  full_rank
# 8       AQP1         0.495103         35
# 9      BICC1         0.492739         36
# 10     SEC63         0.427500         45
# 11    PKD2L1         0.348615         55
# 12    PKD1L1         0.283309         62
# (13, 3)
# EGFR
# 5
# 0 5
# cur_pval:  1.0
# ARL6
# 11
# 1 11
# cur_pval:  0.9219510521881928
# Max: -0.0
# Avg: 0.17646067851093655
# [-0.0, 0.3529213570218731]
# polycystic_kidney_drugnomefull/clin\RandomForestClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PARP1         0.711791      100.000000         0.0
# 1    IFT122         0.697154       99.994961         0.0
# 2     WDR19         0.692675       99.989922         0.0
# 3     ASAP1         0.691995       99.984884         0.0
# 4     SEL1L         0.689564       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 20      PKD1         0.652569       99.899224         1.0
# 49     NPHP3         0.636505       99.753099         1.0
# 59     TRPV4         0.630877       99.702711         1.0
# 78      PKD2         0.623452       99.606974         1.0
# 80      EGFR         0.622961       99.596896         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD1         0.652569          1
# 1     NPHP3         0.636505          2
# 2      PKD2         0.623452          4
# 3      EGFR         0.622961          5
# 4     EXOC5         0.596998          9
#
#     Gene_Name  mantis_ml_proba  full_rank
# 13     HDAC5         0.528306         25
# 14      GNB2         0.526194         26
# 15      BRD4         0.519536         29
# 16     BICC1         0.492739         36
# 17     PKHD1         0.481061         38
# (18, 3)
# PKD1
# 1
# 0 1
# cur_pval:  1.0
# NPHP3
# 2
# 1 2
# cur_pval:  0.4622475856014042
# PKD2
# 4
# 2 4
# cur_pval:  0.28399958250704466
# EGFR
# 5
# 3 5
# cur_pval:  0.1113923390042792
# EXOC5
# 9
# 4 9
# cur_pval:  0.1798230440325352
# Max: -0.0
# Avg: 5.160213957067997
# [-0.0, 3.3512534855759553, 5.466822983861314, 9.531446766899043, 7.451546549003675]
# polycystic_kidney_drugnomefull/clin\RandomForestClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PARP1         0.711791      100.000000         0.0
# 1    IFT122         0.697154       99.994961         0.0
# 2     WDR19         0.692675       99.989922         0.0
# 3     ASAP1         0.691995       99.984884         0.0
# 4     SEL1L         0.689564       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 20      PKD1         0.652569       99.899224         1.0
# 49     NPHP3         0.636505       99.753099         1.0
# 59     TRPV4         0.630877       99.702711         1.0
# 78      PKD2         0.623452       99.606974         1.0
# 80      EGFR         0.622961       99.596896         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD2         0.623452          4
# 1     ADCY6         0.599658          8
# 2     IFT88         0.585501         12
# 3     TRPM4         0.576888         14
# 4    SLC4A2         0.557183         17
#
#     Gene_Name  mantis_ml_proba  full_rank
# 10     SEC63         0.427500         45
# 11     VTI1B         0.360431         53
# 12    PKD2L1         0.348615         55
# 13    PKD1L1         0.283309         62
# 14      ABT1         0.264694         63
# (15, 3)
# PKD2
# 4
# 0 4
# cur_pval:  1.0
# ADCY6
# 8
# 1 8
# cur_pval:  0.8800971944278401
# Max: -0.0
# Avg: 0.277346817244672
# [-0.0, 0.554693634489344]
# polycystic_kidney_drugnomefull/clin\RandomForestClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PARP1         0.711791      100.000000         0.0
# 1    IFT122         0.697154       99.994961         0.0
# 2     WDR19         0.692675       99.989922         0.0
# 3     ASAP1         0.691995       99.984884         0.0
# 4     SEL1L         0.689564       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 20      PKD1         0.652569       99.899224         1.0
# 49     NPHP3         0.636505       99.753099         1.0
# 59     TRPV4         0.630877       99.702711         1.0
# 78      PKD2         0.623452       99.606974         1.0
# 80      EGFR         0.622961       99.596896         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD2         0.623452          4
# 1     TRPM4         0.576888         14
# 2    TMEM67         0.556578         18
# 3     PPARG         0.528985         24
# 4    ARL13B         0.522750         28
#
#     Gene_Name  mantis_ml_proba  full_rank
# 9       NEK8         0.468068         40
# 10      ALG8         0.445565         43
# 11      SSH1         0.417359         48
# 12    PKD2L1         0.348615         55
# 13    PKD1L1         0.283309         62
# (14, 3)
# PKD2
# 4
# 0 4
# cur_pval:  1.0
# TRPM4
# 14
# 1 14
# cur_pval:  0.9736650153124957
# Max: -0.0
# Avg: 0.057952171585470766
# [-0.0, 0.11590434317094153]
# polycystic_kidney_drugnomefull/clin\RandomForestClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PARP1         0.711791      100.000000         0.0
# 1    IFT122         0.697154       99.994961         0.0
# 2     WDR19         0.692675       99.989922         0.0
# 3     ASAP1         0.691995       99.984884         0.0
# 4     SEL1L         0.689564       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 20      PKD1         0.652569       99.899224         1.0
# 49     NPHP3         0.636505       99.753099         1.0
# 59     TRPV4         0.630877       99.702711         1.0
# 78      PKD2         0.623452       99.606974         1.0
# 80      EGFR         0.622961       99.596896         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD1         0.652569          1
# 1     NPHP3         0.636505          2
# 2      PKD2         0.623452          4
# 3      EGFR         0.622961          5
# 4      OFD1         0.619896          6
#
#     Gene_Name  mantis_ml_proba  full_rank
# 21     GLIS3         0.446672         42
# 22    PRKCSH         0.444336         44
# 23     SEC63         0.427500         45
# 24      FJX1         0.354272         54
# 25    PKD1L1         0.283309         62
# (26, 3)
# PKD1
# 1
# 0 1
# cur_pval:  1.0
# NPHP3
# 2
# 1 2
# cur_pval:  0.6220368744512743
# PKD2
# 4
# 2 4
# cur_pval:  0.49604916593503073
# EGFR
# 5
# 3 5
# cur_pval:  0.2812973900550719
# OFD1
# 6
# 4 6
# cur_pval:  0.14494705616303524
# Max: -0.0
# Avg: 3.8005680873748533
# [-0.0, 2.0618386949562026, 3.044752762596618, 5.5083429730489755, 8.38790600627247]
# polycystic_kidney_drugnomefull/clin\RandomForestClassifier.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     PARP1         0.711791      100.000000         0.0
# 1    IFT122         0.697154       99.994961         0.0
# 2     WDR19         0.692675       99.989922         0.0
# 3     ASAP1         0.691995       99.984884         0.0
# 4     SEL1L         0.689564       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 20      PKD1         0.652569       99.899224         1.0
# 49     NPHP3         0.636505       99.753099         1.0
# 59     TRPV4         0.630877       99.702711         1.0
# 78      PKD2         0.623452       99.606974         1.0
# 80      EGFR         0.622961       99.596896         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 20      PKD1         0.652569          1
# 49     NPHP3         0.636505          2
# 59     TRPV4         0.630877          3
# 78      PKD2         0.623452          4
# 80      EGFR         0.622961          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD1         0.652569          1
# 1     NPHP3         0.636505          2
# 2      PKD2         0.623452          4
# 3      EGFR         0.622961          5
# 4      OFD1         0.619896          6
#
#     Gene_Name  mantis_ml_proba  full_rank
# 25    PRKCSH         0.444336         44
# 26     SEC63         0.427500         45
# 27      FJX1         0.354272         54
# 28      PIFO         0.309258         59
# 29    PKD1L1         0.283309         62
# (30, 3)
# PKD1
# 1
# 0 1
# cur_pval:  1.0
# NPHP3
# 2
# 1 2
# cur_pval:  0.6913959613696246
# PKD2
# 4
# 2 4
# cur_pval:  0.5985989427604875
# EGFR
# 5
# 3 5
# cur_pval:  0.38737782191469544
# OFD1
# 6
# 4 6
# cur_pval:  0.23091773239929544
# Max: -0.0
# Avg: 2.8630903582333045
# [-0.0, 1.6027316161746095, 2.228640545417542, 4.118652470546501, 6.365427159027869]
# external_top_dataset:  RandomForest_vs_Polycystic_kidney_dysplasia
# external_top_dataset:  RandomForest_vs_Ectopic_kidney
# external_top_dataset:  RandomForest_vs_Chronic_kidney_disease
# external_top_dataset:  RandomForest_vs_Stage_5_chronic_kidney_disease
# external_top_dataset:  RandomForest_vs_Renal_insufficiency
# external_top_dataset:  RandomForest_vs_Multiple_renal_cysts
# external_top_dataset:  RandomForest_vs_Abnormality_of_renal_excretion
# external_top_dataset:  RandomForest_vs_Abnormal_renal_insterstitial_morphology
# external_top_dataset:  RandomForest_vs_Abnormality_of_the_kidney
# external_top_dataset:  RandomForest_vs_Horseshoe_kidney
# polycystic_kidney_drugnomefull\clin\RandomForest-hits.intersection.txt
# polycystic_kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       TTN         0.991832      100.000000         0.0
# 1      RAF1         0.984530       99.994961         0.0
# 2     CALM3         0.965070       99.989922         0.0
# 3      PKD1         0.944331       99.984884         1.0
# 4      DGKD         0.928700       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 3       PKD1         0.944331       99.984884         1.0
# 26      PKD2         0.862023       99.868991         1.0
# 40     TRPM4         0.843193       99.798448         1.0
# 48      ARL6         0.835540       99.758138         1.0
# 53      ARF4         0.831360       99.732944         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     TRPM4         0.843193          3
# 1     NPHP3         0.828151          6
# 2     IFT88         0.699756         15
# 3    TMEM67         0.695601         16
# 4     SEC63         0.666984         23
#
#    Gene_Name  mantis_ml_proba  full_rank
# ...
#
#      Gene_Name  mantis_ml_proba  full_rank
# 14       NEK1         0.439932         36
# 15       NEK8         0.419253         39
# 16       AQP1         0.410949         40
# 17      GLIS3         0.302978         52
# 18  KIAA0319L         0.286562         58
# (19, 3)
# PRKD3
# 7
# 0 7
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# polycystic_kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       TTN         0.991832      100.000000         0.0
# 1      RAF1         0.984530       99.994961         0.0
# 2     CALM3         0.965070       99.989922         0.0
# 3      PKD1         0.944331       99.984884         1.0
# 4      DGKD         0.928700       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 3       PKD1         0.944331       99.984884         1.0
# 26      PKD2         0.862023       99.868991         1.0
# 40     TRPM4         0.843193       99.798448         1.0
# 48      ARL6         0.835540       99.758138         1.0
# 53      ARF4         0.831360       99.732944         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     PRKD3         0.779686          7
# 1      EGFR         0.738921          9
# 2     TRPC1         0.725410         11
# 3     KIF3A         0.711984         12
# 4    TMEM67         0.695601         16
#
#     Gene_Name  mantis_ml_proba  full_rank
# 9      BICC1         0.563643         32
# 10      NEK8         0.419253         39
# 11      AQP1         0.410949         40
# 12    PKD2L1         0.342188         47
# 13     TTLL4         0.300569         54
# (14, 3)
# PRKD3
# 7
# 0 7
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# polycystic_kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       TTN         0.991832      100.000000         0.0
# 1      RAF1         0.984530       99.994961         0.0
# 2     CALM3         0.965070       99.989922         0.0
# 3      PKD1         0.944331       99.984884         1.0
# 4      DGKD         0.928700       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 3       PKD1         0.944331       99.984884         1.0
# 26      PKD2         0.862023       99.868991         1.0
# 40     TRPM4         0.843193       99.798448         1.0
# 48      ARL6         0.835540       99.758138         1.0
# 53      ARF4         0.831360       99.732944         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0     TRPM4         0.843193          3
# 1      ARL6         0.835540          4
# 2      EGFR         0.738921          9
# 3     TRPC4         0.683130         19
# 4     SEC63         0.666984         23
#
#     Gene_Name  mantis_ml_proba  full_rank
# 8      BICC1         0.563643         32
# 9       AQP1         0.410949         40
# 10      BRD4         0.378546         44
# 11    PKD1L1         0.344845         46
# 12    PKD2L1         0.342188         47
# (13, 3)
# TRPM4
# 3
# 0 3
# cur_pval:  1.0
# ARL6
# 4
# 1 4
# cur_pval:  0.5812115891132569
# EGFR
# 9
# 2 9
# cur_pval:  0.5497821574307212
# Max: -0.0
# Avg: 1.6515836448276193
# [-0.0, 2.356657346394007, 2.5980935880888505]
# polycystic_kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       TTN         0.991832      100.000000         0.0
# 1      RAF1         0.984530       99.994961         0.0
# 2     CALM3         0.965070       99.989922         0.0
# 3      PKD1         0.944331       99.984884         1.0
# 4      DGKD         0.928700       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 3       PKD1         0.944331       99.984884         1.0
# 26      PKD2         0.862023       99.868991         1.0
# 40     TRPM4         0.843193       99.798448         1.0
# 48      ARL6         0.835540       99.758138         1.0
# 53      ARF4         0.831360       99.732944         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD1         0.944331          1
# 1      PKD2         0.862023          2
# 2     TRPM4         0.843193          3
# 3     NPHP3         0.828151          6
# 4       SRC         0.747457          8
#
#     Gene_Name  mantis_ml_proba  full_rank
# 13     BICC1         0.563643         32
# 14     PKHD1         0.471643         34
# 15     PRKD2         0.439726         37
# 16    SLC4A2         0.394695         43
# 17      BRD4         0.378546         44
# (18, 3)
# PKD1
# 1
# 0 1
# cur_pval:  1.0
# PKD2
# 2
# 1 2
# cur_pval:  0.4622475856014042
# TRPM4
# 3
# 2 3
# cur_pval:  0.1689280868385345
# NPHP3
# 6
# 3 6
# cur_pval:  0.18445360609539715
# Max: -0.0
# Avg: 4.6038408370436095
# [-0.0, 3.3512534855759553, 7.722981364272966, 7.341128498325516]
# polycystic_kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       TTN         0.991832      100.000000         0.0
# 1      RAF1         0.984530       99.994961         0.0
# 2     CALM3         0.965070       99.989922         0.0
# 3      PKD1         0.944331       99.984884         1.0
# 4      DGKD         0.928700       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 3       PKD1         0.944331       99.984884         1.0
# 26      PKD2         0.862023       99.868991         1.0
# 40     TRPM4         0.843193       99.798448         1.0
# 48      ARL6         0.835540       99.758138         1.0
# 53      ARF4         0.831360       99.732944         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD2         0.862023          2
# 1     TRPM4         0.843193          3
# 2     IFT88         0.699756         15
# 3     GANAB         0.674152         21
# 4      GNB2         0.670622         22
#
#     Gene_Name  mantis_ml_proba  full_rank
# 10    PKD1L1         0.344845         46
# 11    PKD2L1         0.342188         47
# 12     PI4KB         0.318849         50
# 13     VTI1B         0.261635         61
# 14      ABT1         0.260817         62
# (15, 3)
# PKD2
# 2
# 0 2
# cur_pval:  1.0
# TRPM4
# 3
# 1 3
# cur_pval:  0.5325644504748983
# IFT88
# 15
# 2 15
# cur_pval:  0.9046305081275611
# Max: -0.0
# Avg: 1.0571886559899402
# [-0.0, 2.736278267777801, 0.4352877001920198]
# polycystic_kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       TTN         0.991832      100.000000         0.0
# 1      RAF1         0.984530       99.994961         0.0
# 2     CALM3         0.965070       99.989922         0.0
# 3      PKD1         0.944331       99.984884         1.0
# 4      DGKD         0.928700       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 3       PKD1         0.944331       99.984884         1.0
# 26      PKD2         0.862023       99.868991         1.0
# 40     TRPM4         0.843193       99.798448         1.0
# 48      ARL6         0.835540       99.758138         1.0
# 53      ARF4         0.831360       99.732944         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD2         0.862023          2
# 1     TRPM4         0.843193          3
# 2    TMEM67         0.695601         16
# 3    ARL13B         0.684336         18
# 4     PPARG         0.639142         25
#
#     Gene_Name  mantis_ml_proba  full_rank
# 9       ALG8         0.426699         38
# 10      NEK8         0.419253         39
# 11    PKD1L1         0.344845         46
# 12    PKD2L1         0.342188         47
# 13      SSH1         0.298030         55
# (14, 3)
# PKD2
# 2
# 0 2
# cur_pval:  1.0
# TRPM4
# 3
# 1 3
# cur_pval:  0.5050682416793044
# TMEM67
# 16
# 2 16
# cur_pval:  0.9031991478293057
# Max: -0.0
# Avg: 1.1362213986284966
# [-0.0, 2.966499387477049, 0.4421648084084407]
# polycystic_kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       TTN         0.991832      100.000000         0.0
# 1      RAF1         0.984530       99.994961         0.0
# 2     CALM3         0.965070       99.989922         0.0
# 3      PKD1         0.944331       99.984884         1.0
# 4      DGKD         0.928700       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 3       PKD1         0.944331       99.984884         1.0
# 26      PKD2         0.862023       99.868991         1.0
# 40     TRPM4         0.843193       99.798448         1.0
# 48      ARL6         0.835540       99.758138         1.0
# 53      ARF4         0.831360       99.732944         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD1         0.944331          1
# 1      PKD2         0.862023          2
# 2     NPHP3         0.828151          6
# 3      EGFR         0.738921          9
# 4     KIF3A         0.711984         12
#
#     Gene_Name  mantis_ml_proba  full_rank
# 21      BRD4         0.378546         44
# 22    PKD1L1         0.344845         46
# 23       PGP         0.336652         48
# 24     GLIS3         0.302978         52
# 25      FJX1         0.292601         56
# (26, 3)
# PKD1
# 1
# 0 1
# cur_pval:  1.0
# PKD2
# 2
# 1 2
# cur_pval:  0.6220368744512743
# NPHP3
# 6
# 2 6
# cur_pval:  0.75000166280895
# Max: -0.0
# Avg: 1.1037388107999522
# [-0.0, 2.0618386949562026, 1.249377737443654]
# polycystic_kidney_drugnomefull/clin\SVC.mantis-ml_predictions.csv
# (19846, 4)
# full_ranked_df:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0       TTN         0.991832      100.000000         0.0
# 1      RAF1         0.984530       99.994961         0.0
# 2     CALM3         0.965070       99.989922         0.0
# 3      PKD1         0.944331       99.984884         1.0
# 4      DGKD         0.928700       99.979845         0.0
#
#  external_top ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 3       PKD1         0.944331       99.984884         1.0
# 26      PKD2         0.862023       99.868991         1.0
# 40     TRPM4         0.843193       99.798448         1.0
# 48      ARL6         0.835540       99.758138         1.0
# 53      ARF4         0.831360       99.732944         1.0
# (68, 4)
# full ranking with rank    Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
#
#  Population Size: 68
#
#  Full ranking:
#     Gene_Name  mantis_ml_proba  full_rank
# 3       PKD1         0.944331          1
# 26      PKD2         0.862023          2
# 40     TRPM4         0.843193          3
# 48      ARL6         0.835540          4
# 53      ARF4         0.831360          5
# full_rank_cutoff: 6
# full columns Index(['Gene_Name', 'mantis_ml_proba', 'full_rank'], dtype='object')
#
#    Gene_Name  mantis_ml_proba  full_rank
# 0      PKD1         0.944331          1
# 1      PKD2         0.862023          2
# 2     NPHP3         0.828151          6
# 3       SRC         0.747457          8
# 4      EGFR         0.738921          9
#
#     Gene_Name  mantis_ml_proba  full_rank
# 25    PKD1L1         0.344845         46
# 26       PGP         0.336652         48
# 27     GLIS3         0.302978         52
# 28      FJX1         0.292601         56
# 29      PIFO         0.248547         64
# (30, 3)
# PKD1
# 1
# 0 1
# cur_pval:  1.0
# PKD2
# 2
# 1 2
# cur_pval:  0.6913959613696246
# NPHP3
# 6
# 2 6
# cur_pval:  0.8372005792714743
# Max: -0.0
# Avg: 0.7914788048530901
# [-0.0, 1.6027316161746095, 0.7717047983846608]
# external_top_dataset:  SVC_vs_Polycystic_kidney_dysplasia
# external_top_dataset:  SVC_vs_Ectopic_kidney
# external_top_dataset:  SVC_vs_Chronic_kidney_disease
# external_top_dataset:  SVC_vs_Stage_5_chronic_kidney_disease
# external_top_dataset:  SVC_vs_Renal_insufficiency
# external_top_dataset:  SVC_vs_Multiple_renal_cysts
# external_top_dataset:  SVC_vs_Abnormality_of_renal_excretion
# external_top_dataset:  SVC_vs_Abnormal_renal_insterstitial_morphology
# external_top_dataset:  SVC_vs_Abnormality_of_the_kidney
# external_top_dataset:  SVC_vs_Horseshoe_kidney
# polycystic_kidney_drugnomefull\clin\SVC-hits.intersection.txt
# []

# %%
# f = read_full_ranking('Polycystic kidney disease')
s = pd.read_csv('synonyms.csv', index_col=0)
s.disease.unique()
# Out:
# array(['Polycystic kidney disease', 'Epilepsy', 'Hypertension',
#        'Kidney disease', 'Coronary artery disease',
#        'Chronic obstructive pulmonary disease'], dtype=object)

# %%
s.synonym.unique()
# Out:
# array(['Polycystic_kidney_dysplasia', 'Ectopic_kidney',
#        'Chronic_kidney_disease', 'Stage_5_chronic_kidney_disease',
#        'Renal_insufficiency', 'Multiple_renal_cysts',
#        'Abnormality_of_renal_excretion',
#        'Abnormal_renal_insterstitial_morphology',
#        'Abnormality_of_the_kidney', 'Horseshoe_kidney', 'Seizure',
#        'Myoclonic_seizure', 'Psychogenic_non-epileptic_seizure',
#        'Generalized_myoclonic_seizure', 'Dialeptic_seizure',
#        'Epileptic_encephalopathy', 'Atonic_seizure',
#        'Focal_motor_seizure', 'Focal-onset_seizure',
#        'Symptomatic_seizures', 'Hypertension',
#        'Pulmonary_arterial_hypertension', 'Portal_hypertension',
#        'Elevated_pulmonary_artery_pressure', 'Diabetes_mellitus',
#        'Abnormal_systemic_blood_pressure',
#        'Abnormality_of_intracranial_pressure',
#        'Type_II_diabetes_mellitus', 'Insulin-resistant_diabetes_mellitus',
#        'Hyperlipidemia', 'Renal_tubular_dysfunction',
#        'Abnormality_of_renal_glomerulus_morphology',
#        'Coronary_artery_atherosclerosis', 'Pulmonary_artery_stenosis',
#        'Abnormal_coronary_artery_morphology', 'Arterial_stenosis',
#        'Abnormal_carotid_artery_morphology',
#        'Dilatation_of_the_cerebral_artery',
#        'Abnormal_pulmonary_artery_morphology', 'Coarctation_of_aorta',
#        'Abnormality_of_the_pulmonary_artery', 'Pulmonary_obstruction',
#        'Pulmonary_fibrosis', 'Abnormality_of_pulmonary_circulation',
#        'Interstitial_pulmonary_abnormality', 'Chronic_bronchitis',
#        'Abnormal_pulmonary_valve_physiology',
#        'Abnormality_of_the_pulmonary_vasculature'], dtype=object)
