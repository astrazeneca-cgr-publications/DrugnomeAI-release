# %%
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt

import os
import pandas as pd
import numpy as np
from scipy.stats import hypergeom
import random
import sys
import glob


def calc_phred_score(pval):

    if pval == 0:
        return 500
    else:
        return -10 * np.log10(pval)



def read_full_ranking(disease):

    synonyms = pd.read_csv('synonyms.csv', index_col=0)
    disease_synonyms = synonyms.synonym[synonyms.disease==disease].tolist()
    full_ranked_df = pd.read_csv('predictions_synonyms.csv', index_col=0)
    print(full_ranked_df.head())
    full_ranked_df = full_ranked_df.reset_index()
    full_ranked_df = full_ranked_df.rename(columns = {'index':'Gene_Name'})
    full_ranked_dfs = []
    for synonym in disease_synonyms:
        full_ranked_df.sort_values(synonym, ascending=False, inplace=True)
        r = list(range(1, full_ranked_df.shape[0]+1))
        full_ranked_df['full_rank'] = r
        cols = ['Gene_Name'] + [synonym] + ['full_rank']
        synonym_ranked_df = full_ranked_df[cols]
        print('full ranking with rank', synonym_ranked_df.head())
        full_ranked_dfs.append(synonym_ranked_df)
    return full_ranked_dfs


def read_external_ranking(external_ranking_file, top_genes_ratio = 0.1):
    
    external_top_ranking = pd.read_csv(external_ranking_file)
    
    # external_top top predictions
    print(external_top_ranking.shape)
    print("external_top_ranking: ", external_top_ranking.head())
    
    cutoff = int(external_top_ranking.shape[0] * top_genes_ratio)
    external_top_ranking = external_top_ranking.loc[0:cutoff, :]
    external_top_ranking = external_top_ranking['Gene_Name']
    print("\n external_top ranking:", external_top_ranking.head())
    print(external_top_ranking.shape)

    external_top_genes = external_top_ranking.tolist()
    
    return external_top_genes

# %%
def calc_hypergeom_pvals(external_top_ranking, full_ranked_df, top_full_ranking=0.1):


    M = full_ranked_df.shape[0]
    print('\n Population Size:', M)
    print('\n Full ranking:\n', full_ranked_df.head())

    full_rank_cutoff = int(full_ranked_df.shape[0] * top_full_ranking) # 1050 genes (21015 in total)
    print('full_rank_cutoff:', full_rank_cutoff)
    print('full columns', full_ranked_df.columns)
    
    external_top_genes = read_external_ranking(external_top_ranking, top_genes_ratio = 0.1)

    full_ranked_df = full_ranked_df.loc[full_ranked_df.Gene_Name.isin(external_top_genes)]
    full_ranked_df.reset_index(drop=True, inplace=True)
    print('\n', full_ranked_df.head())
    print('\n', full_ranked_df.tail())
    print(full_ranked_df.shape)
    
    
    n = full_ranked_df.shape[0]
    #print('Total number of Successes:', n)



    # ************* Hypergeometric Test *************
    hypergeom_pvals = []
    hypergeom_ordered_genes = []

    for x in range(full_ranked_df.shape[0]):

        print(full_ranked_df.iloc[x, 0])

        full_rank = full_ranked_df.loc[x, 'full_rank']
        print(full_rank)

        N = full_ranked_df.iloc[x, full_ranked_df.shape[1]-1]
        print(x, N)


        cur_pval = hypergeom.sf(x - 1, M, n, N)
        print('cur_pval: ', cur_pval)

        hypergeom_pvals = hypergeom_pvals + [cur_pval]

        cur_gene = full_ranked_df.loc[x, 'Gene_Name']
        hypergeom_ordered_genes = hypergeom_ordered_genes + [cur_gene]


        if full_rank >= full_rank_cutoff:
            break
    # ***********************************************

    
    min_pval = min(hypergeom_pvals)
    hypergeom_pvals = [calc_phred_score(pval) for pval in hypergeom_pvals]
    print('Max:', min(hypergeom_pvals))
    print('Avg:', np.mean(hypergeom_pvals))

    return hypergeom_pvals, hypergeom_ordered_genes




def plot_hypergeom_stepwise(hypergeom_pvals, ax, label, color='#33a02c', signif_thres = 0.05, plot_pval_thres=True):

    if plot_pval_thres:
        signif_thres = calc_phred_score(signif_thres)
        ax.axhline(y=signif_thres, linestyle='--', color='red', label='p-val: 0.05')


    linewidth = 1
    ax.plot(hypergeom_pvals, color=color,
                label=label,
                linewidth=linewidth)

    ax.set_xlim(left=-0.5)

    y_label = 'Phred score from hypergeometric test\n(significance increasing in positive direction)'
    ax.set_ylabel(y_label, fontsize=14)

    ax.legend(bbox_to_anchor=(1.32, 1), fontsize=12, loc='upper right', framealpha =0.6)
    #ax.set_xlim(0, max_x_lim * 1.5)
    #ax.set_ylim(0, 500)




def run_hypergeom_test(disease, folder='kidney_mantisfull'):

    max_x_lim = 50

    # Provide multiple full ranking files
    full_ranking_files = read_full_ranking(disease)
    external_labels_folders = {'chem': glob.glob(folder + "/chem"),
                                 'clin': glob.glob(folder + "/clin"), 
                                  'bio': glob.glob(folder + "/bio")}
        
    print(full_ranking_files)
    print(external_labels_folders)

    for level in external_labels_folders.keys():
        if glob.glob(folder + '/' + level + '/*.csv'):
            external_top_files = glob.glob(folder + '/' + level + '/*.csv')

            for full_ranking_file in full_ranking_files:

                hypergeom_results = {}
                hypergeom_ordered_genes = {}


                for external_file in external_top_files:
                    print("external file: ", external_file)
                    external_top_ranking = external_file

                    import ntpath
                    def rename_file(file_path):
                        _, file = ntpath.split(file_path)
                        file = file.split('/')[-1]
                        file = file.replace('.mantis-ml_predictions.csv', '')
                        if 'All' not in file:
                            file = file.replace('Classifier', '')
                        return file

    #                 full_ranking_file = rename_file(full_ranking_file)
                    external_file = rename_file(external_file)
                    name = full_ranking_file.columns[1] + "_vs_" + external_file
                    print(name)

                    hypergeom_results[name], hypergeom_ordered_genes[name] = calc_hypergeom_pvals(external_top_ranking,\
                                                                                                  full_ranking_file)
                    print(hypergeom_results[name])


            # random gene ranking
            #random_external_top_ranking = full_ranked_df.sample(frac=1)
            #random_external_top_ranking.drop('full_rank', axis=1, inplace=True)
            #random_hypergeom_pvals = calc_hypergeom_pvals(random_external_top_ranking, full_ranked_df)


            # ------------------------- Start plotting ----------------------------
                fig, ax = plt.subplots(figsize=(18, 13))

                colors = ['#2171b5', '#9ecae1', '#238b45', '#a1d99b', '#cb181d', '#fc9272',
                          '#6a51a3', '#bcbddc', '#fe9929', '#fff7bc']
                cnt = 0

                for external_top_dataset, hypergeom_pvals in hypergeom_results.items():
                    print("external_top_dataset: ", external_top_dataset)

                    plot_hypergeom_stepwise(hypergeom_pvals, ax, label=external_top_dataset, color=colors[cnt], plot_pval_thres=False)
                    cnt += 1

                #plot_hypergeom_stepwise(random_hypergeom_pvals, ax, label='random', color='black')

                signif_thres = 0.05
                signif_thres = calc_phred_score(signif_thres)
                ax.axhline(y=signif_thres, linestyle='--', color='red', label='p-val: 0.05')

                fig.savefig(os.path.join(folder, level, full_ranking_file.columns[1] + ".pdf") , bbox_inches='tight')
                plt.close()


        #         print(hypergeom_ordered_genes)
                intersection_genes_fh = os.path.join(folder, level, full_ranking_file.columns[1] + '-hits.intersection.txt')
                print(intersection_genes_fh)
                out_fh =  open(intersection_genes_fh, 'w')
                for clf, genes in hypergeom_ordered_genes.items():
                    out_fh.write(clf + '\t' + ','.join(genes) + '\n')

                out_fh.close()
        else:
            pass

# %%
run_hypergeom_test(disease='Chronic obstructive pulmonary disease', folder='pulmonary_mantisfull')
# run_hypergeom_test(label='pharos', folder='all-pharos')
# Out:
#         Polycystic_kidney_dysplasia  Ectopic_kidney  Chronic_kidney_disease  \
# PDGFRA                     0.684014        0.734569                0.755655
# TBX5                       0.463923        0.715760                0.248062
# SRF                        0.388756        0.577907                0.170167
# LAMB2                      0.670324        0.605319                0.746830
# TBX3                       0.592567        0.621093                0.520620
#
#         Stage_5_chronic_kidney_disease  Renal_insufficiency  \
# PDGFRA                        0.659536             0.680119
# TBX5                          0.243948             0.573427
# SRF                           0.182204             0.466093
# LAMB2                         0.750944             0.738354
# TBX3                          0.375665             0.688846
#
#         Multiple_renal_cysts  Abnormality_of_renal_excretion  \
# PDGFRA              0.808831                        0.519982
# TBX5                0.458873                        0.461045
# SRF                 0.393737                        0.313876
# LAMB2               0.549268                        0.673198
# TBX3                0.661306                        0.492334
#
#         Abnormal_renal_insterstitial_morphology  Abnormality_of_the_kidney  \
# PDGFRA                                 0.609902                   0.787865
# TBX5                                   0.574112                   0.625357
# SRF                                    0.401117                   0.638727
# LAMB2                                  0.575543                   0.854376
# TBX3                                   0.501898                   0.630095
#
#         Horseshoe_kidney  ...  Pulmonary_obstruction  Pulmonary_fibrosis  \
# PDGFRA          0.728376  ...               0.556014            0.660960
# TBX5            0.629685  ...               0.557775            0.592752
# SRF             0.585833  ...               0.340813            0.343465
# LAMB2           0.478765  ...               0.453136            0.502598
# TBX3            0.599533  ...               0.383432            0.608886
#
#         Abnormality_of_pulmonary_circulation  \
# PDGFRA                              0.792831
# TBX5                                0.691443
# SRF                                 0.695179
# LAMB2                               0.617321
# TBX3                                0.689933
#
#         Interstitial_pulmonary_abnormality  \
# PDGFRA                            0.667245
# TBX5                              0.545838
# SRF                               0.470424
# LAMB2                             0.613958
# TBX3                              0.618614
#
#         Abnormality_of_the_pulmonary_artery.1  Chronic_kidney_disease.2  \
# PDGFRA                               0.894101                  0.755655
# TBX5                                 0.759015                  0.248062
# SRF                                  0.777431                  0.170167
# LAMB2                                0.552269                  0.746830
# TBX3                                 0.741744                  0.520620
#
#         Chronic_bronchitis  Pulmonary_arterial_hypertension.1  \
# PDGFRA            0.327301                           0.786513
# TBX5              0.284806                           0.683400
# SRF               0.097210                           0.698436
# LAMB2             0.491783                           0.718077
# TBX3              0.272717                           0.652799
#
#         Abnormal_pulmonary_valve_physiology  \
# PDGFRA                             0.819550
# TBX5                               0.761338
# SRF                                0.703443
# LAMB2                              0.605862
# TBX3                               0.734676
#
#         Abnormality_of_the_pulmonary_vasculature
# PDGFRA                                  0.872512
# TBX5                                    0.817737
# SRF                                     0.790724
# LAMB2                                   0.539407
# TBX3                                    0.736474
#
# [5 rows x 60 columns]
# full ranking with rank      Gene_Name  Pulmonary_obstruction  full_rank
# 1484  KIAA0586               0.841422          1
# 1029      CUBN               0.825475          2
# 3433       EVC               0.811457          3
# 3536     FANCM               0.806950          4
# 4175     ERCC6               0.802747          5
# full ranking with rank      Gene_Name  Pulmonary_fibrosis  full_rank
# 2679    ABCB11            0.769500          1
# 2543  HLA-DQB1            0.764304          2
# 141      LRRK2            0.761198          3
# 9772  HLA-DPB1            0.755079          4
# 54        LMO7            0.754445          5
# full ranking with rank      Gene_Name  Abnormality_of_pulmonary_circulation  full_rank
# 239       GJA1                              0.817133          1
# 1161     PROCR                              0.816779          2
# 1285       AHR                              0.810957          3
# 823      MMP14                              0.803246          4
# 332      ABCA1                              0.803051          5
# full ranking with rank      Gene_Name  Interstitial_pulmonary_abnormality  full_rank
# 5858   HLA-DRA                            0.790494          1
# 5601  HLA-DQA1                            0.785092          2
# 2543  HLA-DQB1                            0.778207          3
# 42        BCL6                            0.773840          4
# 645      STAT6                            0.767375          5
# full ranking with rank     Gene_Name  Abnormality_of_the_pulmonary_artery  full_rank
# 0      PDGFRA                             0.894101          1
# 86      FGFR1                             0.870666          2
# 144     UBE4B                             0.859300          3
# 702      TCF4                             0.845474          4
# 24       JAG1                             0.837677          5
# full ranking with rank      Gene_Name  Chronic_kidney_disease  full_rank
# 550     IFT172                0.870696          1
# 1891     WDR35                0.865688          2
# 57       ITGA3                0.863971          3
# 3089     NPHS1                0.859419          4
# 129      ITGAV                0.857047          5
# full ranking with rank      Gene_Name  Chronic_bronchitis  full_rank
# 3536     FANCM            0.875860          1
# 3831     MCM10            0.874792          2
# 974     PKD1L1            0.861508          3
# 2038        HR            0.858881          4
# 2519       HRC            0.853827          5
# full ranking with rank     Gene_Name  Pulmonary_arterial_hypertension  full_rank
# 86      FGFR1                         0.795911          1
# 166     FURIN                         0.795789          2
# 237     ADCY3                         0.787710          3
# 0      PDGFRA                         0.786513          4
# 401     ITGA5                         0.786277          5
# full ranking with rank      Gene_Name  Abnormal_pulmonary_valve_physiology  full_rank
# 24        JAG1                             0.873167          1
# 478      PTCH1                             0.862369          2
# 704     NOTCH2                             0.849811          3
# 1296     PBRM1                             0.849502          4
# 130       MED1                             0.848602          5
# full ranking with rank     Gene_Name  Abnormality_of_the_pulmonary_vasculature  full_rank
# 60      GATA2                                  0.896137          1
# 0      PDGFRA                                  0.872512          2
# 182    ACVR1B                                  0.866269          3
# 86      FGFR1                                  0.865871          4
# 61      SMAD7                                  0.864393          5
# [      Gene_Name  Pulmonary_obstruction  full_rank
# 1484   KIAA0586               0.841422          1
# 1029       CUBN               0.825475          2
# 3433        EVC               0.811457          3
# 3536      FANCM               0.806950          4
# 4175      ERCC6               0.802747          5
# ...         ...                    ...        ...
# 16358     PAQR8               0.061283      18622
# 17765      AMN1               0.060097      18623
# 3198     COPS7A               0.058497      18624
# 2581        SRM               0.056297      18625
# 17168  HIST1H3C               0.050357      18626
#
# [18626 rows x 3 columns],       Gene_Name  Pulmonary_fibrosis  full_rank
# 2679     ABCB11            0.769500          1
# 2543   HLA-DQB1            0.764304          2
# 141       LRRK2            0.761198          3
# 9772   HLA-DPB1            0.755079          4
# 54         LMO7            0.754445          5
# ...         ...                 ...        ...
# 18535  C1orf204            0.075147      18622
# 17907     LAMP5            0.074764      18623
# 17553     SLMO1            0.072361      18624
# 18275   TMEM196            0.069888      18625
# 18393  C1ORF220            0.061973      18626
#
# [18626 rows x 3 columns],       Gene_Name  Abnormality_of_pulmonary_circulation  full_rank
# 239        GJA1                              0.817133          1
# 1161      PROCR                              0.816779          2
# 1285        AHR                              0.810957          3
# 823       MMP14                              0.803246          4
# 332       ABCA1                              0.803051          5
# ...         ...                                   ...        ...
# 18473     OR6M1                              0.019533      18622
# 18472    OR10G3                              0.018267      18623
# 18291    OR10V1                              0.017867      18624
# 18271     OR8B8                              0.017716      18625
# 18554  METTL21C                              0.013850      18626
#
# [18626 rows x 3 columns],       Gene_Name  Interstitial_pulmonary_abnormality  full_rank
# 5858    HLA-DRA                            0.790494          1
# 5601   HLA-DQA1                            0.785092          2
# 2543   HLA-DQB1                            0.778207          3
# 42         BCL6                            0.773840          4
# 645       STAT6                            0.767375          5
# ...         ...                                 ...        ...
# 18610  PPAPDC1B                            0.053700      18622
# 18452   C5orf48                            0.052114      18623
# 17242    ZNF738                            0.048629      18624
# 18513     HDHD1                            0.040501      18625
# 18275   TMEM196                            0.039955      18626
#
# [18626 rows x 3 columns],       Gene_Name  Abnormality_of_the_pulmonary_artery  full_rank
# 0        PDGFRA                             0.894101          1
# 86        FGFR1                             0.870666          2
# 144       UBE4B                             0.859300          3
# 702        TCF4                             0.845474          4
# 24         JAG1                             0.837677          5
# ...         ...                                  ...        ...
# 18291    OR10V1                             0.019153      18622
# 18166     OR9G4                             0.018858      18623
# 18590    OR11A1                             0.017183      18624
# 16910     PANX3                             0.015683      18625
# 17317    OR10W1                             0.014426      18626
#
# [18626 rows x 3 columns],       Gene_Name  Chronic_kidney_disease  full_rank
# 550      IFT172                0.870696          1
# 1891      WDR35                0.865688          2
# 57        ITGA3                0.863971          3
# 3089      NPHS1                0.859419          4
# 129       ITGAV                0.857047          5
# ...         ...                     ...        ...
# 18146     PRR18                0.030976      18622
# 18291    OR10V1                0.030357      18623
# 18209  C16orf98                0.029160      18624
# 16470  COX6A1P2                0.028890      18625
# 13485    FAM78A                0.028551      18626
#
# [18626 rows x 3 columns],       Gene_Name  Chronic_bronchitis  full_rank
# 3536      FANCM            0.875860          1
# 3831      MCM10            0.874792          2
# 974      PKD1L1            0.861508          3
# 2038         HR            0.858881          4
# 2519        HRC            0.853827          5
# ...         ...                 ...        ...
# 2677     RAB11B            0.033976      18622
# 3331      RPLP0            0.033541      18623
# 2801       RHOQ            0.030522      18624
# 10120     VPS28            0.030079      18625
# 7860       CMAS            0.029000      18626
#
# [18626 rows x 3 columns],       Gene_Name  Pulmonary_arterial_hypertension  full_rank
# 86        FGFR1                         0.795911          1
# 166       FURIN                         0.795789          2
# 237       ADCY3                         0.787710          3
# 0        PDGFRA                         0.786513          4
# 401       ITGA5                         0.786277          5
# ...         ...                              ...        ...
# 18551    CLDN17                         0.031711      18622
# 17413     OR5P2                         0.031641      18623
# 18228    FABP12                         0.029166      18624
# 18251    OR51B4                         0.027905      18625
# 18199     IL36G                         0.025650      18626
#
# [18626 rows x 3 columns],       Gene_Name  Abnormal_pulmonary_valve_physiology  full_rank
# 24         JAG1                             0.873167          1
# 478       PTCH1                             0.862369          2
# 704      NOTCH2                             0.849811          3
# 1296      PBRM1                             0.849502          4
# 130        MED1                             0.848602          5
# ...         ...                                  ...        ...
# 18613    OR5B21                             0.019807      18622
# 18394    OR10Q1                             0.018857      18623
# 18542  C1orf210                             0.017905      18624
# 18557     ZBED2                             0.014983      18625
# 18580    OR10S1                             0.013912      18626
#
# [18626 rows x 3 columns],       Gene_Name  Abnormality_of_the_pulmonary_vasculature  full_rank
# 60        GATA2                                  0.896137          1
# 0        PDGFRA                                  0.872512          2
# 182      ACVR1B                                  0.866269          3
# 86        FGFR1                                  0.865871          4
# 61        SMAD7                                  0.864393          5
# ...         ...                                       ...        ...
# 16828  C16orf78                                  0.014787      18622
# 18271     OR8B8                                  0.014714      18623
# 18423     OR6X1                                  0.014529      18624
# 18387     OR4D1                                  0.014294      18625
# 18378    OR5M11                                  0.011567      18626
#
# [18626 rows x 3 columns]]
# {'chem': ['pulmonary_mantisfull/chem'], 'clin': [], 'bio': ['pulmonary_mantisfull/bio']}
# external file:  pulmonary_mantisfull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# Pulmonary_obstruction_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Pulmonary_obstruction  full_rank
# 1484  KIAA0586               0.841422          1
# 1029      CUBN               0.825475          2
# 3433       EVC               0.811457          3
# 3536     FANCM               0.806950          4
# 4175     ERCC6               0.802747          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Pulmonary_obstruction', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking: 5    MMP9
# Name: Gene_Name, dtype: object
# (1,)
#
#    Gene_Name  Pulmonary_obstruction  full_rank
# 0      MMP9               0.657381        329
#
#    Gene_Name  Pulmonary_obstruction  full_rank
# 0      MMP9               0.657381        329
# (1, 3)
# MMP9
# 329
# 0 329
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Pulmonary_obstruction_vs_GradientBoosting
# pulmonary_mantisfull\chem\Pulmonary_obstruction-hits.intersection.txt
# external file:  pulmonary_mantisfull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# Pulmonary_fibrosis_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Pulmonary_fibrosis  full_rank
# 2679    ABCB11            0.769500          1
# 2543  HLA-DQB1            0.764304          2
# 141      LRRK2            0.761198          3
# 9772  HLA-DPB1            0.755079          4
# 54        LMO7            0.754445          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Pulmonary_fibrosis', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking: 5    MMP9
# Name: Gene_Name, dtype: object
# (1,)
#
#    Gene_Name  Pulmonary_fibrosis  full_rank
# 0      MMP9             0.64187        197
#
#    Gene_Name  Pulmonary_fibrosis  full_rank
# 0      MMP9             0.64187        197
# (1, 3)
# MMP9
# 197
# 0 197
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Pulmonary_fibrosis_vs_GradientBoosting
# pulmonary_mantisfull\chem\Pulmonary_fibrosis-hits.intersection.txt
# external file:  pulmonary_mantisfull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# Abnormality_of_pulmonary_circulation_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Abnormality_of_pulmonary_circulation  full_rank
# 239       GJA1                              0.817133          1
# 1161     PROCR                              0.816779          2
# 1285       AHR                              0.810957          3
# 823      MMP14                              0.803246          4
# 332      ABCA1                              0.803051          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Abnormality_of_pulmonary_circulation', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking: 5    MMP9
# Name: Gene_Name, dtype: object
# (1,)
#
#    Gene_Name  Abnormality_of_pulmonary_circulation  full_rank
# 0      MMP9                              0.669229        411
#
#    Gene_Name  Abnormality_of_pulmonary_circulation  full_rank
# 0      MMP9                              0.669229        411
# (1, 3)
# MMP9
# 411
# 0 411
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Abnormality_of_pulmonary_circulation_vs_GradientBoosting
# pulmonary_mantisfull\chem\Abnormality_of_pulmonary_circulation-hits.intersection.txt
# external file:  pulmonary_mantisfull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# Interstitial_pulmonary_abnormality_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Interstitial_pulmonary_abnormality  full_rank
# 5858   HLA-DRA                            0.790494          1
# 5601  HLA-DQA1                            0.785092          2
# 2543  HLA-DQB1                            0.778207          3
# 42        BCL6                            0.773840          4
# 645      STAT6                            0.767375          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Interstitial_pulmonary_abnormality', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking: 5    MMP9
# Name: Gene_Name, dtype: object
# (1,)
#
#    Gene_Name  Interstitial_pulmonary_abnormality  full_rank
# 0      MMP9                            0.649658        280
#
#    Gene_Name  Interstitial_pulmonary_abnormality  full_rank
# 0      MMP9                            0.649658        280
# (1, 3)
# MMP9
# 280
# 0 280
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Interstitial_pulmonary_abnormality_vs_GradientBoosting
# pulmonary_mantisfull\chem\Interstitial_pulmonary_abnormality-hits.intersection.txt
# external file:  pulmonary_mantisfull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# Abnormality_of_the_pulmonary_artery_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#      Gene_Name  Abnormality_of_the_pulmonary_artery  full_rank
# 0      PDGFRA                             0.894101          1
# 86      FGFR1                             0.870666          2
# 144     UBE4B                             0.859300          3
# 702      TCF4                             0.845474          4
# 24       JAG1                             0.837677          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Abnormality_of_the_pulmonary_artery', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking: 5    MMP9
# Name: Gene_Name, dtype: object
# (1,)
#
#    Gene_Name  Abnormality_of_the_pulmonary_artery  full_rank
# 0      MMP9                             0.528164       2167
#
#    Gene_Name  Abnormality_of_the_pulmonary_artery  full_rank
# 0      MMP9                             0.528164       2167
# (1, 3)
# MMP9
# 2167
# 0 2167
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Abnormality_of_the_pulmonary_artery_vs_GradientBoosting
# pulmonary_mantisfull\chem\Abnormality_of_the_pulmonary_artery-hits.intersection.txt
# external file:  pulmonary_mantisfull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# Chronic_kidney_disease_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Chronic_kidney_disease  full_rank
# 550     IFT172                0.870696          1
# 1891     WDR35                0.865688          2
# 57       ITGA3                0.863971          3
# 3089     NPHS1                0.859419          4
# 129      ITGAV                0.857047          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Chronic_kidney_disease', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking: 5    MMP9
# Name: Gene_Name, dtype: object
# (1,)
#
#    Gene_Name  Chronic_kidney_disease  full_rank
# 0      MMP9                0.444003       3648
#
#    Gene_Name  Chronic_kidney_disease  full_rank
# 0      MMP9                0.444003       3648
# (1, 3)
# MMP9
# 3648
# 0 3648
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Chronic_kidney_disease_vs_GradientBoosting
# pulmonary_mantisfull\chem\Chronic_kidney_disease-hits.intersection.txt
# external file:  pulmonary_mantisfull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# Chronic_bronchitis_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Chronic_bronchitis  full_rank
# 3536     FANCM            0.875860          1
# 3831     MCM10            0.874792          2
# 974     PKD1L1            0.861508          3
# 2038        HR            0.858881          4
# 2519       HRC            0.853827          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Chronic_bronchitis', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking: 5    MMP9
# Name: Gene_Name, dtype: object
# (1,)
#
#    Gene_Name  Chronic_bronchitis  full_rank
# 0      MMP9            0.567928       1322
#
#    Gene_Name  Chronic_bronchitis  full_rank
# 0      MMP9            0.567928       1322
# (1, 3)
# MMP9
# 1322
# 0 1322
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Chronic_bronchitis_vs_GradientBoosting
# pulmonary_mantisfull\chem\Chronic_bronchitis-hits.intersection.txt
# external file:  pulmonary_mantisfull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# Pulmonary_arterial_hypertension_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#      Gene_Name  Pulmonary_arterial_hypertension  full_rank
# 86      FGFR1                         0.795911          1
# 166     FURIN                         0.795789          2
# 237     ADCY3                         0.787710          3
# 0      PDGFRA                         0.786513          4
# 401     ITGA5                         0.786277          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Pulmonary_arterial_hypertension', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking: 5    MMP9
# Name: Gene_Name, dtype: object
# (1,)
#
#    Gene_Name  Pulmonary_arterial_hypertension  full_rank
# 0      MMP9                         0.514037       2464
#
#    Gene_Name  Pulmonary_arterial_hypertension  full_rank
# 0      MMP9                         0.514037       2464
# (1, 3)
# MMP9
# 2464
# 0 2464
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Pulmonary_arterial_hypertension_vs_GradientBoosting
# pulmonary_mantisfull\chem\Pulmonary_arterial_hypertension-hits.intersection.txt
# external file:  pulmonary_mantisfull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# Abnormal_pulmonary_valve_physiology_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Abnormal_pulmonary_valve_physiology  full_rank
# 24        JAG1                             0.873167          1
# 478      PTCH1                             0.862369          2
# 704     NOTCH2                             0.849811          3
# 1296     PBRM1                             0.849502          4
# 130       MED1                             0.848602          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Abnormal_pulmonary_valve_physiology', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking: 5    MMP9
# Name: Gene_Name, dtype: object
# (1,)
#
#    Gene_Name  Abnormal_pulmonary_valve_physiology  full_rank
# 0      MMP9                              0.40738       5282
#
#    Gene_Name  Abnormal_pulmonary_valve_physiology  full_rank
# 0      MMP9                              0.40738       5282
# (1, 3)
# MMP9
# 5282
# 0 5282
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Abnormal_pulmonary_valve_physiology_vs_GradientBoosting
# pulmonary_mantisfull\chem\Abnormal_pulmonary_valve_physiology-hits.intersection.txt
# external file:  pulmonary_mantisfull/chem\GradientBoostingClassifier.mantis-ml_predictions.csv
# Abnormality_of_the_pulmonary_vasculature_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#      Gene_Name  Abnormality_of_the_pulmonary_vasculature  full_rank
# 60      GATA2                                  0.896137          1
# 0      PDGFRA                                  0.872512          2
# 182    ACVR1B                                  0.866269          3
# 86      FGFR1                                  0.865871          4
# 61      SMAD7                                  0.864393          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Abnormality_of_the_pulmonary_vasculature', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0    CYP3A5         0.999966      100.000000         0.0
# 1     HIF1A         0.999954       99.994961         0.0
# 2      PLAU         0.999932       99.989922         0.0
# 3     PTGS2         0.999930       99.984884         0.0
# 4     ABCB1         0.999927       99.979845         0.0
#
#  external_top ranking: 5    MMP9
# Name: Gene_Name, dtype: object
# (1,)
#
#    Gene_Name  Abnormality_of_the_pulmonary_vasculature  full_rank
# 0      MMP9                                  0.527656       2175
#
#    Gene_Name  Abnormality_of_the_pulmonary_vasculature  full_rank
# 0      MMP9                                  0.527656       2175
# (1, 3)
# MMP9
# 2175
# 0 2175
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Abnormality_of_the_pulmonary_vasculature_vs_GradientBoosting
# pulmonary_mantisfull\chem\Abnormality_of_the_pulmonary_vasculature-hits.intersection.txt
# external file:  pulmonary_mantisfull/bio\GradientBoostingClassifier.mantis-ml_predictions.csv
# Pulmonary_obstruction_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Pulmonary_obstruction  full_rank
# 1484  KIAA0586               0.841422          1
# 1029      CUBN               0.825475          2
# 3433       EVC               0.811457          3
# 3536     FANCM               0.806950          4
# 4175     ERCC6               0.802747          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Pulmonary_obstruction', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     SPARC         0.999772      100.000000         0.0
# 1     ITGAX         0.999693       99.994961         0.0
# 2      C1QA         0.999518       99.989922         1.0
# 3     TGFBI         0.999480       99.984884         0.0
# 4      CD53         0.999316       99.979845         0.0
#
#  external_top ranking: 2       C1QA
# 6     CD300A
# 12     LAIR1
# 15      GNLY
# 20        C3
# Name: Gene_Name, dtype: object
# (9,)
#
#    Gene_Name  Pulmonary_obstruction  full_rank
# 0    COL1A2               0.486870       2593
# 1    COL3A1               0.461069       3287
# 2   HLA-DMA               0.454029       3528
# 3     LAIR1               0.450551       3646
# 4        C3               0.443102       3903
#
#    Gene_Name  Pulmonary_obstruction  full_rank
# 4        C3               0.443102       3903
# 5      GNLY               0.425170       4553
# 6    CD300A               0.392453       5786
# 7    TYROBP               0.305911       9910
# 8      C1QA               0.194876      15705
# (9, 3)
# COL1A2
# 2593
# 0 2593
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Pulmonary_obstruction_vs_GradientBoosting
# pulmonary_mantisfull\bio\Pulmonary_obstruction-hits.intersection.txt
# external file:  pulmonary_mantisfull/bio\GradientBoostingClassifier.mantis-ml_predictions.csv
# Pulmonary_fibrosis_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Pulmonary_fibrosis  full_rank
# 2679    ABCB11            0.769500          1
# 2543  HLA-DQB1            0.764304          2
# 141      LRRK2            0.761198          3
# 9772  HLA-DPB1            0.755079          4
# 54        LMO7            0.754445          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Pulmonary_fibrosis', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     SPARC         0.999772      100.000000         0.0
# 1     ITGAX         0.999693       99.994961         0.0
# 2      C1QA         0.999518       99.989922         1.0
# 3     TGFBI         0.999480       99.984884         0.0
# 4      CD53         0.999316       99.979845         0.0
#
#  external_top ranking: 2       C1QA
# 6     CD300A
# 12     LAIR1
# 15      GNLY
# 20        C3
# Name: Gene_Name, dtype: object
# (9,)
#
#    Gene_Name  Pulmonary_fibrosis  full_rank
# 0   HLA-DMA            0.691827         48
# 1    COL1A2            0.606175        423
# 2        C3            0.585215        632
# 3    COL3A1            0.475474       2944
# 4     LAIR1            0.419296       5020
#
#    Gene_Name  Pulmonary_fibrosis  full_rank
# 4     LAIR1            0.419296       5020
# 5      C1QA            0.412485       5325
# 6    TYROBP            0.378019       6800
# 7      GNLY            0.336729       8759
# 8    CD300A            0.324301       9404
# (9, 3)
# HLA-DMA
# 48
# 0 48
# cur_pval:  1.0
# COL1A2
# 423
# 1 423
# cur_pval:  0.1868122600233833
# C3
# 632
# 2 632
# cur_pval:  0.03532589497434022
# COL3A1
# 2944
# 3 2944
# cur_pval:  0.15846672828131875
# Max: -0.0
# Avg: 7.451408401373634
# [-0.0, 7.285946255053687, 14.519068265779524, 8.000619084661324]
# external_top_dataset:  Pulmonary_fibrosis_vs_GradientBoosting
# pulmonary_mantisfull\bio\Pulmonary_fibrosis-hits.intersection.txt
# external file:  pulmonary_mantisfull/bio\GradientBoostingClassifier.mantis-ml_predictions.csv
# Abnormality_of_pulmonary_circulation_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Abnormality_of_pulmonary_circulation  full_rank
# 239       GJA1                              0.817133          1
# 1161     PROCR                              0.816779          2
# 1285       AHR                              0.810957          3
# 823      MMP14                              0.803246          4
# 332      ABCA1                              0.803051          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Abnormality_of_pulmonary_circulation', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     SPARC         0.999772      100.000000         0.0
# 1     ITGAX         0.999693       99.994961         0.0
# 2      C1QA         0.999518       99.989922         1.0
# 3     TGFBI         0.999480       99.984884         0.0
# 4      CD53         0.999316       99.979845         0.0
#
#  external_top ranking: 2       C1QA
# 6     CD300A
# 12     LAIR1
# 15      GNLY
# 20        C3
# Name: Gene_Name, dtype: object
# (9,)
#
#    Gene_Name  Abnormality_of_pulmonary_circulation  full_rank
# 0    COL1A2                              0.763902         45
# 1    COL3A1                              0.752824         61
# 2        C3                              0.752203         62
# 3      C1QA                              0.613161        944
# 4   HLA-DMA                              0.572151       1469
#
#    Gene_Name  Abnormality_of_pulmonary_circulation  full_rank
# 4   HLA-DMA                              0.572151       1469
# 5    CD300A                              0.374919       6102
# 6     LAIR1                              0.331013       7516
# 7    TYROBP                              0.325544       7716
# 8      GNLY                              0.267287       9954
# (9, 3)
# COL1A2
# 45
# 0 45
# cur_pval:  1.0
# COL3A1
# 61
# 1 61
# cur_pval:  0.02909791082362611
# C3
# 62
# 2 62
# cur_pval:  0.0003866128450183358
# C1QA
# 944
# 3 944
# cur_pval:  0.00866016132794367
# HLA-DMA
# 1469
# 4 1469
# cur_pval:  0.003515640255332219
# CD300A
# 6102
# 5 6102
# cur_pval:  0.13614411980978347
# Max: -0.0
# Avg: 17.21888768779736
# [-0.0, 15.36138191438216, 34.127237208508944, 20.624740175458047, 24.539955713449576, 8.660011114985437]
# external_top_dataset:  Abnormality_of_pulmonary_circulation_vs_GradientBoosting
# pulmonary_mantisfull\bio\Abnormality_of_pulmonary_circulation-hits.intersection.txt
# external file:  pulmonary_mantisfull/bio\GradientBoostingClassifier.mantis-ml_predictions.csv
# Interstitial_pulmonary_abnormality_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Interstitial_pulmonary_abnormality  full_rank
# 5858   HLA-DRA                            0.790494          1
# 5601  HLA-DQA1                            0.785092          2
# 2543  HLA-DQB1                            0.778207          3
# 42        BCL6                            0.773840          4
# 645      STAT6                            0.767375          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Interstitial_pulmonary_abnormality', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     SPARC         0.999772      100.000000         0.0
# 1     ITGAX         0.999693       99.994961         0.0
# 2      C1QA         0.999518       99.989922         1.0
# 3     TGFBI         0.999480       99.984884         0.0
# 4      CD53         0.999316       99.979845         0.0
#
#  external_top ranking: 2       C1QA
# 6     CD300A
# 12     LAIR1
# 15      GNLY
# 20        C3
# Name: Gene_Name, dtype: object
# (9,)
#
#    Gene_Name  Interstitial_pulmonary_abnormality  full_rank
# 0   HLA-DMA                            0.668901        168
# 1    COL1A2                            0.640176        343
# 2        C3                            0.615550        573
# 3    COL3A1                            0.524232       2121
# 4     LAIR1                            0.499071       2778
#
#    Gene_Name  Interstitial_pulmonary_abnormality  full_rank
# 4     LAIR1                            0.499071       2778
# 5      C1QA                            0.462860       3868
# 6    TYROBP                            0.431430       4927
# 7    CD300A                            0.419585       5333
# 8      GNLY                            0.380135       6766
# (9, 3)
# HLA-DMA
# 168
# 0 168
# cur_pval:  1.0
# COL1A2
# 343
# 1 343
# cur_pval:  0.1540688968588237
# C3
# 573
# 2 573
# cur_pval:  0.029467825845186986
# COL3A1
# 2121
# 3 2121
# cur_pval:  0.0732019876072027
# Max: -0.0
# Avg: 8.696035147849711
# [-0.0, 8.12285026991951, 15.30651905489401, 11.354771266585322]
# external_top_dataset:  Interstitial_pulmonary_abnormality_vs_GradientBoosting
# pulmonary_mantisfull\bio\Interstitial_pulmonary_abnormality-hits.intersection.txt
# external file:  pulmonary_mantisfull/bio\GradientBoostingClassifier.mantis-ml_predictions.csv
# Abnormality_of_the_pulmonary_artery_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#      Gene_Name  Abnormality_of_the_pulmonary_artery  full_rank
# 0      PDGFRA                             0.894101          1
# 86      FGFR1                             0.870666          2
# 144     UBE4B                             0.859300          3
# 702      TCF4                             0.845474          4
# 24       JAG1                             0.837677          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Abnormality_of_the_pulmonary_artery', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     SPARC         0.999772      100.000000         0.0
# 1     ITGAX         0.999693       99.994961         0.0
# 2      C1QA         0.999518       99.989922         1.0
# 3     TGFBI         0.999480       99.984884         0.0
# 4      CD53         0.999316       99.979845         0.0
#
#  external_top ranking: 2       C1QA
# 6     CD300A
# 12     LAIR1
# 15      GNLY
# 20        C3
# Name: Gene_Name, dtype: object
# (9,)
#
#    Gene_Name  Abnormality_of_the_pulmonary_artery  full_rank
# 0    COL1A2                             0.765577         94
# 1    COL3A1                             0.701381        332
# 2        C3                             0.615471        988
# 3    CD300A                             0.444113       3898
# 4     LAIR1                             0.405353       4917
#
#    Gene_Name  Abnormality_of_the_pulmonary_artery  full_rank
# 4     LAIR1                             0.405353       4917
# 5      C1QA                             0.398790       5125
# 6    TYROBP                             0.397345       5170
# 7   HLA-DMA                             0.296537       8454
# 8      GNLY                             0.220512      11534
# (9, 3)
# COL1A2
# 94
# 0 94
# cur_pval:  1.0
# COL3A1
# 332
# 1 332
# cur_pval:  0.14947624656717637
# C3
# 988
# 2 988
# cur_pval:  0.0789682927463179
# CD300A
# 3898
# 3 3898
# cur_pval:  0.28655913276893324
# Max: -0.0
# Avg: 6.17690203249237
# [-0.0, 8.254278160647711, 11.025472511077192, 5.427857458244572]
# external_top_dataset:  Abnormality_of_the_pulmonary_artery_vs_GradientBoosting
# pulmonary_mantisfull\bio\Abnormality_of_the_pulmonary_artery-hits.intersection.txt
# external file:  pulmonary_mantisfull/bio\GradientBoostingClassifier.mantis-ml_predictions.csv
# Chronic_kidney_disease_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Chronic_kidney_disease  full_rank
# 550     IFT172                0.870696          1
# 1891     WDR35                0.865688          2
# 57       ITGA3                0.863971          3
# 3089     NPHS1                0.859419          4
# 129      ITGAV                0.857047          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Chronic_kidney_disease', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     SPARC         0.999772      100.000000         0.0
# 1     ITGAX         0.999693       99.994961         0.0
# 2      C1QA         0.999518       99.989922         1.0
# 3     TGFBI         0.999480       99.984884         0.0
# 4      CD53         0.999316       99.979845         0.0
#
#  external_top ranking: 2       C1QA
# 6     CD300A
# 12     LAIR1
# 15      GNLY
# 20        C3
# Name: Gene_Name, dtype: object
# (9,)
#
#    Gene_Name  Chronic_kidney_disease  full_rank
# 0        C3                0.720498        100
# 1    COL1A2                0.583214        939
# 2    COL3A1                0.534986       1640
# 3      C1QA                0.488917       2531
# 4    CD300A                0.328954       7383
#
#    Gene_Name  Chronic_kidney_disease  full_rank
# 4    CD300A                0.328954       7383
# 5     LAIR1                0.291767       8844
# 6   HLA-DMA                0.281390       9273
# 7    TYROBP                0.265336       9994
# 8      GNLY                0.214614      12125
# (9, 3)
# C3
# 100
# 0 100
# cur_pval:  1.0
# COL1A2
# 939
# 1 939
# cur_pval:  0.37227905853741206
# COL3A1
# 1640
# 2 1640
# cur_pval:  0.18462827521566005
# C1QA
# 2531
# 3 2531
# cur_pval:  0.1120154606042194
# Max: -0.0
# Avg: 5.283888028666521
# [-0.0, 4.291313930521951, 7.337017874391182, 9.507220309752952]
# external_top_dataset:  Chronic_kidney_disease_vs_GradientBoosting
# pulmonary_mantisfull\bio\Chronic_kidney_disease-hits.intersection.txt
# external file:  pulmonary_mantisfull/bio\GradientBoostingClassifier.mantis-ml_predictions.csv
# Chronic_bronchitis_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Chronic_bronchitis  full_rank
# 3536     FANCM            0.875860          1
# 3831     MCM10            0.874792          2
# 974     PKD1L1            0.861508          3
# 2038        HR            0.858881          4
# 2519       HRC            0.853827          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Chronic_bronchitis', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     SPARC         0.999772      100.000000         0.0
# 1     ITGAX         0.999693       99.994961         0.0
# 2      C1QA         0.999518       99.989922         1.0
# 3     TGFBI         0.999480       99.984884         0.0
# 4      CD53         0.999316       99.979845         0.0
#
#  external_top ranking: 2       C1QA
# 6     CD300A
# 12     LAIR1
# 15      GNLY
# 20        C3
# Name: Gene_Name, dtype: object
# (9,)
#
#    Gene_Name  Chronic_bronchitis  full_rank
# 0     LAIR1            0.424644       3637
# 1        C3            0.366873       5231
# 2    COL1A2            0.305472       7456
# 3    COL3A1            0.302934       7561
# 4      GNLY            0.291239       8079
#
#    Gene_Name  Chronic_bronchitis  full_rank
# 4      GNLY            0.291239       8079
# 5    CD300A            0.269106       9078
# 6   HLA-DMA            0.225277      11087
# 7    TYROBP            0.135508      15589
# 8      C1QA            0.101656      17235
# (9, 3)
# LAIR1
# 3637
# 0 3637
# cur_pval:  1.0
# Max: -0.0
# Avg: 0.0
# [-0.0]
# external_top_dataset:  Chronic_bronchitis_vs_GradientBoosting
# pulmonary_mantisfull\bio\Chronic_bronchitis-hits.intersection.txt
# external file:  pulmonary_mantisfull/bio\GradientBoostingClassifier.mantis-ml_predictions.csv
# Pulmonary_arterial_hypertension_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#      Gene_Name  Pulmonary_arterial_hypertension  full_rank
# 86      FGFR1                         0.795911          1
# 166     FURIN                         0.795789          2
# 237     ADCY3                         0.787710          3
# 0      PDGFRA                         0.786513          4
# 401     ITGA5                         0.786277          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Pulmonary_arterial_hypertension', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     SPARC         0.999772      100.000000         0.0
# 1     ITGAX         0.999693       99.994961         0.0
# 2      C1QA         0.999518       99.989922         1.0
# 3     TGFBI         0.999480       99.984884         0.0
# 4      CD53         0.999316       99.979845         0.0
#
#  external_top ranking: 2       C1QA
# 6     CD300A
# 12     LAIR1
# 15      GNLY
# 20        C3
# Name: Gene_Name, dtype: object
# (9,)
#
#    Gene_Name  Pulmonary_arterial_hypertension  full_rank
# 0    COL3A1                         0.752076         62
# 1    COL1A2                         0.750553         66
# 2        C3                         0.667155        421
# 3   HLA-DMA                         0.646123        588
# 4      C1QA                         0.591839       1167
#
#    Gene_Name  Pulmonary_arterial_hypertension  full_rank
# 4      C1QA                         0.591839       1167
# 5    TYROBP                         0.537093       2068
# 6    CD300A                         0.389444       5848
# 7      GNLY                         0.359902       6889
# 8     LAIR1                         0.250520      10982
# (9, 3)
# COL3A1
# 62
# 0 62
# cur_pval:  1.0
# COL1A2
# 66
# 1 66
# cur_pval:  0.031449268325916775
# C3
# 421
# 2 421
# cur_pval:  0.016517191049381482
# HLA-DMA
# 588
# 3 588
# cur_pval:  0.002280478365106043
# C1QA
# 1167
# 4 1167
# cur_pval:  0.0014972015738717779
# TYROBP
# 2068
# 5 2068
# cur_pval:  0.0014392903759274515
# Max: -0.0
# Avg: 19.321664348418896
# [-0.0, 15.02389454056972, 17.820638078315053, 26.419740435544313, 28.24719725023105, 28.418515785853252]
# external_top_dataset:  Pulmonary_arterial_hypertension_vs_GradientBoosting
# pulmonary_mantisfull\bio\Pulmonary_arterial_hypertension-hits.intersection.txt
# external file:  pulmonary_mantisfull/bio\GradientBoostingClassifier.mantis-ml_predictions.csv
# Abnormal_pulmonary_valve_physiology_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#       Gene_Name  Abnormal_pulmonary_valve_physiology  full_rank
# 24        JAG1                             0.873167          1
# 478      PTCH1                             0.862369          2
# 704     NOTCH2                             0.849811          3
# 1296     PBRM1                             0.849502          4
# 130       MED1                             0.848602          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Abnormal_pulmonary_valve_physiology', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     SPARC         0.999772      100.000000         0.0
# 1     ITGAX         0.999693       99.994961         0.0
# 2      C1QA         0.999518       99.989922         1.0
# 3     TGFBI         0.999480       99.984884         0.0
# 4      CD53         0.999316       99.979845         0.0
#
#  external_top ranking: 2       C1QA
# 6     CD300A
# 12     LAIR1
# 15      GNLY
# 20        C3
# Name: Gene_Name, dtype: object
# (9,)
#
#    Gene_Name  Abnormal_pulmonary_valve_physiology  full_rank
# 0    COL1A2                             0.750519        107
# 1        C3                             0.730169        180
# 2    COL3A1                             0.711771        272
# 3    CD300A                             0.387260       5880
# 4     LAIR1                             0.369947       6418
#
#    Gene_Name  Abnormal_pulmonary_valve_physiology  full_rank
# 4     LAIR1                             0.369947       6418
# 5   HLA-DMA                             0.366777       6530
# 6    TYROBP                             0.281937       9428
# 7      C1QA                             0.267853       9916
# 8      GNLY                             0.099450      16761
# (9, 3)
# COL1A2
# 107
# 0 107
# cur_pval:  1.0
# C3
# 180
# 1 180
# cur_pval:  0.0837051246994518
# COL3A1
# 272
# 2 272
# cur_pval:  0.00714834100408057
# CD300A
# 5880
# 3 5880
# cur_pval:  0.5783882088868855
# Max: -0.0
# Avg: 8.652058149012671
# [-0.0, 10.772479522748185, 21.457947381112653, 2.377805692189849]
# external_top_dataset:  Abnormal_pulmonary_valve_physiology_vs_GradientBoosting
# pulmonary_mantisfull\bio\Abnormal_pulmonary_valve_physiology-hits.intersection.txt
# external file:  pulmonary_mantisfull/bio\GradientBoostingClassifier.mantis-ml_predictions.csv
# Abnormality_of_the_pulmonary_vasculature_vs_GradientBoosting
#
#  Population Size: 18626
#
#  Full ranking:
#      Gene_Name  Abnormality_of_the_pulmonary_vasculature  full_rank
# 60      GATA2                                  0.896137          1
# 0      PDGFRA                                  0.872512          2
# 182    ACVR1B                                  0.866269          3
# 86      FGFR1                                  0.865871          4
# 61      SMAD7                                  0.864393          5
# full_rank_cutoff: 1862
# full columns Index(['Gene_Name', 'Abnormality_of_the_pulmonary_vasculature', 'full_rank'], dtype='object')
# (19846, 4)
# external_top_ranking:    Gene_Name  mantis_ml_proba  mantis_ml_perc  known_gene
# 0     SPARC         0.999772      100.000000         0.0
# 1     ITGAX         0.999693       99.994961         0.0
# 2      C1QA         0.999518       99.989922         1.0
# 3     TGFBI         0.999480       99.984884         0.0
# 4      CD53         0.999316       99.979845         0.0
#
#  external_top ranking: 2       C1QA
# 6     CD300A
# 12     LAIR1
# 15      GNLY
# 20        C3
# Name: Gene_Name, dtype: object
# (9,)
#
#    Gene_Name  Abnormality_of_the_pulmonary_vasculature  full_rank
# 0    COL1A2                                  0.820813         19
# 1    COL3A1                                  0.729831        268
# 2        C3                                  0.686662        486
# 3    CD300A                                  0.444718       3557
# 4      C1QA                                  0.390395       4790
#
#    Gene_Name  Abnormality_of_the_pulmonary_vasculature  full_rank
# 4      C1QA                                  0.390395       4790
# 5     LAIR1                                  0.366253       5391
# 6    TYROBP                                  0.303994       7140
# 7   HLA-DMA                                  0.273929       8066
# 8      GNLY                                  0.152210      13202
# (9, 3)
# COL1A2
# 19
# 0 19
# cur_pval:  1.0
# COL3A1
# 268
# 1 268
# cur_pval:  0.12231304321765944
# C3
# 486
# 2 486
# cur_pval:  0.02166122752188367
# CD300A
# 3557
# 3 3557
# cur_pval:  0.23819442199095184
# Max: -0.0
# Avg: 7.999781442841445
# [-0.0, 9.125272282015365, 16.64316935943621, 6.230684129914206]
# external_top_dataset:  Abnormality_of_the_pulmonary_vasculature_vs_GradientBoosting
# pulmonary_mantisfull\bio\Abnormality_of_the_pulmonary_vasculature-hits.intersection.txt

# %%
# f = read_full_ranking('Polycystic kidney disease')
s = pd.read_csv('synonyms.csv', index_col=0)
s.disease.unique()
# Out:
# array(['Polycystic kidney disease', 'Epilepsy', 'Hypertension',
#        'Kidney disease', 'Coronary artery disease',
#        'Chronic obstructive pulmonary disease'], dtype=object)
